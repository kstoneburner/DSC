# %% [markdown]
# Color Palette Reference: https://www.datanovia.com/en/blog/top-r-color-palettes-to-know-for-great-data-visualization/

# %%
#//*** Load Libraries.
#//*** Install Pacman installer if not loaded
if (!require("pacman")) install.packages("pacman")

#//*** Load libraries with pacman.
#//*** Automatically installs libraries as needed.
p_load(ggplot2, ggthemes, dplyr, readr, scales, forcats, readxl, showtext, ggrepel, treemapify, RColorBrewer,viridis)

# %%
display.brewer.all()
viridis()
# Out:
# Error in viridis(): argument "n" is missing, with no default
# Traceback:
#
# 1. viridis()
# plot without title

# %%
font_add("Tahoma","Tahoma.ttf")
font_add("XKCD","./fonts/xkcd-Regular.otf")
font_add("Roboto Condensed", "./fonts/RobotoCondensed-Regular.ttf")
#font_add("Decima Mono Pro","DecimaMonoPro.otf")
showtext_auto()

# %%
ex_df <- read_delim("z_wk05_06_expenditures.txt", delim = "\t")
ex_df["category"][ex_df["category"] == "Miscellaneous"] <- "Misc"
ex_df["category"][ex_df["category"] == "Cash Contributions"] <- "Cash"
ex_df["category"][ex_df["category"] == "Tobacco Products"] <- "Tobacco"
ex_df["category"][ex_df["category"] == "Alcoholic Beverages"] <- "Alcohol"

ex_df <- subset (ex_df, select = -sex)
ex_df
# Out:
# Parsed with column specification:
# cols(
#   year = col_double(),
#   category = col_character(),
#   expenditure = col_double(),
#   sex = col_double()
# )
#     year category           expenditure
# 1   2008 Food                6443
# 2   2008 Alcohol              444
# 3   2008 Housing            17109
# 4   2008 Apparel             1801
# 5   2008 Transportation      8604
# 6   2008 Healthcare          2976
# 7   2008 Entertainment       2835
# 8   2008 Personal Care        616
# 9   2008 Reading              116
# 10  2008 Education           1046
# 11  2008 Tobacco              317
# 12  2008 Misc                 840
# 13  2008 Cash                1737
# 14  2008 Personal Insurance  5605
# 15  2007 Food                6113
# 16  2007 Alcohol              457
# 17  2007 Housing            16920
# 18  2007 Apparel             1881
# 19  2007 Transportation      8758
# 20  2007 Healthcare          2853
# 21  2007 Entertainment       2698
# 22  2007 Personal Care        588
# 23  2007 Reading              118
# 24  2007 Education            945
# 25  2007 Tobacco              323
# 26  2007 Misc                 808
# 27  2007 Cash                1821
# 28  2007 Personal Insurance  5336
# 29  2006 Food                6111
# 30  2006 Alcohol              497
# ... ...  ...                ...
# 321 1986 Cash                746
# 322 1986 Personal Insurance 2127
# 323 1985 Food               3477
# 324 1985 Alcohol             306
# 325 1985 Housing            7087
# 326 1985 Apparel            1420
# 327 1985 Transportation     4587
# 328 1985 Healthcare         1108
# 329 1985 Entertainment      1170
# 330 1985 Personal Care       303
# 331 1985 Reading             141
# 332 1985 Education           321
# 333 1985 Tobacco             219
# 334 1985 Misc                529
# 335 1985 Cash                805
# 336 1985 Personal Insurance 2016
# 337 1984 Food               3290
# 338 1984 Alcohol             275
# 339 1984 Housing            6674
# 340 1984 Apparel            1319
# 341 1984 Transportation     4304
# 342 1984 Healthcare         1049
# 343 1984 Entertainment      1055
# 344 1984 Personal Care       289
# 345 1984 Reading             132
# 346 1984 Education           303
# 347 1984 Tobacco             228
# 348 1984 Misc                451
# 349 1984 Cash                706
# 350 1984 Personal Insurance 1897

# %%
plot_df <- ex_df

p <- ggplot(plot_df, aes(area=expenditure, fill=category,subgroup=year, label=category)) +
    labs(
        title="U.S. Household Expenses: 1985 - 2008",
        subtitle="('R' Treemap)",
        x="",
        y="",
        size=1.5


    ) +
    geom_treemap() +
    geom_treemap_text(colour = "white",
                   place = "centre",
                   size = 15,
                   grow = TRUE)+
    geom_treemap_subgroup_text(place = "centre", grow = TRUE,
                             alpha = 0.25, colour = "black",
                             fontface = "italic") +
      geom_treemap_text(colour = "white", place = "centre",
                    size = 15, grow = TRUE)+
    
    scale_fill_viridis(discrete = TRUE, option = "D", alpha=.5)
p
jpeg("output_wk05_06_r_treemap_all_expenses.jpg")

print(p)
dev.off()
# Out:
# png
#   2
# plot without title

# %%
plot_df <- ex_df[ex_df$year == 2008,]

p <- ggplot(plot_df, aes(area=expenditure, fill=category, label=category)) +
    labs(
        title="U.S. Household Expenses: 2008",
        subtitle="('R' Treemap)",
        x="",
        y="",
        size=1.5


    ) +
    geom_treemap() +
    geom_treemap_text(colour = "grey",
                   place = "centre",
                   size = 15,
                   grow = TRUE)+
      geom_treemap_text(colour = "white", place = "centre",
                    size = 15, grow = TRUE)+
    
    scale_fill_viridis(discrete = TRUE, option = "D", alpha=.5)
p
jpeg("output_wk05_06_r_treemap_2008_expenses.jpg")

print(p)
dev.off()
# Out:
# png
#   2
# plot without title

# %%
emp_df <- read_csv("z_wk05_06_unemployement-rate-1948-2010.csv")
# Out:
# Parsed with column specification:
# cols(
#   `Series id` = col_character(),
#   Year = col_double(),
#   Period = col_character(),
#   Value = col_double()
# )

# %%
#//*** Get the average unemployment per year

#//*** Get List of years
years <- unique(emp_df$Year)

#//*** Generate list of averages for each year
avgs <- c()
for (year in years) {
    #avgs[[length(avgs)+1]] <- mean(emp_df[emp_df$Year == year, ]$Value)
    avgs <- append(avgs,mean(emp_df[emp_df$Year == year, ]$Value))
}

plot_df <- data.frame('years'=years)

plot_df$avgs=avgs



fill <- c("#b2d183","#40b8d0")
fill <- c("#c44240","#ca5553", "#d06866", "#d67b79", "#dc8e8c", "#e2a1a0", "#e7b3b3", "#edc6c6", "#f3d9d9", "#f9ecec", "#ffffff")
fill <- c("#d06866", "#e2a1a0", "#f3d9d9", "#f9ecec", "#ffffff")
fontsize <- 20
p <- ggplot(data=plot_df, aes(x=years, y=avgs))+
    geom_area( color='black', fill ='green', size=.3, alpha=.4)+
    labs(
        title="U.S. Average Annual Unemployment Rate: 1948-2009",
        subtitle="('R' Graph)",
        x="",
        y="Year",
        size=1.5


    ) 

p
jpeg("output_wk05_06_r_area_unemployment.jpg")
print(p)
dev.off()

#sum(plot_df["Annual Average Employment"])
# Out:
# png
#   2
# plot without title

# %%
ex_df
# Out:
#     year category           expenditure
# 1   2008 Food                6443
# 2   2008 Alcohol              444
# 3   2008 Housing            17109
# 4   2008 Apparel             1801
# 5   2008 Transportation      8604
# 6   2008 Healthcare          2976
# 7   2008 Entertainment       2835
# 8   2008 Personal Care        616
# 9   2008 Reading              116
# 10  2008 Education           1046
# 11  2008 Tobacco              317
# 12  2008 Misc                 840
# 13  2008 Cash                1737
# 14  2008 Personal Insurance  5605
# 15  2007 Food                6113
# 16  2007 Alcohol              457
# 17  2007 Housing            16920
# 18  2007 Apparel             1881
# 19  2007 Transportation      8758
# 20  2007 Healthcare          2853
# 21  2007 Entertainment       2698
# 22  2007 Personal Care        588
# 23  2007 Reading              118
# 24  2007 Education            945
# 25  2007 Tobacco              323
# 26  2007 Misc                 808
# 27  2007 Cash                1821
# 28  2007 Personal Insurance  5336
# 29  2006 Food                6111
# 30  2006 Alcohol              497
# ... ...  ...                ...
# 321 1986 Cash                746
# 322 1986 Personal Insurance 2127
# 323 1985 Food               3477
# 324 1985 Alcohol             306
# 325 1985 Housing            7087
# 326 1985 Apparel            1420
# 327 1985 Transportation     4587
# 328 1985 Healthcare         1108
# 329 1985 Entertainment      1170
# 330 1985 Personal Care       303
# 331 1985 Reading             141
# 332 1985 Education           321
# 333 1985 Tobacco             219
# 334 1985 Misc                529
# 335 1985 Cash                805
# 336 1985 Personal Insurance 2016
# 337 1984 Food               3290
# 338 1984 Alcohol             275
# 339 1984 Housing            6674
# 340 1984 Apparel            1319
# 341 1984 Transportation     4304
# 342 1984 Healthcare         1049
# 343 1984 Entertainment      1055
# 344 1984 Personal Care       289
# 345 1984 Reading             132
# 346 1984 Education           303
# 347 1984 Tobacco             228
# 348 1984 Misc                451
# 349 1984 Cash                706
# 350 1984 Personal Insurance 1897

# %%
plot_df <- ex_df




fill <- c("#b2d183","#40b8d0")
fill <- c("#c44240","#ca5553", "#d06866", "#d67b79", "#dc8e8c", "#e2a1a0", "#e7b3b3", "#edc6c6", "#f3d9d9", "#f9ecec", "#ffffff")
fill <- c("#d06866", "#e2a1a0", "#f3d9d9", "#f9ecec", "#ffffff")
fontsize <- 20
p <- ggplot(plot_df, aes(x=year, y=expenditure, fill=category))+
    geom_area( )+
    scale_fill_viridis(discrete = TRUE, option = "B", alpha=.9)+
    labs(
    title="U.S. Household Expenses: 1985 - 2008",
    subtitle="('R' Stacked Area)",
    x="",
    y="Year",
    size=1.5


    ) 

p
jpeg("output_wk05_06_r_stacked_area_expenses.jpg",height=1280,aspect_ratio = .5)
print(p)
dev.off()

#sum(plot_df["Annual Average Employment"])
# Out:
# Error in jpeg("output_wk05_06_r_stacked_area_expenses.jpg", height = 1280, : unused argument (aspect_ratio = 0.5)
# Traceback:
# plot without title
