# %% [markdown]
# # Stoneburner, Kurt
# - ## DSC 640 - Week XX

# %%
import os
import sys
# //*** Imports and Load Data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from shapely.geometry import Point
import geopandas as gpd

#//*** Use the whole window in the IPYNB editor
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#//*** Maximize columns and rows displayed by pandas
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# Heatmaps Reference: https://www.geeksforgeeks.org/display-the-pandas-dataframe-in-heatmap-style/
# GeoSpatial Refernce: https://www.datacamp.com/community/tutorials/geospatial-data-python

# %%
bb_df = pd.read_csv("./wk0910/z_wk09_10_ppg2008.csv")


fig,ax = plt.subplots()

# Define a nice color map for our heatmap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(
        data=bb_df.corr(),  # our correlation matrix
        linewidths=0.3,  # the width of lines separating the matrix squares
        square=True,   # enforce 1:1 ratios among correlation cells
        cmap=cmap,  # use the color map we defined above
        vmax=1,  # define the max of our correlation scale
        vmin=-1, # define the min of our correlation scale
        center=0,  # The value at which the color map is centered about (white)
        cbar_kws={"shrink": .75}  # shrink the scale a bit
    )
# adjust y-axis ticks for legibility
plt.yticks(rotation=0)  
# show the heatmap
plt.show()

# %%
# //*** CODE HERE


bb_df.sort_values("G",ascending=False).set_index("Name  ").style.background_gradient(cmap ='cividis')\
    .set_properties(**{'font-size': '10px'})
# Out:
# <style type="text/css">
# #T_326ad_row0_col0, #T_326ad_row1_col0, #T_326ad_row2_col0, #T_326ad_row3_col0, #T_326ad_row4_col0, #T_326ad_row4_col1, #T_326ad_row13_col8, #T_326ad_row14_col9, #T_326ad_row14_col10, #T_326ad_row17_col7, #T_326ad_row17_col12, #T_326ad_row17_col13, #T_326ad_row17_col14, #T_326ad_row17_col17, #T_326ad_row19_col2, #T_326ad_row19_col3, #T_326ad_row19_col4, #T_326ad_row21_col15, #T_326ad_row21_col16, #T_326ad_row24_col11, #T_326ad_row27_col5, #T_326ad_row40_col18, #T_326ad_row44_col19, #T_326ad_row45_col6 {
#   background-color: #fee838;
#   color: #000000;
#   font-size: 10px;
# }
# #T_326ad_row0_col1, #T_326ad_row12_col9, #T_326ad_row14_col8, #T_326ad_row20_col9, #T_326ad_row46_col1 {
#   background-color: #a89e73;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col2, #T_326ad_row8_col3, #T_326ad_row30_col5, #T_326ad_row40_col2, #T_326ad_row42_col4, #T_326ad_row45_col3, #T_326ad_row47_col7, #T_326ad_row48_col7 {
#   background-color: #47516c;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col3, #T_326ad_row6_col3, #T_326ad_row9_col5, #T_326ad_row24_col1, #T_326ad_row30_col1, #T_326ad_row30_col3, #T_326ad_row31_col3, #T_326ad_row37_col3, #T_326ad_row38_col10, #T_326ad_row40_col6 {
#   background-color: #60646f;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col4, #T_326ad_row3_col7, #T_326ad_row15_col4, #T_326ad_row15_col10, #T_326ad_row29_col10, #T_326ad_row37_col10 {
#   background-color: #707173;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col5, #T_326ad_row31_col2, #T_326ad_row48_col5 {
#   background-color: #3c4a6c;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col6, #T_326ad_row15_col5, #T_326ad_row37_col5, #T_326ad_row48_col6 {
#   background-color: #3a486c;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col7, #T_326ad_row14_col4, #T_326ad_row18_col4, #T_326ad_row25_col11, #T_326ad_row49_col15 {
#   background-color: #404c6c;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col8, #T_326ad_row8_col1, #T_326ad_row34_col0, #T_326ad_row46_col14 {
#   background-color: #bdae6c;
#   color: #000000;
#   font-size: 10px;
# }
# #T_326ad_row0_col9, #T_326ad_row16_col9, #T_326ad_row19_col16, #T_326ad_row29_col8, #T_326ad_row48_col9 {
#   background-color: #bcae6c;
#   color: #000000;
#   font-size: 10px;
# }
# #T_326ad_row0_col10, #T_326ad_row6_col1, #T_326ad_row9_col1, #T_326ad_row26_col14, #T_326ad_row46_col13 {
#   background-color: #b6a96f;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col11, #T_326ad_row1_col4, #T_326ad_row4_col15, #T_326ad_row13_col11, #T_326ad_row16_col11, #T_326ad_row19_col5, #T_326ad_row35_col4 {
#   background-color: #686a71;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col12, #T_326ad_row7_col15, #T_326ad_row9_col15, #T_326ad_row10_col12, #T_326ad_row16_col14, #T_326ad_row39_col14, #T_326ad_row41_col14, #T_326ad_row45_col12, #T_326ad_row49_col12 {
#   background-color: #002c64;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col13, #T_326ad_row23_col15 {
#   background-color: #143670;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col14, #T_326ad_row9_col6, #T_326ad_row13_col14, #T_326ad_row25_col15, #T_326ad_row31_col6 {
#   background-color: #053371;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col15, #T_326ad_row0_col16, #T_326ad_row3_col18, #T_326ad_row4_col19, #T_326ad_row10_col16, #T_326ad_row13_col16, #T_326ad_row14_col18, #T_326ad_row18_col13, #T_326ad_row23_col16, #T_326ad_row30_col15, #T_326ad_row30_col19, #T_326ad_row32_col16, #T_326ad_row35_col18, #T_326ad_row38_col15, #T_326ad_row39_col16, #T_326ad_row42_col16, #T_326ad_row44_col16, #T_326ad_row47_col16 {
#   background-color: #38476c;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col17, #T_326ad_row7_col17, #T_326ad_row8_col17, #T_326ad_row18_col17, #T_326ad_row22_col17, #T_326ad_row23_col9, #T_326ad_row30_col17, #T_326ad_row31_col17, #T_326ad_row34_col17, #T_326ad_row37_col17, #T_326ad_row47_col15, #T_326ad_row47_col17, #T_326ad_row49_col17 {
#   background-color: #002f6d;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col18, #T_326ad_row2_col19, #T_326ad_row18_col19, #T_326ad_row19_col19, #T_326ad_row22_col11, #T_326ad_row26_col19, #T_326ad_row28_col16, #T_326ad_row29_col16, #T_326ad_row30_col16, #T_326ad_row41_col15, #T_326ad_row44_col18, #T_326ad_row45_col19 {
#   background-color: #61656f;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row0_col19, #T_326ad_row7_col16, #T_326ad_row11_col19, #T_326ad_row15_col16, #T_326ad_row16_col16, #T_326ad_row20_col19, #T_326ad_row23_col18, #T_326ad_row26_col4, #T_326ad_row31_col14, #T_326ad_row31_col16, #T_326ad_row37_col14, #T_326ad_row39_col18, #T_326ad_row45_col16, #T_326ad_row47_col18 {
#   background-color: #575d6d;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col1 {
#   background-color: #cebc63;
#   color: #000000;
#   font-size: 10px;
# }
# #T_326ad_row1_col2 {
#   background-color: #083370;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col3, #T_326ad_row37_col15 {
#   background-color: #50576c;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col5, #T_326ad_row2_col17, #T_326ad_row12_col17, #T_326ad_row33_col5, #T_326ad_row40_col17, #T_326ad_row45_col13, #T_326ad_row49_col10 {
#   background-color: #213b6e;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col6, #T_326ad_row13_col6, #T_326ad_row32_col14, #T_326ad_row35_col14, #T_326ad_row43_col2 {
#   background-color: #002d68;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col7, #T_326ad_row1_col12, #T_326ad_row3_col12, #T_326ad_row8_col12, #T_326ad_row13_col2, #T_326ad_row14_col7, #T_326ad_row18_col12, #T_326ad_row34_col13, #T_326ad_row35_col12, #T_326ad_row36_col12, #T_326ad_row41_col13, #T_326ad_row48_col12, #T_326ad_row48_col13 {
#   background-color: #00306f;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col8, #T_326ad_row36_col8 {
#   background-color: #c7b767;
#   color: #000000;
#   font-size: 10px;
# }
# #T_326ad_row1_col9, #T_326ad_row9_col12, #T_326ad_row22_col8, #T_326ad_row24_col17, #T_326ad_row44_col8 {
#   background-color: #9f9775;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col10, #T_326ad_row8_col8, #T_326ad_row18_col8, #T_326ad_row23_col7, #T_326ad_row24_col14, #T_326ad_row38_col4, #T_326ad_row48_col1, #T_326ad_row49_col8 {
#   background-color: #a39a74;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col11, #T_326ad_row7_col2, #T_326ad_row12_col11, #T_326ad_row22_col15, #T_326ad_row26_col1, #T_326ad_row38_col14 {
#   background-color: #636670;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col13, #T_326ad_row29_col12, #T_326ad_row44_col12 {
#   background-color: #263d6e;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col14, #T_326ad_row4_col2, #T_326ad_row27_col16, #T_326ad_row28_col6, #T_326ad_row44_col1 {
#   background-color: #18376f;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col15, #T_326ad_row18_col15 {
#   background-color: #32436d;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col16, #T_326ad_row4_col14, #T_326ad_row6_col19, #T_326ad_row7_col5, #T_326ad_row10_col18, #T_326ad_row12_col7, #T_326ad_row14_col14, #T_326ad_row16_col18, #T_326ad_row18_col16, #T_326ad_row20_col16, #T_326ad_row22_col16, #T_326ad_row25_col2, #T_326ad_row26_col18, #T_326ad_row27_col18, #T_326ad_row31_col18, #T_326ad_row32_col11, #T_326ad_row33_col11, #T_326ad_row34_col16, #T_326ad_row38_col16, #T_326ad_row43_col16, #T_326ad_row48_col16 {
#   background-color: #4d556c;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col17, #T_326ad_row3_col17, #T_326ad_row9_col9, #T_326ad_row13_col17, #T_326ad_row14_col2, #T_326ad_row16_col2, #T_326ad_row16_col17, #T_326ad_row20_col17, #T_326ad_row25_col9, #T_326ad_row33_col17, #T_326ad_row39_col17, #T_326ad_row41_col5, #T_326ad_row42_col9, #T_326ad_row44_col17, #T_326ad_row45_col17 {
#   background-color: #00295d;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_326ad_row1_col18, #T_326ad_row5_col16, #T_326ad_row7_col19, #T_326ad_row8_col10, #T_326ad_row8_col18, #T_326ad_row8_col19, #T_326ad_row10_col19, #T_326ad_row18_col10, #T_326ad_row21_col19,

# %%
costco_df = pd.read_csv("./wk0910/z_wk09_10_costcos-geocoded.csv")
costco_df


states = gpd.read_file('maps\cb_2018_us_state_20m.shp')

costco_df['coordinates'] = costco_df[['Longitude', 'Latitude']].values.tolist()
costco_df['coordinates'] = costco_df['coordinates'].apply(Point)
geo_costco_df = gpd.GeoDataFrame(costco_df, geometry='coordinates')

tdf = pd.DataFrame(costco_df.groupby('State').nunique()['Zip Code'])
tdf = tdf.reset_index()
tdf.columns = ['State',"count"]


tdf
# Out:
#              State  count
# 0          Alabama      3
# 1           Alaska      3
# 2          Arizona     17
# 3       California    114
# 4         Colorado     12
# 5      Connecticut      5
# 6         Delaware      1
# 7          Florida     21
# 8          Georgia      9
# 9           Hawaii      7
# 10           Idaho      5
# 11        Illinois     16
# 12         Indiana      3
# 13            Iowa      1
# 14          Kansas      2
# 15        Kentucky      1
# 16        Maryland      9
# 17   Massachusetts      6
# 18        Michigan     11
# 19       Minnesota      6
# 20        Missouri      5
# 21         Montana      5
# 22        Nebraska      1
# 23          Nevada      7
# 24   New Hampshire      1
# 25      New Jersey     12
# 26      New Mexico      3
# 27        New York     15
# 28  North Carolina      7
# 29            Ohio      7
# 30          Oregon     13
# 31    Pennsylvania      7
# 32  South Carolina      4
# 33       Tennessee      4
# 34           Texas     16
# 35            Utah      9
# 36         Vermont      1
# 37        Virginia     15
# 38      Washington     29
# 39       Wisconsin      2

# %%
 = pd.DataFrame(costco_df.groupby('State').nunique()['Zip Code'])

(tds).reset_index()
# Out:
#              State  Zip Code
# 0          Alabama         3
# 1           Alaska         3
# 2          Arizona        17
# 3       California       114
# 4         Colorado        12
# 5      Connecticut         5
# 6         Delaware         1
# 7          Florida        21
# 8          Georgia         9
# 9           Hawaii         7
# 10           Idaho         5
# 11        Illinois        16
# 12         Indiana         3
# 13            Iowa         1
# 14          Kansas         2
# 15        Kentucky         1
# 16        Maryland         9
# 17   Massachusetts         6
# 18        Michigan        11
# 19       Minnesota         6
# 20        Missouri         5
# 21         Montana         5
# 22        Nebraska         1
# 23          Nevada         7
# 24   New Hampshire         1
# 25      New Jersey        12
# 26      New Mexico         3
# 27        New York        15
# 28  North Carolina         7
# 29            Ohio         7
# 30          Oregon        13
# 31    Pennsylvania         7
# 32  South Carolina         4
# 33       Tennessee         4
# 34           Texas        16
# 35            Utah         9
# 36         Vermont         1
# 37        Virginia        15
# 38      Washington        29
# 39       Wisconsin         2

# %%
#//*** Initialize the subplots
fig, ax = plt.subplots()

#//*** Size the plot
fig = plt.gcf()
fig.set_size_inches(10,5)

states
geo_costco_df.plot(ax=ax)
ax.axis('off')
plt.show()

# %%
states = states[states['NAME'].isin(['Alaska','Hawaii','Puerto Rico']) == False]
states.plot()
# Out:
# <AxesSubplot:>
