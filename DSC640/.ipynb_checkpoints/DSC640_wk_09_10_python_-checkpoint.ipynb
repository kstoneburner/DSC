# %% [markdown]
# # Stoneburner, Kurt
# - ## DSC 640 - Week 09 10

# %%
import os
import sys
# //*** Imports and Load Data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from shapely.geometry import Point
import geopandas as gpd

#//*** Use the whole window in the IPYNB editor
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#//*** Maximize columns and rows displayed by pandas
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# Heatmaps Reference: https://www.geeksforgeeks.org/display-the-pandas-dataframe-in-heatmap-style/
#
# GeoSpatial Refernce: https://www.datacamp.com/community/tutorials/geospatial-data-python
#
# Countour Plots via KDEplots: https://seaborn.pydata.org/generated/seaborn.kdeplot.html

# %%
bb_df = pd.read_csv("./wk0910/z_wk09_10_ppg2008.csv")


fig,ax = plt.subplots()

# Define a nice color map for our heatmap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(
        data=bb_df.corr(),  # our correlation matrix
        linewidths=0.3,  # the width of lines separating the matrix squares
        square=True,   # enforce 1:1 ratios among correlation cells
        cmap=cmap,  # use the color map we defined above
        vmax=1,  # define the max of our correlation scale
        vmin=-1, # define the min of our correlation scale
        center=0,  # The value at which the color map is centered about (white)
        cbar_kws={"shrink": .75}  # shrink the scale a bit
    )
# adjust y-axis ticks for legibility
plt.yticks(rotation=0)  
# show the heatmap
plt.show()

# %%
#//*** NBA Per Game Performance
#//** top 50 scoreres during the 2008-2009 Season
#//*** Column Names
col_dict = {
    "G" : "Games",
    "MIN" : "Minutes",
    "PTS" : "Points",
    "FGM" : "Field Goals Made",
    "FGA" : "Field Goal Attempts",
    "FGP" : "Field Goal Percentage",
    "FTM" : "Free Throw Made",
    "FTA" : "Free Throw Attempt",
    "FTP" : "Free Throw Percentage",
    "3PM" : "Three Pointers Made",
    "3PA" : "Three Point Attempts",
    "3PP" : "Three Point Percentage",
    "ORB" : "Offensive Rebounds",
    "DRB" : "Defensive Rebounds",
    "TRB" : "Total Rebounds",
    "AST" : "Assists",
    "STL" : "Steals",
    "BLK" : "Blocks",
    "TO" : "Turnovers"
}
bb_df.sort_values("G",ascending=False).set_index("Name  ").style.background_gradient(cmap ='cividis')\
    .set_properties(**{'font-size': '10px'})
# Out:
# <style type="text/css">
# #T_3b6b9_row0_col0, #T_3b6b9_row1_col0, #T_3b6b9_row2_col0, #T_3b6b9_row3_col0, #T_3b6b9_row4_col0, #T_3b6b9_row4_col1, #T_3b6b9_row13_col8, #T_3b6b9_row14_col9, #T_3b6b9_row14_col10, #T_3b6b9_row17_col7, #T_3b6b9_row17_col12, #T_3b6b9_row17_col13, #T_3b6b9_row17_col14, #T_3b6b9_row17_col17, #T_3b6b9_row19_col2, #T_3b6b9_row19_col3, #T_3b6b9_row19_col4, #T_3b6b9_row21_col15, #T_3b6b9_row21_col16, #T_3b6b9_row24_col11, #T_3b6b9_row27_col5, #T_3b6b9_row40_col18, #T_3b6b9_row44_col19, #T_3b6b9_row45_col6 {
#   background-color: #fee838;
#   color: #000000;
#   font-size: 10px;
# }
# #T_3b6b9_row0_col1, #T_3b6b9_row12_col9, #T_3b6b9_row14_col8, #T_3b6b9_row20_col9, #T_3b6b9_row46_col1 {
#   background-color: #a89e73;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row0_col2, #T_3b6b9_row8_col3, #T_3b6b9_row30_col5, #T_3b6b9_row40_col2, #T_3b6b9_row42_col4, #T_3b6b9_row45_col3, #T_3b6b9_row47_col7, #T_3b6b9_row48_col7 {
#   background-color: #47516c;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row0_col3, #T_3b6b9_row6_col3, #T_3b6b9_row9_col5, #T_3b6b9_row24_col1, #T_3b6b9_row30_col1, #T_3b6b9_row30_col3, #T_3b6b9_row31_col3, #T_3b6b9_row37_col3, #T_3b6b9_row38_col10, #T_3b6b9_row40_col6 {
#   background-color: #60646f;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row0_

#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col1 {
#   background-color: #cebc63;
#   color: #000000;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col2 {
#   background-color: #083370;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col3, #T_3b6b9_row37_col15 {
#   background-color: #50576c;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col5, #T_3b6b9_row2_col17, #T_3b6b9_row12_col17, #T_3b6b9_row33_col5, #T_3b6b9_row40_col17, #T_3b6b9_row45_col13, #T_3b6b9_row49_col10 {
#   background-color: #213b6e;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col6, #T_3b6b9_row13_col6, #T_3b6b9_row32_col14, #T_3b6b9_row35_col14, #T_3b6b9_row43_col2 {
#   background-color: #002d68;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col7, #T_3b6b9_row1_col12, #T_3b6b9_row3_col12, #T_3b6b9_row8_col12, #T_3b6b9_row13_col2, #T_3b6b9_row14_col7, #T_3b6b9_row18_col12, #T_3b6b9_row34_col13, #T_3b6b9_row35_col12, #T_3b6b9_row36_col12, #T_3b6b9_row41_col13, #T_3b6b9_row48_col12, #T_3b6b9_row48_col13 {
#   background-color: #00306f;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col8, #T_3b6b9_row36_col8 {
#   background-color: #c7b767;
#   color: #000000;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col9, #T_3b6b9_row9_col12, #T_3b6b9_row22_col8, #T_3b6b9_row24_col17, #T_3b6b9_row44_col8 {
#   background-color: #9f9775;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col10, #T_3b6b9_row8_col8, #T_3b6b9_row18_col8, #T_3b6b9_row23_col7, #T_3b6b9_row24_col14, #T_3b6b9_row38_col4, #T_3b6b9_row48_col1, #T_3b6b9_row49_col8 {
#   background-color: #a39a74;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col11, #T_3b6b9_row7_col2, #T_3b6b9_row12_col11, #T_3b6b9_row22_col15, #T_3b6b9_row26_col1, #T_3b6b9_row38_col14 {
#   background-color: #636670;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col13, #T_3b6b9_row29_col12, #T_3b6b9_row44_col12 {
#   background-color: #263d6e;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col14, #T_3b6b9_row4_col2, #T_3b6b9_row27_col16, #T_3b6b9_row28_col6, #T_3b6b9_row44_col1 {
#   background-color: #18376f;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col15, #T_3b6b9_row18_col15 {
#   background-color: #32436d;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col16, #T_3b6b9_row4_col14, #T_3b6b9_row6_col19, #T_3b6b9_row7_col5, #T_3b6b9_row10_col18, #T_3b6b9_row12_col7, #T_3b6b9_row14_col14, #T_3b6b9_row16_col18, #T_3b6b9_row18_col16, #T_3b6b9_row20_col16, #T_3b6b9_row22_col16, #T_3b6b9_row25_col2, #T_3b6b9_row26_col18, #T_3b6b9_row27_col18, #T_3b6b9_row31_col18, #T_3b6b9_row32_col11, #T_3b6b9_row33_col11, #T_3b6b9_row34_col16, #T_3b6b9_row38_col16, #T_3b6b9_row43_col16, #T_3b6b9_row48_col16 {
#   background-color: #4d556c;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col17, #T_3b6b9_row3_col17, #T_3b6b9_row9_col9, #T_3b6b9_row13_col17, #T_3b6b9_row14_col2, #T_3b6b9_row16_col2, #T_3b6b9_row16_col17, #T_3b6b9_row20_col17, #T_3b6b9_row25_col9, #T_3b6b9_row33_col17, #T_3b6b9_row39_col17, #T_3b6b9_row41_col5, #T_3b6b9_row42_col9, #T_3b6b9_row44_col17, #T_3b6b9_row45_col17 {
#   background-color: #00295d;
#   color: #f1f1f1;
#   font-size: 10px;
# }
# #T_3b6b9_row1_col18, #T_3b6b9_row5_col16, #T_3b6b9_row7_col19, #T_3b6b9_row8_col10, #T_3b6b9_row8_col18, #T_3b6b9_row8_col19, #T_3b6b9_row10_col19, #T_3b6b9_row18_col10, #T_3b6b9_row21_col19,

# %%
#//*** Initialize the subplots
fig, ax = plt.subplots()

#//*** Size the plot
fig = plt.gcf()
fig.set_size_inches(20,10)

ax = sns.kdeplot(
    data=bb_df, x="MIN", y="PTS", fill=True,
)

plt.title("NBA Top Scorers 2008 Season\nMinutes vs Points",fontsize=30)
ax.set_xlabel("Avg Points per Game",fontsize=15)
ax.set_ylabel("Avg Minutes per Game",fontsize=15)

plt.text(0,-.1,'"Python: Density Contour Plot"', size=20, transform=ax.transAxes)
plt.show()

# %%
#//*** Load the Costco Data set
costco_df = pd.read_csv("./wk0910/z_wk09_10_costcos-geocoded.csv")

#//*** Combine the Longitude and Latitutde Columns into a single column
costco_df['coordinates'] = costco_df[['Longitude', 'Latitude']].values.tolist()

#//*** Convert the coordinates to Geopandas Points
costco_df['coordinates'] = costco_df['coordinates'].apply(Point)

#//*** Convert Costco to a GeoPandas DataFrame
geo_costco_df = gpd.GeoDataFrame(costco_df, geometry='coordinates')

#//*** Get the number of Costcos for each State
tdf = pd.DataFrame(costco_df.groupby('State').nunique()['Zip Code'])

#//*** Move the States From the Index to Columns
tdf = tdf.reset_index()

#//*** Rename Columns
tdf.columns = ['State',"count"]

#//*** A few states have a high concentration of costcos. For scaling purposes, reset all values over 10 to 10.
tdf.loc[tdf[f"count"] > 10,f"count"]=10
tdf


#//*** Load a Shape File of all States into a GeoPandas Frame
states = gpd.read_file('maps\cb_2018_us_state_20m.shp')

#//*** Remove Alaskam Hawaii, Puerto Rico
states = states[states['NAME'].isin(['Alaska','Hawaii','Puerto Rico']) == False]
geo_costco_df = geo_costco_df[geo_costco_df['State'].isin(['Alaska','Hawaii','Puerto Rico']) == False]

#//*** Set the Base column to zero. This is used to draw a map of all states and set the color to 0.
#//*** This draws all the States. This is used to fill in the States that don't have Costcos
states['base'] = 0

#//*** Merge States GeoPandas with the Costco Counts
rankings_df = states.merge(tdf,left_on='NAME',right_on='State')

#//*** Pick a Color map
#//*** https://matplotlib.org/stable/tutorials/colors/colormaps.html
color_map = "YlOrRd"
color_map = "OrRd"

# Create colorbar as a legend
#//*** The Scale is set between 0 and 10
sm = plt.cm.ScalarMappable(cmap=plt.get_cmap(color_map), norm=plt.Normalize(vmin=0, vmax=10))

#//*** Initialize the subplots
fig, ax = plt.subplots()

#//*** Size the plot
fig = plt.gcf()
fig.set_size_inches(20,10)


sm._A = []

#//*** Custom Colorbar ticks
cbar = fig.colorbar(sm,shrink=.7,ticks=[0,2,4,6,8,10])
cbar.ax.set_yticklabels(["0","2","4","6","8","10+"])

#//*** Plot the base map with the 0 color of the colormap
ax=states.plot(column='base', cmap=plt.get_cmap(color_map), edgecolor=(0,0,0,.1), ax=ax,)

#//*** Plot the Heatmap based on Costco Counts
ax=rankings_df.plot(column='count', cmap=plt.get_cmap(color_map), edgecolor=(0,0,0,.1), ax=ax)

#//*** Plot Costco locations based on Lat and Long. 
#//*** Drawing the marker 3 times to all some texture and additional color. This White Dots with Black outline, 
#//*** with a small gray dot in the Middle.

ax=geo_costco_df.plot(ax=ax, marker=".",color="black", markersize=50)
ax=geo_costco_df.plot(ax=ax, marker=".",color="white", markersize=20)
ax=geo_costco_df.plot(ax=ax, marker=".",color=(0,0,0,.2), markersize=1)
ax.axis('off')
plt.title("U.S. Costco Locations",fontsize=20)
plt.text(0,-.1,'"Python: Spatial Heatmap"', size=20, transform=ax.transAxes)
plt.show()
