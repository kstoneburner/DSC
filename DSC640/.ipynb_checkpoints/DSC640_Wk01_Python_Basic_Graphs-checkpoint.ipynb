# %% [markdown]
# # Stoneburner, Kurt
# - ## DSC 640 - Week XX

# %%
import os
import sys
# //*** Imports and Load Data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

#//*** Use the whole window in the IPYNB editor
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#//*** Maximize columns and rows displayed by pandas
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
raw_df = pd.read_excel("z_wk01_allhlcn20.xlsx")

# %%
state_df = raw_df[ (raw_df['Area Type'] == "State") ]
ca_df = state_df[state_df["St Name"]=="California"]
ca_df
# Out:
#      Area\nCode  St  Cnty  Own  NAICS  Year Qtr Area Type     St Name  \
# 3353      06000  06   0.0    0     10  2020   A     State  California
# 3354      06000  06   0.0    1     10  2020   A     State  California
# 3355      06000  06   0.0    2     10  2020   A     State  California
# 3356      06000  06   0.0    3     10  2020   A     State  California
# 3357      06000  06   0.0    5     10  2020   A     State  California
# 3358      06000  06   0.0    5    101  2020   A     State  California
# 3359      06000  06   0.0    5   1011  2020   A     State  California
# 3360      06000  06   0.0    5   1012  2020   A     State  California
# 3361      06000  06   0.0    5   1013  2020   A     State  California
# 3362      06000  06   0.0    5    102  2020   A     State  California
# 3363      06000  06   0.0    5   1021  2020   A     State  California
# 3364      06000  06   0.0    5   1022  2020   A     State  California
# 3365      06000  06   0.0    5   1023  2020   A     State  California
# 3366      06000  06   0.0    5   1024  2020   A     State  California
# 3367      06000  06   0.0    5   1025  2020   A     State  California
# 3368      06000  06   0.0    5   1026  2020   A     State  California
# 3369      06000  06   0.0    5   1027  2020   A     State  California
# 3370      06000  06   0.0    5   1029  2020   A     State  California
#
#                          Area           Ownership  \
# 3353  California -- Statewide       Total Covered
# 3354  California -- Statewide  Federal Government
# 3355  California -- Statewide    State Government
# 3356  California -- Statewide    Local Government
# 3357  California -- Statewide             Private
# 3358  California -- Statewide             Private
# 3359  California -- Statewide             Private
# 3360  California -- Statewide             Private
# 3361  California -- Statewide             Private
# 3362  California -- Statewide             Private
# 3363  California -- Statewide             Private
# 3364  California -- Statewide             Private
# 3365  California -- Statewide             Private
# 3366  California -- Statewide             Private
# 3367  California -- Statewide             Private
# 3368  California -- Statewide             Private
# 3369  California -- Statewide             Private
# 3370  California -- Statewide             Private
#
#                                        Industry Annual Average Status Code  \
# 3353                   10 Total, all industries                        NaN
# 3354                   10 Total, all industries                        NaN
# 3355                   10 Total, all industries                        NaN
# 3356                   10 Total, all industries                        NaN
# 3357                   10 Total, all industries                        NaN
# 3358                        101 Goods-producing                        NaN
# 3359          1011 Natural resources and mining                        NaN
# 3360                          1012 Construction                        NaN
# 3361                         1013 Manufacturing                        NaN
# 3362                      102 Service-providing                        NaN
# 3363  1021 Trade, transportation, and utilities                        NaN
# 3364                           1022 Information                        NaN
# 3365                  1023 Financial activities                        NaN
# 3366    1024 Professional and business services                        NaN
# 3367         1025 Education and health services                        NaN
# 3368               1026 Leisure and hospitality                        NaN
# 3369                        1027 Other services                        NaN
# 3370                          1029 Unclassified                        NaN
#
#       Annual Average Establishment Count  Annual Average Employment  \
# 3353                             1627484                   16376295
# 3354                                3334                     260068
# 3355                               13637                     474295
# 3356                               19348                    1677176
# 3357                             1591166                   13964756
# 3358                              148897                    2544673
# 3359                               17731                     425665
# 3360                               86778                     855713
# 3361                               44388                    1263295
# 3362                             1442269                   11420083
# 3363                              201611                    2888878
# 3364                               29655                     526694
# 3365                              113246                     816914
# 3366                              223273                    2599633
# 3367                              657342                    2650424
# 3368                              118537                    1483790
# 3369                               97944                     452620
# 3370                                 663                       1131
#
#       Annual Total Wages  Annual Average Weekly Wage  Annual Average Pay  \
# 3353       1301826279330                        1529               79495
# 3354         22718907478                        1680               87358
# 3355         42584813264                        1727               89785
# 3356        122885828106                        1409               73269
# 3357       1113636730482                        1534               79746
# 3358        222672030038                        1683               87505
# 3359         18110640593                         818               42547
# 3360         65687839201                        1476               76764
# 3361        138873550244                        2114              109930
# 3362        890964700444                        1500               78017
# 3363        169855315589                        1131               58796
# 3364        114962004954                        4198              218271
# 3365        101394249612                        2387              124119
# 3366        276976337045                        2049              106544
# 3367        152890830445                        1109               57685
# 3368         53516059805                         694               36067
# 3369         21310952105                         905               47084
# 3370            58950889                        1003               52130
#
#       Employment Location Quotient Relative to U.S.  \
# 3353                                           1.00
# 3354                                           0.75
# 3355                                           0.88
# 3356                                           1.04
# 3357                                           1.01
# 3358                                           1.03
# 3359                                           2.03
# 3360                                           1.01
# 3361                                           0.89
# 3362                                           1.00
# 3363                                           0.93
# 3364                                           1.65
# 3365                                           0.85
# 3366                                           1.09
# 3367                                           1.01
# 3368                                           0.98
# 3369                                           0.97
# 3370                                           0.06
#
#       Total Wage Location Quotient Relative to U.S.
# 3353                                           1.00
# 3354                                           0.62
# 3355                                           0.96
# 3356                                           1.08
# 3357                                           1.01
# 3358                                           1.03
# 3359                                           1.14
# 3360                                           0.93
# 3361                                           1.07
# 3362                                           1.00
# 3363                                           0.84
# 3364                                           2.13
# 3365                                           0.79
# 3366                                           1.10
# 3367                                           0.85
# 3368                                           1.11
# 3369                                           0.84
# 3370                                           0.04

# %%
raw_df[ (raw_df['Area Type']=='Nation') & (raw_df["Industry"]=="10 Total, all industries") ] 

all_cols = ['Area\nCode', 'St', 'Cnty', 'Own', 'NAICS', 'Year', 'Qtr', 'Area Type',
       'St Name', 'Area', 'Ownership', 'Industry',
       'Annual Average Status Code', 'Annual Average Establishment Count',
       'Annual Average Employment', 'Annual Total Wages',
       'Annual Average Weekly Wage', 'Annual Average Pay',
       'Employment Location Quotient Relative to U.S.',
       'Total Wage Location Quotient Relative to U.S.']
nation_cols = ['Area Type','Ownership', 'Industry',
       'Annual Average Establishment Count',
       'Annual Average Employment', 'Annual Total Wages',
       'Annual Average Weekly Wage', 'Annual Average Pay',
       'Employment Location Quotient Relative to U.S.',
       'Total Wage Location Quotient Relative to U.S.']

nation_df = raw_df[nation_cols]
nation_df = nation_df[ (nation_df['Area Type']=='Nation') & (nation_df["Industry"]=="10 Total, all industries") ] 
nation_df = nation_df[nation_df["Ownership"] != "Total Covered"]
nation_df
# Out:
#   Area Type           Ownership                  Industry  \
# 1    Nation  Federal Government  10 Total, all industries
# 2    Nation    State Government  10 Total, all industries
# 3    Nation    Local Government  10 Total, all industries
# 4    Nation             Private  10 Total, all industries
#
#    Annual Average Establishment Count  Annual Average Employment  \
# 1                               61310                    2927788
# 2                               70057                    4590784
# 3                              171046                   13643540
# 4                            10192539                  117944857
#
#    Annual Total Wages  Annual Average Weekly Wage  Annual Average Pay  \
# 1        250261448866                        1644               85478
# 2        301891443958                        1265               65760
# 3        776056455733                        1094               56881
# 4       7576501397400                        1235               64238
#
#    Employment Location Quotient Relative to U.S.  \
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
#
#    Total Wage Location Quotient Relative to U.S.
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0

# %%
x3 = "Annual Total Wages"
x2 = "Annual Average Employment"
x1 = "Annual Average Establishment Count"
y = "Ownership"


plot_df = nation_df

size =3
scale=1.5
wedge = size
colors = sns.color_palette('YlOrBr')[0:len(plot_df[x])]
fig1, ax1 = plt.subplots()

fig = plt.gcf()
fig.set_size_inches(20, 20)

ax1.pie(plot_df[x1],
        #labels=plot_df[y], 
        #autopct='%1.1f%%',
        shadow=True,
        colors=colors,
        radius=size,
        wedgeprops=dict(edgecolor='w'),
        startangle=0,)
size*=scale
wedge=size/2

ax1.pie(plot_df[x2],
        #labels=plot_df[y], 
        #autopct='%1.1f%%',
        shadow=True,
        colors=colors,
        radius=size,
        wedgeprops=dict(width=wedge,edgecolor='w'),
        startangle=0,)
wedge=size/2
size*=scale

ax1.pie(plot_df[x3],
        labels=plot_df[y], 
        #autopct='%1.1f%%',
        shadow=False,
        colors=colors,
        radius=size,
        wedgeprops=dict(width=wedge,edgecolor='w'),
        textprops = {'size': 'x-large'},
        startangle=0,)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

font = {'color' : 'black'}
fontsize=30
plt.annotate("Establishments",xy=(-1.5,-1),fontsize=fontsize,color='white')
plt.annotate("Jobs",xy=(-.5,-3.5),fontsize=fontsize,color='white')
plt.annotate("Wages",xy=(-.7,-5.75),fontsize=fontsize,color='white')
plt.title("National Employment Characteristics",fontsize=fontsize*1.5)
#plt.legend()
plt.show()

# %%
x3 = "Annual Total Wages"
x2 = "Annual Average Employment"
x1 = "Annual Average Pay"
y = "Ownership"


plot_df = nation_df

size =7
scale=1.5
wedge = size
colors = sns.color_palette('YlOrBr')[0:len(plot_df[x])]
fig1, ax1 = plt.subplots()

fig = plt.gcf()
fig.set_size_inches(10, 10)

total = plot_df[x1].sum()

ax1.pie(plot_df[x1],
        labels=plot_df[y], 
        autopct = lambda p: '${:.01f}k'.format(p * total / 100000),
        shadow=True,
        colors=colors,
        radius=size,
        wedgeprops=dict(edgecolor='w'),
        textprops = {'size': 'x-large'},
        startangle=0,)

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title("U.S. Average Annual Pay by Sector",fontsize=fontsize*1.5)
#plt.legend()
plt.show()

# %%
state_df
# Out:
#       Area\nCode  St  Cnty  Own  NAICS  Year Qtr Area Type  St Name  \
# 18         01000  01   0.0    0     10  2020   A     State  Alabama
# 19         01000  01   0.0    1     10  2020   A     State  Alabama
# 20         01000  01   0.0    2     10  2020   A     State  Alabama
# 21         01000  01   0.0    3     10  2020   A     State  Alabama
# 22         01000  01   0.0    5     10  2020   A     State  Alabama
# ...          ...  ..   ...  ...    ...   ...  ..       ...      ...
# 55731      56000  56   0.0    5   1024  2020   A     State  Wyoming
# 55732      56000  56   0.0    5   1025  2020   A     State  Wyoming
# 55733      56000  56   0.0    5   1026  2020   A     State  Wyoming
# 55734      56000  56   0.0    5   1027  2020   A     State  Wyoming
# 55735      56000  56   0.0    5   1029  2020   A     State  Wyoming
#
#                        Area           Ownership  \
# 18     Alabama -- Statewide       Total Covered
# 19     Alabama -- Statewide  Federal Government
# 20     Alabama -- Statewide    State Government
# 21     Alabama -- Statewide    Local Government
# 22     Alabama -- Statewide             Private
# ...                     ...                 ...
# 55731  Wyoming -- Statewide             Private
# 55732  Wyoming -- Statewide             Private
# 55733  Wyoming -- Statewide             Private
# 55734  Wyoming -- Statewide             Private
# 55735  Wyoming -- Statewide             Private
#
#                                       Industry Annual Average Status Code  \
# 18                    10 Total, all industries                        NaN
# 19                    10 Total, all industries                        NaN
# 20                    10 Total, all industries                        NaN
# 21                    10 Total, all industries                        NaN
# 22                    10 Total, all industries                        NaN
# ...                                        ...                        ...
# 55731  1024 Professional and business services                        NaN
# 55732       1025 Education and health services                        NaN
# 55733             1026 Leisure and hospitality                        NaN
# 55734                      1027 Other services                        NaN
# 55735                        1029 Unclassified                        NaN
#
#        Annual Average Establishment Count  Annual Average Employment  \
# 18                                 132001                    1910169
# 19                                   1250                      55888
# 20                                   1365                      97435
# 21                                   3702                     208839
# 22                                 125684                    1548007
# ...                                   ...                        ...
# 55731                                4991                      18354
# 55732                                3486                      26932
# 55733                                2421                      32269
# 55734                                1667                       6764
# 55735                                 115                        123
#
#        Annual Total Wages  Annual Average Weekly Wage  Annual Average Pay  \
# 18            99619444620                        1003               52152
# 19             4820416591                        1659               86252
# 20             5625429688                        1110               57735
# 21             9631021976                         887               46117
# 22            79542576365                         988               51384
# ...                   ...                         ...                 ...
# 55731          1105052453                        1158               60209
# 55732          1248088204                         891               46342
# 55733           743850729                         443               23051
# 55734           272455135                         775               40283
# 55735            11311421                        1766               91838
#
#        Employment Location Quotient Relative to U.S.  \
# 18                                              1.00
# 19                                              1.39
# 20                                              1.55
# 21                                              1.11
# 22                                              0.96
# ...                                              ...
# 55731                                           0.48
# 55732                                           0.64
# 55733                                           1.34
# 55734                                           0.91
# 55735                                           0.43
#
#        Total Wage Location Quotient Relative to U.S.
# 18                                              1.00
# 19                                              1.72
# 20                                              1.67
# 21                                              1.11
# 22                                              0.94
# ...                                              ...
# 55731                                           0.43
# 55732                                           0.68
# 55733                                           1.50
# 55734                                           1.05
# 55735                                           0.74
#
# [906 rows x 20 columns]

# %%
x3 = "Annual Total Wages"
x2 = "Annual Average Employment"
x1 = "Annual Average Pay"
x4 = "Annual Average Establishment Count"
y = "St Name"
state_df = raw_df[ (raw_df['Area Type'] == "State") & (raw_df["Ownership"] == "Total Covered")]


x_col= x4
plot_df = state_df.sort_values(x_col,ascending=False).iloc[0:10]

plot_df = plot_df.sort_values(x_col,ascending=True)

fig1, ax = plt.subplots()

fig = plt.gcf()
fig.set_size_inches(10, 10)

ax.barh(plot_df[y],plot_df[x_col])

plt.title("Top 10 States: Total # of Businesses")
plt.show()




x_col= x2

plot_df = state_df.sort_values(x_col,ascending=False).iloc[0:10]



plot_df = plot_df.sort_values(x_col,ascending=True)

fig1, ax = plt.subplots()

fig = plt.gcf()
fig.set_size_inches(10, 10)

ax.barh(plot_df[y],plot_df[x_col])


plt.title("Top 10 States: Total # of Workers")
plt.show()

x_col= x3

plot_df = state_df.sort_values(x_col,ascending=False).iloc[0:10]



plot_df = plot_df.sort_values(x_col,ascending=True)

fig1, ax = plt.subplots()

fig = plt.gcf()
fig.set_size_inches(10, 10)

ax.barh(plot_df[y],plot_df[x_col])


plt.title("Top 10 States: Total Wages Paid")
plt.show()

# %%
x3 = "Annual Total Wages"
x2 = "Annual Average Employment"
x1 = "Annual Average Pay"
x4 = "Annual Average Establishment Count"
y = "St Name"
state_df = raw_df[ (raw_df['Area Type'] == "State") & (raw_df["Ownership"] == "Total Covered")]


x_col= x4
plot_df = state_df.sort_values(x_col,ascending=False).iloc[0:10][[y,x_col]]

f, ax = plt.subplots()

fig = plt.gcf()
fig.set_size_inches(10, 10)

sns.barplot(plot_df[x_col],plot_df[y])
ax.ticklabel_format(style='plain', axis="x")
plt.title("Top 10 States: Total # of Businesses")
plt.show()

x_col= x2

plot_df = state_df.sort_values(x_col,ascending=False).iloc[0:10][[y,x_col]]



fig, ax = plt.subplots()

fig = plt.gcf()
fig.set_size_inches(10, 10)

sns.barplot(plot_df[x_col],plot_df[y])

ax.ticklabel_format(style='plain', axis="x")

plt.title("Top 10 States: Total # of Workers")
plt.show()


x_col= x3

plot_df = state_df.sort_values(x_col,ascending=False).iloc[0:10][[y,x_col]]



fig1, ax = plt.subplots()

fig = plt.gcf()
fig.set_size_inches(10, 10)

sns.barplot(plot_df[x_col],plot_df[y])
ax.ticklabel_format(style='plain', axis="x")

plt.title("Top 10 States: Total Wages Paid")
plt.show()

# %%
state_df.sort_values(x4,ascending=False)
# Out:
#       Area\nCode  St  Cnty  Own  NAICS  Year Qtr Area Type     St Name  \
# 3353       06000  06   0.0    0     10  2020   A     State  California
# 3357       06000  06   0.0    5     10  2020   A     State  California
# 3362       06000  06   0.0    5    102  2020   A     State  California
# 5869       12000  12   0.0    0     10  2020   A     State     Florida
# 5873       12000  12   0.0    5     10  2020   A     State     Florida
# ...          ...  ..   ...  ...    ...   ...  ..       ...         ...
# 50105      50000  50   0.0    5   1029  2020   A     State     Vermont
# 23639      27000  27   0.0    5   1029  2020   A     State   Minnesota
# 10098      16000  16   0.0    5   1029  2020   A     State       Idaho
# 5754       10000  10   0.0    5   1029  2020   A     State    Delaware
# 2060       05000  05   0.0    5   1029  2020   A     State    Arkansas
#
#                           Area      Ownership                  Industry  \
# 3353   California -- Statewide  Total Covered  10 Total, all industries
# 3357   California -- Statewide        Private  10 Total, all industries
# 3362   California -- Statewide        Private     102 Service-providing
# 5869      Florida -- Statewide  Total Covered  10 Total, all industries
# 5873      Florida -- Statewide        Private  10 Total, all industries
# ...                        ...            ...                       ...
# 50105     Vermont -- Statewide        Private         1029 Unclassified
# 23639   Minnesota -- Statewide        Private         1029 Unclassified
# 10098       Idaho -- Statewide        Private         1029 Unclassified
# 5754     Delaware -- Statewide        Private         1029 Unclassified
# 2060     Arkansas -- Statewide        Private         1029 Unclassified
#
#       Annual Average Status Code  Annual Average Establishment Count  \
# 3353                         NaN                             1627484
# 3357                         NaN                             1591166
# 3362                         NaN                             1442269
# 5869                         NaN                              747034
# 5873                         NaN                              741148
# ...                          ...                                 ...
# 50105                        NaN                                   3
# 23639                        NaN                                   1
# 10098                        NaN                                   0
# 5754                         NaN                                   0
# 2060                         NaN                                   0
#
#        Annual Average Employment  Annual Total Wages  \
# 3353                    16376295       1301826279330
# 3357                    13964756       1113636730482
# 3362                    11420083        890964700444
# 5869                     8444982        471508743986
# 5873                     7387056        409275646867
# ...                          ...                 ...
# 50105                          3              253159
# 23639                          1               44332
# 10098                          0                   0
# 5754                           0               13492
# 2060                           0                   0
#
#        Annual Average Weekly Wage  Annual Average Pay  \
# 3353                         1529               79495
# 3357                         1534               79746
# 3362                         1500               78017
# 5869                         1074               55833
# 5873                         1065               55404
# ...                           ...                 ...
# 50105                        1947              101264
# 23639                         731               37999
# 10098                           0                   0
# 5754                         3114              161904
# 2060                            0                   0
#
#        Employment Location Quotient Relative to U.S.  \
# 3353                                            1.00
# 3357                                            1.01
# 3362                                            1.00
# 5869                                            1.00
# 5873                                            1.03
# ...                                              ...
# 50105                                           0.01
# 23639                                           0.00
# 10098                                           0.00
# 5754                                            0.00
# 2060                                            0.00
#
#        Total Wage Location Quotient Relative to U.S.
# 3353                                            1.00
# 3357                                            1.01
# 3362                                            1.00
# 5869                                            1.00
# 5873                                            1.02
# ...                                              ...
# 50105                                           0.01
# 23639                                           0.00
# 10098                                           0.00
# 5754                                            0.00
# 2060                                            0.00
#
# [906 rows x 20 columns]

# %%
temp_df = raw_df[(raw_df['Ownership']=='Total Covered') & (raw_df['Area Type']=='State')].sort_values("Annual Average Pay",ascending = False)

temp_df = temp_df[["St Name","Annual Average Pay"]]

temp_df
# Out:
#                     St Name  Annual Average Pay
# 5823   District of Columbia              107036
# 21812         Massachusetts               83675
# 32666              New York               83117
# 3353             California               79495
# 52780            Washington               76771
# 5557            Connecticut               75395
# 31661            New Jersey               73953
# 21349              Maryland               68882
# 4413               Colorado               66662
# 10864              Illinois               66290
# 50365              Virginia               65146
# 31446         New Hampshire               64868
# 23622             Minnesota               64152
# 45030                 Texas               62865
# 5737               Delaware               62462
# 40081          Pennsylvania               62042
# 1191                 Alaska               61732
# 41254          Rhode Island               60497
# 39398                Oregon               59928
# 22096              Michigan               59432
# 7111                Georgia               58868
# 1739                Arizona               58428
# 9976                 Hawaii               57930
# 33818        North Carolina               56215
# 31115                Nevada               55974
# 36470                  Ohio               55863
# 5869                Florida               55833
# 35552          North Dakota               55464
# 43348             Tennessee               55142
# 49572                  Utah               54822
# 50088               Vermont               54063
# 26559              Missouri               54018
# 54461             Wisconsin               53814
# 14226                  Iowa               52321
# 18                  Alabama               52152
# 19882             Louisiana               51968
# 21036                 Maine               51935
# 12624               Indiana               51925
# 29538              Nebraska               51497
# 15941                Kansas               51473
# 55718               Wyoming               50990
# 17747              Kentucky               50776
# 32075            New Mexico               50357
# 38058              Oklahoma               49598
# 41379        South Carolina               49548
# 42210          South Dakota               49158
# 53476         West Virginia               48724
# 2043               Arkansas               48647
# 28547               Montana               48427
# 10081                 Idaho               47675
# 25139           Mississippi               43209

# %%
# //*** CODE HERE
