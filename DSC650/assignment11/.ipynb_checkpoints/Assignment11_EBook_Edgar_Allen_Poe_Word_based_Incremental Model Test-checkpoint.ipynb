# %% [markdown]
# # Stoneburner, Kurt
# - ## DSC 650 - Week XX
#
# https://www.kaggle.com/shivamb/beginners-guide-to-text-generation-using-lstms
#
# https://bansalh944.medium.com/text-generation-using-lstm-b6ced8629b03

# %%
import os
import sys
# //*** Imports and Load Data
#import matplotlib.pyplot as plt
import numpy as np
#import pandas as pd


from pathlib import Path


#//*** Use the whole window in the IPYNB editor
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#//*** Maximize columns and rows displayed by pandas
#pd.set_option('display.max_rows', 100)
#pd.set_option('display.max_columns', None)

import email
from email.policy import default
from email.parser import Parser

   

from chardet.universaldetector import UniversalDetector
from bs4 import BeautifulSoup
    
#//*** Quiet the BS4 warnings
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='bs4')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import ebooklib
from ebooklib import epub
from html.parser import HTMLParser

#book = epub.read_epub('./books/Moby-Dick-Herman-Melville.epub')
book = epub.read_epub('./books/pg25525.epub')

# %%
"""
import tensorflow.compat.v1 as tf 

tf.enable_eager_execution(tf.ConfigProto(log_device_placement=True)) 

print(tf.add([1.0, 2.0], [3.0, 4.0])) 
"""
print()

# %%
def parse_html_payload(payload):
    #from bs4 import BeautifulSoup
    
    #//*** Quiet the BS4 warnings
    #import warnings
    #warnings.filterwarnings("ignore", category=UserWarning, module='bs4')
    """
    This function uses Beautiful Soup to read HTML data
    and return the text.  If the payload is plain text, then
    Beautiful Soup will return the original content
    """
    soup = BeautifulSoup(payload, 'html.parser')
    #print(soup.find_all("p"))
    return str(soup.get_text()).encode('utf-8').decode('utf-8')
    #return soup
#//********************************************************
#//*** Plot a Fitted Models History of Loss and Accuracy
#//********************************************************
def plot_model_history(input_history):
    import matplotlib.pyplot as plt
    loss_key, acc_key = list(input_history.history.keys())[:2]
    

    acc = input_history.history[acc_key]
    loss = input_history.history[loss_key]

    
    epochs = range(1, len(loss) + 1)
    plt.plot(epochs, acc, "b", label="Training Accuracy")
    plt.title("Training Accuracy\nAccuracy should go up")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

    plt.plot(epochs, loss, "bo", label="Training Loss")
    
    plt.title("Training Loss \nLoss should go down")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

    #//*** Quit if only accuracy and Loss
    if len(list(input_history.history.keys())) == 2:
        return
    

    val_loss_key, val_acc_key = list(input_history.history.keys())[2:]
    
    val_loss = input_history.history[val_loss_key]
    val_acc = input_history.history[val_acc_key]

    plt.plot(epochs, loss, "bo", label="Training loss")
    plt.plot(epochs, val_loss, "b", label="Validation loss")
    plt.title("Training and validation loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()
    
    #//*** Plot the Validation Set Accuracy
    plt.clf()
    
    plt.plot(epochs, acc, "bo", label="Training accuracy")
    plt.plot(epochs, val_acc, "b", label="Validation accuracy")
    plt.title("Training and validation accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

# %%
raw_text = ""
for x in book.get_items():
    if x.get_type() == 9:
        raw_text += parse_html_payload(x.get_body_content())

print("Length Before Cleaning: ", len(raw_text))
#//*******************
#//*** Light cleaning
#//*******************
#//*** Manually remove all text before the first original Poe Story
raw_text = raw_text[raw_text.find("THE UNPARALLELED ADVENTURES OF ONE HANS PFAAL")+1:]    

#//*** Find the end of his collected works, this will remove all the copyright notices and additional comments
end_dex = raw_text.find("NOTES\nOf the many verses from time to time ascribed to the pen of Edgar Poe")
raw_text = raw_text[raw_text.find("THE UNPARALLELED ADVENTURES OF ONE HANS PFAAL"):end_dex]


#//*** Remove \xa0 spacing characters
while "\xa0" in raw_text:
    raw_text = raw_text.replace("\xa0","")
print("Length After Cleaning: ", len(raw_text))
# Out:
# Length Before Cleaning:  2592579
# Length After Cleaning:  2493812

# %%
#//*** Vectorize a corpus
class Vectorizer:
   
    def __init__(self,**kwargs):
        self.corpus_tokens = []
        self.corpus_ngrams = []

        self.max_tokens = None
        self.ngram_size = 1
        self.tidyup = True
        
        self.max_element_count = -1
        
        for key,value in kwargs.items():
            if key =="max_tokens":
                self.max_tokens = value
                
            if key == "ngrams":
                self.ngram_size = value
            
            if key == "tidyup":
                self.tidyup = value
        
        #//*** Load Regex Locally
        if 're' not in globals():
            print("Loading Regex: import re")
            import re
        
        self.re = re
        
        if 'datetime' not in globals():
            print("Loading Datetime: import datetime")
            import datetime
        self.datetime = datetime
        """
        if 'tf' not in globals():
            print("Loading tensorflow: import tensorflow as tf")
            import tensorflow.compat.v1 as tf 
        import tensorflow.compat.v1 as tf 
        self.tf = tf
        """        
        
        
        #//*** One Hot Encoding Dictionaries
        #//*** Key = Token Index, Value = Word
        self.ngram_index = {}
        
        #//*** Key = Word, Value = Token Index
        self.vocabulary_index = {}
        
    def tokenize(self,raw_text):
        
        #//*** Load Regex Locally
        re = self.re

            
        #//*** Initialize Output Tokens
        tokens = []

        #//*** Split Text into words
        for x in re.split("\s",raw_text):

            #//*** Findall Non text characters in each word
            non_text = re.findall("\W",x)

            #//*** Remove non_text Characters
            for i in non_text:
                x = x.replace(i,"")

            #//*** If X has length, append out
            if len(x) > 0:
                tokens.append(x.lower())
        return tokens
    
    #//*** Defaults to building ngrams from a list of lists
    #//*** input_type = "string" will process a single string for ngrams
    def build_ngrams(self,input_type="list"):
        if self.ngram_size <= 0:
            print("Ngram size must be an integer > 0")
            print("Quitting!")
            return None
        
        #//*** Using unigrams, use tokens
        if self.ngram_size == 1:
            self.corpus_ngrams = self.corpus_tokens
            return

        self.corpus_ngrams = []
        
        #//*** Get each token group from corpus_tokens
        for token in self.corpus_tokens:
            
            loop_ngram = []
            
            #//*** For a singular string we only run this once
            if input_type=='string':
                token = self.corpus_tokens
            
            
            
            #//*** Use an index based range to loop through tokens
            for x in range(0,len(token) ):

                #//*** Check if index + ngram_size exceeds the length of tokens
                if x+self.ngram_size <= len(token):

                    result = ""

                    #//*** Build the ngram
                    for y in range(self.ngram_size):
                        #print(self.tokens[x+y])
                        result += token[x+y] + " "

                    loop_ngram.append(result[:-1])

                else:
                    break
            
            #//*** Grab Token Element Count, Keep the greatest count value    
            if len(loop_ngram) > self.max_element_count:
                self.max_element_count = len(loop_ngram)
            
            
            #//*** Token group ngram is built. Add loop_ngram to corpus_ngram
            self.corpus_ngrams.append(loop_ngram)
            
            if input_type=='string':
                self.corpus_ngrams = loop_ngram
                break

    
    def build_vocabulary(self,corpus):
        self.tokens = []

        if isinstance(corpus,list) :
            print("Tokenizing List of Lists...")
            #//*** Tokenize each text entry in the corpus
            for raw_text in corpus:
                self.corpus_tokens.append(self.tokenize(raw_text))
                
            print("Building ngrams...type List")
            #//*** Build ngrams (Defaults to unigrams)
            self.build_ngrams()
        elif isinstance(corpus,str):
            print("Tokenizing String...")
            self.corpus_tokens = self.tokenize(corpus)
            print("Building ngrams...type string")
            #//*** Build ngrams (Defaults to unigrams)
            self.build_ngrams(input_type="string")
        else:
            print("Vectorizer required format is list or string!")
        
        word_freq = {}
        
        print("Building Vocabulary...")
        #//*** Build dictionary of unique words
        #//*** Loop through each element of the corpus
        for element in self.corpus_ngrams:
            
            if isinstance(corpus,str):
                element = self.corpus_ngrams
            
            #//*** Grab Token Element Count, Keep the greatest count value    
            if len(element) > self.max_element_count:
                self.max_element_count = len(element)
            
            #//*** Process each individual ngram
            for ngram in element:

                
                #//*** Add unique words to dictionaries
                if ngram not in self.vocabulary_index.keys():
                    index = len(self.ngram_index.values())
                    self.ngram_index[ index ] = ngram
                    self.vocabulary_index [ ngram ] = index
                    
                    #//*** Initialize Word Frequency
                    word_freq[ ngram ] = 1
                else:
                    #//*** Increment Word Frequency
                    word_freq[ ngram ] += 1
            
            if isinstance(corpus,str):
                break

       
        #//*** END for element in self.corpus_ngrams:
        if self.max_tokens != None:
            
            #//*** Check if token count exceeds max tokens
            if self.max_tokens < len(self.ngram_index.items()):
                
                print("Sorting Word Frequency...")
                #//*** Sort the Word Frequency Dictionary. Keep the highest frequency words
                word_freq = dict(sorted(word_freq.items(), key=lambda x: x[1], reverse=True))
                
                print("Building Token Dictionary")
                #//*** Get list of keys that are lowest frequency
                for key in list(word_freq.keys())[self.max_tokens:]:
                    #//*** Delete Low Frequency ngrams
                    del word_freq[ key ]
                
                self.ngram_index = {}
                self.vocabulary_index = {}
                
                print("Rebuilding Vocabulary")
                #//*** Rebuild ngram_index & vocabulary_index
                for ngram in word_freq.keys():
                    index = len(self.ngram_index.values())
                    self.ngram_index[ index ] = ngram
                    self.vocabulary_index [ ngram ] = index        
            
            #//*** END Trim Low Frequency ngrams
        self.word_freq = word_freq
       
    
    #//***
    def integer_encode(self,corpus):
        #//*** Encoded Results
        results = []
        
        #//*** Set the Max array size to the total number of items in self.ngram_index
        array_size = len(self.ngram_index.keys())
        
        datetime = self.datetime
        
        start_time = datetime.datetime.now()
        count = 0
        
        
        
        for element in corpus:
            #//*** hot encode each ngram
            result = []
            for ngram in element:
                
                #//*** Skip words not in self.vocabulary_index
                #//*** These are skipped due to max_tokens limitations
                if ngram not in self.vocabulary_index.keys():
                    continue    
                
                #//*** Get integer value of ngram from dictionary.
                #//*** Add to result
                result.append(self.vocabulary_index[ngram])
                

            #//*** END for ngram in tokens:
            
            #//*** result is a complete encoded element
            results.append( np.array(result).astype(np.float32) )
            
            count += 1
            
            
            
            #//*** Print a status update every 1000 items
            if count % 5000 == 0:
                print(f"{count} / {len(corpus)} Encoded: {datetime.datetime.now() - start_time}")
        
        print(f"Encoding Complete: {datetime.datetime.now() - start_time}")
        
        #//*** results is a collection of encoded elements
        return np.array(results,dtype=object)
    
    
    def encode(self,corpus,encoding='int'):
        
        if not isinstance(corpus,list) :
            print("Vectorizer Requires a corpus (list of text):")
            return None

        self.corpus_tokens = []
        self.corpus_ngrams = []
        print("Tokenizing...")
        #//*** Tokenize each text entry in the corpus
        for raw_text in corpus:
            self.corpus_tokens.append(self.tokenize(raw_text))
        
        print("Building ngrams...")
        #//*** Build ngrams (Defaults to unigrams)
        self.build_ngrams()
        
        if encoding == 'onehot':
            print("One Hot Coding....")

            #//*** One Hot Encode Values. These are actually sparse tensors for speed.
            encoded = self.one_hot_encode(self.corpus_ngrams)
   
        if encoding == 'int':
            print("Interger encoding....")

            #//*** Convert ngrams to integers. These are actually sparse tensors for speed.
            encoded = self.integer_encode(self.corpus_ngrams)
            
            #//*** Convert lists to Numpy array of float 32 type. This is the expected structure for Keras
            #encoded = np.asarray(encoded).astype('float32')
            
        #//*** TidyUp (Delete) ngrams and Tokens
        if self.tidyup:
            self.corpus_tokens = []
            self.corpus_ngrams = []
        
        return encoded


    #//*** Convert One-Hot-Encoding to text
    def decode(self,elements):
        
        results = []
        
        #//*** For Each element in Corpus
            
        decoded = ""

        #//*** For Each ngram (word(s)) in Elements
        for ngram in elements:

            #//*** Grab Index of 1 from sparse tensor
            index = ngram.indices[0].numpy()[1]
            
            #ngram = list(ngram.numpy())

            decoded += self.ngram_index[ index ] + " "

        #//*** END for ngram in elements:
        results.append( decoded[:-1])
        
    #//*** One Hot encode the corpus.
    #//*** Handling the corpus as a whole increases processing speed
    #//*** Hot encode to a sparse tensor to for increased encoding speed compared to a dense array
    #//*** S
    def one_hot_encode(self,corpus,targets,phrase_size):
        
        #//*** Encoded Results
        results = []
        
        #//*** Set the Max array size to the total number of items in self.ngram_index
        array_size = len(self.ngram_index.keys())
        
        datetime = self.datetime
 
        start_time = datetime.datetime.now()
        count = 0
        print( len(corpus), phrase_size, len(self.vocabulary_index.keys()) )
        
        #//*** Build 3 Dimensional Array for LSTM
        x = np.zeros( (len(corpus), phrase_size, len(self.vocabulary_index.keys() ) ), dtype=bool )
        y = np.zeros( (len(corpus), len(self.vocabulary_index.keys())), dtype=bool )
        print(x.shape)
        
        #//*** Loop through the corpus, i = index of first dimension of each element
        for i, element in enumerate(corpus):
            
            
            #//*** Loop through each ngram
            for t, ngram, in enumerate(element):
                
                #//*** Print this to help make sense of the loop
                #print(i, t, element, ngram, self.vocabulary_index[ngram])
               
                #//*** row, element, ngram
                #//*** Corpus / Training
                x[ i, t, self.vocabulary_index[ngram] ] = 1
            
            #//*** Print this to help make sense of the loop   
            #print("y = ", i, targets[i], self.vocabulary_index[ targets[i] ])         
            
            #//*** y = 2D array. i == row, and index of the target value
            y[ i, self.vocabulary_index[ targets[i] ] ] = 1
            
            count += 1
            
            #//*** Print a status update every 1000 items
            if count % 10000 == 0:
                print(f"{count} / {len(corpus)} Encoded: {datetime.datetime.now() - start_time}")

        #//*** Tensorflow is attached as a local variable
        #tf = self.tf  
        """
        for element in corpus:
            #//*** hot encode each ngram
            indexes = []
            values = []
            dense_shape =  [ len(element),len(self.vocabulary_index.keys()) ]
            
            #//*** Build the indexes for the sparse tensor. 
            #//*** This is the row, and the index of the ngram
            
            #//*** values are always 1. We could get clever and build this once. But we'll just add a one each time we build an index
            for row,ngram in enumerate(element):
                
                #//*** Skip words not in self.vocabulary_index
                #//*** These are skipped due to max_tokens limitations
                if ngram not in self.vocabulary_index.keys():
                    continue

                
                #//*** Add the one-hot-encoded word to encoded text
                indexes.append( [ row,self.vocabulary_index[ngram] ] )
                values.append(1)

            #//*** END for ngram in tokens:
            
            #print(dense_shape, len(element), len(indexes), len(values))
            
            #//*** No items in the dictionary to process. Skip this element
            if len(indexes) == 0:
                continue
            #//*** Build Sparse Tensor
            #sparse_tensor = tf.SparseTensor(indices=indexes,values=values,dense_shape=dense_shape)
            
            results.append(sparse_tensor)
            
            count += 1
            
            #print(sparse_tensor)
            
            #//*** Print a status update every 1000 items
            if count % 10000 == 0:
                print(f"{count} / {len(corpus)} Encoded: {datetime.datetime.now() - start_time}")
        """
        print(f"Encoding Complete: {datetime.datetime.now() - start_time}")
        
        return x,y
            
    #//*** Use corpus for text prediction
    #//*** Convert Corpus to string if neccessary
    #//*** Tokenize & ngram
    def encode_words_for_text_prediction(self,corpus,phrase_size=10,step=3):
        
        big_text = ""
        if isinstance(corpus,list) :
            print("Vectorizer compressing list into string")
            
            for text in corpus:
                big_text += "".join(text)
            
            corpus = big_text

        self.corpus_tokens = []
        self.corpus_ngrams = []
        
        self.corpus_tokens = self.tokenize(corpus)
        self.build_ngrams(input_type="string")

        #//*** use ngrams that are on in vocabulary
        self.vocabulary_ngrams = []
        
        
        for ngram in self.corpus_ngrams:
            if ngram in self.vocabulary_index.keys():
                self.vocabulary_ngrams.append(ngram)
                
        print("Total ngram Count:",len(self.corpus_ngrams))
        print("Max Token ngrams for modeling:",len(self.vocabulary_ngrams))
          
        train = []
        targets = []
        
        for i in range(0, len(self.vocabulary_ngrams) - phrase_size, step):
            #//*** Assign training words.
            #//*** Range of Phase size in increments of step
            train.append( self.vocabulary_ngrams[i:i+phrase_size] )
            
            #//*** Build target word, which is the word following the training words
            #//*** If Unigram, keep the whole phrase
            
                
            targets.append(self.vocabulary_ngrams[i+phrase_size])
            
        
        return self.one_hot_encode(train,targets,phrase_size=phrase_size)
        
sample_text = raw_text[:int(len(raw_text)*1)]
max_tokens = 10000
phrase_size = 10
step = int(phrase_size *.3)

if step <= 0:
    step = 1
print("Step: ", step)
ngrams=1
#//*** Test the Vectorizer with some sample data
vectorizer = Vectorizer(max_tokens=max_tokens,ngrams=ngrams, tidyup=False)

vectorizer.build_vocabulary(sample_text)   
print(len(vectorizer.corpus_tokens),len(vectorizer.corpus_ngrams))
#hot_vals = vectorizer.encode(raw_email[:100],encoding='onehot')
train,targets = vectorizer.encode_words_for_text_prediction(sample_text,phrase_size=phrase_size,step=step)

print(train.shape)
print(targets.shape)
# Out:
# Step:  3
# Loading Regex: import re
# Loading Datetime: import datetime
# Tokenizing String...
# Building ngrams...type string
# Building Vocabulary...
# Sorting Word Frequency...
# Building Token Dictionary
# Rebuilding Vocabulary
# 434094 434094
# Total ngram Count: 434094
# Max Token ngrams for modeling: 411328
# 137106 10 10000
# (137106, 10, 10000)
# 10000 / 137106 Encoded: 0:00:00.154530
# 20000 / 137106 Encoded: 0:00:00.295986
# 30000 / 137106 Encoded: 0:00:00.427167
# 40000 / 137106 Encoded: 0:00:00.561383
# 50000 / 137106 Encoded: 0:00:00.692743
# 60000 / 137106 Encoded: 0:00:00.825136
# 70000 / 137106 Encoded: 0:00:00.969326
# 80000 / 137106 Encoded: 0:00:01.108897
# 90000 / 137106 Encoded: 0:00:01.250343
# 100000 / 137106 Encoded: 0:00:01.383364
# 110000 / 137106 Encoded: 0:00:01.524660
# 120000 / 137106 Encoded: 0:00:01.656501
# 130000 / 137106 Encoded: 0:00:01.799996
# Encoding Complete: 0:00:01.901516
# (137106, 10, 10000)
# (137106, 10000)

# %%
print(train.shape)
print(targets.shape)
print(len(targets))

import keras
from keras import layers
from keras.layers import Dropout
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(phrase_size, max_tokens)))
model.add(Dropout(0.1))
model.add(layers.Dense(max_tokens, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer="rmsprop",metrics=["accuracy"])
              
model.summary()

#model.fit(train, targets, batch_size=128, epochs=1)
# Out:
# (137106, 10, 10000)
# (137106, 10000)
# 137106
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 128)               5186048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10000)             1290000
# =================================================================
# Total params: 6,476,048
# Trainable params: 6,476,048
# Non-trainable params: 0
# _________________________________________________________________

# %%
#//*** 100% Text, 10000 Tokens, size=10, step=.3 size, ngram=1
results = model.fit(train, targets, batch_size=128, epochs=100)

plot_model_history(results)
# Out:
# Epoch 1/100
# 1072/1072 [==============================] - 184s 171ms/step - loss: 6.5953 - accuracy: 0.0846
# Epoch 2/100
# 1072/1072 [==============================] - 186s 174ms/step - loss: 6.3132 - accuracy: 0.1044
# Epoch 3/100
# 1072/1072 [==============================] - 187s 174ms/step - loss: 6.1513 - accuracy: 0.1216
# Epoch 4/100
# 1072/1072 [==============================] - 186s 174ms/step - loss: 6.0405 - accuracy: 0.1329
# Epoch 5/100
# 1072/1072 [==============================] - 187s 174ms/step - loss: 5.9463 - accuracy: 0.1420
# Epoch 6/100
# 1072/1072 [==============================] - 187s 174ms/step - loss: 5.8565 - accuracy: 0.1514
# Epoch 7/100
# 1072/1072 [==============================] - 186s 174ms/step - loss: 5.7698 - accuracy: 0.1608
# Epoch 8/100
# 1072/1072 [==============================] - 194s 181ms/step - loss: 5.6900 - accuracy: 0.1696
# Epoch 9/100
# 1072/1072 [==============================] - 194s 181ms/step - loss: 5.6150 - accuracy: 0.1792
# Epoch 10/100
# 1072/1072 [==============================] - 193s 180ms/step - loss: 5.5506 - accuracy: 0.1893
# Epoch 11/100
# 1072/1072 [==============================] - 192s 179ms/step - loss: 5.5251 - accuracy: 0.1990
# Epoch 12/100
# 1072/1072 [==============================] - 190s 178ms/step - loss: 5.6100 - accuracy: 0.2117
# Epoch 13/100
# 1072/1072 [==============================] - 188s 175ms/step - loss: 5.7432 - accuracy: 0.2229
# Epoch 14/100
# 1072/1072 [==============================] - 188s 175ms/step - loss: 5.8184 - accuracy: 0.2340
# Epoch 15/100
# 1072/1072 [==============================] - 188s 175ms/step - loss: 5.8215 - accuracy: 0.2446
# Epoch 16/100
# 1072/1072 [==============================] - 188s 175ms/step - loss: 5.7867 - accuracy: 0.2561
# Epoch 17/100
# 1072/1072 [==============================] - 188s 175ms/step - loss: 5.7218 - accuracy: 0.2698
# Epoch 18/100
# 1072/1072 [==============================] - 188s 176ms/step - loss: 5.6533 - accuracy: 0.2817
# Epoch 19/100
# 1072/1072 [==============================] - 189s 177ms/step - loss: 5.5791 - accuracy: 0.2939
# Epoch 20/100
# 1072/1072 [==============================] - 188s 175ms/step - loss: 5.5087 - accuracy: 0.3065
# Epoch 21/100
# 1072/1072 [==============================] - 189s 177ms/step - loss: 5.4387 - accuracy: 0.3186
# Epoch 22/100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 5.3691 - accuracy: 0.3299
# Epoch 23/100
# 1072/1072 [==============================] - 188s 176ms/step - loss: 5.3073 - accuracy: 0.3418
# Epoch 24/100
# 1072/1072 [==============================] - 188s 175ms/step - loss: 5.2505 - accuracy: 0.3531
# Epoch 25/100
# 1072/1072 [==============================] - 188s 176ms/step - loss:
100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 3.9355 - accuracy: 0.5879
# Epoch 78/100
# 1072/1072 [==============================] - 189s 177ms/step - loss: 3.9269 - accuracy: 0.5905
# Epoch 79/100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 3.9146 - accuracy: 0.5914
# Epoch 80/100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 3.9023 - accuracy: 0.5926
# Epoch 81/100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 3.8882 - accuracy: 0.5946
# Epoch 82/100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 3.8747 - accuracy: 0.5965
# Epoch 83/100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 3.8622 - accuracy: 0.5978
# Epoch 84/100
# 1072/1072 [==============================] - 193s 180ms/step - loss: 3.8468 - accuracy: 0.5999
# Epoch 85/100
# 1072/1072 [==============================] - 195s 182ms/step - loss: 3.8357 - accuracy: 0.5994
# Epoch 86/100
# 1072/1072 [==============================] - 188s 176ms/step - loss: 3.8240 - accuracy: 0.5999
# Epoch 87/100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 3.8135 - accuracy: 0.6015
# Epoch 88/100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 3.8070 - accuracy: 0.6029
# Epoch 89/100
# 1072/1072 [==============================] - 188s 176ms/step - loss: 3.7996 - accuracy: 0.6039
# Epoch 90/100
# 1072/1072 [==============================] - 188s 176ms/step - loss: 3.7899 - accuracy: 0.6054
# Epoch 91/100
# 1072/1072 [==============================] - 188s 176ms/step - loss: 3.7814 - accuracy: 0.6058
# Epoch 92/100
# 1072/1072 [==============================] - 188s 176ms/step - loss: 3.7688 - accuracy: 0.6087
# Epoch 93/100
# 1072/1072 [==============================] - 188s 176ms/step - loss: 3.7596 - accuracy: 0.6102
# Epoch 94/100
# 1072/1072 [==============================] - 188s 176ms/step - loss: 3.7514 - accuracy: 0.6105
# Epoch 95/100
# 1072/1072 [==============================] - 188s 176ms/step - loss: 3.7443 - accuracy: 0.6102
# Epoch 96/100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 3.7344 - accuracy: 0.6123
# Epoch 97/100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 3.7262 - accuracy: 0.6126
# Epoch 98/100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 3.7189 - accuracy: 0.6128 - l - ETA: 2s - loss:
# Epoch 99/100
# 1072/1072 [==============================] - 189s 176ms/step - loss: 3.7144 - accuracy: 0.6148
# Epoch 100/100
# 1072/1072 [==============================] - 188s 176ms/step - loss: 3.7084 - accuracy: 0.6160

# %%
import pickle

filename = f"./results/model_EdgarAllenPoe_Words_T{max_tokens}_PS{phrase_size}_S{step}_({len(sample_text)})"

#//*** Save The Model
from keras.models import load_model
model.save(f"{filename}.h5")

#//*** Save dictionaries parameters and ngrams
pickle_collection = {

    "vocabulary_ngrams" : vectorizer.vocabulary_ngrams,
    
    "vocabulary_index" : vectorizer.vocabulary_index,
    
    "history" : results.history,

    "params" : {
        "max_tokens" : max_tokens,
        "phrase_size":phrase_size,
        "step" : step,
    },
    "ngrams" : vectorizer.corpus_ngrams,
    "sample_text" : sample_text,
    
}

with open(f"{filename}.pkl",'wb') as f:
    pickle.dump(pickle_collection, f)
    
#print(filename)
#print("Done")

# %%
t =

# %%
#//*** 50% Text, 1000 Tokens, size=10, step=.3 size, ngram=1
results = model.fit(train, targets, batch_size=128, epochs=100)

plot_model_history(results)
# Out:
# Epoch 1/100
# 436/436 [==============================] - 13s 26ms/step - loss: 5.3599 - accuracy: 0.1003
# Epoch 2/100
# 436/436 [==============================] - 11s 26ms/step - loss: 5.1740 - accuracy: 0.1271
# Epoch 3/100
# 436/436 [==============================] - 11s 26ms/step - loss: 5.0174 - accuracy: 0.1454
# Epoch 4/100
# 436/436 [==============================] - 12s 29ms/step - loss: 4.8998 - accuracy: 0.1617
# Epoch 5/100
# 436/436 [==============================] - 12s 29ms/step - loss: 4.8173 - accuracy: 0.1708
# Epoch 6/100
# 436/436 [==============================] - 12s 29ms/step - loss: 4.7508 - accuracy: 0.1773
# Epoch 7/100
# 436/436 [==============================] - 12s 28ms/step - loss: 4.6931 - accuracy: 0.1833
# Epoch 8/100
# 436/436 [==============================] - 12s 29ms/step - loss: 4.6398 - accuracy: 0.1898
# Epoch 9/100
# 436/436 [==============================] - 13s 29ms/step - loss: 4.5891 - accuracy: 0.1938
# Epoch 10/100
# 436/436 [==============================] - 13s 29ms/step - loss: 4.5404 - accuracy: 0.1985
# Epoch 11/100
# 436/436 [==============================] - 12s 29ms/step - loss: 4.4917 - accuracy: 0.2040
# Epoch 12/100
# 436/436 [==============================] - 12s 29ms/step - loss: 4.4445 - accuracy: 0.2087
# Epoch 13/100
# 436/436 [==============================] - 13s 29ms/step - loss: 4.3972 - accuracy: 0.2147
# Epoch 14/100
# 436/436 [==============================] - 13s 29ms/step - loss: 4.3511 - accuracy: 0.2188
# Epoch 15/100
# 436/436 [==============================] - 12s 29ms/step - loss: 4.3034 - accuracy: 0.2245
# Epoch 16/100
# 436/436 [==============================] - 12s 29ms/step - loss: 4.2553 - accuracy: 0.2286
# Epoch 17/100
# 436/436 [==============================] - 12s 29ms/step - loss: 4.2072 - accuracy: 0.2352
# Epoch 18/100
# 436/436 [==============================] - 13s 29ms/step - loss: 4.1552 - accuracy: 0.2416
# Epoch 19/100
# 436/436 [==============================] - 12s 29ms/step - loss: 4.1042 - accuracy: 0.2472
# Epoch 20/100
# 436/436 [==============================] - 13s 29ms/step - loss: 4.0515 - accuracy: 0.2547
# Epoch 21/100
# 436/436 [==============================] - 12s 28ms/step - loss: 3.9965 - accuracy: 0.2614
# Epoch 22/100
# 436/436 [==============================] - 12s 29ms/step - loss: 3.9463 - accuracy: 0.2693
# Epoch 23/100
# 436/436 [==============================] - 13s 29ms/step - loss: 3.8935 - accuracy: 0.2753
# Epoch 24/100
# 436/436 [==============================] - 12s 29ms/step - loss: 3.8451 - accuracy: 0.2824
# Epoch 25/100
# 436/436 [==============================] - 12s 29ms/step - loss: 3.7908 - accuracy: 0.2907
# Epoch 26/100
# 436/436 [==============================] - 12s 28ms/step - loss: 3.7400 - accuracy: 0.2978
# Epoch 27/100
# 436/436 [==============================] - 12s 29ms/step - loss: 3.6931 - accuracy: 0.3073
# Epoch 28/100
# 436/436 [==============================] - 13s 29ms/step - loss: 3.6430 - accuracy: 0.3136
# Epoch 29/100
# 436/436 [==============================] - 12s 29ms/step - loss: 3.5950 - accuracy: 0.3237
# Epoch 30/100
# 436/436 [==============================] - 12s 29ms/step - loss: 3.5444 - accuracy: 0.3320
# Epoch 31/100
# 436/436 [==============================] - 12s 29ms/step - loss: 3.4995 - accuracy: 0.3379
# Epoch 32/100
# 436/436 [==============================] - 13s 29ms/step - loss: 3.4544 - accuracy: 0.3462
# Epoch 33/100
# 436/436 [==============================] - 13s 29ms/step - loss: 3.4107 - accuracy: 0.3550
# Epoch 34/100
# 436/436 [==============================] - 13s 29ms/step - loss: 3.3720 - accuracy: 0.3618
# Epoch 35/100
# 436/436 [==============================] - 12s 29ms/step - loss: 3.3274 - accuracy: 0.3706
# Epoch 36/100
# 436/436 [==============================] - 13s 29ms/step - loss: 3.2864 - accuracy: 0.3811
# Epoch 37/100
# 436/436 [==============================] - 13s 29ms/step - loss: 3.2482 - accuracy: 0.3863
# Epoch 38/100
# 436/436 [==============================] - 12s 29ms/step - loss: 3.2068 - accuracy: 0.3957
# Epoch 39/100
# 436/436 [==============================] - 13s 29ms/step - loss: 3.1699 - accuracy: 0.4027
# Epoch 40/100
# 436/436 [==============================] - 12s 29ms/step - loss: 3.1298 - accuracy: 0.4128
# Epoch 41/100
# 436/436 [==============================] - 13s 29ms/step - loss: 3.0960 - accuracy: 0.4198
# Epoch 42/100
# 436/436 [==============================] - 13s 29ms/step - loss: 3.0570 - accuracy: 0.4279
# Epoch 43/100
# 436/436 [==============================] - 13s 30ms/step - loss: 3.0219 - accuracy: 0.4354
# Epoch 44/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.9909 - accuracy: 0.4412
# Epoch 45/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.9571 - accuracy: 0.4495
# Epoch 46/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.9244 - accuracy: 0.4572
# Epoch 47/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.8971 - accuracy: 0.4637
# Epoch 48/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.8637 - accuracy: 0.4718
# Epoch 49/100
# 436/436 [==============================] - 12s 29ms/step - loss: 2.8305 - accuracy: 0.4791
# Epoch 50/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.7964 - accuracy: 0.4856
# Epoch 51/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.7646 - accuracy: 0.4929
# Epoch 52/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.7399 - accuracy: 0.4977
# Epoch 53/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.7011 - accuracy: 0.5058
# Epoch 54/100
# 436/436 [==============================] - 12s 29ms/step - loss: 2.6786 - accuracy: 0.5106
# Epoch 55/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.6436 - accuracy: 0.5178
# Epoch 56/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.6140 - accuracy: 0.5239
# Epoch 57/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.5881 - accuracy: 0.5307
# Epoch 58/100
# 436/436 [==============================] - 12s 29ms/step - loss: 2.5606 - accuracy: 0.5367
# Epoch 59/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.5326 - accuracy: 0.5441
# Epoch 60/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.5051 - accuracy: 0.5499
# Epoch 61/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.4805 - accuracy: 0.5553
# Epoch 62/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.4496 - accuracy: 0.5627
# Epoch 63/100
# 436/436 [==============================] - 12s 29ms/step - loss: 2.4240 - accuracy: 0.5676
# Epoch 64/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.3969 - accuracy: 0.5725
# Epoch 65/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.3740 - accuracy: 0.5783
# Epoch 66/100
# 436/436 [==============================] - 13s 29ms/step - loss: 2.3541 - accuracy: 0.5829
# Epoch 67/100
# 436/436 [==============================] - 12s 28ms/step - loss: 2.3254 - accuracy: 0.5900
# Epoch 68/100
# 436/436 [==============================] - 12s 29ms/step - loss: 2
100
# 218/218 [==============================] - 11s 50ms/step - loss: 2.0709 - accuracy: 0.6171
# Epoch 57/100
# 218/218 [==============================] - 11s 51ms/step - loss: 2.0417 - accuracy: 0.6224
# Epoch 58/100
# 218/218 [==============================] - 11s 50ms/step - loss: 2.0127 - accuracy: 0.6287
# Epoch 59/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.9756 - accuracy: 0.6395
# Epoch 60/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.9502 - accuracy: 0.6420
# Epoch 61/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.9218 - accuracy: 0.6473
# Epoch 62/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.8946 - accuracy: 0.6551
# Epoch 63/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.8635 - accuracy: 0.6596
# Epoch 64/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.8425 - accuracy: 0.66500s - loss: 1.8388 - ac
# Epoch 65/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.8115 - accuracy: 0.67370s - loss:
# Epoch 66/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.7917 - accuracy: 0.6785
# Epoch 67/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.7586 - accuracy: 0.6842
# Epoch 68/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.7393 - accuracy: 0.6900
# Epoch 69/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.7154 - accuracy: 0.6927
# Epoch 70/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.6882 - accuracy: 0.6980
# Epoch 71/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.6629 - accuracy: 0.7027
# Epoch 72/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.6436 - accuracy: 0.7098
# Epoch 73/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.6219 - accuracy: 0.7135
# Epoch 74/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.6036 - accuracy: 0.7167
# Epoch 75/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.5797 - accuracy: 0.7226
# Epoch 76/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.5570 - accuracy: 0.7281
# Epoch 77/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.5338 - accuracy: 0.7327
# Epoch 78/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.5198 - accuracy: 0.7339
# Epoch 79/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.4938 - accuracy: 0.7412
# Epoch 80/100
# 218/218 [==============================] - 12s 53ms/step - loss: 1.4741 - accuracy: 0.7477
# Epoch 81/100
# 218/218 [==============================] - 12s 53ms/step - loss: 1.4617 - accuracy: 0.7484
# Epoch 82/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.4388 - accuracy: 0.7535
# Epoch 83/100
# 218/218 [==============================] - 11s 52ms/step - loss: 1.4222 - accuracy: 0.7545
# Epoch 84/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.4023 - accuracy: 0.7612
# Epoch 85/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.3879 - accuracy: 0.7641
# Epoch 86/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.3638 - accuracy: 0.7681
# Epoch 87/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.3499 - accuracy: 0.7701
# Epoch 88/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.3392 - accuracy: 0.7753
# Epoch 89/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.3230 - accuracy: 0.7789
# Epoch 90/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.3068 - accuracy: 0.7805
# Epoch 91/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.2893 - accuracy: 0.7843
# Epoch 92/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.2824 - accuracy: 0.7854
# Epoch 93/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.2637 - accuracy: 0.7893
# Epoch 94/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.2478 - accuracy: 0.7940
# Epoch 95/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.2364 - accuracy: 0.7974
# Epoch 96/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.2202 - accuracy: 0.7983
# Epoch 97/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.2041 - accuracy: 0.8020
# Epoch 98/100
# 218/218 [==============================] - 11s 50ms/step - loss: 1.1955 - accuracy: 0.8024
# Epoch 99/100
# 218/218 [==============================] - 11s 51ms/step - loss: 1.1865 - accuracy: 0.8060
# Epoch 100/100
# 218/218 [==============================] - 12s 53ms/step - loss: 1.1654 - accuracy: 0.8109

# %%
plot_model_history(results)

# %%
#//*** 50% Text, 1000 Tokens, size=10, step=.3 size, ngram=1
results = model.fit(train, targets, batch_size=128, epochs=100)
# Out:
# Epoch 1/100
# 436/436 [==============================] - 13s 26ms/step - loss: 5.3575 - accuracy: 0.1005
# Epoch 2/100
# 436/436 [==============================] - 11s 26ms/step - loss: 5.1815 - accuracy: 0.1238
# Epoch 3/100
# 436/436 [==============================] - 12s 27ms/step - loss: 5.0204 - accuracy: 0.1441
# Epoch 4/100
# 436/436 [==============================] - 13s 29ms/step - loss: 4.9041 - accuracy: 0.1619
# Epoch 5/100
# 436/436 [==============================] - 12s 29ms/step - loss: 4
100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.5976 - accuracy: 0.1901
# Epoch 9/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.5736 - accuracy: 0.1921
# Epoch 10/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.5495 - accuracy: 0.1943
# Epoch 11/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.5251 - accuracy: 0.1964
# Epoch 12/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.5031 - accuracy: 0.1980
# Epoch 13/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.4836 - accuracy: 0.1990
# Epoch 14/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 4.4647 - accuracy: 0.2002
# Epoch 15/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 4.4569 - accuracy: 0.2017
# Epoch 16/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.4517 - accuracy: 0.2024
# Epoch 17/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.4463 - accuracy: 0.2034
# Epoch 18/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.4509 - accuracy: 0.2050
# Epoch 19/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 4.4496 - accuracy: 0.2056
# Epoch 20/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.4440 - accuracy: 0.2068
# Epoch 21/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.4328 - accuracy: 0.2082
# Epoch 22/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.4187 - accuracy: 0.2097
# Epoch 23/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.4074 - accuracy: 0.2115
# Epoch 24/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.3934 - accuracy: 0.2129
# Epoch 25/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.3798 - accuracy: 0.2142
# Epoch 26/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.3670 - accuracy: 0.2153
# Epoch 27/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.3564 - accuracy: 0.2170
# Epoch 28/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.3427 - accuracy: 0.2178
# Epoch 29/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.3289 - accuracy: 0.2193
# Epoch 30/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.3189 - accuracy: 0.2208
# Epoch 31/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.3079 - accuracy: 0.2223
# Epoch 32/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.2983 - accuracy: 0.2242
# Epoch 33/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.2878 - accuracy: 0.2255
# Epoch 34/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.2776 - accuracy: 0.2273
# Epoch 35/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.2677 - accuracy: 0.2287
# Epoch 36/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.2576 - accuracy: 0.2297
# Epoch 37/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.2459 - accuracy: 0.2313
# Epoch 38/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.2343 - accuracy: 0.2332
# Epoch 39/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.2280 - accuracy: 0.2348
# Epoch 40/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.2160 - accuracy: 0.2358
# Epoch 41/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.2069 - accuracy: 0.2374
# Epoch 42/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.1981 - accuracy: 0.2377
# Epoch 43/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.1871 - accuracy: 0.2404
# Epoch 44/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 4.1781 - accuracy: 0.2421
# Epoch 45/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.1674 - accuracy: 0.2430
# Epoch 46/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.1566 - accuracy: 0.2449
# Epoch 47/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.1487 - accuracy: 0.2459
# Epoch 48/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.1405 - accuracy: 0.2479
# Epoch 49/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.1296 - accuracy: 0.2497
# Epoch 50/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 4.1234 - accuracy: 0.2514
# Epoch 51/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 4.1135 - accuracy: 0.2521
# Epoch 52/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 4.1026 - accuracy: 0.2540
# Epoch 53/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 4.0959 - accuracy: 0.2556
# Epoch 54/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.0869 - accuracy: 0.2570
# Epoch 55/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.0759 - accuracy: 0.2583
# Epoch 56/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.0677 - accuracy: 0.2599
# Epoch 57/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 4.0617 - accuracy: 0.2611
# Epoch 58/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.0519 - accuracy: 0.2620
# Epoch 59/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.0421 - accuracy: 0.2635
# Epoch 60/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 4.0347 - accuracy: 0.2654
# Epoch 61/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 4.0256 - accuracy: 0.2662
# Epoch 62/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 4.0190 - accuracy: 0.2680
# Epoch 63/100
# 1308/1308 [==============================] - 15s 12ms/step - loss: 4.0085 - accuracy: 0.2697
# Epoch 64/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 4.0017 - accuracy: 0.2710
# Epoch 65/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 3.9937 - accuracy: 0.2722
# Epoch 66/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.9861 - accuracy: 0.2734
# Epoch 67/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.9787 - accuracy: 0.2755
# Epoch 68/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 3.9710 - accuracy: 0.2763
# Epoch 69/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.9659 - accuracy: 0.2775
# Epoch 70/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.9590 - accuracy: 0.2786
# Epoch 71/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.9509 - accuracy: 0.2801
# Epoch 72/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.9451 - accuracy: 0.2811
# Epoch 73/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.9371 - accuracy: 0.2838
# Epoch 74/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.9289 - accuracy: 0.2845
# Epoch 75/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.9233 - accuracy: 0.2852
# Epoch 76/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.9147 - accuracy: 0.2860
# Epoch 77/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.9093 - accuracy: 0.2876
# Epoch 78/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.9033 - accuracy: 0.2891
# Epoch 79/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8966 - accuracy: 0.2909
# Epoch 80/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8898 - accuracy: 0.2914
# Epoch 81/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8860 - accuracy: 0.2925
# Epoch 82/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8797 - accuracy: 0.2929
# Epoch 83/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8739 - accuracy: 0.2958
# Epoch 84/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8650 - accuracy: 0.2969
# Epoch 85/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8583 - accuracy: 0.2987
# Epoch 86/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 3.8533 - accuracy: 0.2989
# Epoch 87/100
# 1308/1308 [==============================] - 15s 11ms/step - loss: 3.8459 - accuracy: 0.3005
# Epoch 88/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8435 - accuracy: 0.3011
# Epoch 89/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8342 - accuracy: 0.3026
# Epoch 90/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8306 - accuracy: 0.3030
# Epoch 91/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8253 - accuracy: 0.3046
# Epoch 92/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8186 - accuracy: 0.3055
# Epoch 93/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8142 - accuracy: 0.3064
# Epoch 94/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8097 - accuracy: 0.3073
# Epoch 95/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.8018 - accuracy: 0.3089
# Epoch 96/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.7942 - accuracy: 0.3092
# Epoch 97/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.7914 - accuracy: 0.3103
# Epoch 98/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.7867 - accuracy: 0.3110
# Epoch 99/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.7806 - accuracy: 0.3121
# Epoch 100/100
# 1308/1308 [==============================] - 14s 11ms/step - loss: 3.7759 - accuracy: 0.3134

# %%
#//*** 50% Text, 1000 Tokens, size=3, step=.3 size, ngram=1
results = model.fit(train, targets, batch_size=128, epochs=10)
# Out:
# Epoch 1/10
# 1308/1308 [==============================] - 27s 20ms/step - loss: 5.2741 - accuracy: 0.1136
# Epoch 2/10
# 1308/1308 [==============================] - 25s 19ms/step - loss: 4.9315 - accuracy: 0.1575
# Epoch 3/10
# 1308/1308 [==============================] - 25s 19ms/step - loss: 4.8016 - accuracy: 0.1712
# Epoch 4/10
# 1308/1308 [==============================] - 25s 19ms/step - loss: 4.7345 - accuracy: 0.1774
# Epoch 5/10
# 1308/1308 [==============================] - 25s 19ms/step - loss: 4.6918 - accuracy: 0.1824
# Epoch 6/10
# 1308/1308 [==============================] - 25s 19ms/step - loss: 4.6561 - accuracy: 0.1853
# Epoch 7/10
# 1308/1308 [==============================] - 25s 19ms/step - loss: 4.6282 - accuracy: 0.1881
# Epoch 8/10
# 1308/1308 [==============================] - 25s 19ms/step - loss: 4.5979 - accuracy: 0.1909
# Epoch 9/10
# 1308/1308 [==============================] - 25s 19ms/step - loss: 4.5685 - accuracy: 0.1938
# Epoch 10/10
# 1308/1308 [==============================] - 26s 20ms/step - loss: 4.5406 - accuracy: 0.1945

# %%
#//*** 50% Text, 1000 Tokens, size=5, step=5, ngram=1
results = model.fit(train, targets, batch_size=128, epochs=10)
# Out:
# Epoch 1/10
#
# 262/262 [==============================] - 11s 41ms/step - loss: 4.9197 - accuracy: 0.1565
# Epoch 7/10
# 262/262 [==============================] - 11s 41ms/step - loss: 4.8506 - accuracy: 0.1637
# Epoch 8/10
# 262/262 [==============================] - 11s 41ms/step - loss: 4.7884 - accuracy: 0.1713
# Epoch 9/10
# 262/262 [==============================] - 11s 41ms/step - loss: 4.7291 - accuracy: 0.1762
# Epoch 10/10
# 262/262 [==============================] - 11s 41ms/step - loss: 4.6726 - accuracy: 0.1817

# %%
#//*** 50% Text, 1000 Tokens, size=10, step=3, ngram=1
results = model.fit(train, targets, batch_size=128, epochs=5)
# Out:
# Epoch 1/5
# 436/436 [==============================] - 20s 42ms/step - loss: 5.3558 - accuracy: 0.1017
# Epoch 2/5
# 436/436 [==============================] - 19s 44ms/step - loss: 5.1635 - accuracy: 0.1286
# Epoch 3/5
# 436/436 [==============================] - 18s 42ms/step - loss: 5.0050 - accuracy: 0.1467
# Epoch 4/5
# 436/436 [==============================] - 18s 41ms/step - loss: 4.8938 - accuracy: 0.1624
# Epoch 5/5
# 436/436 [==============================] - 18s 41ms/step - loss: 4.8121 - accuracy: 0.1709

# %%
import random 

def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

print(len(vectorizer.vocabulary_ngrams))
start_index = random.randint(0, len(vectorizer.vocabulary_ngrams) - phrase_size - 1)

generated_text = vectorizer.vocabulary_ngrams[start_index : start_index + phrase_size]

print(generated_text)

for temperature in [.1,1.0, 2.0,3.0,4.0]:
    print("----- temperature: ", temperature)
    print("----- Seed Text:   "," ".join(generated_text))
    predicted_words = []
    for i in range(60):
        sampled = np.zeros( (1, phrase_size,len(vectorizer.vocabulary_index.keys())) )

        for t, char in enumerate(generated_text):

            sampled[0, t, vectorizer.vocabulary_index[char]]

        preds = model.predict(sampled, verbose=0)[0]

        next_index = sample(preds, temperature)

        next_char = vectorizer.vocabulary_ngrams[next_index]

        generated_text.pop(0)
        generated_text.append(next_char)

        predicted_words.append(next_char)
    print(" ".join(predicted_words))
# Out:
# 411328
# ['to', 'speak', 'of', 'the', 'quaint', 'in', 'phraseology', 'and', 'in', 'general']
# ----- temperature:  0.1
# ----- Seed Text:    to speak of the quaint in phraseology and in general
# all all all all all all all all all all all all all all all all all all nature heavens all all all all all all heavens all all all all all all all all all all all all all all all all all all all all all all all all all all all all all all all all all
# ----- temperature:  1.0
# ----- Seed Text:    all all all all all all all all all all
# than about apparently one so corners my portion at of momentary mind friendly put in remarkable never purposes no corners to clew thousand a destroy in an occupant which arrived be great by substance doubt date all one ever to object people egregious philosophical corners no open all open indeed the was utterly pfaall similar of on to of broad
# ----- temperature:  2.0
# ----- Seed Text:    the was utterly pfaall similar of on to of broad
# whatever my all leave tiny good in man but before the mynheer employment accounts reflection and pfaall his obtaining nature repeatedly to cause it was seen reasonable one for uttered was in into nearly date the declared of martin imagine be for mind in childish huge more lost back imagine two was view a shape not bad of way on
# ----- temperature:  3.0
# ----- Seed Text:    two was view a shape not bad of way on
# an of properly at not i his multitude compared roaring cords the trouble of top city regarded state open miles liberty may to name by appeared it dug being government about ever substance thought of own its am unaccountable the of was a no there seen city enveloped it me rotterdam the into his it not shaped as state burgomaster
# ----- temperature:  4.0
# ----- Seed Text:    rotterdam the into his it not shaped as state burgomaster
# area the their handkerchief bodies astronomical but of was heterogeneous the enable this rise astronomy same therefrom so ten remember rotterdam of nerve in is tied properly attached business to if late equipment an whole question of surface and bulk a utterly a from could the which bosom have however attached take and mean rice conceived better faces and inducing

# %%
generated_text = ['he', 'determined', 'to', 'keep', 'up', 'his', 'character', 'for', 'firmness', 'and']
generated_text = ['to', 'speak', 'of', 'the', 'quaint', 'in', 'phraseology', 'and', 'in', 'general']
generated_text = ['to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to']

#//*** Empty one hot encoded array
sampled = np.zeros( (1, phrase_size,len(vectorizer.vocabulary_index.keys())) )

#//*** one hot encode generated_text
for t, char in enumerate(generated_text):

    sampled[0, t, vectorizer.vocabulary_index[char]]


#//*** Predict word
preds = model.predict(sampled, verbose=0)[0]

print(preds)
#vectorizer.vocabulary_ngrams[np.argmax(preds)]

np.argsort(-preds)

#np.argmax(preds)
# Out:
# [7.7167591e-05 1.2079880e-04 3.5489848e-04 ... 1.9615483e-07 8.1949992e-08
#  8.2628020e-08]
# array([  57,  189,   99, ..., 5001, 8816, 4689], dtype=int64)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

import random
import sys

for epoch in range(1,60):
    print('epoch', epoch)
    model.fit(train, targets, batch_size=128, epochs=1)
    continue
    start_index = random.randint(0, len(vectorizer.vocabulary_ngrams) - phrase_size - 1)

    generated_text = vectorizer.vocabulary_ngrams[start_index : start_index + phrase_size]


    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print("----- temperature: ", temperature)
        predicted_words = []
        for i in range(60):
            sampled = np.zeros( (1, phrase_size,len(vectorizer.vocabulary_index.keys())) )

            for t, char in enumerate(generated_text):

                sampled[0, t, vectorizer.vocabulary_index[char]]

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = vectorizer.vocabulary_ngrams[next_index]

            generated_text.pop(0)
            generated_text.append(next_char)

            predicted_words.append(next_char)
        print(" ".join(predicted_words))

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

import random
import sys

for epoch in range(1,60):
    print('epoch', epoch)
    model.fit(train, targets, batch_size=128, epochs=1)

    start_index = random.randint(0, len(vectorizer.vocabulary_ngrams) - phrase_size - 1)

    generated_text = vectorizer.vocabulary_ngrams[start_index : start_index + phrase_size]


    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print("----- temperature: ", temperature)
        predicted_words = []
        for i in range(60):
            sampled = np.zeros( (1, phrase_size,len(vectorizer.vocabulary_index.keys())) )

            for t, char in enumerate(generated_text):

                sampled[0, t, vectorizer.vocabulary_index[char]]

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = vectorizer.vocabulary_ngrams[next_index]

            generated_text.pop(0)
            generated_text.append(next_char)

            predicted_words.append(next_char)
        print(" ".join(predicted_words))

# %%
sample_text = raw_text[:int(len(raw_text)*1)]
max_tokens = 10000
phrase_size = 3
step = int(phrase_size *.3)

if step <= 0:
    step = 1
print("Step: ", step)
ngrams=1
#//*** Test the Vectorizer with some sample data
vectorizer = Vectorizer(max_tokens=max_tokens,ngrams=ngrams, tidyup=False)

vectorizer.build_vocabulary(sample_text)   
print(len(vectorizer.corpus_tokens),len(vectorizer.corpus_ngrams))
#hot_vals = vectorizer.encode(raw_email[:100],encoding='onehot')
train,targets = vectorizer.encode_words_for_text_prediction(sample_text,phrase_size=phrase_size,step=step)

print(train.shape)
print(targets.shape)
