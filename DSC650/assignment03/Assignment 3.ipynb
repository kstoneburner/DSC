# %% [markdown]
# # Assignment 3 #
#
# **json schema Reference**
# https://json-schema.org/learn/getting-started-step-by-step.html
#
# **json schema library reference:**
# https://python-jsonschema.readthedocs.io/en/stable/
#
# **Avro** is a language-neutral data serialization system. It can be processed by many languages (currently C, C++, C#, Java, Python, and Ruby). Avro creates binary structured format that is both compressible and splittable. Hence it can be efficiently used as the input to Hadoop MapReduce jobs.
#
# reference:
# https://www.tutorialspoint.com/avro/avro_overview.htm
#
# FastAvro Schema:
# https://fastavro.readthedocs.io/en/latest/schema.html
#
# FastAvro Home:
# https://fastavro.readthedocs.io/en/latest/
#
#
#
#
# **Apache Parquet**
# Gzip Reference:
# https://docs.python.org/3/library/gzip.html
#
# Apache Parquet Load from JSONL files
# https://arrow.apache.org/docs/python/json.html
#
# Apache Parquet, Read/Write parquet tables
# https://arrow.apache.org/docs/python/parquet.html
#
# Python Check if File Exists:
# https://www.pythontutorial.net/python-basics/python-check-if-file-exists/
#
#
# **Google Protocol Buffers:**
# https://developers.google.com/protocol-buffers/docs/pythontutorial
#
# note: use .CopyFrom() when assigning a metaclass to a key.
#
# gzip encoding example:
# https://gist.github.com/LouisAmon/4bd79b8ab80d3851601f3f9016300ac4

# %% [markdown]
# Import libraries and define common helper functions

# %%
import os
import sys
import gzip
import json
from pathlib import Path
import csv

import pandas as pd
#import s3fs
import pyarrow as pa
from pyarrow.json import read_json
import pyarrow.parquet as pq
import fastavro
import pygeohash
#//*** Note: install with: pip install python-snappy
import snappy
import jsonschema
from jsonschema.exceptions import ValidationError


endpoint_url='https://storage.budsc.midwest-datascience.com'

current_dir = Path(os.getcwd()).absolute()
schema_dir = current_dir.joinpath('schemas')
results_dir = current_dir.joinpath('results')
results_dir.mkdir(parents=True, exist_ok=True)

validation_csv_path = results_dir.joinpath("json_schema_validation.csv")

def read_jsonl_data():
    src_data_path = 'routes.jsonl.gz'
    
    with gzip.open(src_data_path, 'rb') as f:
        records = [json.loads(line) for line in f.readlines()]

    return records

# %% [markdown]
# Load the records from https://storage.budsc.midwest-datascience.com/data/processed/openflights/routes.jsonl.gz

# %%
records = read_jsonl_data()

# %% [markdown]
# ### Remove Record Keys with None Data types ###
#
# Some of the SRC and DST airports are Empty/None. This causes issues with the Schema Validation. It's fine to have errors for this assignment, but might as well address the issue before validating the schema. Probably could have set the schema to optional as well.

# %%
#//*** Remove Records with None Type
for record in records:
    empty_keys = []
    
    for key,value in record.items():
        if value is None:
            empty_keys.append(key)
    for empty_key in empty_keys:
        del record[empty_key]

# %% [markdown]
# ### Programatically Build JSON Schema ###
# Parsing each value of a record to generate a schema probably didn't save me any time. But it might be helpful for future tasks. Rolling through programatically means I won't miss any keys and my typos will be consistent.

# %%
 def type_as_string(val):
    if isinstance(val,int):
        return "integer"
    
    if isinstance(val,str):
        return "string"
    
    if isinstance(val,bool):
        return "boolean"

    if isinstance(val,float):
        return "number"
    
    if isinstance(val,list):
        return "array"

    return type(val)

#//*** Pick an index to build the schema
dex=0

out = ''
out+= '{'
#out+='\n\t'
#out += '"$schema": "https://json-schema.org/draft/2020-12/schema",'
out+='\n\t'
out += '"$id": "http://json-schema.org/draft-07/schema#",'
out+='\n\t'
out += '"$schema": "http://json-schema.org/draft-07/schema#",'
out+='\n\t'
out += '"title": "Product",'
out+='\n\t'
out += '"description": "Some Product",'
out+='\n\t'
out += '"type": "object",'
out+='\n\t'
out += '"properties": {'
#out+='\n\t\t'
for key in records[dex].keys():
    #print(key, isinstance(records[0][key],dict) )
    
    if isinstance(records[dex][key],dict):
        out+='\n\t\t'
        #print(key)
        out += f'"{key}" : '
        out += "{"
        out+='\n\t\t\t'
        out+= '"type": "object",'
        out+='\n\t\t\t'
        out += '"properties": {'
        out+='\n\t\t\t\t'
        for key2,value2 in records[dex][key].items():
            out += f'"{key2}" : '
            out += "{"
            out+='\n\t\t\t\t\t'
            if key2 == 'active':
                out += f'"type": "boolean"'     
            else:
                out += f'"type": "{type_as_string(value2)}"' 
            out+='\n\t\t\t\t'
            out += "},"
            if key == "airline" and key2 == "active":
                out = out[:-1]
                continue
            if key == "src_airport" and key2 == "source":
                out = out[:-1]
                continue
                
            if key == "dst_airport" and key2 == "source":
                out = out[:-1]
                continue

            out+='\n\t\t\t\t'
        out+='\n\t\t\t'
        out+="}"   
        out+='\n\t\t'
        out += "},"
        continue
        
    out+='\n\t\t'
    out += f'"{key}" : '
    out += "{"
    out+='\n\t\t\t'
    
    if key == 'codeshare':
        out += f'"type": "boolean"'
    else:
        out += f'"type": "{type_as_string(records[dex][key])}"'
    out+='\n\t\t'
    out+="},"    
        
out = out[:-1]
out+='\n\t'
out+= "}"
out+='\n'
out+= "}"
print(out)

#//*** Write Schema to File
schema_path = schema_dir.joinpath('routes-schema.json')
with open(schema_path, 'w') as f:
    f.write(out)
# Out:
# {
# 	"$id": "http://json-schema.org/draft-07/schema#",
# 	"$schema": "http://json-schema.org/draft-07/schema#",
# 	"title": "Product",
# 	"description": "Some Product",
# 	"type": "object",
# 	"properties": {
# 		"airline" : {
# 			"type": "object",
# 			"properties": {
# 				"airline_id" : {
# 					"type": "integer"
# 				},
# 				"name" : {
# 					"type": "string"
# 				},
# 				"alias" : {
# 					"type": "string"
# 				},
# 				"iata" : {
# 					"type": "string"
# 				},
# 				"icao" : {
# 					"type": "string"
# 				},
# 				"callsign" : {
# 					"type": "string"
# 				},
# 				"country" : {
# 					"type": "string"
# 				},
# 				"active" : {
# 					"type": "boolean"
# 				}
# 			}
# 		},
# 		"src_airport" : {
# 			"type": "object",
# 			"properties": {
# 				"airport_id" : {
# 					"type": "integer"
# 				},
# 				"name" : {
# 					"type": "string"
# 				},
# 				"city" : {
# 					"type": "string"
# 				},
# 				"country" : {
# 					"type": "string"
# 				},
# 				"iata" : {
# 					"type": "string"
# 				},
# 				"icao" : {
# 					"type": "string"
# 				},
# 				"latitude" : {
# 					"type": "number"
# 				},
# 				"longitude" : {
# 					"type": "number"
# 				},
# 				"altitude" : {
# 					"type": "integer"
# 				},
# 				"timezone" : {
# 					"type": "number"
# 				},
# 				"dst" : {
# 					"type": "string"
# 				},
# 				"tz_id" : {
# 					"type": "string"
# 				},
# 				"type" : {
# 					"type": "string"
# 				},
# 				"source" : {
# 					"type": "string"
# 				}
# 			}
# 		},
# 		"dst_airport" : {
# 			"type": "object",
# 			"properties": {
# 				"airport_id" : {
# 					"type": "integer"
# 				},
# 				"name" : {
# 					"type": "string"
# 				},
# 				"city" : {
# 					"type": "string"
# 				},
# 				"country" : {
# 					"type": "string"
# 				},
# 				"iata" : {
# 					"type": "string"
# 				},
# 				"icao" : {
# 					"type": "string"
# 				},
# 				"latitude" : {
# 					"type": "number"
# 				},
# 				"longitude" : {
# 					"type": "number"
# 				},
# 				"altitude" : {
# 					"type": "integer"
# 				},
# 				"timezone" : {
# 					"type": "number"
# 				},
# 				"dst" : {
# 					"type": "string"
# 				},
# 				"tz_id" : {
# 					"type": "string"
# 				},
# 				"type" : {
# 					"type": "string"
# 				},
# 				"source" : {
# 					"type": "string"
# 				}
# 			}
# 		},
# 		"codeshare" : {
# 			"type": "boolean"
# 		},
# 		"equipment" : {
# 			"type": "array"
# 		}
# 	}
# }

# %% [markdown]
# ### 3.1.a JSON Schema

# %%
def validate_jsonl_data(records):
    schema_path = schema_dir.joinpath('routes-schema.json')
    
    with open(schema_path) as f:
        schema = json.load(f)
    
    with open(validation_csv_path, 'w') as f:    
        for i, record in enumerate(records):
            try:
                jsonschema.validate(record,schema)
                f.write(f"{i},valid,,\n")
                
            except ValidationError as e:
                ## Print message if invalid record
                print("Schema/Record Error Record:",i,"\n\n",e,"\n\n")
            
#//*** All Data is Schema valid
validate_jsonl_data(records)

# %% [markdown]
# ### 3.1.b Avro

# %%
#//*** Reload Clean Records
records = read_jsonl_data()


from fastavro import parse_schema
from fastavro import writer

def create_avro_dataset(records):
    schema_path = schema_dir.joinpath('routes.avsc')
    data_path = results_dir.joinpath('routes.avro')
    
    #//*** Load Avro Schema
    with open(schema_path, 'r') as f:
        avro_schema = json.loads(f.read())
    
    #//*** Parse Avro Schema
    parsed_schema = parse_schema(avro_schema)
    
    with open(data_path, 'wb') as out:
        writer(out, parsed_schema, records)
        
create_avro_dataset(records)

# %% [markdown]
# ### 3.1.c Parquet

# %% [markdown]
# Gzip Reference:
# https://docs.python.org/3/library/gzip.html
#
# Apache Parquet Load from JSONL files
# https://arrow.apache.org/docs/python/json.html
#
# Apache Parquet, Read/Write parquet tables
# https://arrow.apache.org/docs/python/parquet.html
#
# Python Check if File Exists:
# https://www.pythontutorial.net/python-basics/python-check-if-file-exists/

# %%
def create_parquet_dataset():
    from pyarrow import json
    import os
    
    parquet_output_path = results_dir.joinpath('routes.parquet')

    #//*** PyArrow supports native JSONL files
    #//*** Extract the compressed JSONL files to disk
    src_data_path = 'routes.jsonl.gz'
    jsonl_path = 'routes.jsonl'
    
    #//*** Open the compressed file
    with open(src_data_path, 'rb') as f:
    
        #//*** Open the extracted file for writing
        with open(jsonl_path,'wb') as writer:
                
            #//*** Write the decompressed jsonl file
            writer.write(gzip.decompress(f.read()))

    #//*** Load the jsonl file into a parquet table
    parquet_table = json.read_json(jsonl_path)
    
    #//*** Delete the Extracted File
    if os.path.exists(jsonl_path):
        os.remove(jsonl_path)
    
    #//*** Print the First 5000 characters of the string output of parquet_table
    print(str(parquet_table)[:5000])
    
    #//*** Write Parquet Table to disk
    pq.write_table(parquet_table,parquet_output_path)
    
    

create_parquet_dataset()
# Out:
# pyarrow.Table
# airline: struct<airline_id: int64, name: string, alias: string, iata: string, icao: string, callsign: string, country: string, active: bool>
#   child 0, airline_id: int64
#   child 1, name: string
#   child 2, alias: string
#   child 3, iata: string
#   child 4, icao: string
#   child 5, callsign: string
#   child 6, country: string
#   child 7, active: bool
# src_airport: struct<airport_id: int64, name: string, city: string, country: string, iata: string, icao: string, latitude: double, longitude: double, altitude: int64, timezone: double, dst: string, tz_id: string, type: string, source: string>
#   child 0, airport_id: int64
#   child 1, name: string
#   child 2, city: string
#   child 3, country: string
#   child 4, iata: string
#   child 5, icao: string
#   child 6, latitude: double
#   child 7, longitude: double
#   child 8, altitude: int64
#   child 9, timezone: double
#   child 10, dst: string
#   child 11, tz_id: string
#   child 12, type: string
#   child 13, source: string
# dst_airport: struct<airport_id: int64, name: string, city: string, country: string, iata: string, icao: string, latitude: double, longitude: double, altitude: int64, timezone: double, dst: string, tz_id: string, type: string, source: string>
#   child 0, airport_id: int64
#   child 1, name: string
#   child 2, city: string
#   child 3, country: string
#   child 4, iata: string
#   child 5, icao: string
#   child 6, latitude: double
#   child 7, longitude: double
#   child 8, altitude: int64
#   child 9, timezone: double
#   child 10, dst: string
#   child 11, tz_id: string
#   child 12, type: string
#   child 13, source: string
# codeshare: bool
# equipment: list<item: string>
#   child 0, item: string
# ----
# airline: [  -- is_valid: all not null  -- child 0 type: int64
#     [
#       410,
#       410,
#       410,
#       410,
#       410,
#       410,
#       410,
#       410,
#       410,
#       410,
#       ...
#       10758,
#       10758,
#       10758,
#       10758,
#       10758,
#       10758,
#       10758,
#       10758,
#       10758,
#       10758
#     ]  -- child 1 type: string
#     [
#       "Aerocondor",
#       "Aerocondor",
#       "Aerocondor",
#       "Aerocondor",
#       "Aerocondor",
#       "Aerocondor",
#       "Aerocondor",
#       "Aerocondor",
#       "Aerocondor",
#       "Aerocondor",
#       ...
#       "Safi Airlines",
#       "Safi Airlines",
#       "Safi Airlines",
#       "Safi Airlines",
#       "Safi Airlines",
#       "Safi Airlines",
#       "Safi Airlines",
#       "Safi Airlines",
#       "Safi Airlines",
#       "Safi Airlines"
#     ]  -- child 2 type: string
#     [
#       "ANA All Nippon Airways",
#       "ANA All Nippon Airways",
#       "ANA All Nippon Airways",
#       "ANA All Nippon Airways",
#       "ANA All Nippon Airways",
#       "ANA All Nippon Airways",
#       "ANA All Nippon Airways",
#       "ANA All Nippon Airways",
#       "ANA All Nippon Airways",
#       "ANA All Nippon Airways",
#       ...
#       "nan",
#       "nan",
#       "nan",
#       "nan",
#       "nan",
#       "nan",
#       "nan",
#       "nan",
#       "nan",
#       "nan"
#     ]  -- child 3 type: string
#     [
#       "2B",
#       "2B",
#       "2B",
#       "2B",
#       "2B",
#       "2B",
#       "2B",
#       "2B",
#       "2B",
#       "2B",
#       ...
#       "4Q",
#       "4Q",
#       "4Q",
#       "4Q",
#       "4Q",
#       "4Q",
#       "4Q",
#       "4Q",
#       "4Q",
#       "4Q"
#     ]  -- child 4 type: string
#     [
#       "ARD",
#       "ARD",
#       "ARD",
#       "ARD",
#       "ARD",
#       "ARD",
#       "ARD",
#       "ARD",
#       "ARD",
#       "ARD",
#       ...
#       "LOC",
#       "LOC",
#       "LOC",
#       "LOC",
#       "LOC",
#       "LOC",
#       "LOC",
#       "LOC",
#       "LOC",
#       "LOC"
#     ]  -- child 5 type: string
#     [
#       "AEROCONDOR",
#       "AEROCONDOR",
#       "AEROCONDOR",
#       "AEROCONDOR",
#       "AEROCONDOR",
#       "AEROCONDOR",
#       "AEROCONDOR",
#       "AEROCONDOR",
#       "AEROCONDOR",
#       "AEROCONDOR",
#       ...
#       "nan",
#       "nan",
#       "nan",
#       "nan",
#       "nan",
#       "nan",
#       "nan",
#       "nan",
#       "nan",
#       "nan"
#     ]  -- child 6 type: string
#     [
#       "Portugal",
#       "Portugal",
#       "Portugal",
#       "Portugal",
#       "Portugal",
#       "Portugal",
#       "Portugal",
#       "Portugal",
#       "Portugal",
#       "Portugal",
#       ...
#       "Afghanistan",
#       "Afghanistan",
#       "Afghanistan",
#       "Afghanistan",
#       "Afghanistan",
#       "Afghanistan",
#       "Afghanistan",
#       "Afghanistan",
#       "Afghanistan",
#       "Afghanistan"
#     ]  -- child 7 type: bool
#     [
#       true,
#       true,
#       true,
#       true,
#       true,
#       true,
#       true,
#       true,
#       true,
#       true,
#       ...
#       true,
#       true,
#       true,
#       true,
#       true,
#       true,
#       true,
#       true,
#       true,
#       true
#     ],  -- is_valid: all not null  -- child 0 type: int64
#     [
#       10758,
#       10758,
#       1401,
#       1401,
#       1401,
#       1401,
#       1401,
#       1401,
#       1401,
#       1401,
#       ...
#       2994,
#       2994,
#       2994,
#       2994,
#       2994,
#       2994,
#       2994,
#       2994,
#       2994,
#       2994
#     ]  -- child 1 type: string
#     [
#       "Safi Airlines

# %% [markdown]
# ### 3.1.d Protocol Buffers

# %%
#//*** Reload Clean Records Data
records = read_jsonl_data()

# %%
sys.path.insert(0, os.path.abspath('routes_pb2'))

import routes_pb2

def _airport_to_proto_obj(airport):
    obj = routes_pb2.Airport()
    if airport is None:
        return None
    if airport.get('airport_id') is None:
        return None

    obj.airport_id = airport.get('airport_id')
    if airport.get('name'):
        obj.name = airport.get('name')
    if airport.get('city'):
        obj.city = airport.get('city')
    if airport.get('iata'):
        obj.iata = airport.get('iata')
    if airport.get('icao'):
        obj.icao = airport.get('icao')
    if airport.get('altitude'):
        obj.altitude = airport.get('altitude')
    if airport.get('timezone'):
        obj.timezone = airport.get('timezone')
    if airport.get('dst'):
        obj.dst = airport.get('dst')
    if airport.get('tz_id'):
        obj.tz_id = airport.get('tz_id')
    if airport.get('type'):
        obj.type = airport.get('type')
    if airport.get('source'):
        obj.source = airport.get('source')

    obj.latitude = airport.get('latitude')
    obj.longitude = airport.get('longitude')

    return obj


def _airline_to_proto_obj(airline):
    
    
    obj = routes_pb2.Airline()

    #//*** If key exists, load value into obj
    if airline.get('airline_id'):
        obj.airline_id = airline.get('airline_id')

    if airline.get('name'):
        obj.name = airline.get('name')

    if airline.get('alias'):
        obj.alias = airline.get('alias')

    if airline.get('iata'):
        obj.iata = airline.get('iata')

    if airline.get('icao'):
        obj.icao = airline.get('icao')

    if airline.get('callsign'):
        obj.callsign = airline.get('callsign')

    if airline.get('country'):
        obj.country = airline.get('country')
    
    if 'active' in airline.keys():
        obj.active = airline['active']
    
    return obj


def create_protobuf_dataset(records):
    routes = routes_pb2.Routes()
    
    
    for record in records:
        
        #//*** Add a Record to routes
        route = routes.route.add()
        
        if 'codeshare' in record.keys():
            route.codeshare = record['codeshare']
        
        if record.get('stops'):
            route.stops = record.get('stops')
            
        #//*** Use extend to add lists/arrays. 
        if record.get('equipment'):
            route.equipment.extend(record.get('equipment'))
        
        #//*** generate Airline Object
        if 'src_airport' in record.keys():

            #//*** If src_airport exists Build Object from record
            src_airport = _airport_to_proto_obj(record['src_airport'])
            
            #//*** Skip if None
            if src_airport is not None:
                #//*** Use CopyFrom to assign objects
                route.src_airport.CopyFrom( src_airport )

        if 'dst_airport' in record.keys():
            

            #//*** If dst_airport exists Build Object from record
            dst_airport = _airport_to_proto_obj(record['dst_airport'])

            #//*** Skip if None
            if dst_airport is not None:
                #//*** Use CopyFrom to assign objects
                route.dst_airport.CopyFrom(dst_airport)
        
        if 'airline' in record.keys():
            #//*** If airline exists Build Object from record
            airline = _airline_to_proto_obj(record['airline'])

            #//*** Skip if None
            if airline is not None:
                #//*** Use CopyFrom to assign objects
                route.airline.CopyFrom(airline)

    #//*** Display the first 10,000 characters of routes
    print(str(routes)[:10000])
    
    data_path = results_dir.joinpath('routes.pb')

    with open(data_path, 'wb') as f:
        f.write(routes.SerializeToString())
        
    compressed_path = results_dir.joinpath('routes.pb.snappy')
    
    with open(compressed_path, 'wb') as f:
        f.write(snappy.compress(routes.SerializeToString()))
        
create_protobuf_dataset(records)
# Out:
# route {
#   airline {
#     airline_id: 410
#     name: "Aerocondor"
#     alias: "ANA All Nippon Airways"
#     iata: "2B"
#     icao: "ARD"
#     callsign: "AEROCONDOR"
#     country: "Portugal"
#     active: true
#   }
#   src_airport {
#     airport_id: 2965
#     name: "Sochi International Airport"
#     city: "Sochi"
#     iata: "AER"
#     icao: "URSS"
#     latitude: 43.449902
#     longitude: 39.9566
#     altitude: 89
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   dst_airport {
#     airport_id: 2990
#     name: "Kazan International Airport"
#     city: "Kazan"
#     iata: "KZN"
#     icao: "UWKD"
#     latitude: 55.606201171875
#     longitude: 49.278701782227
#     altitude: 411
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   codeshare: false
#   equipment: "CR2"
# }
# route {
#   airline {
#     airline_id: 410
#     name: "Aerocondor"
#     alias: "ANA All Nippon Airways"
#     iata: "2B"
#     icao: "ARD"
#     callsign: "AEROCONDOR"
#     country: "Portugal"
#     active: true
#   }
#   src_airport {
#     airport_id: 2966
#     name: "Astrakhan Airport"
#     city: "Astrakhan"
#     iata: "ASF"
#     icao: "URWA"
#     latitude: 46.2832984924
#     longitude: 48.0063018799
#     altitude: -65
#     timezone: 4.0
#     dst: "N"
#     tz_id: "Europe/Samara"
#     type: "airport"
#     source: "OurAirports"
#   }
#   dst_airport {
#     airport_id: 2990
#     name: "Kazan International Airport"
#     city: "Kazan"
#     iata: "KZN"
#     icao: "UWKD"
#     latitude: 55.606201171875
#     longitude: 49.278701782227
#     altitude: 411
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   codeshare: false
#   equipment: "CR2"
# }
# route {
#   airline {
#     airline_id: 410
#     name: "Aerocondor"
#     alias: "ANA All Nippon Airways"
#     iata: "2B"
#     icao: "ARD"
#     callsign: "AEROCONDOR"
#     country: "Portugal"
#     active: true
#   }
#   src_airport {
#     airport_id: 2966
#     name: "Astrakhan Airport"
#     city: "Astrakhan"
#     iata: "ASF"
#     icao: "URWA"
#     latitude: 46.2832984924
#     longitude: 48.0063018799
#     altitude: -65
#     timezone: 4.0
#     dst: "N"
#     tz_id: "Europe/Samara"
#     type: "airport"
#     source: "OurAirports"
#   }
#   dst_airport {
#     airport_id: 2962
#     name: "Mineralnyye Vody Airport"
#     city: "Mineralnye Vody"
#     iata: "MRV"
#     icao: "URMM"
#     latitude: 44.22510147094727
#     longitude: 43.08190155029297
#     altitude: 1054
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   codeshare: false
#   equipment: "CR2"
# }
# route {
#   airline {
#     airline_id: 410
#     name: "Aerocondor"
#     alias: "ANA All Nippon Airways"
#     iata: "2B"
#     icao: "ARD"
#     callsign: "AEROCONDOR"
#     country: "Portugal"
#     active: true
#   }
#   src_airport {
#     airport_id: 2968
#     name: "Chelyabinsk Balandino Airport"
#     city: "Chelyabinsk"
#     iata: "CEK"
#     icao: "USCC"
#     latitude: 55.305801
#     longitude: 61.5033
#     altitude: 769
#     timezone: 5.0
#     dst: "N"
#     tz_id: "Asia/Yekaterinburg"
#     type: "airport"
#     source: "OurAirports"
#   }
#   dst_airport {
#     airport_id: 2990
#     name: "Kazan International Airport"
#     city: "Kazan"
#     iata: "KZN"
#     icao: "UWKD"
#     latitude: 55.606201171875
#     longitude: 49.278701782227
#     altitude: 411
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   codeshare: false
#   equipment: "CR2"
# }
# route {
#   airline {
#     airline_id: 410
#     name: "Aerocondor"
#     alias: "ANA All Nippon Airways"
#     iata: "2B"
#     icao: "ARD"
#     callsign: "AEROCONDOR"
#     country: "Portugal"
#     active: true
#   }
#   src_airport {
#     airport_id: 2968
#     name: "Chelyabinsk Balandino Airport"
#     city: "Chelyabinsk"
#     iata: "CEK"
#     icao: "USCC"
#     latitude: 55.305801
#     longitude: 61.5033
#     altitude: 769
#     timezone: 5.0
#     dst: "N"
#     tz_id: "Asia/Yekaterinburg"
#     type: "airport"
#     source: "OurAirports"
#   }
#   dst_airport {
#     airport_id: 4078
#     name: "Tolmachevo Airport"
#     city: "Novosibirsk"
#     iata: "OVB"
#     icao: "UNNT"
#     latitude: 55.012599945068
#     longitude: 82.650703430176
#     altitude: 365
#     timezone: 7.0
#     dst: "N"
#     tz_id: "Asia/Krasnoyarsk"
#     type: "airport"
#     source: "OurAirports"
#   }
#   codeshare: false
#   equipment: "CR2"
# }
# route {
#   airline {
#     airline_id: 410
#     name: "Aerocondor"
#     alias: "ANA All Nippon Airways"
#     iata: "2B"
#     icao: "ARD"
#     callsign: "AEROCONDOR"
#     country: "Portugal"
#     active: true
#   }
#   src_airport {
#     airport_id: 4029
#     name: "Domodedovo International Airport"
#     city: "Moscow"
#     iata: "DME"
#     icao: "UUDD"
#     latitude: 55.40879821777344
#     longitude: 37.90629959106445
#     altitude: 588
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   dst_airport {
#     airport_id: 2990
#     name: "Kazan International Airport"
#     city: "Kazan"
#     iata: "KZN"
#     icao: "UWKD"
#     latitude: 55.606201171875
#     longitude: 49.278701782227
#     altitude: 411
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   codeshare: false
#   equipment: "CR2"
# }
# route {
#   airline {
#     airline_id: 410
#     name: "Aerocondor"
#     alias: "ANA All Nippon Airways"
#     iata: "2B"
#     icao: "ARD"
#     callsign: "AEROCONDOR"
#     country: "Portugal"
#     active: true
#   }
#   src_airport {
#     airport_id: 4029
#     name: "Domodedovo International Airport"
#     city: "Moscow"
#     iata: "DME"
#     icao: "UUDD"
#     latitude: 55.40879821777344
#     longitude: 37.90629959106445
#     altitude: 588
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   dst_airport {
#     airport_id: 6969
#     name: "Begishevo Airport"
#     city: "Nizhnekamsk"
#     iata: "NBC"
#     icao: "UWKE"
#     latitude: 55.56470108032226
#     longitude: 52.09249877929688
#     altitude: 643
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   codeshare: false
#   equipment: "CR2"
# }
# route {
#   airline {
#     airline_id: 410
#     name: "Aerocondor"
#     alias: "ANA All Nippon Airways"
#     iata: "2B"
#     icao: "ARD"
#     callsign: "AEROCONDOR"
#     country: "Portugal"
#     active: true
#   }
#   src_airport {
#     airport_id: 4029
#     name: "Domodedovo International Airport"
#     city: "Moscow"
#     iata: "DME"
#     icao: "UUDD"
#     latitude: 55.40879821777344
#     longitude: 37.90629959106445
#     altitude: 588
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   codeshare: false
#   equipment: "CR2"
# }
# route {
#   airline {
#     airline_id: 410
#     name: "Aerocondor"
#     alias: "ANA All Nippon Airways"
#     iata: "2B"
#     icao: "ARD"
#     callsign: "AEROCONDOR"
#     country: "Portugal"
#     active: true
#   }
#   src_airport {
#     airport_id: 4029
#     name: "Domodedovo International Airport"
#     city: "Moscow"
#     iata: "DME"
#     icao: "UUDD"
#     latitude: 55.40879821777344
#     longitude: 37.90629959106445
#     altitude: 588
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   dst_airport {
#     airport_id: 6160
#     name: "Bugulma Airport"
#     city: "Bugulma"
#     iata: "UUA"
#     icao: "UWKB"
#     latitude: 54.63999938964844
#     longitude: 52.80170059204102
#     altitude: 991
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   codeshare: false
#   equipment: "CR2"
# }
# route {
#   airline {
#     airline_id: 410
#     name: "Aerocondor"
#     alias: "ANA All Nippon Airways"
#     iata: "2B"
#     icao: "ARD"
#     callsign: "AEROCONDOR"
#     country: "Portugal"
#     active: true
#   }
#   src_airport {
#     airport_id: 6156
#     name: "Belgorod International Airport"
#     city: "Belgorod"
#     iata: "EGO"
#     icao: "UUOB"
#     latitude: 50.643798828125
#     longitude: 36.5900993347168
#     altitude: 735
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   dst_airport {
#     airport_id: 2952
#     name: "Khrabrovo Airport"
#     city: "Kaliningrad"
#     iata: "KGD"
#     icao: "UMKK"
#     latitude: 54.88999938964844
#     longitude: 20.592599868774414
#     altitude: 42
#     timezone: 2.0
#     dst: "N"
#     tz_id: "Europe/Kaliningrad"
#     type: "airport"
#     source: "OurAirports"
#   }
#   codeshare: false
#   equipment: "CR2"
# }
# route {
#   airline {
#     airline_id: 410
#     name: "Aerocondor"
#     alias: "ANA All Nippon Airways"
#     iata: "2B"
#     icao: "ARD"
#     callsign: "AEROCONDOR"
#     country: "Portugal"
#     active: true
#   }
#   src_airport {
#     airport_id: 6156
#     name: "Belgorod International Airport"
#     city: "Belgorod"
#     iata: "EGO"
#     icao: "UUOB"
#     latitude: 50.643798828125
#     longitude: 36.5900993347168
#     altitude: 735
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   dst_airport {
#     airport_id: 2990
#     name: "Kazan International Airport"
#     city: "Kazan"
#     iata: "KZN"
#     icao: "UWKD"
#     latitude: 55.606201171875
#     longitude: 49.278701782227
#     altitude: 411
#     timezone: 3.0
#     dst: "N"
#     tz_id: "Europe/Moscow"
#     type: "airport"
#     source: "OurAirports"
#   }
#   codeshare: false
#   equipment: "CR2"
# }
# route {
#   airline {
#     airline_id: 410
#     name: "Aerocondor"
#     alias: "ANA All Nippon Airways"
#     iata: "2B"
#     icao: "ARD"
#     callsign: "AEROCONDOR"
#     country: "Portugal"
#     active: true
#   }
#   src_airport {
#     airport_id: 2922
#     name: "Heydar Aliyev International Airport"
#     city: "Baku"
#     iata: "GYD"
#     icao: "UBBB"
#     latitude: 40.46749877929688
#     longitude: 50.04669952392578
#     altitude: 10
#     timezone: 4.0
#     dst: "E"
#     tz_id: "Asia/Baku"
#     type: "airport"
#     source: "OurAirports"
#   }
#   dst_airport {
#     airport_id: 6969
#     name: "Begishevo Airport"
#     city: "Nizhnekamsk"
#     iata: "NBC"
#     icao: "UWKE"
#     latitude: 55.56470108032226
#     longitude: 5

# %% [markdown]
# ## 3.1e  Size Comparison ##

# %%
src_data_path = 'routes.jsonl.gz'

#//*** Get Filesize of Compressed JSON
json_compressed_file_size = os.path.getsize(src_data_path)


jsonl_path = 'routes.jsonl'
#//*** Open the compressed file
with open(src_data_path, 'rb') as f:
    #//*** Open the extracted file for writing
    with open(jsonl_path,'wb') as writer:
        #//*** Write the decompressed jsonl file
        writer.write(gzip.decompress(f.read()))

#//*** Get Filesize of Compressed JSON
json_uncompressed_file_size = os.path.getsize(jsonl_path)
        
#//*** Delete the Extracted File
if os.path.exists(jsonl_path):
    os.remove(jsonl_path)
    
#//*** Get Avro File size
avro_path = results_dir.joinpath('routes.avro')
avro_file_size = os.path.getsize(avro_path)    

parquet_output_path = results_dir.joinpath('routes.parquet')
parquet_file_size = os.path.getsize(parquet_output_path)    

pb_path = results_dir.joinpath('routes.pb')
pb_file_size = os.path.getsize(pb_path)    

compressed_pb_path = results_dir.joinpath('routes.pb.snappy')
compressed_pb_file_size = os.path.getsize(compressed_pb_path)    

print("JSON Compressed File Size:                     ",format(json_compressed_file_size,',d')," bytes")
print("JSON Uncompressed File Size:                   ",format(json_uncompressed_file_size, ',d')," bytes")
print("Avro Encoded  File Size:                       ",format(avro_file_size,',d')," bytes")
print("Parquet Encoded File Size:                     ",format(parquet_file_size,',d')," bytes")
print("Protocol Buffer File Size:                     ",format(pb_file_size,',d')," bytes")
print("Protocol Buffer (Snappy Compressed) File Size: ",format(compressed_pb_file_size,',d')," bytes")

out = ""
out += f"JSON,compressed,{json_compressed_file_size}\n"
out += f"JSON,uncompressed,{json_uncompressed_file_size}\n"
out += f"Avro,uncompressed,{avro_file_size}\n"
out += f"Parquet,uncompressed,{parquet_file_size}\n"
out += f"Protocol Buffer,uncompressed,{pb_file_size}\n"
out += f"Protocol Buffer,compressed,{compressed_pb_file_size}\n"

comparision_path = results_dir.joinpath('comparison.csv')
print("==========================================================================")
print("Writing Results to ./results/comparison.csv")

with open(comparision_path,'w') as writer:
    writer.write(out)
# Out:
# JSON Compressed File Size:                      3,327,145  bytes
# JSON Uncompressed File Size:                    59,109,449  bytes
# Avro Encoded  File Size:                        19,646,227  bytes
# Parquet Encoded File Size:                      1,975,465  bytes
# Protocol Buffer File Size:                      22,523,154  bytes
# Protocol Buffer (Snappy Compressed) File Size:  3,762,689  bytes
# ==========================================================================
# Writing Results to ./results/comparison.csv

# %% [markdown]
# ## 3.2

# %% [markdown]
# ### 3.2.a Simple Geohash Index

# %%
#//*** Load a clean copy of records
records = read_jsonl_data()

# %%
#//*** Reimport json lest we get confused with parquet json loader
import json    

#//************************************************************************************************************
#//*** Crawl each record and generate a dictionary that maps the folder and file structure for the index
#//*** Parse the dictionary map to generate the needed files and folder for the index
#//************************************************************************************************************
def create_hash_dirs(records):
    geoindex_dir = results_dir.joinpath('geoindex')
    geoindex_dir.mkdir(exist_ok=True, parents=True)
    hashes = []
    
    airport_hash_dict = {}
    airport_hashmap = {}

    #//*** Generate geohashes for each airport in src_destinations 
    #//*** geohashes are stored in hashes for sorting
    #//** and airport_hash_dict to associate the name with the geohash
    for record in records:
        
        if record['src_airport'] is None:
            continue
        
        airport_geohash = pygeohash.encode(record['src_airport']['latitude'], record['src_airport']['longitude'])
        if airport_geohash not in airport_hash_dict.keys():
            #print(record['src_airport']['name']," - ",airport_geohash) 
            
            #//*** Add to hashes if airport is unique.
            #hashes.append(airport_geohash)
        
            #//*** Add Airport_geohash to dictionary. 
            #//*** This assiociates the airport name with the geohash and conveniently prevents duplicates.
            airport_hash_dict[airport_geohash] = record['src_airport']['name']
            
            #//*** add the geohash to the airport_hashmap dictionary
            key1 = airport_geohash[:1]
            key2 = airport_geohash[:2]
            key3 = airport_geohash[:3]
            
            #//*** Initialize Keys as needed
            if key1 not in airport_hashmap.keys():
                airport_hashmap[key1] = {}
            
            if key2 not in airport_hashmap[key1].keys():
                airport_hashmap[key1][key2] = {}

            if key3 not in airport_hashmap[key1][key2].keys():
                airport_hashmap[key1][key2][key3] = {}

            #//*** Associate the whole Airport record with the Geohash.
            #//*** We'll keep everything together. We could also just use the airport_id and keep 
            #//*** the airport info in a separate dictionary/database for 
            airport_hashmap[key1][key2][key3][airport_geohash] = record['src_airport']
    
    #//****************************
    #//*** END record in records
    #//****************************
    
    #//*****************************************************
    #//*** Parse hashmap, Build directories and json files
    #//*****************************************************
    #//*** Top Level - Level 1
    for key1,values1 in airport_hashmap.items():

        #//*** Build Level1 Folders as needed
        level1_path = geoindex_dir.joinpath(key1)
        level1_path.mkdir(exist_ok=True, parents=True)

        print(key1,level1_path)

        #//*** Loop through Level2 sub folders
        for key2,values2 in airport_hashmap[key1].items():

            #//*** Build Level2 Folders as needed
            level2_path = level1_path.joinpath(key2)
            level2_path.mkdir(exist_ok=True, parents=True)

            #//*** Only Print Top 2 Levels for display
            print("--",key2,level2_path)

            #//*** Loop through Level3 - File Level
            for key3,values3 in airport_hashmap[key1][key2].items():

                filepath = level2_path.joinpath(f"{key3}.json.gz")
                #//*** Generate JSON String
                json_data = json.dumps(values3)

                #//*** Encode JSON data as bytes
                encoded = json_data.encode('utf-8')
                
                #//*** Compress encoded file and write to disk
                with open(filepath,'wb') as f:
                    f.write(gzip.compress(encoded))

airport_hashmap = create_hash_dirs(records)
# Out:
# s C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s
# -- sz C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sz
# -- s1 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\s1
# -- s4 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\s4
# -- sr C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sr
# -- sw C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sw
# -- su C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\su
# -- sp C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sp
# -- s0 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\s0
# -- sf C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sf
# -- sx C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sx
# -- st C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\st
# -- sv C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sv
# -- sg C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sg
# -- sn C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sn
# -- sq C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sq
# -- sb C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sb
# -- s8 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\s8
# -- sy C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sy
# -- ss C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\ss
# -- sm C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sm
# -- sc C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sc
# -- s2 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\s2
# -- s6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\s6
# -- s5 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\s5
# -- sh C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sh
# -- sj C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sj
# -- sd C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\sd
# -- se C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\se
# -- s3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\s\s3
# v C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v
# -- v0 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\v0
# -- v3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\v3
# -- v1 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\v1
# -- vd C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\vd
# -- ve C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\ve
# -- vc C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\vc
# -- v6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\v6
# -- v7 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\v7
# -- v5 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\v5
# -- vh C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\vh
# -- v4 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\v4
# -- v2 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\v2
# -- v9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\v9
# -- vb C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\vb
# -- v8 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\v8
# -- vu C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\vu
# -- vf C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\vf
# -- vg C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\v\vg
# u C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u
# -- uc C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\uc
# -- u3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\u3
# -- ud C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\ud
# -- u0 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\u0
# -- u7 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\u7
# -- u6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\u6
# -- ue C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\ue
# -- u4 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\u4
# -- u1 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\u1
# -- u2 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\u2
# -- ug C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\ug
# -- us C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\us
# -- uk C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\uk
# -- ub C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\ub
# -- uf C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\uf
# -- u8 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\u8
# -- u5 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\u5
# -- u9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\u9
# -- um C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\u\um
# t C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t
# -- tp C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tp
# -- th C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\th
# -- t0 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\t0
# -- tr C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tr
# -- tx C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tx
# -- tq C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tq
# -- tz C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tz
# -- tu C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tu
# -- tk C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tk
# -- tt C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tt
# -- tw C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tw
# -- ts C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\ts
# -- tg C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tg
# -- te C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\te
# -- td C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\td
# -- t9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\t9
# -- tf C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tf
# -- tn C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tn
# -- tc C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tc
# -- tj C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tj
# -- t8 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\t8
# -- tm C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tm
# -- ty C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\ty
# -- t4 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\t4
# -- t5 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\t5
# -- t1 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\t1
# -- tv C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\t\tv
# y C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y
# -- y6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\y6
# -- y9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\y9
# -- y3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\y3
# -- ye C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\ye
# -- yd C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\yd
# -- yg C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\yg
# -- yb C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\yb
# -- y8 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\y8
# -- y1 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\y1
# -- y7 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\y7
# -- y2 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\y2
# -- y0 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\y0
# -- yu C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\y\yu
# 6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6
# -- 6m C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6m
# -- 6q C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6q
# -- 6r C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6r
# -- 6p C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6p
# -- 6y C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6y
# -- 6v C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6v
# -- 6g C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6g
# -- 6u C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6u
# -- 69 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\69
# -- 67 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\67
# -- 63 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\63
# -- 6k C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6k
# -- 66 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\66
# -- 6e C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6e
# -- 6c C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6c
# -- 6f C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6f
# -- 62 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\62
# -- 6d C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6d
# -- 68 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\68
# -- 6s C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6s
# -- 6w C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6w
# -- 6t C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6t
# -- 6x C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6x
# -- 6z C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6z
# -- 6n C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\6\6n
# e C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e
# -- eb C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\eb
# -- ef C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\ef
# -- ec C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\ec
# -- ed C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\ed
# -- ez C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\ez
# -- es C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\es
# -- e9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\e9
# -- ev C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\ev
# -- ey C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\ey
# -- et C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\et
# -- eq C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\eq
# -- ee C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\ee
# -- eu C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\eu
# -- e6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\e6
# -- er C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\e\er
# d C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d
# -- d2 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\d2
# -- dp C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\dp
# -- dj C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\dj
# -- dh C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\dh
# -- dk C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\dk
# -- dn C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\dn
# -- d6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\d6
# -- d3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\d3
# -- de C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\de
# -- db C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\db
# -- dd C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\dd
# -- d7 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\d7
# -- dr C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\dr
# -- d5 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\d5
# -- d1 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\d1
# -- d4 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\d4
# -- d9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\d9
# -- dt C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\dt
# -- dq C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\dq
# -- dx C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\dx
# -- d8 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\d8
# -- d0 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\d\d0
# g C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\g
# -- gc C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\g\gc
# -- gb C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\g\gb
# -- gf C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\g\gf
# -- g7 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\g\g7
# -- g5 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\g\g5
# -- gk C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\g\gk
# -- gs C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\g\gs
# -- ge C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\g\ge
# -- gg C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\g\gg
# b C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b
# -- bd C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\bd
# -- be C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\be
# -- bf C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\bf
# -- bs C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\bs
# -- bg C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\bg
# -- b6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\b6
# -- b7 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\b7
# -- bk C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\bk
# -- bu C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\bu
# -- b5 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\b5
# -- b1 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\b1
# -- b3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\b3
# -- b4 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\b\b4
# w C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w
# -- we C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\we
# -- wc C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wc
# -- wf C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wf
# -- w9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\w9
# -- wd C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wd
# -- w4 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\w4
# -- w7 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\w7
# -- wt C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wt
# -- w1 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\w1
# -- w2 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\w2
# -- w0 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\w0
# -- w6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\w6
# -- w5 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\w5
# -- w3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\w3
# -- ws C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\ws
# -- ww C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\ww
# -- wz C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wz
# -- wm C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wm
# -- wx C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wx
# -- wj C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wj
# -- wp C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wp
# -- wr C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wr
# -- wq C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wq
# -- wy C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wy
# -- wk C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wk
# -- wh C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wh
# -- w8 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\w8
# -- wv C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wv
# -- wu C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wu
# -- wb C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wb
# -- wn C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\w\wn
# 7 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\7
# -- 75 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\7\75
# -- 7h C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\7\7h
# -- 7j C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\7\7j
# -- 7n C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\7\7n
# -- 7r C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\7\7r
# -- 7p C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\7\7p
# 9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9
# -- 9z C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9z
# -- 9y C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9y
# -- 9v C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9v
# -- 9q C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9q
# -- 9f C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9f
# -- 9e C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9e
# -- 9s C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9s
# -- 9t C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9t
# -- 9g C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9g
# -- 9u C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9u
# -- 9m C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9m
# -- 9w C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9w
# -- 9r C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9r
# -- 9x C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9x
# -- 9p C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\9\9p
# c C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c
# -- c1 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\c1
# -- c2 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\c2
# -- cv C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\cv
# -- c3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\c3
# -- c7 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\c7
# -- cg C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\cg
# -- cs C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\cs
# -- ck C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\ck
# -- cf C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\cf
# -- ch C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\ch
# -- cu C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\cu
# -- cc C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\cc
# -- c5 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\c5
# -- cb C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\cb
# -- c6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\c6
# -- c0 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\c0
# -- c8 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\c8
# -- c9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\c9
# -- c4 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\c4
# -- cd C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\c\cd
# f C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f
# -- f6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\f6
# -- fd C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\fd
# -- f3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\f3
# -- f7 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\f7
# -- f9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\f9
# -- f2 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\f2
# -- f4 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\f4
# -- f0 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\f0
# -- f8 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\f8
# -- fj C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\fj
# -- fk C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\fk
# -- fh C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\fh
# -- fs C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\fs
# -- fe C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\fe
# -- f5 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\f5
# -- fb C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\fb
# -- fg C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\fg
# -- fu C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\fu
# -- ff C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\ff
# -- fm C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\fm
# -- fc C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\fc
# -- f1 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\f\f1
# k C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k
# -- kz C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\kz
# -- ky C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\ky
# -- k3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\k3
# -- ke C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\ke
# -- kd C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\kd
# -- kx C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\kx
# -- kr C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\kr
# -- kq C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\kq
# -- kv C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\kv
# -- ks C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\ks
# -- kt C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\kt
# -- k9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\k9
# -- kk C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\kk
# -- kw C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\kw
# -- km C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\km
# -- kp C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\kp
# -- ku C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\ku
# -- kg C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\kg
# -- k6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\k6
# -- k7 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\k\k7
# q C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q
# -- qv C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qv
# -- qd C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qd
# -- qq C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qq
# -- qw C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qw
# -- qg C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qg
# -- qx C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qx
# -- qp C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qp
# -- qr C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qr
# -- qz C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qz
# -- qy C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qy
# -- q9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\q9
# -- qu C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qu
# -- qs C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qs
# -- qe C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qe
# -- qj C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qj
# -- qf C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\q\qf
# x C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\x
# -- xn C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\x\xn
# -- x4 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\x\x4
# -- xp C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\x\xp
# -- xb C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\x\xb
# -- xj C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\x\xj
# -- xc C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\x\xc
# -- x8 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\x\x8
# -- x9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\x\x9
# -- x3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\x\x3
# -- x1 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\x\x1
# r C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r
# -- r1 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\r1
# -- r3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\r3
# -- rc C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rc
# -- r7 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\r7
# -- rb C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rb
# -- rh C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rh
# -- ru C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\ru
# -- rk C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rk
# -- rj C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rj
# -- rr C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rr
# -- rn C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rn
# -- rq C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rq
# -- rp C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rp
# -- r6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\r6
# -- ry C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\ry
# -- rw C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rw
# -- rv C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rv
# -- rs C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rs
# -- rt C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rt
# -- r2 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\r2
# -- rd C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rd
# -- rx C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\rx
# -- r5 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\r5
# -- r4 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\r4
# -- r0 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\r0
# -- re C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\r\re
# 4 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\4
# -- 4x C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\4\4x
# -- 4q C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\4\4q
# -- 4r C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\4\4r
# -- 4w C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\4\4w
# 8 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\8
# -- 87 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\8\87
# -- 8e C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\8\8e
# -- 88 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\8\88
# 2 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\2
# -- 2s C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\2\2s
# -- 2j C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\2\2j
# -- 2h C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\2\2h
# -- 2k C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\2\2k
# -- 2t C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\2\2t
# -- 2y C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\2\2y
# -- 2v C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\2\2v
# -- 2u C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\2\2u
# -- 2e C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\2\2e
# m C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\m
# -- mj C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\m\mj
# -- mk C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\m\mk
# -- mh C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\m\mh
# -- mp C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\m\mp
# -- m5 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\m\m5
# -- mx C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\m\mx
# z C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\z
# -- z0 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\z\z0
# -- z6 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\z\z6
# -- zk C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\z\zk
# -- zs C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\z\zs
# -- zg C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\z\zg
# -- zu C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\z\zu
# -- z9 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\z\z9
# p C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\p
# -- px C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\p\px
# -- pz C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\p\pz
# 3 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\3
# -- 3z C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\3\3z
# -- 3e C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\3\3e
# -- 35 C:\Users\family\DSCProjects\DSC\DSC650\assignment03\results\geoindex\3\35

# %% [markdown]
# ### 3.2.b Simple Search Feature

# %%
def airport_search(latitude, longitude,distance=150):
    
    #//*** Distance in kilometers
    
    geoindex_dir = results_dir.joinpath('geoindex')
    
    tgt_geohash = pygeohash.encode(latitude, longitude)
    
    level1 = tgt_geohash[:1]
    level2 = tgt_geohash[:2]
    
    folderpath = geoindex_dir.joinpath(level1).joinpath(level2)
    
    #//*** If Filepath doesn't exist, blame the user!
    if os.path.exists(folderpath) == False:
        print("There are no airports near these coordinates")
        return
    
    #//*** Get a list of files in the folder path
    files = os.listdir(folderpath)
    
    airport_dict = {}
    
    airports_in_range = []
    
    #//*** Load all airports into a dictionary
    for file in files:
        
        filepath = folderpath.joinpath(file)
        
        #//*** Decode compressed JSON file.
        with gzip.open(filepath,'rb') as f:
            
            #//*** Open each file and add to dictionary
            for key,value in json.loads(f.read().decode()).items():
                airport_dict[key] = value
                
                #//*** Find the Distance and add to dist_dict.
                #//*** Makes it easier to search by distance
                airport_distance = int(pygeohash.geohash_approximate_distance(tgt_geohash, key) / 1000 )
                
                #//*** If Airport_Distance is less than Target distance, keep airport geohash for reporting
                if airport_distance <= distance:
                    airports_in_range.append(key)
                    
                
                
                
        
    #for key,value in dist_dict.items():
    #    print(tgt_geohash,key,value,airport_dict[key]['name'],airport_dict[key]['city'],airport_dict[key]['tz_id'])
    
    print(f"There are {len(airports_in_range)} airports within {distance}km of ({latitude}, {longitude})")
    for index, dst_geohash in enumerate(airports_in_range):
        print(f"{index+1}.) {int(pygeohash.geohash_approximate_distance(tgt_geohash, dst_geohash) / 1000 )}km {airport_dict[dst_geohash]['name']}, {airport_dict[dst_geohash]['city']} Region: {airport_dict[dst_geohash]['tz_id']}")
        
        
    print()
    
                                   
                                   
    
airport_search(41.1499988, -95.91779)

print("Search Near the San Francisco Bay Area")
airport_search(37.59592,-122.01375)

print("Search airports near Berlin, DE")
airport_search(52.52246,13.40457)

print("Search airports near Dubai, UAE")
airport_search(25.19721,55.26848)
# Out:
# There are 2 airports within 150km of (41.1499988, -95.91779)
# 1.) 19km Eppley Airfield, Omaha Region: America/Chicago
# 2.) 123km Lincoln Airport, Lincoln Region: America/Chicago
#
# Search Near the San Francisco Bay Area
# There are 5 airports within 150km of (37.59592, -122.01375)
# 1.) 123km Monterey Peninsula Airport, Monterey Region: America/Los_Angeles
# 2.) 123km Metropolitan Oakland International Airport, Oakland Region: America/Los_Angeles
# 3.) 123km Norman Y. Mineta San Jose International Airport, San Jose Region: America/Los_Angeles
# 4.) 123km Stockton Metropolitan Airport, Stockton Region: America/Los_Angeles
# 5.) 123km Modesto City Co-Harry Sham Field, Modesto Region: America/Los_Angeles
#
# Search airports near Berlin, DE
# There are 2 airports within 150km of (52.52246, 13.40457)
# 1.) 123km Berlin-Tegel Airport, Berlin Region: Europe/Berlin
# 2.) 123km Berlin-Schönefeld Airport, Berlin Region: Europe/Berlin
#
# Search airports near Dubai, UAE
# There are 3 airports within 150km of (25.19721, 55.26848)
# 1.) 123km Al Maktoum International Airport, Dubai Region: Asia/Dubai
# 2.) 19km Dubai International Airport, Dubai Region: Asia/Dubai
# 3.) 123km Al Ain International Airport, Al Ain Region: Asia/Dubai
