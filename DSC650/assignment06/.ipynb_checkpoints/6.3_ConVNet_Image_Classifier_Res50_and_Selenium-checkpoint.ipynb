# %% [markdown]
# # Stoneburner, Kurt
# - ## DSC 650 - Week 06
# - ## Assignment 6.3 - Load the ResNet50 model. Perform image classification on five to ten images of your choice.
#
# Reference:
# https://keras.io/api/applications/#classify-imagenet-classes-with-resnet50
#
# Resnet Tutorial/Explainer:
# https://am-nazerz.medium.com/transfer-learning-using-pre-trained-models-for-image-classification-resnet50-in-keras-e140892180d1

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt
model = ResNet50(weights='imagenet')

img_path = './results/elephant.jpg'
img_path = './results/tiger.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# Predicted: [('n02129604', 'tiger', 0.7411675), ('n02123159', 'tiger_cat', 0.2530865), ('n02128925', 'jaguar', 0.004568744)]

# %%
from IPython.display import Image
Image(filename=img_path)

# %%
import urllib.request
data = urllib.request.urlopen("https://duckduckgo.com/?q=random+animals&t=ffab&iar=images&iax=images&ia=images")
data = data.read().decode()
print(data)
#file = open("content.txt", "w+")
#file.write(data)
#file.close()
# Out:
# <!DOCTYPE html><html lang="en-US" class="no-js has-zcm  no-theme is-link-style-exp is-link-order-exp is-link-breadcrumb-exp is-related-search-exp is-vertical-tabs-exp"><head><meta name="description" content="DuckDuckGo. Privacy, Simplified."><meta http-equiv="content-type" content="text/html; charset=utf-8"><title>random animals at DuckDuckGo</title><!--DEFER DJS--><link rel="stylesheet" href="/s2028.css" type="text/css"><link rel="stylesheet" href="/r2028.css" type="text/css"><link rel="stylesheet" data-href="/wbmm2028.css" id="react-css" type="text/css"><script type="text/javascript" data-src="/wbmm3.js" id="react"></script><meta name="robots" content="noindex,nofollow"><meta name="referrer" content="origin"><meta name="apple-mobile-web-app-title" content="random animals"><link rel="preconnect" href="https://links.duckduckgo.com"><link rel="preload" href="/font/ProximaNova-Reg-webfont.woff2" as="font" type="font/woff2" crossorigin="anonymous" /><link rel="preload" href="/font/Proxi
# ...

# %%
import requests
import time
import random
urlpage ='https://abc7news.com/education/'
urlpage = "https://duckduckgo.com/?q=random+animals&t=ffab&iar=images&iax=images&ia=images"
print(urlpage)

from selenium import webdriver

# run firefox webdriver from executable path of your choice
driver = webdriver.Firefox()


# get web page
driver.get(urlpage)
# execute script to scroll down the page
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
# sleep for 30s
time.sleep(30)
# Out:
# https://duckduckgo.com/?q=random+animals&t=ffab&iar=images&iax=images&ia=images

# %%
from selenium.webdriver.common.by import By

#https://pynative.com/python-random-randrange/
import random

#//*** Number of Random images to chose from the results. Must be less than 100
image_count = 15

image_dict = {}

#results = driver.find_elements_by_class_name("tile--img__img")
results = driver.find_elements(By.CLASS_NAME,"tile--img__img")

print()

loop_random_value = random.randint(0, len(results)-1)

print(len(image_dict.keys()))
print(len(results),loop_random_value,results[loop_random_value].get_property('src'))

link = results[loop_random_value].get_property('src')
import urllib.request

disp_img = urllib.request.urlopen(link).read()



with open("temp.jpg", "wb") as binary_file:
    
    # Write bytes to file
    binary_file.write(disp_img)


img = image.load_img("temp.jpg", target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
Image(disp_img)
# Out:
# 0
# 100 91 https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.RX3gr5ExDvvywcz_32J7tAHaH4%26pid%3DApi&f=1
# Predicted: [('n01531178', 'goldfinch', 0.5022104), ('n04033901', 'quill', 0.15238777), ('n07753275', 'pineapple', 0.055251364)]

# %%
dir(By)
# Out:
# ['CLASS_NAME',
#  'CSS_SELECTOR',
#  'ID',
#  'LINK_TEXT',
#  'NAME',
#  'PARTIAL_LINK_TEXT',
#  'TAG_NAME',
#  'XPATH',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']
