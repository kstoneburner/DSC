# %% [markdown]
# https://towardsdatascience.com/data-science-skills-web-scraping-javascript-using-python-97a29738353f
#
# https://exceptionshub.com/selenium-cant-click-element-because-other-element-obscures-it.html
#
# https://www.toolsqa.com/selenium-webdriver/handle-iframes-in-selenium/
#
# https://www.selenium.dev/documentation/webdriver/elements/finders/
#
# https://www.selenium.dev/selenium/docs/api/javascript/module/selenium-webdriver/index_exports_By.html
#
# Add Excel Formatting
# https://medium.com/codeptivesolutions/https-medium-com-nensi26-formatting-in-excel-sheet-using-xlsxwriter-part-1-2c2c547b2bea

# %%
import time, datetime, requests,random, os, hashlib

from pathlib import Path

from selenium.webdriver.common.action_chains import ActionChains
from selenium import webdriver
from selenium.webdriver.common.by import By

import pandas as pd
#//*** install xlsxwriter for pandas
#pip install xlsxwriter

#//*********************************************************
#//*** Build the tgt_date from the slected Quarter and Year
#//*********************************************************
tgt_year = 2022
quarter = "Q4"

if quarter == "Q1":
    tgt_date = f"{tgt_year}-01-01"
elif quarter == "Q2": 
    tgt_date = f"{tgt_year}-04-01"
elif quarter == "Q3": 
    tgt_date = f"{tgt_year}-07-01"
elif quarter == "Q4": 
    tgt_date = f"{tgt_year}-10-01"

tgt_date = datetime.datetime.strptime(tgt_date, "%Y-%m-%d")

print(tgt_date)

#//*** Get Filename for dataframe Cache
cache_filepath =  f"{tgt_year}_{quarter}_scripts.dat"
current_dir = Path(os.getcwd()).absolute()
cache_filepath = current_dir.joinpath(cache_filepath)

#//*** If Cache File Exists Load it. Else Start a Fresh DataFrame
if os.path.exists(cache_filepath):
    cache_df = pd.read_pickle(cache_filepath)
else:
    cache_df = pd.DataFrame()
# Out:
# 2022-10-01 00:00:00

# %%
#//*** Parses a 
def get_scripts(source_urls,headless=True):
    
    out = []
    
    #//*** Initialize Headless Firefox options 
    options = webdriver.FirefoxOptions()
    options.add_argument('-headless')   
    
    if headless:


        #//*** Span Headless Instance
        page_driver = webdriver.Firefox(options=options)
    else:
        # run firefox webdriver from executable path of your choice
        page_driver = webdriver.Firefox()

    
    
    for i,url in enumerate(source_urls):
        
        error_counter = 1
        print(f"({i+1}/{len(source_urls)}) - {url}")
        
        while error_counter < 6:
            print("Downloading Page: Attempt ",error_counter )
            try:
                page_driver.get(url)
                error_counter = 10
            except:
                error_counter += 1
                
                print("Problem Getting Page...Trying Again")

        #//*** Reset any Story errors 
        story_error = False
        
        loop_story = {
                "url" : url,
                "headline" : None,
                "time_text" : None,
                "body_text" : None,
                'time_date' : None,
            }
        #//*******************
        #//**** Get Headline
        #//*******************

        #FITT_Article_main__body
        main_body = page_driver.find_elements(By.CLASS_NAME,"FITT_Article_main__body")
        
        #//*** Verify we have main_body elements
        if len(main_body) > 0:
            #//*** Assume Main Body is the first element. If not we in trouble
            #//*** mmmmm dirty dirty Type conversion
            main_body = main_body[0]
            

            #//*******************
            #//**** Get Headline
            #//*******************
            #//*** Only assign valid headline
            
            #//*** Get the Headline from the main Body. It should be the first (and only) h1. 
            headline = main_body.find_elements(By.CSS_SELECTOR,"h1")
            
            #//*** Check to ensure we actually have h1 elements
            if len(headline) > 0:
                #//*** Dirty dirty type conversion
                headline = headline[0].text
                
                #//*** Assign Headline
                loop_story["headline"] = headline
        
            #//********************
            #//**** Get Date
            #//********************

            #//*** Date is located withing the ShareByline Class
            byLine = main_body.find_elements(By.CLASS_NAME,"ShareByline")[0]

            #//*** Get All divs under ShareByline
            div_list = byLine.find_elements(By.CSS_SELECTOR,"div")

            #//*** The Date will be in a div with no children
            for elem in div_list:
                #//*** If div has div children, skip it
                if len(elem.find_elements(By.CSS_SELECTOR,"div")) > 0:
                       continue

                #//*** Try to convert Element Text to Date
                #//*** Skip Element if conversion fails
                try:
                    d = pd.to_datetime(elem.text)        
                except:
                    continue

                #//*** Verify d is actually a timestamp / Date.
                #//*** Will get NaT result on empty field
                if isinstance(d,pd._libs.tslibs.timestamps.Timestamp):
                    loop_story["time_text"] = elem.text
                    loop_story['time_date'] = d
                    break

            #//********************************
            #//*** Get Main Body Text
            #//********************************

            #//*** Article is contained within the article tag
            article = main_body.find_elements(By.CSS_SELECTOR,"article")

            whole_text = ""

            #//*** Double check we actually have the article
            if len(article) > 0:
                #//*** We could take the entire article text, but it includes related links and add text.
                #//*** We are better than that.
                #//*** Get each p element. Keep elements that have 0 children
                #//*** In the example, the first p element has one child, probably for datelineing. We'll keep the first
                #//*** p element then skip any element that has children.

                elems = article[0].find_elements(By.CSS_SELECTOR,"p")

                #//*** Check to see if we actually have story text
                if len(elems) > 0:
                    #//*** Assume First elem is valid
                    whole_text += elems[0].text
                    for elem in elems:
                        try:
                            #//*** Only Keep elements with no children
                            if len(elem.find_elements(By.XPATH, ".//*")) == 0:
                                whole_text += elem.text
                        except:
                            print("Problem processing Story Text. Element may have gone stale")
                            story_error = True 

                    loop_story["body_text"] = whole_text
            else:
                pass

            

            
        else:
            print("Problem Processing Main Body. Got a core parsing issue")
            story_error = True
    
        
        #//*** Throw an error if any loop_story field is None:
        for key,value in loop_story.items():
            
            if value == None:
                story_error = True
                print("Story Parsing Error:",key,"is",value)
            
        #//*** Keep Story if No Errors
        if not story_error:
            out.append(loop_story)
        
        #wait between 1/2 to 3 seconds
        time.sleep(random.randint(500, 3000)/1000)                                                              

    page_driver.quit()
                                                                        
    return out

# %%
def get_all_urls_in_page(source_url,tgt_date,headless=True):

    #//*** Keep all classnames in a dictionary
    g = {
        #//*** Classname for the Show More Button
        "class_more_button" : "show-button-more",
        
        #//*** Grid Classname that contains the linked stories
        "story_grid" : "grid3",
        
        #//*** Story Classes that contain the href Links
        "story_link_class" : "AnchorLink",
        
    }
    
    #//*** Initialize Headless Firefox options 
    options = webdriver.FirefoxOptions()
    options.add_argument('-headless')   
    
    if headless:


        #//*** Span Headless Instance
        driver = webdriver.Firefox(options=options)
    else:
        # run firefox webdriver from executable path of your choice
        driver = webdriver.Firefox()


    # Load Web Page
    driver.get(source_url)
    
    # execute script to scroll down the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")


    #//*****************************************************
    #//*** Wait until the Show More Button is loaded
    #//*****************************************************
    elements = []
    control = 0
    while len(elements) == 0:

        #//*** Page is Loaded when class_more_button is displayed
        #elements = driver.find_elements_by_class_name(g["class_more_button"])
        elements = driver.find_elements(By.CLASS_NAME,g["class_more_button"])

        control += 1
        #//*** Wait if element not found
        if len(elements) == 0:
            time.sleep(1)

        if control > 15:
            print("Show More Button Not Loaded!")
            return
            break

    #//*************************************************
    #//*** The first elements is the button to click
    #//*************************************************
    elem_show_more = elements[0]

    #actions = ActionChains(driver)
    #actions.move_to_element(element).perform()

    print(elem_show_more.is_displayed())
    print(elem_show_more.location['y'])
    
    #results = driver.find_elements_by_class_name(g["story_grid"])[0].find_elements_by_class_name(g["story_link_class"])
    results = driver.find_elements(By.CLASS_NAME,g["story_grid"])[0].find_elements(By.CLASS_NAME,g["story_link_class"])

    if len(results) > 0:
        print("Last Page: ", results[0].get_property('href'))

    
    
    #print(results[-1].get_property('href'))

    
    #print(story_time,tgt_date, story_time < tgt_date)
                                                                        
    #//*** Get the last url to check in stories are within the quarter
    last_url = results[-1].get_property('href')
    
    try:
        #//*** Download the last script
        last_script = get_scripts([last_url])[0]
    except:
        print("Problem getting last script")
        print("Last url: ", last_url)
        print("get Scripts: ", get_scripts([last_url]))
        print("Skipping..")
        return []
    last_date = last_script['time_date']
    print("Last Script: ", last_script['headline'],"\n",last_script["time_text"])
    print("Last Script: ", last_script['time_date'] < tgt_date)
    
    #//*** Maximum number of while loops.
    maxDepth = 20
    depth = 0
    
    #//*** Click Show More until Last Story is older than the tgt_date
    while last_date > tgt_date:
        depth += 1
        
        #//*** Scroll to Bottom of page
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        
        print(f"Clicking More Depth: {depth}")
        #print(dir(elem_show_more))
        while elem_show_more.is_displayed() == False:
            print("Is Displayed:",str(elem_show_more.is_displayed()))
            time.sleep(1)
        
        
        try:
            #//*** Click Show More
            elem_show_more.click()
        except:
            iframes = driver.find_elements_by_tag_name("iframe")
            for iframe in iframes:
                print(iframe.get_property("name"))
                
                
                driver.execute_script("arguments[0].style.visibility='hidden'", iframe)
            #//*** Click Show More
            elem_show_more.click()
                
        #    return

    
        #//*** Get Updated Results
        #results = driver.find_elements_by_class_name(g["story_grid"])[0].find_elements_by_class_name(g["story_link_class"])        
        results = driver.find_elements(By.CLASS_NAME,g["story_grid"])[0].find_elements(By.CLASS_NAME,g["story_link_class"])        
        
        #//*** Get the last url to check in stories are within the quarter
        last_url = results[-1].get_property('href')

        #//*** Download the last script
        script_list = get_scripts([last_url])
        if len(script_list) == 0:
            print("No Scripts Found in this category")
            print("Quitting")
            driver.quit()
            return []
            
        last_script = script_list[0]
        last_date = last_script['time_date']
        print("Last Script: ", last_script['headline'],"\n",last_script["time_text"])
        print("Last Script: ", last_script['time_date'] < tgt_date)

        if depth > maxDepth:
            print("Maximum Depth Reached on Clicking Show More")
            break
        
    
    out = []
    
    for result in results:
        out.append(result.get_property('href'))
    
    #//*** Shut down main scrape
    driver.quit()
    
    

    return out

# %%
#//*** Hash url list and compare to cache_df
#//*** returns a tuple of urls (orig_urls,dupe_urls)
def keep_original_urls(urls,cache_df):
    orig_urls = []
    dupe_urls = []
    
    tdf = pd.DataFrame()
    tdf['urls'] = urls
    
    tdf['hash'] = pd.util.hash_pandas_object(tdf['urls'])


    #//*** Check for Duplicates
    tdf['dupe'] = tdf['hash'].isin(cache_df['hash'])
    #tdf['dupe'] = tdf['urls'].isin(cache_df['urls'])
    
    #//*** Keep Only False Stories, which are not duplicates
    #//*** This means a story can have only a single category.
    #//*** May have to handle multiple categories at a future time
    #print(f"Length Before: {len(tdf)} ")

    orig_urls = list(tdf[tdf['dupe'] == False]['urls'])
    dupe_urls = list(tdf[tdf['dupe'] == True]['urls'])

    
    
    return orig_urls,dupe_urls

# %%
url_items = [
    {
        "url" : "https://abc7news.com/tag/climate-change/",
        "cat" : "Climate"
    },
    {
        "url" : "https://abc7news.com/tag/environment/",
        "cat" : "Environment"
    },
 
    {
        "url" : "https://abc7news.com/tag/economy/",
        "cat" : "Economy"
    },
    {
        "url" : "https://abc7news.com/tag/jobs/",
        "cat" : "Jobs"
    },    
    {
        "url" : "https://abc7news.com/tag/safety/",
        "cat" : "Safety"
    },
    {
        "url" : "https://abc7news.com/tag/health/",
        "cat" : "Health"
    },
    {
        "url" : "https://abc7news.com/education/",
        "cat" : "Education"
    },
    {
        "url" : "https://abc7news.com/tag/race-and-culture/",
        "cat" : "Race"
    },
    {
        "url" : "https://abc7news.com/tag/discrimination/",
        "cat" : "Discrimination"
    },
    {
        "url" : "https://abc7news.com/tag/civil-rights/",
        "cat" : "Civil Rights"
    },
    {
        "url" : "https://abc7news.com/tag/building-a-better-bay-area/",
        "cat" : "BABBA"
    },
    {
        "url" : "https://abc7news.com/7onyourside/",
        "cat" : "7OYS"
    },
    {
        "url" : "https://abc7news.com/tag/covid-19/",
        "cat" : "COVID"
    },

    {
        "url" : "https://abc7news.com/iteam/",
        "cat" : "I-TEAM"
    },
    

    
]
urlpages = ['https://abc7news.com/education/',
            'https://abc7news.com/tag/building-a-better-bay-area/',
            'https://abc7news.com/7onyourside/',
            'https://abc7news.com/tag/covid-19/',
            'https://abc7news.com/tag/climate-change/',
            'https://abc7news.com/iteam/'
           ]

#urlpage ='https://abc7news.com/education/'
#urls = get_all_urls_in_page(urlpages[1],tgt_date,False)
#print(urlpage)

#//*** Loop through top level url_items
for item in url_items:
    cat_url = item['url']
    cat = item['cat']
    
    #//*** Download the ctageory URLs
    urls = get_all_urls_in_page(cat_url,tgt_date,False)
    
    #//*** Get non-duplicate urls to download and a list of the duplicate urls
    #//*** We may need to incorporate duplicates with different categories...later
    if len(cache_df) > 0:
        urls_to_dl,dupe_urls = keep_original_urls(urls,cache_df)
    else:
        #//*** There is no cache initialize and move one
        urls_to_dl = urls
        dupe_urls = []
    print("=====================")
    print(f"Category: {cat}")
    print("=====================")
    print(f"DL Items: {len(urls_to_dl)} - Duplicate: {len(dupe_urls)}")
    
    if len(urls_to_dl) == 0:
        print("No New Items to Download!")
    
    if len(urls_to_dl) > 0:
        scripts = get_scripts(urls_to_dl)
        
        #//*** Convert Scripts to DataFrame
        df = pd.DataFrame()
        #df['urls'] = urls_to_dl

        s = {}

        #//*** Get each script value as a list
        for script in scripts:

            for key,value in script.items():
                if key not in s.keys():
                    s[key] = []
                s[key].append(value)

        #//*** build Urls field
        #//*** Use the Story URL in case an url was skipped.
        df['urls'] = s['url']
        df['hash'] = pd.util.hash_pandas_object(df['urls'])
        df['cat'] = cat

        #//*** Add lists of script values as columns
        for key,value in s.items():
            df[key] = value

        #//*** Combine cache_df and df
        cache_df = pd.concat([cache_df,df])


#//*** Everything is Gathered. Write Cache_df to disk
#//*** Write DF to file
pd.to_pickle(cache_df,cache_filepath)
# Out:
# True
# 1807
# Last Page:  https://abc7news.com/power-outage-ca-heat-wave-flex-alert-california-schools-ac-energy-use-weather/12207872/
# (1/1) - https://abc7news.com/water-conservation-petaluma-use-ca-drought-saving/12178956/
# Downloading Page: Attempt  1
# Last Script:  North Bay city leads Bay Area and California for water conservation during historic drought
#  Monday, August 29, 2022
# Last Script:  False
# Clicking More Depth: 1
# (1/1) - https://abc7news.com/lake-mead-dead-bodies-nevada-climate-change/12107581/
# Downloading Page: Attempt  1
# Last Script:  Fourth set of human remains discovered in Lake Mead's receding waters amid drought
#  Sunday, August 7, 2022
# Last Script:  False
# Clicking More Depth: 2
# (1/1) - https://abc7news.com/coldplay-climate-pledge-arena-music-of-the-spheres-tour-carbon-neutral-levis-stadium-2022/11824183/
# Downloading Page: Attempt  1
# Last Script:  Coldplay app encourages fans to ride public transportation to Levi's concert in Santa Clara
#  Friday, May 6, 2022
# Last Script:  True
# =====================
# Category: Climate
# =====================
# DL Items: 36 - Duplicate: 0
# (1/36) - https://abc7news.com/power-outage-ca-heat-wave-flex-alert-california-schools-ac-energy-use-weather/12207872/
# Downloading Page: Attempt  1
# (2/36) - https://abc7news.com/power-outage-ca-heat-wave-flex-alert-california-schools-ac-energy-use-weather/12203370/
# Downloading Page: Attempt  1
# (3/36) - https://abc7news.com/bay-area-blackouts-power-outages-ca-grid-heat-wave/12206035/
# Downloading Page: Attempt  1
# (4/36) - https://abc7news.com/thwaites-glacier-doomsday-antarctica-sea-level-rise/12203645/
# Downloading Page: Attempt  1
# (5/36) - https://abc7news.com/ca-heat-wave-flex-alert-california-gavin-newsom-energy-use-weather/12200269/
# Downloading Page: Attempt  1
# Problem processing Story Text. Element may have gone stale
# Problem processing Story Text. Element may have gone stale
# (6/36) - https://abc7news.com/ca-heat-wave-flex-alert-california-gavin-newsom-energy-use-weather/12183148/
# Downloading Page: Attempt  1
# (7/36) - https://abc7news.com/flex-alert-rolling-blackouts-california-power-outages-pge/12187119/
# Downloading Page: Attempt  1
# (8/36) - https://abc7news.com/dutch-slough-climate-change-tidal-marsh-environmental-research-east-bay/12181153/
# Downloading Page: Attempt  1
# (9/36) - https://abc7news.com/seaweed-invasion-caribbean-toxic-sargassum-mexico/12182985/
# Downloading Page: Attempt  1
# (10/36) - https://abc7news.com/not-having-kids-gen-z-millennial-us-birth-rate/12180436/
# Downloading Page: Attempt  1
# (11/36) - https://abc7news.com/greenland-zombie-ice-sea-level-climate-change/12179468/
# (32/36) - https://abc7news.com/crypto-market-crash-bitcoin-whats-causing-the-should-i-buy-now/11841736/
# Downloading Page: Attempt  1
# (33/36) - https://abc7news.com/biden-inflation-speech-today-news-trump/11834376/
# Downloading Page: Attempt  1
# (34/36) - https://abc7news.com/gas-prices-expensive-us-san-francisco-bay-area-most/11830161/
# Downloading Page: Attempt  1
# (35/36) - https://abc7news.com/california-gas-rebate-checks-delayed-newsom-report/11828736/
# Downloading Page: Attempt  1
# (36/36) - https://abc7news.com/stock-market-today-dow-jones-stocks-inflation/11820683/
# Downloading Page: Attempt  1
# True
# 1766
# Last Page:  https://abc7news.com/peloton-bike-raising-prices-layoffs-price/12121926/
# (1/1) - https://abc7news.com/4-day-work-week-uk-four-pilot-companies/11935573/
# Downloading Page: Attempt  1
# Last Script:  World's biggest 4-day work week pilot begins in UK, involving 3.3K workers at 70 companies
#  Tuesday, June 7, 2022
# Last Script:  True
# =====================
# Category: Jobs
# =====================
# DL Items: 11 - Duplicate: 1
# (1/11) - https://abc7news.com/peloton-bike-raising-prices-layoffs-price/12121926/
# Downloading Page: Attempt  1
# (2/11) - https://abc7news.com/veteran-career-fairs-2022-disney-veterans-institute-hiring-heroes/12102105/
# Downloading Page: Attempt  1
# (3/11) - https://abc7news.com/digital-production-associate-jobs-bay-area-news-san-francisco-abc7-job-openings-opening/12112343/
# Downloading Page: Attempt  1
# (4/11) - https://abc7news.com/reporter-jobs-bay-area-news-san-francisco-abc7-job-openings-opening/12110380/
# Downloading Page: Attempt  1
# (5/11) - https://abc7news.com/oakland-unified-school-district-ousd-back-to-hiring-teachers-teacher-shortage/12109249/
# Downloading Page: Attempt  1
# (6/11) - https://abc7news.com/ac-transit-careers-jobs-recruiting/12092018/
# Downloading Page: Attempt  1
# (7/11) - https://abc7news.com/abc7-harassment-sexual-workplace/3143891/
# Downloading Page: Attempt  1
# (8/11) - https://abc7news.com/abc7-veterans-resources-suicide/3195820/
# Downloading Page: Attempt  1
# (9/11) - https://abc7news.com/guns-gun-control-laws-violence/3160748/
# Downloading Page: Attempt  1
# (10/11) - https://abc7news.com/time2play-buffet-taste-tester-fun-jobs-las-vegas-job/12033518/
# Downloading Page: Attempt  1
# (11/11) - https://abc7news.com/4-day-work-week-uk-four-pilot-companies/11935573/
# Downloading Page: Attempt  1
# True
# 1822
# Last Page:  https://abc7news.com/target-car-seat-trade-in-dates-2022-coupon-baby-gear-stroller/12216508/
# (1/1) - https://abc7news.com/starbread-bakery-pittsburg-east-bay-attacked-covid-guidelines/12067950/
# Downloading Page: Attempt  1
# Last Script:  EXCLUSIVE: Starbread Pittsburg employees attacked by customer over COVID rules
#  Friday, July 22, 2022
# Last Script:  False
# Clicking More Depth: 1
# (1/1) - https://abc7news.com/san-jose-crime-sjpd-foot-patrols-increase-police-presence-in-downtown-department-funding/11958760/
# Downloading Page: Attempt  1
# Last Script:  San Jose considers adding police foot patrols to downtown
#  Tuesday, June 14, 2022
# Last Script:  True
# =====================
# Category: Safety
# =====================
# DL Items: 24 - Duplicate: 0
# Downloading Page: Attempt  1
# (24/24) - https://abc7news.com/san-jose-crime-sjpd-foot-patrols-increase-police-presence-in-downtown-department-funding/11958760/
# Downloading Page: Attempt  1
# True
# 1807
# Last Page:  https://abc7news.com/what-is-life-expectancy-us-average-2021/12183595/
# (1/1) - https://abc7news.com/pandemic-farmworkers-farmworker-conditions-benefits-essential-work/12135608/
# Downloading Page: Attempt  1
# Last Script:  Heralded as heroes, Bay Area farmworkers still in the shadows post-pandemic
#  Thursday, August 18, 2022
# Last Script:  False
# Clicking More Depth: 1
# (1/1) - https://abc7news.com/monkeypox-vaccine-san-francisco-bay-area-cases-symptoms-sf/12074323/
# Downloading Page: Attempt  1
# Last Script:  Monkeypox SF Bay Area update: Local health emergency declared in San Francisco
#  Friday, July 29, 2022
# Last Script:  False
# Clicking More Depth: 2
# (1/1) - https://abc7news.com/florida-covid-19-vaccines-white-house/11969969/
# Downloading Page: Attempt  1
# Last Script:  Florida's decision not to preorder vaccines for young kids will create access issues: White House
#  Friday, June 17, 2022
# Last Script:  True
# =====================
# Category: Health
# =====================
# DL Items: 35 - Duplicate: 1
# (1/35) - https://abc7news.com/what-is-life-expectancy-us-average-2021/12183595/
# Downloading Page: Attempt  1
# (2/35) - https://abc7news.com/monkeypox-death-immunocompromised-patient-dies-texas/12182757/
# Downloading Page: Attempt  1
# (3/35) - https://abc7news.com/monkeypox-vaccine-clinic-san-francisco-vaccines-bay-area-cases-symptoms/12153020/
# Downloading Page: Attempt  1
# Problem processing Story Text. Element may have gone stale
# Problem processing Story Text. Element may have gone stale
# Problem processing Story Text. Element may have gone stale
# (4/35) - https://abc7news.com/mask-mandate-alum-rock-union-school-district-sj-schools-covid-guidelines-cdc/12167180/
# Downloading Page: Attempt  1
# (5/35) - https://abc7news.com/california-drug-injection-sites-governor-gavin-newsroom-bill-vetoed-iv-user-ca/12154913/
# Downloading Page: Attempt  1
# (6/35) - https://abc7news.com/pfizer-covid-19-vaccines-omicron/12154914/
# Downloading Page: Attempt  1
# (7/35) - https://abc7news.com/san-francisco-80-over-celebrating-old-age-ucsf-dr-anna-chodos-life-after-30s/12145095/
# Downloading Page: Attempt  1
# (8/35) - https://abc7news.com/fda-almond-recall-blue-diamond-growers-almonds-salmonella/12147671/
# Downloading Page: Attempt  1
# (9/35) - https://abc7news.com/genentech-lab-south-san-francisco-biologic-drugs-manufacturing/12143644/
# Downloading Page: Attempt  1
# (10/35) - https://abc7news.com/monkeypox-vaccine-clinic-san-francisco-vaccines-bay-area-cases-symptoms/12127093/
# Downloading Page: Attempt  1
# (11/35) - https://abc7news.com/mountain-view-whisman-school-district-students-covid-19-masks-video-student-sent-home-no-mask-theuerkauf-elementary/12140927/
# Downloading Page: Attempt  1
# (12/35) - https://abc7news.com/pandemic-farmworkers-farmworker-conditions-benefits-essential-work/12135608/
# Downloading Page: Attempt  1
# (13/35) - https://abc7news.com/gavin-newsom-master-plan-mental-health-kids-fresno/12137527/
# Downloading Page: Attempt  1
# Last Script:  Texas doctor suing Chase bank for denying service: 'They didn't respect my credentials'
#  Thursday, February 3, 2022
# Last Script:  True
# =====================
# Category: Discrimination
# =====================
# DL Items: 4 - Duplicate: 8
# (1/4) - https://abc7news.com/jett-hawkins-crown-coalition-ida-nelson-black-hair/11573758/
# Downloading Page: Attempt  1
# (2/4) - https://abc7news.com/labor-union-unions-san-francisco-sf-whistleblower/11549963/
# Downloading Page: Attempt  1
# (3/4) - https://abc7news.com/diabetes-sofi-stadium-super-bowl-lvi-location-in-los-angeles-ca/11546372/
# Downloading Page: Attempt  1
# (4/4) - https://abc7news.com/jp-morgan-chase-bank-discrimination-lawsuit/11532589/
# Downloading Page: Attempt  1
# True
# 1804
# Last Page:  https://abc7news.com/nyc-subway-shooting-frank-james-fbi-civil-rights/11801180/
# (1/1) - https://abc7news.com/title-ix-protections-transgender-department-of-education-for-students/10797768/
# Downloading Page: Attempt  1
# Last Script:  Education Dept. says Title IX protections apply to LGBTQ+ students
#  Wednesday, June 16, 2021
# Last Script:  True
# =====================
# Category: Civil Rights
# =====================
# DL Items: 0 - Duplicate: 12
# No New Items to Download!
# True
# 1777
# Last Page:  https://abc7news.com/sf-street-vendors-mission-district-stolen-items-being-sold-vendor-permit/12225349/
# (1/1) - https://abc7news.com/covid-pandemic-learning-loss-back-to-school-students/12188096/
# Downloading Page: Attempt  1
# Last Script:  COVID pandemic, lockdowns set student learning back decades, new data shows
#  Thursday, September 1, 2022
# Last Script:  False
# Clicking More Depth: 1
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# (1/1) - https://abc7news.com/covid-pandemic-learning-loss-back-to-school-students/12188096/
# Downloading Page: Attempt  1
# Last Script:  COVID pandemic, lockdowns set student learning back decades, new data shows
#  Thursday, September 1, 2022
# Last Script:  False
# Clicking More Depth: 2
# (1/1) - https://abc7news.com/camp-okizu-destroyed-in-north-complex-fire-new-location-livermore-for-families-of-cancer-patients/12135458/
# Downloading Page: Attempt  1
# Last Script:  Camp Okizu for families coping with cancer gets new life in temporary location
#  Friday, August 19, 2022
# Last Script:  False
# Clicking More Depth: 3
# (1/1) - https://abc7news.com/back-to-school-oakland-backpack-giveaway-ousd-acron-projects/12115855/
# Downloading Page: Attempt  1
# Last Script:  Oakland backpack giveaway sends message of encouragement to students
#  Wednesday, August 10, 2022
# Last Script:  False
# Clicking More Depth: 4
# (1/1) - https://abc7news.com/monkeypox-state-of-emergency-california-outbreak-vaccine-testing/12094663/
# Downloading Page: Attempt  1
# Last Script:  Here's what declaration of monkeypox as state of emergency means for California
#  Tuesday, August 2, 2022
# Last Script:  False
# Clicking More Depth: 5
# (1/1) - https://abc7news.com/monkeypox-vaccine-production-testing-what-company-makes-monkepox-cases-in-bay-area/12071383/
# Downloading Page: Attempt  1
# Last Script:  California lawmakers pressure federal officials to boost monkeypox vaccine production
#  Monday, July 25, 2022
# Last Script:  False
# Clicking More Depth: 6
# (1/1) - https://abc7news.com/lowell-high-school-admissions-merit-based-sfusd-board-vote-sf-lottery-system-ranking/11989124/
# Downloading Page: Attempt  1
# Last Script:  SF school board votes to bring back merit-based admissions at Lowell High School
# Downloading Page: Attempt  1
# (22/84) - https://abc7news.com/sf-mission-bay-sinking-san-francisco-sidewalks-streets-berding--weil-lawsuit/12159249/
# Downloading Page: Attempt  1
# (23/84) - https://abc7news.com/autonomous-vehicles-home-delivery-self-driving-cars-delivering-nuro-aurora/12139535/
# Downloading Page: Attempt  1
# (24/84) - https://abc7news.com/camp-okizu-destroyed-in-north-complex-fire-new-location-livermore-for-families-of-cancer-patients/12135458/
# Downloading Page: Attempt  1
# ...
# Downloading Page: Attempt  1
# (72/84) - https://abc7news.com/san-jose-underground-bunker-stolen-items-in-sj-homeless-encampment-camp-near-coyote-creek-wool-drive/12050583/
# Downloading Page: Attempt  1
# (73/84) - https://abc7news.com/brooke-jenkins-sf-district-attorney-crime-chesa-boudin-replacement/12050416/
# Downloading Page: Attempt  1
# (74/84) - https://abc7news.com/inflation-91-bay-area-rent-gas-prices-barbell-effect/12049783/
# Downloading Page: Attempt  1
# (75/84) - https://abc7news.com/sf-monkeypox-cases-outbreak-vaccine-appointments/12046671/
# Downloading Page: Attempt  1
# (76/84) - https://abc7news.com/ba5-covid-immunity-omicron-ba4-reinfections-how-long-are-you-immune-from-after-having-it/12047575/
# Downloading Page: Attempt  1
# (77/84) - https://abc7news.com/sf-drug-crisis-tenderloin-homeless-video-use/12044189/
# Downloading Page: Attempt  1
# (78/84) - https://abc7news.com/omicron-ba5-subvariant-transmissibility-latest-covid-variant-symptoms/12044541/
# Downloading Page: Attempt  1
# (79/84) - https://abc7news.com/art-gallery-closed-businesses-shuttered-storefronts-the-drawing-room/12024756/
# Downloading Page: Attempt  1
# (80/84) - https://abc7news.com/sf-pride-event-monkeypox-comfort-and-joy-electroluxx-at-midway-exposure/12021571/
# Downloading Page: Attempt  1
# (81/84) - https://abc7news.com/sf-tenderloin-news-linkage-center-district-homeless-in-san-francisco/12004611/
# Downloading Page: Attempt  1
# (82/84) - https://abc7news.com/ca-gas-tax-prices-in-california-annual-increase-rebate/12001986/
# Downloading Page: Attempt  1
# (83/84) - https://abc7news.com/monkeypox-cases-in-bay-area-wastewater-vaccine-cdc/12001998/
# Downloading Page: Attempt  1
# (84/84) - https://abc7news.com/lowell-high-school-admissions-merit-based-sfusd-board-vote-sf-lottery-system-ranking/11989124/
# Downloading Page: Attempt  1
# True
# 1807
# Last Page:  https://abc7news.com/inflation-reduction-act-energy-rebate-solar-power-alternative/12191090/
# (1/1) - https://abc7news.com/pge-impostor-scam-wells-fargo-zelle-transfer-money/12117841/
# Downloading Page: Attempt  1
# Last Script:  PG&E imposters use Zelle to steal thousands from Bay Area Wells Fargo customer
#  Friday, August 26, 2022
# Last Script:  False
# Clicking More Depth: 1
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# Is Displayed: False
# Downloading Page: Attempt  1
# (23/36) - https://abc7news.com/gift-cards-refund-get-money-back-from-starbucks-reloadable-card/12067873/
# Downloading Page: Attempt  1
# (24/36) - https://abc7news.com/robocalls-robotexts-spam-calls-texts/12061561/
# Downloading Page: Attempt  1
# (25/36) - https://abc7news.com/california-unemployment-tax-refund-seized-edd-fraud-scam/12059394/
# Downloading Page: Attempt  1
# (26/36) - https://abc7news.com/san-francisco-parking-violations-driveway-carport/12009975/
# Downloading Page: Attempt  1
# (27/36) - https://abc7news.com/counterfeit-sneakers-nikes-fake-how-to-tell-if-are/12054273/
# Downloading Page: Attempt  1
# (28/36) - https://abc7news.com/san-francisco-parking-violations-sf-couple-army-aerial-photo-expert/12051938/
# Downloading Page: Attempt  1
# (29/36) - https://abc7news.com/san-francisco-parking-violations-driveway-carport/12044542/
# Downloading Page: Attempt  1
# (30/36) - https://abc7news.com/fair-plan-california-insurance-homeowners-fire/12050142/
# Downloading Page: Attempt  1
# (31/36) - https://abc7news.com/amazon-prime-day-sale-deals-membership/12033229/
# Downloading Page: Attempt  1
# (32/36) - https://abc7news.com/crypto-romance-scam-fraud-cryptocurrency-defi-base/12046925/
# Downloading Page: Attempt  1
# (33/36) - https://abc7news.com/bank-of-america-class-action-lawsuit-zelle-scam-refund-app/12024520/
# Downloading Page: Attempt  1
# (34/36) - https://abc7news.com/lowes-return-policy-90-day-shipping-delays-returns/12020936/
# Downloading Page: Attempt  1
# (35/36) - https://abc7news.com/401k-plan-recover-lost-how-to-transfer-retirement-plans/12017666/
# Downloading Page: Attempt  1
# (36/36) - https://abc7news.com/dog-training-auburn-k9-trainer-qualifications-assembly-bill-1901/12007157/
# Downloading Page: Attempt  1
# True
# 1807
# Last Page:  https://abc7news.com/covid-boosters-cdc-booster-shots-coronavirus/12187380/
# (1/1) - https://abc7news.com/dr-fauci-dr-anthony-steps-down-covid-19-response/12153418/
# Downloading Page: Attempt  1
# Last Script:  Dr. Anthony Fauci, nation's top infectious disease expert at center of COVID response, to step down
#  Monday, August 22, 2022
# Last Script:  False
# Clicking More Depth: 1
# (1/1) - https://abc7news.com/dr-fauci-dr-anthony-steps-down-covid-19-response/12153418/
# Downloading Page: Attempt  1
# Last Script:  Dr. Anthony Fauci, nation's top infectious disease expert at center of COVID response, to step down
#  Monday, August 22, 2022
# Last Script:  False
# Clicking More Depth: 2
# (1/1) - https://abc7news.com/biden-covid-19-negative-test-sick/12104708/
# Downloading Page: Attempt  1
# Last Script:  Biden tests negative for COVID but will keep isolating out of 'caution'
#  Saturday, August 6, 2022
# Last Script:  False
# Clicking More Depth: 3
# (1/1) - https://abc7news.com/covid-testing-near-me-san-francisco-test-free/8098382/
# Downloading Page: Attempt  1
# Story Parsing Error: time_text is None
# Story Parsing Error: time_date is None
# No Scripts Found in this category
# Quitting
# =====================
# Category: COVID
# =====================
# DL Items: 0 - Duplicate: 0
# No New Items to Download!
# True
# 1799
# 0   WASHINGTON -- President Joe Biden will announc... 2022-07-20
# 1   WASHINGTON -- President Joe Biden will travel ... 2022-07-19
# 2   SANTA CRUZ, Calif. (KGO) -- As a senior land m... 2022-07-15
# 3   WASHINGTON -- The Supreme Court on Thursday li... 2022-06-30
# 4   SAN FRANCISCO -- There is no Spare the Air Ale... 2022-06-22
# ..                                                ...        ...
# 30  SAN FRANCISCO (KGO) -- The overturn of Roe wil... 2022-06-28
# 31  SAN FRANCISCO (KGO) -- People across the count... 2022-06-28
# 32  SAN FRANCISCO (KGO) -- Meal delivery service D... 2022-06-28
# 33  SAN FRANCISCO (KGO) -- New lawsuits are floodi... 2022-06-27
# 34  SAN FRANCISCO (KGO) -- An employee with UCSF s... 2022-06-22
#
# [1377 rows x 8 columns]

# %%
#cache_df['time_date'] = cache_df['time_date'].dt.date
#print("Length Before de-dupe:",len(cache_df)
#cache_df = cache_df.drop_duplicates(subset="url")
      
#print("Length Before de-dupe:",len(cache_df)

# %%
#//*** Write to excel file
output_filename = f"{tgt_year}_{quarter}_Collected_Stories.xlsx"
print(output_filename)

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(output_filename, engine='xlsxwriter')

#//*** Build Sheet and Data from From each url_item element
for url_item in url_items:
    sheet = url_item['cat']
    
    tdf = cache_df[cache_df['cat'] == sheet].copy()
    
    tdf = tdf[['urls','time_date','time_text','headline','body_text']].sort_values('time_date',ascending=False)
    
    tdf.to_excel(writer,sheet_name=sheet)
    
try:
    writer.save()    
except:
    print("Trouble Saving the Spreadsheet. It's Probably Open Somewhere. Close it and Retry")
# Out:
# 2022_Q3_Collected_Stories.xlsx

# %% [raw]
# writer.close

# %%
cache_df
# Out:
#                                                  urls                  hash  \
# 0   https://abc7news.com/president-joe-biden-clima...   3340588433118293791
# 1   https://abc7news.com/president-joe-biden-clima...  11179669141244742564
# 2   https://abc7news.com/indigenous-forest-managem...   9544418966223491738
# 3   https://abc7news.com/supreme-court-remaining-c...   4614620187172708451
# 4   https://abc7news.com/air-quality-bay-area-spar...  11398640325941118735
# ..                                                ...                   ...
# 30  https://abc7news.com/ivf-treatment-ro-v-wade-a...  15306288454229551831
# 31  https://abc7news.com/planned-parenthood-aborti...   9534249791868771498
# 32  https://abc7news.com/daily-harvest-lentil-crum...   3952527858334626713
# 33  https://abc7news.com/priest-sex-abuse-catholic...  11645930866639425220
# 34  https://abc7news.com/ucsf-parnassus-juneteenth...   6433339220313226173
#
#         cat                                                url  \
# 0   Climate  https://abc7news.com/president-joe-biden-clima...
# 1   Climate  https://abc7news.com/president-joe-biden-clima...
# 2   Climate  https://abc7news.com/indigenous-forest-managem...
# 3   Climate  https://abc7news.com/supreme-court-remaining-c...
# 4   Climate  https://abc7news.com/air-quality-bay-area-spar...
# ..      ...                                                ...
# 30   I-TEAM  https://abc7news.com/ivf-treatment-ro-v-wade-a...
# 31   I-TEAM  https://abc7news.com/planned-parenthood-aborti...
# 32   I-TEAM  https://abc7news.com/daily-harvest-lentil-crum...
# 33   I-TEAM  https://abc7news.com/priest-sex-abuse-catholic...
# 34   I-TEAM  https://abc7news.com/ucsf-parnassus-juneteenth...
#
#                                              headline  \
# 0   President Biden to announce new actions on cli...
# 1   Biden holds off - for now - on climate emergen...
# 2   Indigenous peoples use ceremonial burns as Red...
# 3   Supreme Court ruling limits EPA's ability to r...
# 4       No Spare the Air Alert issued in the Bay Area
# ..                                                ...
# 30  Doctors say IVF treatment process likely to ge...
# 31  NorCal Planned Parenthood clinics ready for in...
# 32  Daily Harvest responds to customers sickened, ...
# 33  Survivor of priest sex abuse speaks out as new...
# 34  UCSF responds to images of watermelon on emplo...
#
#                    time_text  \
# 0   Wednesday, July 20, 2022
# 1     Tuesday, July 19, 2022
# 2      Friday, July 15, 2022
# 3    Thursday, June 30, 2022
# 4   Wednesday, June 22, 2022
# ..                       ...
# 30    Tuesday, June 28, 2022
# 31    Tuesday, June 28, 2022
# 32    Tuesday, June 28, 2022
# 33     Monday, June 27, 2022
# 34  Wednesday, June 22, 2022
#
#                                             body_text  time_date
# 0   WASHINGTON -- President Joe Biden will announc... 2022-07-20
# 1   WASHINGTON -- President Joe Biden will travel ... 2022-07-19
# 2   SANTA CRUZ, Calif. (KGO) -- As a senior land m... 2022-07-15
# 3   WASHINGTON -- The Supreme Court on Thursday li... 2022-06-30
# 4   SAN FRANCISCO -- There is no Spare the Air Ale... 2022-06-22
# ..                                                ...        ...
# 30  SAN FRANCISCO (KGO) -- The overturn of Roe wil... 2022-06-28
# 31  SAN FRANCISCO (KGO) -- People across the count... 2022-06-28
# 32  SAN FRANCISCO (KGO) -- Meal delivery service D... 2022-06-28
# 33  SAN FRANCISCO (KGO) -- New lawsuits are floodi... 2022-06-27
# 34  SAN FRANCISCO (KGO) -- An employee with UCSF s... 2022-06-22
#
# [1377 rows x 8 columns]

# %%
cache_df.drop_duplicates(subset="url")
cache_df.drop_duplicates(subset="headline")
# Out:
#                                                  urls                  hash  \
# 0   https://abc7news.com/president-joe-biden-clima...   3340588433118293791
# 1   https://abc7news.com/president-joe-biden-clima...  11179669141244742564
# 2   https://abc7news.com/indigenous-forest-managem...   9544418966223491738
# 3   https://abc7news.com/supreme-court-remaining-c...   4614620187172708451
# 4   https://abc7news.com/air-quality-bay-area-spar...  11398640325941118735
# ..                                                ...                   ...
# 5   https://abc7news.com/mohammed-nuru-prison-sent...   2902462583129161661
# 6   https://abc7news.com/mohammed-nuru-sentencing-...    228513101865639475
# 7   https://abc7news.com/house-of-aloha-hawaii-wen...  11829385315766357507
# 8   https://abc7news.com/zeppelin-ransomware-fraud...   4663597021600570367
# 33  https://abc7news.com/priest-sex-abuse-catholic...  11645930866639425220
#
#         cat                                                url  \
# 0   Climate  https://abc7news.com/president-joe-biden-clima...
# 1   Climate  https://abc7news.com/president-joe-biden-clima...
# 2   Climate  https://abc7news.com/indigenous-forest-managem...
# 3   Climate  https://abc7news.com/supreme-court-remaining-c...
# 4   Climate  https://abc7news.com/air-quality-bay-area-spar...
# ..      ...                                                ...
# 5    I-TEAM  https://abc7news.com/mohammed-nuru-prison-sent...
# 6    I-TEAM  https://abc7news.com/mohammed-nuru-sentencing-...
# 7    I-TEAM  https://abc7news.com/house-of-aloha-hawaii-wen...
# 8    I-TEAM  https://abc7news.com/zeppelin-ransomware-fraud...
# 33   I-TEAM  https://abc7news.com/priest-sex-abuse-catholic...
#
#                                              headline  \
# 0   President Biden to announce new actions on cli...
# 1   Biden holds off - for now - on climate emergen...
# 2   Indigenous peoples use ceremonial burns as Red...
# 3   Supreme Court ruling limits EPA's ability to r...
# 4       No Spare the Air Alert issued in the Bay Area
# ..                                                ...
# 5   Judge sentences Mohammed Nuru to 7 years in pr...
# 6   Major figure in SF government bribery case to ...
# 7   House of Aloha Hawaii travel booker must pay v...
# 8   FBI warns new variant of ransomware fraud targ...
# 33  Survivor of priest sex abuse speaks out as new...
#
#                      time_text  \
# 0     Wednesday, July 20, 2022
# 1       Tuesday, July 19, 2022
# 2        Friday, July 15, 2022
# 3      Thursday, June 30, 2022
# 4     Wednesday, June 22, 2022
# ..                         ...
# 5    Thursday, August 25, 2022
# 6   Wednesday, August 24, 2022
# 7   Wednesday, August 24, 2022
# 8     Tuesday, August 23, 2022
# 33       Monday, June 27, 2022
#
#                                             body_text   time_date
# 0   WASHINGTON -- President Joe Biden will announc...  2022-07-20
# 1   WASHINGTON -- President Joe Biden will travel ...  2022-07-19
# 2   SANTA CRUZ, Calif. (KGO) -- As a senior land m...  2022-07-15
# 3   WASHINGTON -- The Supreme Court on Thursday li...  2022-06-30
# 4   SAN FRANCISCO -- There is no Spare the Air Ale...  2022-06-22
# ..                                                ...         ...
# 5   SAN FRANCISCO (KGO) -- A San Francisco judge o...  2022-08-25
# 6   SAN FRANCISCO (KGO) -- A massive government co...  2022-08-24
# 7   SAN FRANCISCO (KGO) -- A travel booker accused...  2022-08-24
# 8   SAN FRANCISCO (KGO) -- The FBI and federal cyb...  2022-08-23
# 33  SAN FRANCISCO (KGO) -- New lawsuits are floodi...  2022-06-27
#
# [495 rows x 8 columns]

# %%
url_items = [
    {
        "url" : "https://abc7news.com/tag/climate-change/",
        "cat" : "Climate"
    },
    {
        "url" : "https://abc7news.com/tag/environment/",
        "cat" : "Environment"
    },
 
    {
        "url" : "https://abc7news.com/tag/economy/",
        "cat" : "Economy"
    },
    {
        "url" : "https://abc7news.com/tag/jobs/",
        "cat" : "Jobs"
    },    
    {
        "url" : "https://abc7news.com/tag/safety/",
        "cat" : "Safety"
    },
    {
        "url" : "https://abc7news.com/tag/health/",
        "cat" : "Health"
    },
    {
        "url" : "https://abc7news.com/education/",
        "cat" : "Education"
    },
    {
        "url" : "https://abc7news.com/tag/race-and-culture/",
        "cat" : "Race"
    },
    {
        "url" : "https://abc7news.com/tag/discrimination/",
        "cat" : "Discrimination"
    },
    {
        "url" : "https://abc7news.com/tag/civil-rights/",
        "cat" : "Civil Rights"
    },
    {
        "url" : "https://abc7news.com/tag/building-a-better-bay-area/",
        "cat" : "BABBA"
    },
    {
        "url" : "https://abc7news.com/7onyourside/",
        "cat" : "7OYS"
    },
    {
        "url" : "https://abc7news.com/tag/covid-19/",
        "cat" : "COVID"
    },

    {
        "url" : "https://abc7news.com/iteam/",
        "cat" : "I-TEAM"
    },
    

    
]

try:
    cache_df['time_date'] = cache_df['time_date'].dt.date
except:
    pass

#//*** Write to excel file
output_filename = f"{tgt_year}_{quarter}_Collected_Stories.xlsx"
print(output_filename)

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(output_filename, engine='xlsxwriter')

#//*** Build Sheet and Data from From each url_item element
for url_item in url_items:
    sheet = url_item['cat']
    
    tdf = cache_df[cache_df['cat'] == sheet].copy().sort_values("time_date",ascending=False)
    
    tdf = tdf[['urls','time_date','time_text','headline','body_text']]
    
    tdf.to_excel(writer,sheet_name=sheet)
    

workbook = writer.book


cell_format = workbook.add_format()


for url_item in url_items:
    sheet = url_item['cat']
    writer.sheets[sheet].set_column(2,2, 10)      
    writer.sheets[sheet].set_column(4,4, 20) 
    
for url_item in url_items:
    sheet = url_item['cat']
    cell_format.set_font_name('Arial')
    cell_format.set_font_size(12)


     
    writer.sheets[sheet].set_column('A:F', None, cell_format)  
    
    
try:
    writer.close()    
except:
    print("Trouble Saving the Spreadsheet. It's Probably Open Somewhere. Close it and Retry")
# Out:
# 2022_Q3_Collected_Stories.xlsx

# %%
dir(cell_format)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_escape_attributes',
#  '_escape_data',
#  '_format_key',
#  '_get_align_properties',
#  '_get_alignment_key',
#  '_get_border_key',
#  '_get_color',
#  '_get_dxf_index',
#  '_get_fill_key',
#  '_get_font_key',
#  '_get_format_key',
#  '_get_protection_properties',
#  '_get_xf_index',
#  '_set_filehandle',
#  '_set_xml_writer',
#  '_to_string',
#  '_xml_close',
#  '_xml_data_element',
#  '_xml_declaration',
#  '_xml_empty_tag',
#  '_xml_empty_tag_unencoded',
#  '_xml_end_tag',
#  '_xml_formula_element',
#  '_xml_inline_string',
#  '_xml_number_element',
#  '_xml_rich_inline_string',
#  '_xml_rich_si_element',
#  '_xml_si_element',
#  '_xml_start_tag',
#  '_xml_start_tag_unencoded',
#  '_xml_string_element',
#  'bg_color',
#  'bold',
#  'border_count',
#  'border_index',
#  'bottom',
#  'bottom_color',
#  'color_indexed',
#  'diag_border',
#  'diag_color',
#  'diag_type',
#  'dxf_format_indices',
#  'dxf_index',
#  'escapes',
#  'fg_color',
#  'fh',
#  'fill_count',
#  'fill_index',
#  'font_charset',
#  'font_color',
#  'font_condense',
#  'font_extend',
#  'font_family',
#  'font_index',
#  'font_name',
#  'font_only',
#  'font_outline',
#  'font_scheme',
#  'font_script',
#  'font_shadow',
#  'font_size',
#  'font_strikeout',
#  'has_border',
#  'has_dxf_border',
#  'has_dxf_fill',
#  'has_dxf_font',
#  'has_fill',
#  'has_font',
#  'hidden',
#  'hyperlink',
#  'indent',
#  'internal_fh',
#  'italic',
#  'just_distrib',
#  'left',
#  'left_color',
#  'locked',
#  'merge_range',
#  'num_format',
#  'num_format_index',
#  'pattern',
#  'reading_order',
#  'right',
#  'right_color',
#  'rotation',
#  'set_align',
#  'set_bg_color',
#  'set_bold',
#  'set_border',
#  'set_border_color',
#  'set_bottom',
#  'set_bottom_color',
#  'set_center_across',
#  'set_color',
#  'set_color_indexed',
#  'set_diag_border',
#  'set_diag_color',
#  'set_diag_type',
#  'set_dxf_index',
#  'set_fg_color',
#  'set_font',
#  'set_font_charset',
#  'set_font_color',
#  'set_font_condense',
#  'set_font_extend',
#  'set_font_family',
#  'set_font_index',
#  'set_font_name',
#  'set_font_only',
#  'set_font_outline',
#  'set_font_scheme',
#  'set_font_script',
#  'set_font_shadow',
#  'set_font_size',
#  'set_font_strikeout',
#  'set_has_fill',
#  'set_has_font',
#  'set_hidden',
#  'set_hyperlink',
#  'set_indent',
#  'set_italic',
#  'set_left',
#  'set_left_color',
#  'set_locked',
#  'set_num_format',
#  'set_num_format_index',
#  'set_pattern',
#  'set_reading_order',
#  'set_right',
#  'set_right_color',
#  'set_rotation',
#  'set_shrink',
#  'set_size',
#  'set_text_h_align',
#  'set_text_justlast',
#  'set_text_v_align',
#  'set_text_wrap',
#  'set_theme',
#  'set_top',
#  'set_top_color',
#  'set_underline',
#  'set_valign',
#  'set_xf_index',
#  'shrink',
#  'text_h_align',
#  'text_justlast',
#  'text_v_align',
#  'text_wrap',
#  'theme',
#  'top',
#  'top_color',
#  'underline',
#  'xf_format_indices',
#  'xf_id',
#  'xf_index']

# %%
"""
END MAIN PROGRAM
Degbugging Code Below
"""
# Out:
# '\nEND MAIN PROGRAM\nDegbugging Code Below\n'

# %%
STOP_HERE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21956/388381140.py in <module>
# ----> 1 STOP_HERE
#
# NameError: name 'STOP_HERE' is not defined

# %%
urls = ['https://abc7news.com/california-drought-santa-cruz-county-seawater-intrusion-soquel-creek-water-district/11869614/']
get_scripts(urls,False)

# %%
page_driver = webdriver.Firefox()
page_driver.get(urls[0])

# %%
url = urls[0]
loop_story = {
    "url" : url,
    "headline" : page_driver.find_elements(By.CLASS_NAME,"headline")[0].text,
    "time_text" : page_driver.find_elements(By.CLASS_NAME,"lastmodified")[0].text,
    "body_text" : page_driver.find_elements(By.CLASS_NAME,"body-text")[0].text,
}

# %%
element = page_driver.find_element_by_tag_name("body")
raw_text = element.get_attribute('innerHTML')
for x in raw_text.split(">"):
    print(x)

# %%
#//*******************
#//**** Get Headline
#//*******************

#FITT_Article_main__body
main_body = page_driver.find_elements(By.CLASS_NAME,"FITT_Article_main__body")[0]

#//*** Main Body Headline
main_body.find_elements(By.CSS_SELECTOR,"h1")[0].text

# %%
#//********************
#//**** Get Date
#//********************

#//*** Date is located withing the ShareByline Class
byLine = main_body.find_elements(By.CLASS_NAME,"ShareByline")[0]
 
#//*** Get All divs under ShareByline
div_list = byLine.find_elements(By.CSS_SELECTOR,"div")

#//*** The Date will be in a div with no children
for elem in div_list:
    #//*** If div has div children, skip it
    if len(elem.find_elements(By.CSS_SELECTOR,"div")) > 0:
           continue
            
    #//*** Try to convert Element Text to Date
    #//*** Skip Element if conversion fails
    try:
        d = pd.to_datetime(elem.text)        
    except:
        continue
    
    #//*** Verify d is actually a timestamp / Date.
    #//*** Will get NaT result on empty field
    if isinstance(d,pd._libs.tslibs.timestamps.Timestamp):
        print("Date is ",d)
        break
    else:
        d = None

# %%
#//*** Extract Main Body.

#//*** Article is contained within the article tag
article = main_body.find_elements(By.CSS_SELECTOR,"article")

whole_text = ""

#//*** Double check we actually have the article
if len(article) > 0:
    #//*** We could take the entire article text, but it includes related links and add text.
    #//*** We are better than that.
    #//*** Get each p element. Keep elements that have 0 children
    #//*** In the example, the first p element has one child, probably for datelineing. We'll keep the first
    #//*** p element then skip any element that has children.
    
    elems = article[0].find_elements(By.CSS_SELECTOR,"p")
    
    #//*** Assume First elem is valid
    whole_text += elems[0].text
    for elem in elems:
        #//*** Only Keep elements with no children
        if len(elem.find_elements(By.XPATH, ".//*")) == 0:
            whole_text += elem.text
else:
    pass

print(whole_text)

# %%
for item in url_items:
    cat_url = item['url']
    cat = item['cat']
    
    #//*** Download the ctageory URLs
    urls = get_all_urls_in_page(cat_url,tgt_date,False)
    
    break

# %%
#//*** Parses a 
def get_scripts(source_urls,headless=True):
    
    out = []
    
    #//*** Initialize Headless Firefox options 
    options = webdriver.FirefoxOptions()
    options.add_argument('-headless')   
    
    if headless:


        #//*** Span Headless Instance
        page_driver = webdriver.Firefox(options=options)
    else:
        # run firefox webdriver from executable path of your choice
        page_driver = webdriver.Firefox()

    
    
    for i,url in enumerate(source_urls):
        
        print(f"({i+1}/{len(source_urls)}) - {url}")
        try:
            page_driver.get(url)
        except:
            print("Problem Getting Page...Skipping")
            continue
        
        #//*** Reset any Story errors 
        story_error = False
        
        loop_story = {
                "url" : url,
                "headline" : None,
                "time_text" : None,
                "body_text" : None,
            }
        #//*******************
        #//**** Get Headline
        #//*******************

        #FITT_Article_main__body
        main_body = page_driver.find_elements(By.CLASS_NAME,"FITT_Article_main__body")
        
        #//*** Verify we have main_body elements
        if len(main_body) > 0:
            #//*** Assume Main Body is the first element. If not we in trouble
            #//*** mmmmm dirty dirty Type conversion
            main_body = main_body[0]
            

            #//*******************
            #//**** Get Headline
            #//*******************
            #//*** Only assign valid headline
            
            #//*** Get the Headline from the main Body. It should be the first (and only) h1. 
            headline = main_body.find_elements(By.CSS_SELECTOR,"h1")
            
            #//*** Check to ensure we actually have h1 elements
            if len(headline) > 0:
                #//*** Dirty dirty type conversion
                headline = headline[0].text
                
                #//*** Assign Headline
                loop_story["headline"] = headline
        
            #//********************
            #//**** Get Date
            #//********************

            #//*** Date is located withing the ShareByline Class
            byLine = main_body.find_elements(By.CLASS_NAME,"ShareByline")[0]

            #//*** Get All divs under ShareByline
            div_list = byLine.find_elements(By.CSS_SELECTOR,"div")

            #//*** The Date will be in a div with no children
            for elem in div_list:
                #//*** If div has div children, skip it
                if len(elem.find_elements(By.CSS_SELECTOR,"div")) > 0:
                       continue

                #//*** Try to convert Element Text to Date
                #//*** Skip Element if conversion fails
                try:
                    d = pd.to_datetime(elem.text)        
                except:
                    continue

                #//*** Verify d is actually a timestamp / Date.
                #//*** Will get NaT result on empty field
                if isinstance(d,pd._libs.tslibs.timestamps.Timestamp):
                    loop_story["time_text"] = d
                    break

            #//********************************
            #//*** Get Main Body Text
            #//********************************

            #//*** Article is contained within the article tag
            article = main_body.find_elements(By.CSS_SELECTOR,"article")

            whole_text = ""

            #//*** Double check we actually have the article
            if len(article) > 0:
                #//*** We could take the entire article text, but it includes related links and add text.
                #//*** We are better than that.
                #//*** Get each p element. Keep elements that have 0 children
                #//*** In the example, the first p element has one child, probably for datelineing. We'll keep the first
                #//*** p element then skip any element that has children.

                elems = article[0].find_elements(By.CSS_SELECTOR,"p")

                #//*** Assume First elem is valid
                whole_text += elems[0].text
                for elem in elems:
                    #//*** Only Keep elements with no children
                    if len(elem.find_elements(By.XPATH, ".//*")) == 0:
                        whole_text += elem.text
                
                loop_story["body_text"] = whole_text
            else:
                pass

            

            
        else:
            print("Problem Processing Main Body. Got a core parsing issue")
            story_error = True
        
        loop_story["body_text"] = None
        
        #//*** Throw an error if any loop_story field is None:
        for key,value in loop_story.items():
            
            if value == None:
                story_error = True
                print("Story Parsing Error:",key,"is",value)
            
        #//*** Keep Story if No Errors
        if not story_error:
            out.append(loop_story)
        
        #wait between 1/2 to 3 seconds
        time.sleep(random.randint(500, 3000)/1000)                                                              

    page_driver.quit()
                                                                        
    return out

scripts = get_scripts(['https://abc7news.com/president-joe-biden-climate-change-executive-actions-emergency-declaration/12062764/'])
print(scripts[0])
print('done')

# %%
#//*** Split the Date
loop_story['time_date'] = loop_story['time_text'].split()

#//*** Rebuild Date string using only the first four fields. Drop the extra time
loop_story['time_date'] = " ".join(loop_story['time_date'][:4])

loop_story['time_date'] = datetime.datetime.strptime(loop_story['time_date'], "%A, %B %d, %Y")

# %%
#//*** Backup Copy of original get_scripts
"""
#//*** Parses a 
def get_scripts(source_urls,headless=True):
    
    out = []
    
    #//*** Initialize Headless Firefox options 
    options = webdriver.FirefoxOptions()
    options.add_argument('-headless')   
    
    if headless:
    if headless:


        #//*** Span Headless Instance
        page_driver = webdriver.Firefox(options=options)
    else:
        # run firefox webdriver from executable path of your choice
        page_driver = webdriver.Firefox()

    
    
    for i,url in enumerate(source_urls):
        
        print(f"({i+1}/{len(source_urls)}) - {url}")
        try:
            page_driver.get(url)
        except:
            print("Problem Getting Page...Skipping")
            continue
            
        
        try:
        
            loop_story = {
                "url" : url,
                "headline" : page_driver.find_elements(By.CLASS_NAME,"headline")[0].text,
                "time_text" : page_driver.find_elements(By.CLASS_NAME,"lastmodified")[0].text,
                "body_text" : page_driver.find_elements(By.CLASS_NAME,"body-text")[0].text,
            }
            #//*** Split the Date
            loop_story['time_date'] = loop_story['time_text'].split()

            #//*** Rebuild Date string using only the first four fields. Drop the extra time
            loop_story['time_date'] = " ".join(loop_story['time_date'][:4])

            loop_story['time_date'] = datetime.datetime.strptime(loop_story['time_date'], "%A, %B %d, %Y")
        except:
            print("Problem Processing Story. Skipping")
            continue
        out.append(loop_story)
        
        #wait between 1/2 to 3 seconds
        time.sleep(random.randint(500, 3000)/1000)                                                              

    page_driver.quit()
                                                                        
    return out
"""
print()
