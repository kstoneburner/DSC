# %%
import logging
import datetime
from datetime import date
from suds.client import Client
from suds.wsse import *
from suds.client import MethodNotFound
from suds.plugin import MessagePlugin

#adding security header
def login(login, password, service):
    class PasswordType(MessagePlugin):
        def marshalled(self, context):
            password = context.envelope.childAtPath('Header/Security/UsernameToken/Password')
            password.set('Type', 'http://docs.oasis-open.org/wss/2004/01/oasis-200401-wss-username-token-profile-1.0#PasswordText')
    security = Security()
    token = UsernameToken(login, password)
    security.tokens.append(token)
    plugin = PasswordType()	
    service.set_options(wsse=security, plugins=[plugin])

#defining the client
WSDL_URL = "http://OM-CASF-DLCOR11:8080/DaletWebService/services/ConfigurationService?wsdl"
#WSDL_URL = "http://OM-CASF-DLCOR11:8080/DaletWebService/services/CategoryService?wsdl"
#WSDL_URL = "http://OM-CASF-DLCOR11:8080/DaletWebService/services/RundownService?wsdl"

user = "SWNA\stonk013" 
pswd = "inara51More"
#user = "SWNA\$kgotvscripts" 
#pswd = "ABC7news"
client = Client(WSDL_URL)
login(user, pswd, client)

#usage example of the client
try:	
    #result = client.service.getAllStations()
    result = client.service._ServiceSelector__services
    #result = client.service._ServiceSelector__services
    #result_1 = client.service._ServiceSelector__services
    #result_1 = client.service   
    print((result))
    #print(result_1[0].ports[0].binding.operations.keys())
    #print(result_1[0].ports[0].binding.operations['getRundownsByRange'])
except MethodNotFound:	
	print ("sorry but method is not defined")
			
#logging.basicConfig(level=logging.INFO) 
#logging.getLogger('suds.client').setLevel(logging.DEBUG) 
#logging.getLogger('suds.transport').setLevel(logging.DEBUG)
# Out:
# [(Service){
#    name = "ConfigurationService"
#    qname = "(ConfigurationService, http://configurationservice.services.webservice.dalet.com/)"
#    ports[] =
#       (Port){
#          name = "ConfigurationServicePort"
#          qname = "(ConfigurationServicePort, http://configurationservice.services.webservice.dalet.com/)"
#          _Port__service = (Service)...
#          binding =
#             (Binding){
#                name = "ConfigurationServiceSoapBinding"
#                qname = "(ConfigurationServiceSoapBinding, http://configurationservice.services.webservice.dalet.com/)"
#                operations =
#                   {
#                      getAllStations =
#                         (Operation){
#                            name = "getAllStations"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllStations" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllStations', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllStationsResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllStationsResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      getMediaMigrationPolicyInfos =
#                         (Operation){
#                            name = "getMediaMigrationPolicyInfos"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getMediaMigrationPolicyInfos" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getMediaMigrationPolicyInfos', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getMediaMigrationPolicyInfosResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getMediaMigrationPolicyInfosResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      getAllDataFieldTypes =
#                         (Operation){
#                            name = "getAllDataFieldTypes"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllDataFieldTypes" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllDataFieldTypes', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllDataFieldTypesResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllDataFieldTypesResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      getAllSubtitlesAssetTypes =
#                         (Operation){
#                            name = "getAllSubtitlesAssetTypes"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllSubtitlesAssetTypes" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllSubtitlesAssetTypes', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllSubtitlesAssetTypesResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllSubtitlesAssetTypesResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      getUserMediaFormatInfos =
#                         (Operation){
#                            name = "getUserMediaFormatInfos"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getUserMediaFormatInfos" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getUserMediaFormatInfos', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getUserMediaFormatInfosResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getUserMediaFormatInfosResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] =
#                                     (Fault){
#                                        name = "ResourceDoesNotExist"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourceDoesNotExist" name="ResourceDoesNotExist">
#     </wsdl:part>
#                                              name = "ResourceDoesNotExist"
#                                              qname[] =
#                                                 "ResourceDoesNotExist",
#                                                 "http://configurationservice.services.dalet.com",
#                                              element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                               }
#                         }
#                      getAllCGAssetTypes =
#                         (Operation){
#                            name = "getAllCGAssetTypes"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllCGAssetTypes" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllCGAssetTypes', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllCGAssetTypesResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllCGAssetTypesResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      getStorageUnits =
#                         (Operation){
#                            name = "getStorageUnits"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getStorageUnits" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getStorageUnits', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getStorageUnitsResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getStorageUnitsResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      getMediaFormatDescription =
#                         (Operation){
#                            name = "getMediaFormatDescription"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getMediaFormatDescription" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getMediaFormatDescription', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getMediaFormatDescriptionResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getMediaFormatDescriptionResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] =
#                                     (Fault){
#                                        name = "ResourceDoesNotExist"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourceDoesNotExist" name="ResourceDoesNotExist">
#     </wsdl:part>
#                                              name = "ResourceDoesNotExist"
#                                              qname[] =
#                                                 "ResourceDoesNotExist",
#                                                 "http://configurationservice.services.dalet.com",
#                                              element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                               }
#                         }
#                      getAllStatuses =
#                         (Operation){
#                            name = "getAllStatuses"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllStatuses" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllStatuses', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllStatusesResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllStatusesResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      getAllLocatorsTypes =
#                         (Operation){
#                            name = "getAllLocatorsTypes"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllLocatorsTypes" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllLocatorsTypes', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllLocatorsTypesResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllLocatorsTypesResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      getAllTrackStackTemplates =
#                         (Operation){
#                            name = "getAllTrackStackTemplates"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllTrackStackTemplates" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllTrackStackTemplates', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllTrackStackTemplatesResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllTrackStackTemplatesResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      getDataFieldTypeByName =
#                         (Operation){
#                            name = "getDataFieldTypeByName"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getDataFieldTypeByName" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getDataFieldTypeByName', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getDataFieldTypeByNameResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getDataFieldTypeByNameResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      getAllDeployedSolrIndexes =
#                         (Operation){
#                            name = "getAllDeployedSolrIndexes"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllDeployedSolrIndexes" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllDeployedSolrIndexes', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllDeployedSolrIndexesResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
#                                                    element = "('getAllDeployedSolrIndexesResponse', 'http://configurationservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://configurationservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      getAllDataFields =
#                         (Operation){
#                            name = "getAllDataFields"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getAllDataFields" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://configurationservice.services.dalet.com",
# ...
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://configurationservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            output =
#                               (Output){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:getAllLanguagesResponse" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://configurationservice.services.dalet.com",
#                                              element = "('getAllLanguagesResponse', 'http://configurationservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://configurationservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            faults[] = <empty>
#                         }
#                   }
#                getAllStudios =
#                   (Method){
#                      name = "getAllStudios"
#                      location = "http://OM-CASF-DLCOR11:8080/DaletWebService/services/ConfigurationService"
#                      binding =
#                         (binding){
#                            input = <suds.bindings.document.Document object at 0x00000186FBADE9A0>
#                            output = <suds.bindings.document.Document object at 0x00000186FBADE9A0>
#                         }
#                      soap =
#                         (soap){
#                            action = """"
#                            style = "document"
#                            input =
#                               (Input){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:getAllStudios" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://configurationservice.services.dalet.com",
#                                              element = "('getAllStudios', 'http://configurationservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://configurationservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            output =
#                               (Output){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:getAllStudiosResponse" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://configurationservice.services.dalet.com",
#                                              element = "('getAllStudiosResponse', 'http://configurationservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://configurationservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            faults[] = <empty>
#                         }
#                   }
#                getAllLocatorFamilies =
#                   (Method){
#                      name = "getAllLocatorFamilies"
#                      location = "http://OM-CASF-DLCOR11:8080/DaletWebService/services/ConfigurationService"
#                      binding =
#                         (binding){
#                            input = <suds.bindings.document.Document object at 0x00000186FBADE9A0>
#                            output = <suds.bindings.document.Document object at 0x00000186FBADE9A0>
#                         }
#                      soap =
#                         (soap){
#                            action = """"
#                            style = "document"
#                            input =
#                               (Input){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:getAllLocatorFamilies" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://configurationservice.services.dalet.com",
#                                              element = "('getAllLocatorFamilies', 'http://configurationservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://configurationservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            output =
#                               (Output){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:getAllLocatorFamiliesResponse" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://configurationservice.services.dalet.com",
#                                              element = "('getAllLocatorFamiliesResponse', 'http://configurationservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://configurationservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            faults[] = <empty>
#                         }
#                   }
#                getAllStoryTemplates =
#                   (Method){
#                      name = "getAllStoryTemplates"
#                      location = "http://OM-CASF-DLCOR11:8080/DaletWebService/services/ConfigurationService"
#                      binding =
#                         (binding){
#                            input = <suds.bindings.document.Document object at 0x00000186FBADE9A0>
#                            output = <suds.bindings.document.Document object at 0x00000186FBADE9A0>
#                         }
#                      soap =
#                         (soap){
#                            action = """"
#                            style = "document"
#                            input =
#                               (Input){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:getAllStoryTemplates" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://configurationservice.services.dalet.com",
#                                              element = "('getAllStoryTemplates', 'http://configurationservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://configurationservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            output =
#                               (Output){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:getAllStoryTemplatesResponse" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://configurationservice.services.dalet.com",
#                                              element = "('getAllStoryTemplatesResponse', 'http://configurationservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://configurationservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            faults[] = <empty>
#                         }
#                   }
#                getMediaFormatInfos =
#                   (Method){
#                      name = "getMediaFormatInfos"
#                      location = "http://OM-CASF-DLCOR11:8080/DaletWebService/services/ConfigurationService"
#                      binding =
#                         (binding){
#                            input = <suds.bindings.document.Document object at 0x00000186FBADE9A0>
#                            output = <suds.bindings.document.Document object at 0x00000186FBADE9A0>
#                         }
#                      soap =
#                         (soap){
#                            action = """"
#                            style = "document"
#                            input =
#                               (Input){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:getMediaFormatInfos" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://configurationservice.services.dalet.com",
#                                              element = "('getMediaFormatInfos', 'http://configurationservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://configurationservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            output =
#                               (Output){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:getMediaFormatInfosResponse" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://configurationservice.services.dalet.com",
#                                              element = "('getMediaFormatInfosResponse', 'http://configurationservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://configurationservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            faults[] = <empty>
#                         }
#                   }
#             }
#       },
#  }]

# %%
rawStudio = client.service.getAllStations()
for thisElem in rawStudio:
    if thisElem.isRecordingType == False:
        print(thisElem.name, thisElem.id)

#//*** Get all endpoint functions 
for x in result[0].ports[0].binding.operations:
    print(x)
# Out:
# KGO_NEWS 1132
# getAllStations
# getMediaMigrationPolicyInfos
# getAllDataFieldTypes
# getAllSubtitlesAssetTypes
# getUserMediaFormatInfos
# getAllCGAssetTypes
# getStorageUnits
# getMediaFormatDescription
# getAllStatuses
# getAllLocatorsTypes
# getAllTrackStackTemplates
# getDataFieldTypeByName
# getAllDeployedSolrIndexes
# getAllDataFields
# getAllExtendedAssetTypes
# getDataFieldsByNames
# getAllLanguages
# getAllStudios
# getAllLocatorFamilies
# getAllStoryTemplates
# getMediaFormatInfos

# %%
startDate = datetime.today() + timedelta(days=-1)
endDate = datetime.today() + timedelta(days=1)

WSDL_URL = "http://OM-CASF-DLCOR11:8080/DaletWebService/services/RundownService?wsdl"
client = Client(WSDL_URL)
login(user, pswd, client)

result = client.service.getRundownsByRange(1,startDate,endDate)

#rundownService.getRundownsByRange(playoutStationId, startDate, endDate, None)
# Out:
# <suds.sax.document.Document object at 0x00000186FBCFCCD0>
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\suds\transport\http.py in send(self, request)
#      81             log.debug('sending:\n%s', request)
# ---> 82             fp = self.u2open(u2request)
#      83             self.getcookies(fp, u2request)
#
# ~\Anaconda3\lib\site-packages\suds\transport\http.py in u2open(self, u2request)
#     131             return url.open(u2request)
# --> 132         return url.open(u2request, timeout=tm)
#     133
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 500: Internal Server Error
#
# During handling of the above exception, another exception occurred:
#
# TransportError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\suds\client.py in send(self, soapenv)
#     612             timer.start()
# --> 613             reply = self.options.transport.send(request)
#     614             timer.stop()
#
# ~\Anaconda3\lib\site-packages\suds\transport\https.py in send(self, request)
#      65         self.addcredentials(request)
# ---> 66         return HttpTransport.send(self, request)
#      67
#
# ~\Anaconda3\lib\site-packages\suds\transport\http.py in send(self, request)
#      93             else:
# ---> 94                 raise TransportError(e.msg, e.code, e.fp)
#      95         return result
#
# TransportError: Internal Server Error
#
# During handling of the above exception, another exception occurred:
#
# WebFault                                  Traceback (most recent call last)
# <ipython-input-126-8c210582374e> in <module>
#       6 login(user, pswd, client)
#       7
# ----> 8 result = client.service.getRundownsByRange(1132,startDate,endDate)
#       9
#      10 #rundownService.getRundownsByRange(playoutStationId, startDate, endDate, None)
#
# ~\Anaconda3\lib\site-packages\suds\client.py in __call__(self, *args, **kwargs)
#     519         client = clientclass(self.client, self.method)
#     520         try:
# --> 521             return client.invoke(args, kwargs)
#     522         except WebFault as e:
#     523             if self.faults():
#
# ~\Anaconda3\lib\site-packages\suds\client.py in invoke(self, args, kwargs)
#     579             timer)
#     580         timer.start()
# --> 581         result = self.send(soapenv)
#     582         timer.stop()
#     583         metrics.log.debug("method '%s' invoked: %s", self.method.name, timer)
#
# ~\Anaconda3\lib\site-packages\suds\client.py in send(self, soapenv)
#     616         except TransportError as e:
#     617             content = e.fp and e.fp.read() or ''
# --> 618             return self.process_reply(reply=content, status=e.httpcode,
#     619                 description=tostr(e), original_soapenv=original_soapenv)
#     620         return self.process_reply(reply=reply.message,
#
# ~\Anaconda3\lib\site-packages\suds\client.py in process_reply(self, reply, status, description, original_soapenv)
#     668                             "Reporting as an internal server error.", status)
#     669                     if self.options.faults:
# --> 670                         raise WebFault(fault, replyroot)
#     671                     return (http.client.INTERNAL_SERVER_ERROR, fault)
#     672             if status != http.client.OK:
#
# WebFault: Server raised fault: 'Parameter Dates is invalid. Invalidated Restriction: End date MUST be greater than Start date.'

# %%
print((datetime.today()))
# Out:
# 2021-03-09 20:03:40.635085

# %%
WSDL_URL = "http://OM-CASF-DLCOR11:8080/DaletWebService/services/RundownService?wsdl"

user = "SWNA\stonk013" 
pswd = "inara51More"
#user = "SWNA\$kgotvscripts" 
#pswd = "ABC7news"
client = Client(WSDL_URL)
login(user, pswd, client)

#usage example of the client
try:	
    #result = client.service.getAllStations()
    result = client.service._ServiceSelector__services
    #result = client.service._ServiceSelector__services
    #result_1 = client.service._ServiceSelector__services
    #result_1 = client.service   
    print((result))
    #print(result_1[0].ports[0].binding.operations.keys())
    #print(result_1[0].ports[0].binding.operations['getRundownsByRange'])
except MethodNotFound:	
	print ("sorry but method is not defined")
# Out:
# [(Service){
#    name = "RundownService"
#    qname = "(RundownService, http://rundownservice.services.webservice.dalet.com/)"
#    ports[] =
#       (Port){
#          name = "RundownServicePort"
#          qname = "(RundownServicePort, http://rundownservice.services.webservice.dalet.com/)"
#          _Port__service = (Service)...
#          binding =
#             (Binding){
#                name = "RundownServiceSoapBinding"
#                qname = "(RundownServiceSoapBinding, http://rundownservice.services.webservice.dalet.com/)"
#                operations =
#                   {
#                      getRundownItemFields =
#                         (Operation){
#                            name = "getRundownItemFields"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getRundownItemFields" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('getRundownItemFields', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getRundownItemFieldsResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('getRundownItemFieldsResponse', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] =
#                                     (Fault){
#                                        name = "ResourceDoesNotExist"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourceDoesNotExist" name="ResourceDoesNotExist">
#     </wsdl:part>
#                                              name = "ResourceDoesNotExist"
#                                              qname[] =
#                                                 "ResourceDoesNotExist",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                               }
#                         }
#                      getBroadcastReportByRange =
#                         (Operation){
#                            name = "getBroadcastReportByRange"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getBroadcastReportByRange" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('getBroadcastReportByRange', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getBroadcastReportByRangeResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('getBroadcastReportByRangeResponse', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] =
#                                     (Fault){
#                                        name = "InvalidParameter"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:InvalidParameter" name="InvalidParameter">
#     </wsdl:part>
#                                              name = "InvalidParameter"
#                                              qname[] =
#                                                 "InvalidParameter",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('InvalidParameter', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                                     (Fault){
#                                        name = "ResourceDoesNotExist"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourceDoesNotExist" name="ResourceDoesNotExist">
#     </wsdl:part>
#                                              name = "ResourceDoesNotExist"
#                                              qname[] =
#                                                 "ResourceDoesNotExist",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                                     (Fault){
#                                        name = "ResourcePreconditionViolation"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourcePreconditionViolation" name="ResourcePreconditionViolation">
#     </wsdl:part>
#                                              name = "ResourcePreconditionViolation"
#                                              qname[] =
#                                                 "ResourcePreconditionViolation",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('ResourcePreconditionViolation', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                               }
#                         }
#                      deleteRundown =
#                         (Operation){
#                            name = "deleteRundown"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:deleteRundown" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('deleteRundown', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:deleteRundownResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('deleteRundownResponse', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      deleteBlockItemFromRundown =
#                         (Operation){
#                            name = "deleteBlockItemFromRundown"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:deleteBlockItemFromRundown" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('deleteBlockItemFromRundown', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:deleteBlockItemFromRundownResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('deleteBlockItemFromRundownResponse', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] =
#                                     (Fault){
#                                        name = "ResourceDoesNotExist"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourceDoesNotExist" name="ResourceDoesNotExist">
#     </wsdl:part>
#                                              name = "ResourceDoesNotExist"
#                                              qname[] =
#                                                 "ResourceDoesNotExist",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                               }
#                         }
#                      getItemOnAirStatus =
#                         (Operation){
#                            name = "getItemOnAirStatus"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getItemOnAirStatus" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('getItemOnAirStatus', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getItemOnAirStatusResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('getItemOnAirStatusResponse', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] =
#                                     (Fault){
#                                        name = "ResourceDoesNotExist"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourceDoesNotExist" name="ResourceDoesNotExist">
#     </wsdl:part>
#                                              name = "ResourceDoesNotExist"
#                                              qname[] =
#                                                 "ResourceDoesNotExist",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                                     (Fault){
#                                        name = "ResourcePreconditionViolation"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourcePreconditionViolation" name="ResourcePreconditionViolation">
#     </wsdl:part>
#                                              name = "ResourcePreconditionViolation"
#                                              qname[] =
#                                                 "ResourcePreconditionViolation",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('ResourcePreconditionViolation', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                               }
#                         }
#                      getRundowns =
#                         (Operation){
#                            name = "getRundowns"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getRundowns" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('getRundowns', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getRundownsResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('getRundownsResponse', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] = <empty>
#                               }
#                         }
#                      setRundownItemFields =
#                         (Operation){
#                            name = "setRundownItemFields"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:setRundownItemFields" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('setRundownItemFields', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:setRundownItemFieldsResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('setRundownItemFieldsResponse', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] =
#                                     (Fault){
#                                        name = "ResourceDoesNotExist"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourceDoesNotExist" name="ResourceDoesNotExist">
#     </wsdl:part>
#                                              name = "ResourceDoesNotExist"
#                                              qname[] =
#                                                 "ResourceDoesNotExist",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                               }
#                         }
#                      deleteAssetItemFromRundown =
#                         (Operation){
#                            name = "deleteAssetItemFromRundown"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:deleteAssetItemFromRundown" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('deleteAssetItemFromRundown', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:deleteAssetItemFromRundownResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('deleteAssetItemFromRundownResponse', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] =
#                                     (Fault){
#                                        name = "ResourceDoesNotExist"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourceDoesNotExist" name="ResourceDoesNotExist">
#     </wsdl:part>
#                                              name = "ResourceDoesNotExist"
#                                              qname[] =
#                                                 "ResourceDoesNotExist",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                                     (Fault){
#                                        name = "ResourcePreconditionViolation"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourcePreconditionViolation" name="ResourcePreconditionViolation">
#     </wsdl:part>
#                                              name = "ResourcePreconditionViolation"
#                                              qname[] =
#                                                 "ResourcePreconditionViolation",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('ResourcePreconditionViolation', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                               }
#                         }
#                      getRundownsByRange =
#                         (Operation){
#                            name = "getRundownsByRange"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getRundownsByRange" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('getRundownsByRange', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:getRundownsByRangeResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('getRundownsByRangeResponse', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] =
#                                     (Fault){
#                                        name = "InvalidParameter"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:InvalidParameter" name="InvalidParameter">
#     </wsdl:part>
#                                              name = "InvalidParameter"
#                                              qname[] =
#                                                 "InvalidParameter",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('InvalidParameter', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                                     (Fault){
#                                        name = "ResourceDoesNotExist"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourceDoesNotExist" name="ResourceDoesNotExist">
#     </wsdl:part>
#                                              name = "ResourceDoesNotExist"
#                                              qname[] =
#                                                 "ResourceDoesNotExist",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                                     (Fault){
#                                        name = "ResourcePreconditionViolation"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:ResourcePreconditionViolation" name="ResourcePreconditionViolation">
#     </wsdl:part>
#                                              name = "ResourcePreconditionViolation"
#                                              qname[] =
#                                                 "ResourcePreconditionViolation",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('ResourcePreconditionViolation', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                               }
#                         }
#                      createRundown =
#                         (Operation){
#                            name = "createRundown"
#                            soap =
#                               (soap){
#                                  action = """"
#                                  style = "document"
#                                  input =
#                                     (Input){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:createRundown" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('createRundown', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  output =
#                                     (Output){
#                                        body =
#                                           (Body){
#                                              parts[] =
#                                                 (Part){
#                                                    root = <wsdl:part element="ns1:createRundownResponse" name="parameters">
#     </wsdl:part>
#                                                    name = "parameters"
#                                                    qname[] =
#                                                       "parameters",
#                                                       "http://rundownservice.services.dalet.com",
#                                                    element = "('createRundownResponse', 'http://rundownservice.services.dalet.com')"
#                                                    type = "None"
#                                                 },
#                                              use = "literal"
#                                              namespace[] =
#                                                 "tns",
#                                                 "http://rundownservice.services.webservice.dalet.com/",
#                                              wrapped = True
#                                           }
#                                        headers[] = <empty>
#                                     }
#                                  faults[] =
#                                     (Fault){
#                                        name = "InvalidParameter"
#                                        use = "literal"
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns2:InvalidParameter" name="InvalidParameter">
#     </wsdl:part>
#                                              name = "InvalidParameter"
#                                              qname[] =
#                                                 "InvalidParameter",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('InvalidParameter', 'http://errors.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                     },
#                                     (Fault){
#                                        name = "ResourceDoesNotExist"
#                                        use = "literal"
#                                        parts[] =
# ...
#                                        element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                        type = "None"
#                                     },
#                               },
#                         }
#                   }
#                createBlockItemInRundown =
#                   (Method){
#                      name = "createBlockItemInRundown"
#                      location = "http://OM-CASF-DLCOR11:8080/DaletWebService/services/RundownService"
#                      binding =
#                         (binding){
#                            input = <suds.bindings.document.Document object at 0x0000015CE5DAE670>
#                            output = <suds.bindings.document.Document object at 0x0000015CE5DAE670>
#                         }
#                      soap =
#                         (soap){
#                            action = """"
#                            style = "document"
#                            input =
#                               (Input){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:createBlockItemInRundown" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('createBlockItemInRundown', 'http://rundownservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://rundownservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            output =
#                               (Output){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:createBlockItemInRundownResponse" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('createBlockItemInRundownResponse', 'http://rundownservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://rundownservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            faults[] =
#                               (Fault){
#                                  name = "InvalidParameter"
#                                  use = "literal"
#                                  parts[] =
#                                     (Part){
#                                        root = <wsdl:part element="ns2:InvalidParameter" name="InvalidParameter">
#     </wsdl:part>
#                                        name = "InvalidParameter"
#                                        qname[] =
#                                           "InvalidParameter",
#                                           "http://rundownservice.services.dalet.com",
#                                        element = "('InvalidParameter', 'http://errors.services.dalet.com')"
#                                        type = "None"
#                                     },
#                               },
#                               (Fault){
#                                  name = "ResourceDoesNotExist"
#                                  use = "literal"
#                                  parts[] =
#                                     (Part){
#                                        root = <wsdl:part element="ns2:ResourceDoesNotExist" name="ResourceDoesNotExist">
#     </wsdl:part>
#                                        name = "ResourceDoesNotExist"
#                                        qname[] =
#                                           "ResourceDoesNotExist",
#                                           "http://rundownservice.services.dalet.com",
#                                        element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                        type = "None"
#                                     },
#                               },
#                         }
#                   }
#                createAssetItemInRundown =
#                   (Method){
#                      name = "createAssetItemInRundown"
#                      location = "http://OM-CASF-DLCOR11:8080/DaletWebService/services/RundownService"
#                      binding =
#                         (binding){
#                            input = <suds.bindings.document.Document object at 0x0000015CE5DAE670>
#                            output = <suds.bindings.document.Document object at 0x0000015CE5DAE670>
#                         }
#                      soap =
#                         (soap){
#                            action = """"
#                            style = "document"
#                            input =
#                               (Input){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:createAssetItemInRundown" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('createAssetItemInRundown', 'http://rundownservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://rundownservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            output =
#                               (Output){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:createAssetItemInRundownResponse" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('createAssetItemInRundownResponse', 'http://rundownservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://rundownservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            faults[] =
#                               (Fault){
#                                  name = "ResourceDoesNotExist"
#                                  use = "literal"
#                                  parts[] =
#                                     (Part){
#                                        root = <wsdl:part element="ns2:ResourceDoesNotExist" name="ResourceDoesNotExist">
#     </wsdl:part>
#                                        name = "ResourceDoesNotExist"
#                                        qname[] =
#                                           "ResourceDoesNotExist",
#                                           "http://rundownservice.services.dalet.com",
#                                        element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                        type = "None"
#                                     },
#                               },
#                         }
#                   }
#                createFullRundown =
#                   (Method){
#                      name = "createFullRundown"
#                      location = "http://OM-CASF-DLCOR11:8080/DaletWebService/services/RundownService"
#                      binding =
#                         (binding){
#                            input = <suds.bindings.document.Document object at 0x0000015CE5DAE670>
#                            output = <suds.bindings.document.Document object at 0x0000015CE5DAE670>
#                         }
#                      soap =
#                         (soap){
#                            action = """"
#                            style = "document"
#                            input =
#                               (Input){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:createFullRundown" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('createFullRundown', 'http://rundownservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://rundownservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            output =
#                               (Output){
#                                  body =
#                                     (Body){
#                                        parts[] =
#                                           (Part){
#                                              root = <wsdl:part element="ns1:createFullRundownResponse" name="parameters">
#     </wsdl:part>
#                                              name = "parameters"
#                                              qname[] =
#                                                 "parameters",
#                                                 "http://rundownservice.services.dalet.com",
#                                              element = "('createFullRundownResponse', 'http://rundownservice.services.dalet.com')"
#                                              type = "None"
#                                           },
#                                        use = "literal"
#                                        namespace[] =
#                                           "tns",
#                                           "http://rundownservice.services.webservice.dalet.com/",
#                                        wrapped = True
#                                     }
#                                  headers[] = <empty>
#                               }
#                            faults[] =
#                               (Fault){
#                                  name = "InvalidParameter"
#                                  use = "literal"
#                                  parts[] =
#                                     (Part){
#                                        root = <wsdl:part element="ns2:InvalidParameter" name="InvalidParameter">
#     </wsdl:part>
#                                        name = "InvalidParameter"
#                                        qname[] =
#                                           "InvalidParameter",
#                                           "http://rundownservice.services.dalet.com",
#                                        element = "('InvalidParameter', 'http://errors.services.dalet.com')"
#                                        type = "None"
#                                     },
#                               },
#                               (Fault){
#                                  name = "ResourceDoesNotExist"
#                                  use = "literal"
#                                  parts[] =
#                                     (Part){
#                                        root = <wsdl:part element="ns2:ResourceDoesNotExist" name="ResourceDoesNotExist">
#     </wsdl:part>
#                                        name = "ResourceDoesNotExist"
#                                        qname[] =
#                                           "ResourceDoesNotExist",
#                                           "http://rundownservice.services.dalet.com",
#                                        element = "('ResourceDoesNotExist', 'http://errors.services.dalet.com')"
#                                        type = "None"
#                                     },
#                               },
#                               (Fault){
#                                  name = "ResourcePreconditionViolation"
#                                  use = "literal"
#                                  parts[] =
#                                     (Part){
#                                        root = <wsdl:part element="ns2:ResourcePreconditionViolation" name="ResourcePreconditionViolation">
#     </wsdl:part>
#                                        name = "ResourcePreconditionViolation"
#                                        qname[] =
#                                           "ResourcePreconditionViolation",
#                                           "http://rundownservice.services.dalet.com",
#                                        element = "('ResourcePreconditionViolation', 'http://errors.services.dalet.com')"
#                                        type = "None"
#                                     },
#                               },
#                         }
#                   }
#             }
#       },
#  }]

# %%
for x in result[0].ports[0].binding.operations:
    print(x)
# Out:
# getRundownItemFields
# getBroadcastReportByRange
# deleteRundown
# deleteBlockItemFromRundown
# getItemOnAirStatus
# getRundowns
# setRundownItemFields
# deleteAssetItemFromRundown
# getRundownsByRange
# createRundown
# updateRundown
# createBlockItemInRundown
# createAssetItemInRundown
# createFullRundown

# %%
print(dir(result))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
print(result.__dict__.keys())
print(result._ServiceSelector__services)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-42ff8ee40ae5> in <module>
# ----> 1 print(result.__dict__.keys())
#       2 print(result._ServiceSelector__services)
#
# AttributeError: 'list' object has no attribute '__dict__'

# %%
#//*** This thread helped with the connection
#//***https://stackoverflow.com/questions/37692780/error-28000-login-failed-for-user-domain-user-with-pyodbc

#//**** Update the ODBC Driver
#//**** https://docs.microsoft.com/en-us/sql/connect/odbc/download-odbc-driver-for-sql-server?view=sql-server-ver15
import pyodbc

print(pyodbc.drivers())
# Some other example server values are
# server = 'localhost\sqlexpress' # for a named instance
# server = 'myserver,port' # to specify an alternate port
server = 'tcp:OM-CASF-DB01' 
server = 'OM-CASF-DLSQL' 
database = 'DaletDB' 
username = 'SWNA\stonk013' 
password = 'inara51More' 
#username = '$kgotvscripts' 
#password = 'ABC7news' 

#cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cnxn = pyodbc.connect('Trusted_Connection=yes;DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()
# Out:
# ['SQL Server', 'SQL Server Native Client 11.0', 'ODBC Driver 17 for SQL Server']

# %%
query = """
SELECT
  *
FROM
  INFORMATION_SCHEMA.TABLES
"""

cursor.execute(query)
tables = cursor.fetchall()

# %%
master_tables = []
for table in tables:
    master_tables.append(table[2])
master_tables.sort()

# %%
for table in master_tables:
    print(table)
# Out:
# AD_DomainsPerUser
# AD_Groups
# AFF_FROM_FORMAT
# AFF_FROM_STORAGE
# AFF_TO_FORMAT
# AFF_TO_STORAGE
# AccessRights
# AccessibleFormatForUser
# ActivationPlacements
# ActivationRules
# AdditionalLocatorsFromEDLToCopy
# AdsGroupsToSync
# Affinities
# AliasGroups
# AliasInAliasGroups
# AliasesPools
# AliasesPoolsData
# Allocation_Policies
# ApplicationServerTypes
# ApplicationServers
# Attributes_Order
# AuditTrailActionsConfiguration
# AutoSaveData
# BPMKeyPerformanceIndicators
# BPMTaskListBoardAssociations
# BPMTaskListBoardViews
# BPMTaskListViews
# BPMTaskTypes
# BPMTasksGroups
# BPMTasksUsers
# BlockTemplates
# BrokerJobs
# BrowserViewRules
# BrowserViews
# CGTemplates
# CRConfiguration
# CacheModule
# CacheSetting
# Callers
# Capabilities
# CategoriesCodes
# CategoryNotifyRules
# ChatRoomParticipateGroups
# ChatRoomParticipateUsers
# ChatRooms
# ClassCreationForms
# ClassDataDictDateTime
# ClassDataDictGlossary
# ClassDataDictInteger
# ClassDataDictObject
# ClassDataDictPeriod
# ClassDataDictString
# ClassDataDictText
# ClassDataDictTimeCode
# ClassDataDictTimeCodeDate
# ClassDataDictTitle
# ClassLastUsedForms
# ClipsInputData
# CommentDefaultProperties
# ComplianceWarnings
# ContactFolders
# Contacts
# ContactsInFolders
# ContainerPolicyAssoc
# ContextMapViews
# ContextPlugins
# ConversionRules
# Conversion_Types
# CreateAndModifyLocators
# CreatedModifiedGlossaryValues
# CreatedModifiedItems
# CurrentlyOpenedTitles
# CustomerOptions
# DRCAMFieldsParameters
# DRCCategoryParameters
# DRCParameters
# DRCStatusParameters
# DaletFavoriteItems
# DaletMessageQueues
# DaletSupportedMediaConvertion
# DaletToSolRField
# DataFieldTypes
# DataFields
# DatabaseUpgradeLabels
# DateTimeFormats
# DefaultDisplayedFields
# DefaultEventsMapping
# DefaultPoliciesAssoc
# DetailedFastFetchItems
# DeviceControllerEvents
# DeviceControllerRegEvents
# DeviceControllerTypes
# DeviceControllers
# DialogSpecFields
# DialogSpecRules
# DialogSpecs
# DisplayedFields
# DnDAllocationPolicy
# Domains
# DrcTextParameters
# EnumTypes
# ErrorWires
# FastFetchAccessRights
# FastFetchItems
# FastPurgeTitles
# FastPurgeWires
# Features
# Fields
# FileNameConventionScheme
# FilterFolders
# FilterQueryAttr
# FolderLastUsedViews
# FoldersInMiniFilters
# FoldersInTabs
# FoldersInTabsCount
# FormatIdToSCMov
# FormatLocation
# FormatSet
# FormatTrackMappingDefault
# FormatWrappers
# FormatsMediaPlayers
# GalaxyCommandContexts
# GalaxyCommandSets
# GalaxyCommandSetsBitmaps
# GalaxyCommands
# GalaxyDefaultKeyboardShortcuts
# GalaxyDisabledCommands
# GalaxyGlobalWorkspacesToGroups
# GalaxyKeyboardShortcuts
# GalaxyScripts
# GalaxySearchHistory
# GalaxySearchProfiles
# GalaxySharedHomescreens
# GalaxyToolbarBitmaps
# GalaxyWorkspaces
# GenealogyRenderedSegments
# GenealogySegmentAMfields
# GenericFolders
# GetOrCreateItemCodeSession
# GlossaryAssociatedFieldsHistory
# GlossaryEquivalence
# GlossaryType
# GlossaryTypeAssociatedFields
# GlossaryTypeFields
# GlossaryValue
# GlossaryValueParentChild
# GlossaryValue_Language
# GlossaryValuesToUpdate
# GroupsPluginRights
# HeavyTasksRequired
# HostAlias
# HostGroups
# HostResourceAssociation
# HostWorkspaces
# Hosts
# HostsInHostGroups
# IcingaAlerts
# ImageBaseFormats
# IngestResourceGroups
# IngestResourcesInGroups
# IntegersTo5000
# ItemsToBeIndexed
# ItemsToRemove
# JettySessions
# Languages
# LocalTimeZoneInformation
# LocatorDataDictAssociatedFields
# LocatorDataDictDateTime
# LocatorDataDictGlossary
# LocatorDataDictInteger
# LocatorDataDictObject
# LocatorDataDictPeriod
# LocatorDataDictString
# LocatorDataDictText
# LocatorDataDictTimeCode
# LocatorDataDictTimeCodeDate
# LocatorDataDictTitle
# LocatorFamily
# LocatorThumbnails
# LocatorTypeFields
# LocatorTypes
# LocatorViewRules
# LocatorViews
# LocatorViewsAssoc
# LocatorViewsAssocType
# Locators
# LocatorsFromEDLToCopy
# LockedObjects
# LoggedUsers
# LongTexts
# MEDIA_EXPORT
# MXFDevicesFormats
# MacroTypes
# MapOldClockIdToNewTitleIdHelper
# McsTransitions
# MediaContainerTypes
# MediaContainers
# MediaFormats
# MediaFormatsData
# MediaJobs
# MediaPackTemplateItems
# MediaPackTemplates
# MediaPresets
# MediaProcessStatus
# MediaProfiles
# MediaPurgeRequests
# MediaResource_types
# MediaTemplates
# Media_Purge_Rules
# MigrationProtocols
# Migration_Policies
# MosDeviceCategories
# MosDeviceTypes
# MosDevices
# MutexLocatorTypeGroups
# NLEEditors
# NLEExportFormats
# NLESequencePresets
# NLPExtractionInfo
# NewsWires
# NotifierJMSSettings
# ObjectAssignedStatus
# ObjectStatus
# ObjectTypeAvailFields
# ObjectsInAppServers
# OneCutPreferences
# OneCutPreferencesBkp
# ParsedMediaInfo
# PendingEventsJobList
# PendingEventsSubscriberList
# PlaceHolderRules
# PlanningAreas
# PlanningEventTitles
# PlayoutItemsStatus
# Plugins
# PrintReport
# PurgeLog
# QuotaRuleFormat
# QuotaRuleStorage
# QuotaRules
# RDViewsFieldsStrings
# RULES_ACTIVATIONS
# RcDeviceControllers
# RcEventsMapping
# ReadWires
# RecycleBin
# RecycledObjectsToRemove
# RegisteredSocialApps
# RemovedRecycledObjects
# RemovedRecycledObjectsEx
# RenderProfiles
# RenderProfilesTranisitions
# RenderTranisitionPresets
# ResourceConnections
# ResourceContexts
# RosterGroups
# RosterItems
# RosterItemsInGroups
# RsuAppServers
# RundownViews
# RundownViewsAssociations
# RundownViewsFields
# SOMUpdateHistory
# ScheduledSoMePosts
# SiblingVideoPairs
# SiteObjectTypeDisplayedFields
# SocialMediaAccounts
# SocialNetworkTypes
# SolRCore
# SolRFieldTypes
# SolRIndexes
# SolRSiteConnectionParameters
# SolrIndexDeployment
# SolrSpecialWords
# Sound_Convert
# StatusChangeCategoryRules
# StatusLog
# StatusTN
# StatusTransition
# StatusTransitionAccessRights
# StorageFolders
# StorageUnitDomains
# Storageunit_aliases
# StoryContent
# StoryTemplateAMSection
# StoryTemplateCCConfiguration
# StoryTemplateCGConfiguration
# StoryTemplates
# StoryTransformationPolicy
# StoryViews
# StreamingServers
# StudioCGConfigPerStoryTemplate
# StudioChannels
# StudioDevices
# Studios
# SubtitleDiv
# SubtitleDivStyle
# SubtitleLocatorStyle
# SubtitleLocators
# SubtitleRegion
# SubtitleRegionStyle
# SubtitleStyle
# SubtitleStyleStyle
# SubtitleVideoRegions
# SubtitleVideoStyles
# SubtitlesTypes
# TNVersions
# TableSizesPattern
# Tabs
# TaskListViewRules
# TaskListViews
# Tech_Support
# TitleChangeNotifyRules
# TitleCreationForms
# TitleDataDictDateTime
# TitleDataDictGlossary
# TitleDataDictInteger
# TitleDataDictObject
# TitleDataDictPeriod
# TitleDataDictString
# TitleDataDictText
# TitleDataDictTimeCode
# TitleDataDictTimeCodeDate
# TitleDataDictTitle
# TitleDurationUpdates
# TitleLastUsedForms
# TitleType_to_MediaType
# Title_Files
# TitlesPendingForDelete
# Titles_ExFields
# TrackStackTemplates
# TransferSessions
# UILanguages
# UIMessages
# UsageRestrictaionLocators
# UserObjectDisplayedFields
# UserObjectTypeDisplayedFields
# UserOptions
# ValueOptions
# VersionConfiguraton
# Versions
# VideoCGs
# ViewAssociations
# WeakReferenceMediaInfo
# WebApplications
# WebFolders
# WebLinks
# WebLinksInFolders
# WebSpaceCommands
# WebSpaceDefaultKeyboardShortcuts
# WebSpaceDisabledCommands
# WebSpaceKeyboardShortcuts
# WebSpaceMacros
# WebViewsAssociations
# WebspaceCommandCategory
# WebspaceViews
# WireCategories
# WireFoldersNotify
# WireFormats
# WireFormatsAdditionalRoots
# WireImages
# WiresContributors
# WiresInFilterFolders
# WiresInFolders
# Workspaces
# access_rights_object_types
# admin_user_in_group
# airedStoriesArchiver_rules
# album
# am_layouts
# applicationservers_aliases
# archiveTickerMessages
# artist
# artist_band
# attribute_values
# attributes
# available_access_rights
# band
# block_item
# block_safewindow
# block_types
# blocks
# broadcast_clocks
# broadcast_items
# cClient
# cMediaJobs
# cReservations
# cblock
# cclock
# class_tree
# classes
# clocks
# clocks_references
# commands
# compagny
# config_int
# ctitles
# daletConversation
# ensemble
# ensemble_link
# ensemble_restrictions
# feed_types
# generics
# groups
# historical_rule
# id_factory
# industries
# industry_values
# items
# items_references
# keywords
# kick_rule
# mediaresources
# mediums
# mr_policy
# mr_rule
# object_access_rights
# objects_in_titles
# objects_references
# ofConParticipant
# ofConversation
# ofExtComponentConf
# ofGroup
# ofGroupProp
# ofGroupUser
# ofID
# ofMessageArchive
# ofMucAffiliation
# ofMucConversationLog
# ofMucMember
# ofMucRoom
# ofMucRoomProp
# ofMucService
# ofMucServiceProp
# ofOffline
# ofPresence
# ofPrivacyList
# ofPrivate
# ofProperty
# ofPubsubAffiliation
# ofPubsubDefaultConf
# ofPubsubItem
# ofPubsubNode
# ofPubsubNodeGroups
# ofPubsubNodeJIDs
# ofPubsubSubscription
# ofRRDs
# ofRemoteServerConf
# ofRoster
# ofRosterGroups
# ofSASLAuthorized
# ofSecurityAuditLog
# ofUser
# ofUserFlag
# ofUserProp
# ofVCard
# ofVersion
# opener_rule
# order_interval
# placement_restriction
# policy_rule
# products
# proportion_rule
# radio_attributes
# radio_ensembles
# radio_groups
# radio_recycle_weight
# radios
# radios_in_groups
# randomvalues_view
# recycle_weights
# reg_value_int
# reg_value_string
# reg_value_text
# reg_value_timestamp
# resourceReservations
# restricted_segue
# routerTypes
# routers
# schedule_patterns
# segues_rule
# selectionRelations
# separation_rule
# soundfile_units
# soundfiles
# spots
# sysdiagrams
# texts
# title_artist
# title_interfaces
# title_keyword
# title_types
# titles
# titles_attributes
# titles_comments
# titles_extend
# titles_in_class
# titles_mix
# titles_references
# titles_to_convert
# user_in_group
# user_reg_value_int
# user_reg_value_string
# user_reg_value_timestamp
# users
# voice_inserts

# %%
query = """
SELECT
*
FROM
RundownViews
"""
cursor.execute(query)
results = cursor.fetchall()
for x in results:
    print(x)
# Out:
# (136, '<RundownView id.l="136" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="45"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_Hold</displayName><name t="ws">ITEM_Hold</name><title t="lt"><UIString langId.l="1033"><str t="ws">Float</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="4"><description t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></description><displayName t="ws">TITLE_LockedBy</displayName><name t="ws">TITLE_LockedBy</name><title t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="180"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l= ...
# (128, '<RundownView id.l="128" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="45"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_Hold</displayName><name t="ws">ITEM_Hold</name><title t="lt"><UIString langId.l="1033"><str t="ws">Float</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="4"><description t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></description><displayName t="ws">TITLE_LockedBy</displayName><name t="ws">TITLE_LockedBy</name><title t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="180"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l= ...
# (130, '<RundownView id.l="130" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings itemHighlight.null="" nextItemHighlight.null="" userGroupsForDeviceTracking.ll=""/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="150"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Digital Producer</str></UIString></description><displayName t="ws">OTV Digital Producer</displayName><name t="ws">OTV Digital Producer</name><title t="lt"><UIString langId.l="1033"><str t="ws">Digital Producer</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="1"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" width.l="37"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="400"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">STORY</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">STORY</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="11" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="1"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="200"><field t="t"><FieldDef fieldObjectTypes.ll="8"><displayName t="ws">Digital Reporter</displayName><name t="ws">Digital Reporter</name><title t="lt"><UIString langId.l="1033"><str t="ws">Reporter</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOr ...
# (132, '<RundownView id.l="132" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields HideFrameRateInfo.b="false" ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="25"><field t="t"><FieldDef fieldObjectTypes.ll="4 128"><description t="lt"><UIString langId.l="1033"><str t="ws">Locked</str></UIString></description><displayName t="ws">ITEM_Locking</displayName><name t="ws">ITEM_Locking</name><title t="lt"><UIString langId.l="1033"><str t="ws">L</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="55"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="150"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" exclud ...
# (135, '<RundownView id.l="135" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields HideFrameRateInfo.b="false" ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="85"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_BackTime</displayName><name t="ws">ITEM_BackTime</name><timeFormat t="lt"><UIString langId.l="1033"><str t="ws"> &lt;LocaleTime&gt;</str></UIString></timeFormat></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws"></fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="55"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="150"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0"  ...
# (122, '<RundownView id.l="122" viewType.l="2"><blankLineCommentFieldName t="ws"></blankLineCommentFieldName><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="200"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="100"><field t="t"><FieldDef fieldObjectTypes.ll="8"><displayName t="ws">OTV News-Digital Shared</displayName><name t="ws">OTV News-Digital Shared</name><title t="lt"><UIString langId.l="1033"><str t="ws">Usage</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="12253694" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="150"><field t="t"><FieldDef fieldObjectTypes.ll="8"><displayName t="ws">OTV Digital Section</displayName><name t="ws">OTV Digital Section</name><title t="lt"><UIString langId.l="1033"><str t="ws">Digital Section</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="12253694" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="70"><field t="t"><FieldDef fieldObjectTypes.ll="8"><displayName t="ws">OTV Digital Priority</displayName><name t="ws">OTV Digital Priority</name><title t="lt"><UIString langId.l="1033"><str t="ws">Priority</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="12253694" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="5" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="70"><field t="t"><FieldDef fieldObjectTypes.ll="8"><displayName t="ws">OTV Digital Producer</displayName><name t="ws">OTV Digital Producer</name><title t="lt"><UIString langId.l="1033"><str t="ws">Producer</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="12253694" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSi ...
# (123, '<RundownView id.l="123" viewType.l="2"><blankLineCommentFieldName t="ws"></blankLineCommentFieldName><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="60"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="250"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15390696" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="30"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Section</str></UIString></description><displayName t="ws">OTV Sections</displayName><name t="ws">OTV Sections</name><title t="lt"><UIString langId.l="1033"><str t="ws"></str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15390696" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="20"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Sort/priority within the section.</str></UIString></description><displayName t="ws">Desk Priority</displayName><name t="ws">Desk Priority</name><title t="lt"><UIString langId.l="1033"><str t="ws"></str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15390696" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="100"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Event Time</str></UIString></description><displayName t="ws">OTV Shoot Time</displayName><name t="ws">OTV Shoot Time</name><title t="lt"><UIString langId.l="1033"><str t="ws">Event Time</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15390696" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="5" rtl.l="0" showGlossaryPath.b="false"  ...
# (133, '<RundownView id.l="133" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="45"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="180"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1"><customFieldAssetFieldType t="ws">null</customFieldAssetFieldType><description t="lt"><UIString langId.l="1033"><str t="ws">Brio 5</str></UIString></description><displayName t="ws">VIEW_RSUSpotStatus_Format[HIRES]_Storage[Brio_05]</displayName><name t="ws">VIEW_RSUSpotStatus_2889_34</name><title t="lt"><UIString langId.l="1033"><str t="ws">5</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="12" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws"></fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1"><customFieldAssetFieldType t=" ...
# (127, '<RundownView id.l="127" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields HideFrameRateInfo.b="false" ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="85"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_BackTime</displayName><name t="ws">ITEM_BackTime</name><timeFormat t="lt"><UIString langId.l="1033"><str t="ws"> &lt;LocaleTime&gt;</str></UIString></timeFormat></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws"></fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="55"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="150"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0"  ...
# (125, '<RundownView id.l="125" viewType.l="1"><blankLineCommentFieldName t="ws"></blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="60"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="200"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="80"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Segment</str></UIString></description><displayName t="ws">OTV Segment</displayName><name t="ws">OTV Segment</name><title t="lt"><UIString langId.l="1033"><str t="ws">Segment</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Anchor</str></UIString></description><displayName t="ws">OTV Anchor</displayName><name t="ws">OTV Anchor</name><title t="lt"><UIString langId.l="1033"><str t="ws">Anchor</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><description t="lt"><UIString langId.l="1033"><str t="ws">Writer</str></UIString></description><displayName t="ws">ITEM_Custom7</displayName><name t="ws">ITEM_Custom7</name><title t="lt"><UIString langId.l="1033"><str t="ws">Writer (bad)</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="5" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Writer</str></UIString></description><displayName t="ws">OTV Writer</displayName><name t="ws">OTV Writer</name><title t="lt"><UIString langId.l="1033"><str t="ws">Writer (good)</str></UIString></title></FieldDef></fiel ...
# (117, '<RundownView id.l="117" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="12" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws"></fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="45"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="180"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="12" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws"></fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="80"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><description t="lt"><UIString langId.l="1033"><str t="ws">Segment (Dalet Item Custom 2 field)</str></UIString></description><displayName t="ws">ITEM_Custom2</displayName><name t="ws">ITEM_Custom2</name><title t="lt"><UIString langId.l="1033"><str t="ws">Segment</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="12" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws"></fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint ...
# (137, '<RundownView id.l="137" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="60"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_Hold</displayName><name t="ws">ITEM_Hold</name><title t="lt"><UIString langId.l="1033"><str t="ws">Float</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="4"><description t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></description><displayName t="ws">TITLE_LockedBy</displayName><name t="ws">TITLE_LockedBy</name><title t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="180"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l= ...

# %%
query = """
SELECT
*
FROM
StoryContent
WHERE
TitleId='29807928'
"""
cursor.execute(query)
results = cursor.fetchall()
for x in results:
    for y in x:
        print(y)
# Out:
# 29807928
# <StoryContent dilVersion.l="57420" lastModifyMainSection.td="2021-03-09T06:43:22.098" lastModifySoMeSection.td="2021-03-08T19:51:07.229" maxEmbeddedItemId.l="11" nextSocialMediaSectionId.l="1" titleId.l="29807928"><SecondarySections t="lt"><SecondarySection SectionType.l="2" lastModifySection.td="2021-03-09T06:43:22.098"><StoryObjects t="lt"></StoryObjects><rtf t="ws">{\rtf1\ansi\ansicpg1252\deff0\deflang1033{\fonttbl{\f0\fnil\fcharset0 Arial;}}&#xd;&#xa;{\colortbl ;\red0\green0\blue0;}&#xd;&#xa;{\*\generator Msftedit 5.41.21.2510;}\viewkind4\uc1\pard\cf1\fs24\par&#xd;&#xa;}&#xd;&#xa;</rtf><text t="ws"></text><xml t="ws">&lt;?xml version=&quot;1.0&quot; ?&gt;&#xd;&#xa;&lt;STORY&gt;&lt;FONT color=&quot;#000000&quot;/&gt;&lt;FONT size=&quot;3&quot;/&gt;&lt;BR/&gt;&lt;FONT/&gt;&lt;FONT/&gt;&#xd;&#xa;&lt;/STORY&gt;&#xd;&#xa;</xml></SecondarySection></SecondarySections><SocialMediaSections t="lt"></SocialMediaSections><StoryObjects t="lt"><EmbeddedObject ObjectId.l="29807930" ObjectType.l="2" PositionInText.l="0" idInStory.l="2"><itemSpot t="t"><Spot/></itemSpot></EmbeddedObject><EmbeddedObject ObjectId.l="29807931" ObjectType.l="2" PositionInText.l="4" idInStory.l="11"><itemSpot t="t"><Spot/></itemSpot></EmbeddedObject><EmbeddedObject ObjectId.l="29807933" ObjectType.l="2" PositionInText.l="179" idInStory.l="8"><itemSpot t="t"><Spot/></itemSpot></EmbeddedObject><EmbeddedObject ObjectId.l="29807935" ObjectType.l="2" PositionInText.l="182" idInStory.l="6"><itemSpot t="t"><Spot/></itemSpot></EmbeddedObject></StoryObjects><rtf t="ws">{\rtf1\ansi\ansicpg1252\deff0\deflang1033{\fonttbl{\f0\fnil Arial;}{\f1\fnil\fcharset0 Arial;}}&#xd;&#xa;{\colortbl ;\red0\green0\blue0;\red231\green231\blue231;}&#xd;&#xa;{\*\generator Msftedit 5.41.21.2510;}\viewkind4\uc1\pard\cf1\f0\fs24\objattph\&apos;20\par&#xd;&#xa;\par&#xd;&#xa;\par&#xd;&#xa;\objattph\&apos;20\par&#xd;&#xa;\par&#xd;&#xa;\par&#xd;&#xa;\par&#xd;&#xa;[[***ON CAM***]]\par&#xd;&#xa;\par&#xd;&#xa;\f1\tab GOOD MORNING..\par&#xd;&#xa;\tab IT&apos;S [[ date]].\par&#xd;&#xa;\tab I&apos;m Liz Kreutz.\par&#xd;&#xa;\tab LET&apos;S START WITH A QUICK LOOK AT THE WEATHER.\par&#xd;&#xa;[[***FRAMES***]]\par&#xd;&#xa;\tab HERE&apos;S METEOROLOGIST LISA ARGEN.\par&#xd;&#xa;\f0\par&#xd;&#xa;\par&#xd;&#xa;\par&#xd;&#xa;\par&#xd;&#xa;\cf1\objattph\&apos;20\cf1\par&#xd;&#xa;\par&#xd;&#xa;\cf1\objattph\&apos;20\cf1\par&#xd;&#xa;\cf1\par&#xd;&#xa;}&#xd;&#xa;</rtf><text t="ws"> &#xa;&#xa;&#xa; &#xa;&#xa;&#xa;&#xa;[[***ON CAM***]]&#xa;&#xa;&#x9;GOOD MORNING..&#xa;&#x9;IT&apos;S [[ date]].&#xa;&#x9;I&apos;m Liz Kreutz.&#xa;&#x9;LET&apos;S START WITH A QUICK LOOK AT THE WEATHER.&#xa;[[***FRAMES***]]&#xa;&#x9;HERE&apos;S METEOROLOGIST LISA ARGEN.&#xa;&#xa;&#xa;&#xa;&#xa; &#xa;&#xa; &#xa;</text><textWithoutComments t="ws"> &#xd;&#xa;&#xd;&#xa;&#xd;&#xa; &#xd;&#xa;&#xd;&#xa;&#xd;&#xa;&#xd;&#xa;&#xd;&#xa;&#xd;&#xa;GOOD MORNING..&#xd;&#xa;IT&apos;S .&#xd;&#xa;I&apos;m Liz Kreutz.&#xd;&#xa;LET&apos;S START WITH A QUICK LOOK AT THE WEATHER.&#xd;&#xa;&#xd;&#xa;HERE&apos;S METEOROLOGIST LISA ARGEN.&#xd;&#xa;&#xd;&#xa;&#xd;&#xa;&#xd;&#xa;&#xd;&#xa; &#xd;&#xa;&#xd;&#xa; &#xd;&#xa;&#xd;&#xa;</textWithoutComments><xml t="ws">&lt;?xml version=&quot;1.0&quot; ?&gt;&#xd;&#xa;&lt;STORY&gt;&lt;FONT color=&quot;#000000&quot;/&gt;&lt;FONT face=&quot;Arial&quot;/&gt;&lt;FONT size=&quot;3&quot;/&gt;&lt;EmbeddedObject ObjectId.l=&quot;29807930&quot; ObjectType.l=&quot;2&quot; PositionInText.l=&quot;0&quot; idInStory.l=&quot;2&quot;&gt;&lt;itemSpot t=&quot;t&quot;&gt;&lt;Spot/&gt;&lt;/itemSpot&gt;&lt;/EmbeddedObject&gt; &lt;BR/&gt;&lt;BR/&gt;&lt;BR/&gt;&lt;EmbeddedObject ObjectId.l=&quot;29807931&quot; ObjectType.l=&quot;2&quot; PositionInText.l=&quot;4&quot; idInStory.l=&quot;11&quot;&gt;&lt;itemSpot t=&quot;t&quot;&gt;&lt;Spot/&gt;&lt;/itemSpot&gt;&lt;/EmbeddedObject&gt; &lt;BR/&gt;&lt;BR/&gt;&lt;BR/&gt;&lt;BR/&gt;&lt;CommentForTimingS/&gt;***ON CAM***&lt;CommentForTimingE/&gt;&lt;BR/&gt;&lt;BR/&gt;&lt;FONT/&gt;&lt;FONT face=&quot; ...
#
#
#
#
#
#
#
# [[***ON CAM***]]
#
# 	GOOD MORNING..
# 	IT'S [[ date]].
# 	I'm Liz Kreutz.
# 	LET'S START WITH A QUICK LOOK AT THE WEATHER.
# [[***FRAMES***]]
# 	HERE'S METEOROLOGIST LISA ARGEN.

# %%
 
query = """
SELECT *
FROM RundownViewsAssociations 
"""
cursor.execute(query)
results = cursor.fetchall()

# %%
print ([x[0] for x in cursor.description])
for row in results:
    print(row)
# Out:
# ['ObjectId', 'ObjectType', 'RundownViewId', 'Priority', 'DefaultPriority']
# ('438', 'GROUP-Program', 132, 2, None)
# ('9', 'GROUP-Program', 132, 3, None)
# ('438', 'GROUP-Pattern', 137, 1, None)
# ('9', 'GROUP-Program', 136, 4, None)
# ('438', 'GROUP-Program', 135, 5, None)
# ('438', 'GROUP-Planning', 123, 0, None)
# ('438', 'GROUP-Program', 133, 3, None)
# ('9', 'GROUP-Program', 133, 4, None)
# ('438', 'GROUP-Program', 127, 0, None)
# ('9', 'GROUP-Program', 127, 0, None)
# ('438', 'GROUP-Pattern', 125, 0, None)
# ('9', 'GROUP-Pattern', 125, 0, None)
# ('438', 'GROUP-Program', 128, 1, None)
# ('9', 'GROUP-Program', 128, 2, None)

# %%
query = """
SELECT * 
FROM INFORMATION_SCHEMA.COLUMNS 
"""
cursor.execute(query)
results = cursor.fetchall()

# %%
titleid_dict = {}
#//*** Script ID 29807928
#//*** Rundown ID 29620400
for row in results:
    if  row[7] == 'int':
        #print(row[2],row[3])
        loop_query = f"""
        SELECT count(*)
        FROM {row[2]}
        WHERE {row[3]}='29620400' 
        """
        cursor.execute(loop_query)
        loop_result = cursor.fetchall()[0][0]
        if loop_result > 0:
            print(row[2],row[3],loop_result)
            titleid_dict[row[2]] = row[3]
# Out:
# Titles_ExFields Title_id 1
# TitleDataDictInteger TitleId 33
# TitleDataDictString TitleId 29
# TitleDataDictDateTime TitleId 2
# TitleDataDictText TitleId 1
# items clock_id 58
# titles_extend title_id 1
# ItemsToBeIndexed Item_id 1
# titles_in_class title_id 1
# titles_references title_id 1
# titles_mix title_id 1
# CreatedModifiedItems Item_id 1
# PlayoutItemsStatus ClockId 103
# resourceReservations clockId 1
# clocks clock_id 1
# ObjectStatus ObjectId 1
# titles title_id 1
# StatusLog ObjectId 1

# %%
query = """
SELECT * 
FROM INFORMATION_SCHEMA.COLUMNS 
"""
cursor.execute(query)
results = cursor.fetchall()
titleid_dict = {}
#//*** Script ID 29807928
#//*** Rundown ID 29620400
for row in results:
    #print(row)
    if  row[7] == 'int':
        #print(row[2],row[3])
        loop_query = f"""
        SELECT count(*)
        FROM {row[2]}
        WHERE {row[3]}='29807930' 
        """
        cursor.execute(loop_query)
        loop_result = cursor.fetchall()[0][0]
        if loop_result > 0:
            print(row[2],row[3],loop_result)
            titleid_dict[row[2]] = row[3]
# Out:
# Titles_ExFields Title_id 1
# TitleDataDictString TitleId 4
# TitleDataDictText TitleId 1
# titles_extend title_id 1
# ItemsToBeIndexed Item_id 1
# titles_in_class title_id 1
# objects_in_titles Object_id 3
# titles_references title_id 1
# titles_mix title_id 1
# CreatedModifiedItems Item_id 1
# ObjectStatus ObjectId 1
# titles title_id 1
# StatusLog ObjectId 1

# %%
for table,column in titleid_dict.items():
        loop_query = f"""
        SELECT *
        FROM {table}
        WHERE {column}='29807930' 
        """
        cursor.execute(loop_query)
        loop_result = cursor.fetchall()
        print(f"{table} -- {column}")
        print ([x for x in cursor.description])
        
        for row in loop_result:
            print(row)
        print("=============")
# Out:
# Titles_ExFields -- Title_id
# [('Title_id', <class 'int'>, None, 10, 10, 0, False), ('Language_id', <class 'int'>, None, 10, 10, 0, False), ('Topic', <class 'str'>, None, 32, 32, 0, True), ('VersionComment', <class 'str'>, None, 1073741823, 1073741823, 0, True)]
# (29807930, 99, None, 'Title Created')
# =============
# TitleDataDictString -- TitleId
# [('DataField_Id', <class 'int'>, None, 10, 10, 0, False), ('TitleId', <class 'int'>, None, 10, 10, 0, False), ('ValueOrder', <class 'int'>, None, 10, 10, 0, False), ('StrValue', <class 'str'>, None, 255, 255, 0, False)]
# (93, 29807930, 1, '5bc5021e2a183')
# (94, 29807930, 1, 'kgo.pcr2.ovd.mos')
# (1178, 29807930, 1, '--')
# (1232, 29807930, 1, '--')
# =============
# TitleDataDictText -- TitleId
# [('DataField_Id', <class 'int'>, None, 10, 10, 0, False), ('TitleId', <class 'int'>, None, 10, 10, 0, False), ('ValueOrder', <class 'int'>, None, 10, 10, 0, False), ('TextValue', <class 'str'>, None, 1073741823, 1073741823, 0, False)]
# (82, 29807930, 1, "<mos><mosID>kgo.pcr2.ovd.mos</mosID><itemID>0</itemID><mosAbstract>4A DIS - Ross Video - Transition: 2_DIS CLR G1 - Audio AFV: Disabled - 4 Clip: IGNITE:ANCHOR</mosAbstract><objSlug>4A DIS - Ross Video - Transition: 2_DIS CLR G1 - Audio AFV: Disabled - 4 Clip: IGNITE:ANCHOR</objSlug><mosPlugInID>Ross.Inception</mosPlugInID><objID>5bc5021e2a183</objID><mosItemEditorProgID>RossClem.RossEditor</mosItemEditorProgID><objDur>1</objDur><objTB>60</objTB><abstract /><itemSlug /><mosExternalMetadata><mosScope>PLAYLIST</mosScope><mosSchema>http:'rossvideo.com/schemas/MOS/external/1.0</mosSchema><mosPayload><shotID>12607</shotID><dbAppVersion><major>18</major><minor>4</minor><revision>11</revision><build>6170</build></dbAppVersion><dbTemplate><templateNumber>203</templateNumber><shotName>4A DIS</shotName><imageURL>/icons/KGO/TEST/D4A.jpg</imageURL><transition><id>41</id><name>2_DIS CLR G1</name></transition><mleList><id>33002</id><busList><busType><id>0</id></busType><device><id>32</id><name>4</name></device><primaryClip><clipValue>IGNITE:ANCHOR</clipValue></primaryClip></busList></mleList><afvLevel>-2</afvLevel><additionalAudioList><additionalAudio><id>23488</id><order>359</order><audio><id>1</id><name>ANCH</name><type>CHANNEL</type></audio><customLevel>-1</customLevel><overrideState>OVERRIDE_ON</overrideState></additionalAudio><additionalAudio><id>23489</id><order>360</order><audio><id>2</id><name>COAN</name><type>CHANNEL</type></audio><customLevel>-1</customLevel><overrideState>OVERRIDE_ON</overrideState></additionalAudio></additionalAudioList><floorDirectorCueNote /><floorDirectorCueNoteEnabled>false</floorDirectorCueNoteEnabled></dbTemplate><icon>/icons/KGO/TEST/D4A.jpg</icon></mosPayload></mosExternalMetadata></mos>")
# =============
# titles_extend -- title_id
# [('title_id', <class 'int'>, None, 10, 10, 0, False), ('source', <class 'str'>, None, 255, 255, 0, True), ('reader', <class 'int'>, None, 10, 10, 0, False), ('read_rate', <class 'int'>, None, 10, 10, 0, False), ('year_composed', <class 'int'>, None, 10, 10, 0, False), ('medium', <class 'int'>, None, 10, 10, 0, False), ('status', <class 'int'>, None, 10, 10, 0, False), ('custom1', <class 'str'>, None, 255, 255, 0, True), ('custom2', <class 'str'>, None, 255, 255, 0, True), ('label_reference', <class 'str'>, None, 16, 16, 0, False), ('volume_number', <class 'str'>, None, 16, 16, 0, False), ('oeuvre', <class 'str'>, None, 255, 255, 0, True), ('act', <class 'str'>, None, 64, 64, 0, False), ('orchestra', <class 'str'>, None, 255, 255, 0, True), ('composer', <class 'str'>, None, 255, 255, 0, True), ('conductor', <class 'str'>, None, 255, 255, 0, True), ('period', <class 'str'>, None, 128, 128, 0, False), ('industry', <class 'int'>, None, 10, 10, 0, False), ('product', <class 'int'>, None, 10, 10, 0, False), ('language', <class 'str'>, None, 64, 64, 0, False), ('cut', <class 'str'>, None, 64, 64, 0, False), ('version', <class 'str'>, None, 3, 3, 0, False), ('voice', <class 'str'>, None, 255, 255, 0, True), ('creator', <class 'str'>, None, 255, 255, 0, True)]
# (29807930, ' ', 0, 0, 1900, 0, 0, ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 0, 0, '', ' ', 'p ', ' ', ' ')
# =============
# ItemsToBeIndexed -- Item_id
# [('Item_id', <class 'int'>, None, 10, 10, 0, False), ('Item_type', <class 'int'>, None, 10, 10, 0, False), ('ModifiedAt', <class 'datetime.datetime'>, None, 23, 23, 3, True), ('IsInRecycleBin', <class 'int'>, None, 5, 5, 0, False)]
# (29807930, 2, datetime.datetime(2021, 3, 9, 6, 43, 21, 920000), 0)
# =============
# titles_in_class -- title_id
# [('class_id', <class 'int'>, None, 10, 10, 0, False), ('title_id', <class 'int'>, None, 10, 10, 0, False), ('is_primary_class', <class 'int'>, None, 10, 10, 0, False), ('order_in_class', <class 'int'>, None, 10, 10, 0, True)]
# (26092, 29807930, 1, None)
# =============
# objects_in_titles -- Object_id
# [('Object_id', <class 'int'>, None, 10, 10, 0, False), ('Object_type', <class 'int'>, None, 10, 10, 0, False), ('Title_id', <class 'int'>, None, 10, 10, 0, False), ('Rank', <class 'int'>, None, 10, 10, 0, False), ('Offset', <class 'int'>, None, 10, 10, 0, False)]
# (29807930, 2, 29807928, 0, -1)
# (29807930, 2, 29813840, 0, -1)
# (29807930, 2, 29813841, 0, -1)
# =============
# titles_references -- title_id
# [('title_id', <class 'int'>, None, 10, 10, 0, False), ('reference_id', <class 'int'>, None, 10, 10, 0, False), ('reference_text', <class 'str'>, None, 255, 255, 0, False)]
# (29807930, 1, 'KGO3719013')
# =============
# titles_mix -- title_id
# [('title_id', <class 'int'>, None, 10, 10, 0, False), ('begin_offset', <class 'int'>, None, 10, 10, 0, False), ('end_offset', <class 'int'>, None, 10, 10, 0, False), ('intro1', <class 'int'>, None, 10, 10, 0, False), ('intro2', <class 'int'>, None, 10, 10, 0, False), ('outro', <class 'int'>, None, 10, 10, 0, False), ('fade_in', <class 'int'>, None, 10, 10, 0, False), ('fade_out', <class 'int'>, None, 10, 10, 0, False), ('crossfade', <class 'int'>, None, 10, 10, 0, False), ('is_endless_loop', <class 'int'>, None, 10, 10, 0, False)]
# (29807930, 0, 0, 0, 0, 0, 0, 0, 0, 0)
# =============
# CreatedModifiedItems -- Item_id
# [('Item_id', <class 'int'>, None, 10, 10, 0, False), ('Item_type', <class 'int'>, None, 10, 10, 0, False), ('CreatedBy', <class 'int'>, None, 10, 10, 0, True), ('ModifiedBy', <class 'int'>, None, 10, 10, 0, True), ('CreatedAt', <class 'datetime.datetime'>, None, 23, 23, 3, True), ('ModifiedAt', <class 'datetime.datetime'>, None, 23, 23, 3, True), ('CreatedByName', <class 'str'>, None, 64, 64, 0, True), ('ModifiedByName', <class 'str'>, None, 64, 64, 0, True), ('IsInRecycleBin', <class 'int'>, None, 5, 5, 0, False)]
# (29807930, 2, 1915, 1915, datetime.datetime(2021, 3, 8, 19, 51, 6, 337000), datetime.datetime(2021, 3, 8, 19, 51, 8, 200000), 'KGO DaletService', 'KGO DaletService', 0)
# =============
# ObjectStatus -- ObjectId
# [('ObjectId', <class 'int'>, None, 10, 10, 0, False), ('ObjectType', <class 'int'>, None, 10, 10, 0, False), ('Status_id', <class 'int'>, None, 10, 10, 0, False)]
# (29807930, 82, 1)
# =============
# titles -- title_id
# [('title_id', <class 'int'>, None, 10, 10, 0, False), ('title_type_id', <class 'int'>, None, 10, 10, 0, False), ('title_interface_id', <class 'int'>, None, 10, 10, 0, False), ('user_id', <class 'int'>, None, 10, 10, 0, False), ('title', <class 'str'>, None, 255, 255, 0, False), ('interpret', <class 'str'>, None, 4000, 4000, 0, False), ('author', <class 'str'>, None, 255, 255, 0, False), ('client', <class 'str'>, None, 255, 255, 0, False), ('duration', <class 'int'>, None, 10, 10, 0, False), ('is_online', <class 'int'>, None, 10, 10, 0, False), ('is_recorded', <class 'int'>, None, 10, 10, 0, False), ('record_date', <class 'datetime.datetime'>, None, 23, 23, 3, False), ('start_date', <class 'datetime.datetime'>, None, 23, 23, 3, False), ('end_date', <class 'datetime.datetime'>, None, 23, 23, 3, False), ('kill_date', <class 'datetime.datetime'>, None, 23, 23, 3, False), ('audio_duration', <class 'int'>, None, 10, 10, 0, False), ('use_manual_duration', <class 'int'>, None, 10, 10, 0, False), ('soundfile_id', <class 'int'>, None, 10, 10, 0, False), ('year', <class 'int'>, None, 10, 10, 0, False), ('keywords', <class 'str'>, None, 4000, 4000, 0, False), ('site_origin', <class 'int'>, None, 10, 10, 0, False), ('no_overwrite', <class 'int'>, None, 10, 10, 0, False), ('is_rotational_cart', <class 'int'>, None, 10, 10, 0, False), ('replacement', <class 'str'>, None, 16, 16, 0, False), ('last_words', <class 'str'>, None, 255, 255, 0, False), ('is_opener', <class 'int'>, None, 10, 10, 0, True), ('weight', <class 'int'>, None, 5, 5, 0, True), ('beats_pm', <class 'int'>, None, 10, 10, 0, True), ('master_record', <class 'int'>, None, 10, 10, 0, True), ('compagny_id', <class 'int'>, None, 10, 10, 0, True), ('compagny_disp_name', <class 'str'>, None, 255, 255, 0, True), ('album_disp_name', <class 'str'>, None, 255, 255, 0, True), ('package_id', <class 'int'>, None, 10, 10, 0, True), ('album_id', <class 'int'>, None, 10, 10, 0, True), ('song_id', <class 'int'>, None, 10, 10, 0, True), ('day_part_rest_id', <class 'int'>, None, 10, 10, 0, True), ('keep_date', <class 'datetime.datetime'>, None, 23, 23, 3, False)]
# (29807930, 1046, 0, 0, '4A DIS - Ross Video - Transition: 2_DIS CLR G1 - Audio AFV: Disabled - 4 Clip: IGNITE:ANCHOR', ' ', 'KGO DaletService', '', 16, 1, 0, datetime.datetime(2021, 2, 27, 12, 0, 37, 570000), datetime.datetime(2021, 3, 8, 19, 51, 6, 260000), datetime.datetime(2021, 3, 15, 19, 51, 6, 260000), datetime.datetime(2021, 3, 22, 19, 51, 6, 260000), 0, 0, 0, 2021, ' ', 0, 0, 0, ' ', ' ', 0, 100, -1, None, None, ' ', ' ', None, None, None, None, datetime.datetime(2021, 3, 7, 19, 51, 6, 260000))
# =============
# StatusLog -- ObjectId
# [('Order1', <class 'decimal.Decimal'>, None, 18, 18, 0, False), ('ObjectId', <class 'int'>, None, 10, 10, 0, False), ('ObjectType', <class 'int'>, None, 10, 10, 0, False), ('To_status', <class 'int'>, None, 10, 10, 0, False), ('Log_date', <class 'datetime.datetime'>, None, 23, 23, 3, True), ('Commentt', <class 'str'>, None, 255, 255, 0, True), ('UserLastName', <class 'str'>, None, 32, 32, 0, False), ('UserFirstName', <class 'str'>, None, 32, 32, 0, False)]
# (Decimal('10995724'), 29807930, 82, 1, datetime.datetime(2021, 3, 8, 19, 51, 6, 250000), 'Copied with original title status', 'KGO', 'DaletService')
# =============

# %%
def hunt_db(input_search,input_type='int'):
    query = """
    SELECT * 
    FROM INFORMATION_SCHEMA.COLUMNS 
    """
    cursor.execute(query)
    results = cursor.fetchall()
    titleid_dict = {}
    #//*** Script ID 29807928
    #//*** Rundown ID 29620400
    for row in results:
        #print(row)
        if  row[7] == input_type:
            #print(row[2],row[3])
            loop_query = f"""
            SELECT count(*)
            FROM {row[2]}
            WHERE {row[3]}='{input_search}' 
            """
            cursor.execute(loop_query)
            loop_result = cursor.fetchall()[0][0]
            if loop_result > 0:
                print(row[2],row[3],loop_result)
                titleid_dict[row[2]] = row[3]
                
    for table,column in titleid_dict.items():
        loop_query = f"""
        SELECT *
        FROM {table}
        WHERE {column}='{input_search}' 
        """
        cursor.execute(loop_query)
        loop_result = cursor.fetchall()
        print(f"{table} -- {column}")
        print ([x for x in cursor.description])

        for row in loop_result:
            print(row)
        print("=============")

            
            
            
hunt_db('29807933')
# Out:
# Titles_ExFields Title_id 1
# TitleDataDictString TitleId 4
# TitleDataDictText TitleId 2
# titles_extend title_id 1
# ItemsToBeIndexed Item_id 1
# titles_in_class title_id 1
# objects_in_titles Object_id 3
# titles_references title_id 1
# titles_mix title_id 1
# CreatedModifiedItems Item_id 1
# Title_Files Title_id 3
# ObjectStatus ObjectId 1
# titles title_id 1
# StatusLog ObjectId 1
# Titles_ExFields -- Title_id
# [('Title_id', <class 'int'>, None, 10, 10, 0, False), ('Language_id', <class 'int'>, None, 10, 10, 0, False), ('Topic', <class 'str'>, None, 32, 32, 0, True), ('VersionComment', <class 'str'>, None, 1073741823, 1073741823, 0, True)]
# (29807933, 99, None, 'Title Created')
# =============
# TitleDataDictString -- TitleId
# [('DataField_Id', <class 'int'>, None, 10, 10, 0, False), ('TitleId', <class 'int'>, None, 10, 10, 0, False), ('ValueOrder', <class 'int'>, None, 10, 10, 0, False), ('StrValue', <class 'str'>, None, 255, 255, 0, False)]
# (93, 29807933, 1, '{1B8C7EBC-606B-46C4-9AFC-3E5EF002091A}')
# (94, 29807933, 1, 'xpn.kgo.abc.mos')
# (1178, 29807933, 1, '--')
# (1232, 29807933, 1, '--')
# =============
# TitleDataDictText -- TitleId
# [('DataField_Id', <class 'int'>, None, 10, 10, 0, False), ('TitleId', <class 'int'>, None, 10, 10, 0, False), ('ValueOrder', <class 'int'>, None, 10, 10, 0, False), ('TextValue', <class 'str'>, None, 1073741823, 1073741823, 0, False)]
# (81, 29807933, 1, '<mos>\r\n<mosID>xpn.kgo.abc.mos</mosID>\r\n<objID>{1B8C7EBC-606B-46C4-9AFC-3E5EF002091A}</objID>\r\n<storyID />\r\n<storyNum />\r\n<itemSlug>L3 LOWER 3RD:Good Morning! | ABC7 NEWS |  |  |  | Chips | ABC7 Mornings Franchise BANNER (Default) | &lt;none&gt; | 5 ...</itemSlug>\r\n<objSlug>L3 LOWER 3RD:Good Morning! | ABC7 NEWS |  |  |  | Chips | ABC7 Mornings Franchise BANNER (Default) | &lt;none&gt; | 5 ...</objSlug>\r\n<mosAbstract>| 1 |   Good Morning! | ABC7 NEWS |  |  |  | Chips | ABC7 Mornings Franchise BANNER (Defaul ...</mosAbstract>\r\n<itemID>0</itemID>\r\n<objTB>60</objTB>\r\n<objDur>0</objDur>\r\n<itemChannel>1</itemChannel>\r\n<itemTrigger>CHAINED</itemTrigger>\r\n<itemComment />\r\n<mosItemBrowserProgID>XPression.MOSItemBrowser.1</mosItemBrowserProgID>\r\n<mosItemEditorProgID>XPression.MOSItemEditor.1</mosItemEditorProgID>\r\n<mosItemPlayerProgID>XPression.MOSItemPlayer.1</mosItemPlayerProgID>\r\n<macroIn />\r\n<macroOut>NONE</macroOut>\r\n<mosPlugInID>XPression.MOSItemEditor.1</mosPlugInID>\r\n<mosExternalMetadata>\r\n<mosScope>PLAYLIST</mosScope>\r\n<mosSchema />\r\n<mosPayload>\r\n<version>1</version>\r\n<type>CG</type>\r\n<ispreset>0</ispreset>\r\n<sceneid>8478</sceneid>\r\n<index>0</index>\r\n<scenename>L3 LOWER 3RD</scenename>\r\n<show>KGO News 2020</show>\r\n<category />\r\n<style />\r\n<forcestyle>0</forcestyle>\r\n<revision>14</revision>\r\n<description />\r\n<channel>1</channel>\r\n<layer>1000001</layer>\r\n<pvframe>30</pvframe>\r\n<projectguid>{00000000-0000-0000-0000-000000000000}</projectguid>\r\n<projectversion>0</projectversion>\r\n<projectsubversion>0</projectsubversion>\r\n<duration>21</duration>\r\n<width>1280</width>\r\n<height>720</height>\r\n<framerate>0</framerate>\r\n<frameratediv>0</frameratediv>\r\n<gfxtype>OTHER</gfxtype>\r\n<savedname />\r\n<itcObjTB>60</itcObjTB>\r\n<itcTimeIn>0</itcTimeIn>\r\n<itcTimeDur>0</itcTimeDur>\r\n<iss>117520</iss>\r\n<itype />\r\n<content>Good Morning! | ABC7 NEWS |  |  |  | Chips | ABC7 Mornings Franchise BANNER (Default) | &lt;no ...</content>\r\n<datalinqkeys />\r\n<objects>\r\n<object>\r\n<name>SELECT TOP LINE</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value>Good Morning!</value>\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>TXT BOTTOM LINE</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value>ABC7 NEWS</value>\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>SELECT MAIN TAB</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value />\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>SELECT MISC TAB</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value />\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>SELECT LIVE BUG</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value />\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>SELECT IMAGE BANNER</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value>Chips</value>\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>IMAGE</name>\r\n<properties>\r\n<property type="32" name="Material">\r\n<face>\r\n<mtype>2</mtype>\r\n<name>Face</name>\r\n<value>&lt;STLN:STREAMLINE/38191_default/ABC7 Mornings Franchise BANNER (Default)&gt;ABC7 Mornings Franchise BANNER (Default)</value>\r\n</face>\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>HEADS</name>\r\n<properties>\r\n<property type="32" name="Material">\r\n<face>\r\n<mtype>0</mtype>\r\n<name>Face</name>\r\n<value />\r\n</face>\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>DO NOT USE / FOR IMAGE</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value>5</value>\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>DO NOT USE / TXT TRAFFIC NUMBER</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value />\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>DO NOT USE / FOR SOCIAL</name>\r\n< ...
# (82, 29807933, 1, '<mos>\r\n<mosID>xpn.kgo.abc.mos</mosID>\r\n<objID>{1B8C7EBC-606B-46C4-9AFC-3E5EF002091A}</objID>\r\n<storyID />\r\n<storyNum />\r\n<itemSlug>L3 LOWER 3RD:Good Morning! | ABC7 NEWS |  |  |  | Chips | ABC7 Mornings Franchise BANNER (Default) | &lt;none&gt; | 5 ...</itemSlug>\r\n<objSlug>L3 LOWER 3RD:Good Morning! | ABC7 NEWS |  |  |  | Chips | ABC7 Mornings Franchise BANNER (Default) | &lt;none&gt; | 5 ...</objSlug>\r\n<mosAbstract>| 1 |   Good Morning! | ABC7 NEWS |  |  |  | Chips | ABC7 Mornings Franchise BANNER (Defaul ...</mosAbstract>\r\n<itemID>0</itemID>\r\n<objTB>60</objTB>\r\n<objDur>0</objDur>\r\n<itemChannel>1</itemChannel>\r\n<itemTrigger>CHAINED</itemTrigger>\r\n<itemComment />\r\n<mosItemBrowserProgID>XPression.MOSItemBrowser.1</mosItemBrowserProgID>\r\n<mosItemEditorProgID>XPression.MOSItemEditor.1</mosItemEditorProgID>\r\n<mosItemPlayerProgID>XPression.MOSItemPlayer.1</mosItemPlayerProgID>\r\n<macroIn />\r\n<macroOut>NONE</macroOut>\r\n<mosPlugInID>XPression.MOSItemEditor.1</mosPlugInID>\r\n<mosExternalMetadata>\r\n<mosScope>PLAYLIST</mosScope>\r\n<mosSchema />\r\n<mosPayload>\r\n<version>1</version>\r\n<type>CG</type>\r\n<ispreset>0</ispreset>\r\n<sceneid>8478</sceneid>\r\n<index>0</index>\r\n<scenename>L3 LOWER 3RD</scenename>\r\n<show>KGO News 2020</show>\r\n<category />\r\n<style />\r\n<forcestyle>0</forcestyle>\r\n<revision>14</revision>\r\n<description />\r\n<channel>1</channel>\r\n<layer>1000001</layer>\r\n<pvframe>30</pvframe>\r\n<projectguid>{00000000-0000-0000-0000-000000000000}</projectguid>\r\n<projectversion>0</projectversion>\r\n<projectsubversion>0</projectsubversion>\r\n<duration>21</duration>\r\n<width>1280</width>\r\n<height>720</height>\r\n<framerate>0</framerate>\r\n<frameratediv>0</frameratediv>\r\n<gfxtype>OTHER</gfxtype>\r\n<savedname />\r\n<itcObjTB>60</itcObjTB>\r\n<itcTimeIn>0</itcTimeIn>\r\n<itcTimeDur>0</itcTimeDur>\r\n<iss>117520</iss>\r\n<itype />\r\n<content>Good Morning! | ABC7 NEWS |  |  |  | Chips | ABC7 Mornings Franchise BANNER (Default) | &lt;no ...</content>\r\n<datalinqkeys />\r\n<objects>\r\n<object>\r\n<name>SELECT TOP LINE</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value>Good Morning!</value>\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>TXT BOTTOM LINE</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value>ABC7 NEWS</value>\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>SELECT MAIN TAB</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value />\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>SELECT MISC TAB</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value />\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>SELECT LIVE BUG</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value />\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>SELECT IMAGE BANNER</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value>Chips</value>\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>IMAGE</name>\r\n<properties>\r\n<property type="32" name="Material">\r\n<face>\r\n<mtype>2</mtype>\r\n<name>Face</name>\r\n<value>&lt;STLN:STREAMLINE/38191_default/ABC7 Mornings Franchise BANNER (Default)&gt;ABC7 Mornings Franchise BANNER (Default)</value>\r\n</face>\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>HEADS</name>\r\n<properties>\r\n<property type="32" name="Material">\r\n<face>\r\n<mtype>0</mtype>\r\n<name>Face</name>\r\n<value />\r\n</face>\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>DO NOT USE / FOR IMAGE</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value>5</value>\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>DO NOT USE / TXT TRAFFIC NUMBER</name>\r\n<properties>\r\n<property type="1" name="Text">\r\n<value />\r\n</property>\r\n</properties>\r\n</object>\r\n<object>\r\n<name>DO NOT USE / FOR SOCIAL</name>\r\n< ...
# =============
# titles_extend -- title_id
# [('title_id', <class 'int'>, None, 10, 10, 0, False), ('source', <class 'str'>, None, 255, 255, 0, True), ('reader', <class 'int'>, None, 10, 10, 0, False), ('read_rate', <class 'int'>, None, 10, 10, 0, False), ('year_composed', <class 'int'>, None, 10, 10, 0, False), ('medium', <class 'int'>, None, 10, 10, 0, False), ('status', <class 'int'>, None, 10, 10, 0, False), ('custom1', <class 'str'>, None, 255, 255, 0, True), ('custom2', <class 'str'>, None, 255, 255, 0, True), ('label_reference', <class 'str'>, None, 16, 16, 0, False), ('volume_number', <class 'str'>, None, 16, 16, 0, False), ('oeuvre', <class 'str'>, None, 255, 255, 0, True), ('act', <class 'str'>, None, 64, 64, 0, False), ('orchestra', <class 'str'>, None, 255, 255, 0, True), ('composer', <class 'str'>, None, 255, 255, 0, True), ('conductor', <class 'str'>, None, 255, 255, 0, True), ('period', <class 'str'>, None, 128, 128, 0, False), ('industry', <class 'int'>, None, 10, 10, 0, False), ('product', <class 'int'>, None, 10, 10, 0, False), ('language', <class 'str'>, None, 64, 64, 0, False), ('cut', <class 'str'>, None, 64, 64, 0, False), ('version', <class 'str'>, None, 3, 3, 0, False), ('voice', <class 'str'>, None, 255, 255, 0, True), ('creator', <class 'str'>, None, 255, 255, 0, True)]
# (29807933, ' ', 0, 0, 1900, 0, 0, ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 0, 0, '', ' ', 'p ', ' ', ' ')
# =============
# ItemsToBeIndexed -- Item_id
# [('Item_id', <class 'int'>, None, 10, 10, 0, False), ('Item_type', <class 'int'>, None, 10, 10, 0, False), ('ModifiedAt', <class 'datetime.datetime'>, None, 23, 23, 3, True), ('IsInRecycleBin', <class 'int'>, None, 5, 5, 0, False)]
# (29807933, 2, datetime.datetime(2021, 3, 9, 6, 43, 21, 920000), 0)
# =============
# titles_in_class -- title_id
# [('class_id', <class 'int'>, None, 10, 10, 0, False), ('title_id', <class 'int'>, None, 10, 10, 0, False), ('is_primary_class', <class 'int'>, None, 10, 10, 0, False), ('order_in_class', <class 'int'>, None, 10, 10, 0, True)]
# (33596, 29807933, 1, None)
# =============
# objects_in_titles -- Object_id
# [('Object_id', <class 'int'>, None, 10, 10, 0, False), ('Object_type', <class 'int'>, None, 10, 10, 0, False), ('Title_id', <class 'int'>, None, 10, 10, 0, False), ('Rank', <class 'int'>, None, 10, 10, 0, False), ('Offset', <class 'int'>, None, 10, 10, 0, False)]
# (29807933, 2, 29807928, 2, -1)
# (29807933, 2, 29813840, 2, -1)
# (29807933, 2, 29813841, 2, -1)
# =============
# titles_references -- title_id
# [('title_id', <class 'int'>, None, 10, 10, 0, False), ('reference_id', <class 'int'>, None, 10, 10, 0, False), ('reference_text', <class 'str'>, None, 255, 255, 0, False)]
# (29807933, 1, 'KGO3719016')
# =============
# titles_mix -- title_id
# [('title_id', <class 'int'>, None, 10, 10, 0, False), ('begin_offset', <class 'int'>, None, 10, 10, 0, False), ('end_offset', <class 'int'>, None, 10, 10, 0, False), ('intro1', <class 'int'>, None, 10, 10, 0, False), ('intro2', <class 'int'>, None, 10, 10, 0, False), ('outro', <class 'int'>, None, 10, 10, 0, False), ('fade_in', <class 'int'>, None, 10, 10, 0, False), ('fade_out', <class 'int'>, None, 10, 10, 0, False), ('crossfade', <class 'int'>, None, 10, 10, 0, False), ('is_endless_loop', <class 'int'>, None, 10, 10, 0, False)]
# (29807933, 0, 0, 0, 0, 0, 0, 0, 0, 0)
# =============
# CreatedModifiedItems -- Item_id
# [('Item_id', <class 'int'>, None, 10, 10, 0, False), ('Item_type', <class 'int'>, None, 10, 10, 0, False), ('CreatedBy', <class 'int'>, None, 10, 10, 0, True), ('ModifiedBy', <class 'int'>, None, 10, 10, 0, True), ('CreatedAt', <class 'datetime.datetime'>, None, 23, 23, 3, True), ('ModifiedAt', <class 'datetime.datetime'>, None, 23, 23, 3, True), ('CreatedByName', <class 'str'>, None, 64, 64, 0, True), ('ModifiedByName', <class 'str'>, None, 64, 64, 0, True), ('IsInRecycleBin', <class 'int'>, None, 5, 5, 0, False)]
# (29807933, 2, 1915, 1915, datetime.datetime(2021, 3, 8, 19, 51, 6, 787000), datetime.datetime(2021, 3, 8, 19, 51, 8, 47000), 'KGO DaletService', 'KGO DaletService', 0)
# =============
# Title_Files -- Title_id
# [('Title_id', <class 'int'>, None, 10, 10, 0, False), ('Soundfile_id', <class 'int'>, None, 10, 10, 0, False)]
# (29807933, 10030152)
# (29807933, 10030153)
# (29807933, 10030154)
# =============
# ObjectStatus -- ObjectId
# [('ObjectId', <class 'int'>, None, 10, 10, 0, False), ('ObjectType', <class 'int'>, None, 10, 10, 0, False), ('Status_id', <class 'int'>, None, 10, 10, 0, False)]
# (29807933, 82, 1)
# =============
# titles -- title_id
# [('title_id', <class 'int'>, None, 10, 10, 0, False), ('title_type_id', <class 'int'>, None, 10, 10, 0, False), ('title_interface_id', <class 'int'>, None, 10, 10, 0, False), ('user_id', <class 'int'>, None, 10, 10, 0, False), ('title', <class 'str'>, None, 255, 255, 0, False), ('interpret', <class 'str'>, None, 4000, 4000, 0, False), ('author', <class 'str'>, None, 255, 255, 0, False), ('client', <class 'str'>, None, 255, 255, 0, False), ('duration', <class 'int'>, None, 10, 10, 0, False), ('is_online', <class 'int'>, None, 10, 10, 0, False), ('is_recorded', <class 'int'>, None, 10, 10, 0, False), ('record_date', <class 'datetime.datetime'>, None, 23, 23, 3, False), ('start_date', <class 'datetime.datetime'>, None, 23, 23, 3, False), ('end_date', <class 'datetime.datetime'>, None, 23, 23, 3, False), ('kill_date', <class 'datetime.datetime'>, None, 23, 23, 3, False), ('audio_duration', <class 'int'>, None, 10, 10, 0, False), ('use_manual_duration', <class 'int'>, None, 10, 10, 0, False), ('soundfile_id', <class 'int'>, None, 10, 10, 0, False), ('year', <class 'int'>, None, 10, 10, 0, False), ('keywords', <class 'str'>, None, 4000, 4000, 0, False), ('site_origin', <class 'int'>, None, 10, 10, 0, False), ('no_overwrite', <class 'int'>, None, 10, 10, 0, False), ('is_rotational_cart', <class 'int'>, None, 10, 10, 0, False), ('replacement', <class 'str'>, None, 16, 16, 0, False), ('last_words', <class 'str'>, None, 255, 255, 0, False), ('is_opener', <class 'int'>, None, 10, 10, 0, True), ('weight', <class 'int'>, None, 5, 5, 0, True), ('beats_pm', <class 'int'>, None, 10, 10, 0, True), ('master_record', <class 'int'>, None, 10, 10, 0, True), ('compagny_id', <class 'int'>, None, 10, 10, 0, True), ('compagny_disp_name', <class 'str'>, None, 255, 255, 0, True), ('album_disp_name', <class 'str'>, None, 255, 255, 0, True), ('package_id', <class 'int'>, None, 10, 10, 0, True), ('album_id', <class 'int'>, None, 10, 10, 0, True), ('song_id', <class 'int'>, None, 10, 10, 0, True), ('day_part_rest_id', <class 'int'>, None, 10, 10, 0, True), ('keep_date', <class 'datetime.datetime'>, None, 23, 23, 3, False)]
# (29807933, 1052, 0, 0, 'L3 LOWER 3RD:Good Morning! | ABC7 NEWS |  |  |  | Chips | ABC7 Mornings Franchise BANNER (Default) | <none> | 5 ...', ' ', 'KGO DaletService', '', 0, 1, 0, datetime.datetime(2021, 3, 1, 16, 12, 27, 697000), datetime.datetime(2021, 3, 8, 19, 51, 6, 693000), datetime.datetime(2021, 3, 15, 19, 51, 6, 693000), datetime.datetime(2021, 3, 22, 19, 51, 6, 693000), 0, 0, 10030154, 2021, ' ', 0, 0, 0, ' ', ' ', 0, 100, -1, None, None, ' ', ' ', None, None, None, None, datetime.datetime(2021, 3, 7, 19, 51, 6, 693000))
# =============
# StatusLog -- ObjectId
# [('Order1', <class 'decimal.Decimal'>, None, 18, 18, 0, False), ('ObjectId', <class 'int'>, None, 10, 10, 0, False), ('ObjectType', <class 'int'>, None, 10, 10, 0, False), ('To_status', <class 'int'>, None, 10, 10, 0, False), ('Log_date', <class 'datetime.datetime'>, None, 23, 23, 3, True), ('Commentt', <class 'str'>, None, 255, 255, 0, True), ('UserLastName', <class 'str'>, None, 32, 32, 0, False), ('UserFirstName', <class 'str'>, None, 32, 32, 0, False)]
# (Decimal('10995727'), 29807933, 82, 1, datetime.datetime(2021, 3, 8, 19, 51, 6, 680000), 'Copied with original title status', 'KGO', 'DaletService')
# =============

# %%
#select  count(*)
#from playoutItemsStatus, clocks, MosDevices, titles 
#where content like '%onairstatus%' and STAT.ClockId = clocks.clock_id and clocks.clock_id = titles.title_id
#order by Rundown_date_time desc ;
query = """
SELECT *
FROM playoutItemsStatus
"""
cursor.execute(query)
results = cursor.fetchall()
for x in results:
    print(x)
# Out:
# (29610532, '29610532:1000055487', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">rundown accepted</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">rundown accepted</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">rundown accepted</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">rundown accepted</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">rundown accepted</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487', 'ShowTimeTrackingProgramInfo', 'ShowTimeTracking', '<ShowTimeTrackingProgramInfo actualAiredStartTime.td="2021-02-25T17:59:04.996" onairStatus.l="0" startTrackWithBeginTime.l="0" trackUserId.l="-1" triggerStatus.l="1"/>')
# (29610532, '29610532:1000055487:815351', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021-02-25T17:59:04.996" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055487:815351:S0:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S0:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S1:2', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S1:2', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S2:3', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S2:3', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S3:4', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S3:4', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S4:5', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S4:5', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S5:6', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S5:6', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S6:7', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815351:S6:7', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815352', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815352', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815352', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815352', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021-02-25T17:59:04.996" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055487:815353', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815353', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815353', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815353', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021-02-25T17:59:04.996" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055487:815354', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815354', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815354', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815354', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedDuration.tp="P52.352299S" airedStartTime.td="2021-02-25T17:59:04.996" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055487:815354:S0:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815354:S0:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815354:S1:4', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815354:S1:4', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815354:S1:4', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815355', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815355', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815355', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815355', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021-02-25T17:59:57.347" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055487:815355:S0:4', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815355:S0:4', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815355:S1:3', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815355:S1:3', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815355:S1:3', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815356', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815356', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815356', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055487:815356', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021-02-25T17:59:57.347" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055488:815359', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815359', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815359', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815359', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedDuration.tp="P3:35.565349S" airedStartTime.td="2021-02-25T17:59:57.347" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055488:815359:S0:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815359:S0:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815359:S1:6', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815359:S1:6', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815359:S2:5', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815359:S2:5', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815360', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedDuration.tp="P19.069050S" airedStartTime.td="2021-02-25T18:03:32.911" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055488:815371', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371:S0:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371:S0:1', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371:S0:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371:S1:6', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371:S1:6', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371:S2:7', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371:S2:7', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371:S3:8', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371:S3:8', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371:S4:9', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815371:S4:9', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815375:S0:4', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815375:S0:4', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815375:S1:5', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815375:S1:5', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815375:S2:6', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815375:S2:6', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815480', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedDuration.tp="P0.650650S" airedStartTime.td="2021-02-25T18:03:51.986" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055488:815481', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021-02-25T18:03:52.642" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055488:815482', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815482', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815482', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815482', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedDuration.tp="P0.700700S" airedStartTime.td="2021-02-25T18:03:52.642" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055488:815482:S0:4', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815482:S0:4', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedDuration.tp="P0.617283S" airedStartTime.td="2021-02-25T18:03:53.341" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055488:815483:S0:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483:S0:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483:S1:11', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483:S1:11', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483:S2:2', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="0"><statusDescription t="ws">Clearing story&apos;s playout status due to update</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483:S2:6', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483:S2:6', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483:S3:2', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483:S3:2', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815483:S3:2', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815500', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815500', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815500', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815500:S0:2', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815500:S0:2', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815501', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815501', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815501', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815501:S0:2', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815501:S0:2', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815501:S1:4', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815501:S1:4', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504:S0:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504:S0:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504:S1:5', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504:S1:5', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504:S2:2', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="0"><statusDescription t="ws">Clearing story&apos;s playout status due to update</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504:S2:4', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504:S2:4', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504:S3:2', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504:S3:2', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815504:S3:2', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815505', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedDuration.tp="P0.950950S" airedStartTime.td="2021-02-25T18:03:53.966" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055488:815507', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815507', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815507', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815507:S0:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815507:S0:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815509', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815509', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815509', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815509:S0:2', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815509:S0:2', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815510', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815510', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815510', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815510:S0:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815510:S0:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815510:S1:3', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815510:S1:3', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815511', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815511', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815511', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815511:S0:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815511:S0:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815511:S1:4', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815511:S1:4', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815511:S2:5', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815511:S2:5', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815512', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815512', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815512', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815512:S0:3', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815512:S0:3', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815512:S1:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815512:S1:1', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815512:S1:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815513', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815513', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815513', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815513:S0:2', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815513:S0:2', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815513:S1:3', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815513:S1:3', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815513:S2:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815513:S2:1', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815513:S2:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S0:11', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S0:11', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S1:12', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S1:12', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S2:3', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S2:3', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S2:3', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S3:13', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S3:13', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S4:14', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S4:14', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S5:15', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S5:15', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S6:16', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S6:16', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S6:16', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S7:17', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815514:S7:17', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815518', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815518', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815518', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815518:S0:5', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815518:S0:5', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815519', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815519', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815519', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815519:S0:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815519:S0:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815519:S1:3', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815519:S1:3', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815520', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815520', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815520', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815520:S0:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815520:S0:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815520:S1:4', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815520:S1:4', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815520:S2:5', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815520:S2:5', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932', 'GatewayItemInfo', '14', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932', 'GatewayItemInfo', '15', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S0:1', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S0:1', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S1:9', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S1:9', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S2:10', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S2:10', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S3:6', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S3:6', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S3:6', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S4:3', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S4:3', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S4:3', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S5:4', 'GatewayItemInfo', '20', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S5:4', 'GatewayItemInfo', '22', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:815932:S5:4', 'GatewayItemInfo', '24', '<GatewayItemInfo status.l="3"><statusDescription t="ws">got no reply for rundown sent</statusDescription></GatewayItemInfo>')
# (29610532, '29610532:1000055488:816654', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedDuration.tp="P14.581233S" airedStartTime.td="2021-02-25T18:03:54.909" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055488:817261', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021-02-25T17:59:57.347" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055488:817262', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021-02-25T17:59:57.347" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055488:817264', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021-02-25T17:59:57.347" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29610532, '29610532:1000055488:817265', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021-02-25T17:59:57.347" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# ...
# (29811556, '29811556:1000055935:825543', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055935:825544', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825547', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825548', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825549', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825550', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825551', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825552', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825553', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825554', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825555', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825560', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825561', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825562', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825563', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055936:825564', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825567', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825568', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825570', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825571', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825572', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825573', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825574', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825575', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825576', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825577', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825578', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825579', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825581', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825582', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825583', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825584', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825585', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825586', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825587', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825588', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825589', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825590', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825592', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825593', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825594', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825595', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825596', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825597', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825598', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825599', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825600', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825601', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825603', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055937:825604', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825608', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825609', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825610', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825611', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825612', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825613', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825614', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825615', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825616', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825617', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825618', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825619', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825620', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825621', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055938:825622', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055939:825625', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055939:825627', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055939:825628', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055939:825629', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055939:825630', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055939:825632', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055939:825633', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055939:825634', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055939:825635', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055940:825638', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055940:825639', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055940:825640', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055940:825641', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055940:825642', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055940:825643', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055940:825644', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055940:825645', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055940:825646', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055940:825647', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (29811556, '29811556:1000055940:825648', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
