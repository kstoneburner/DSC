# %%
#//*** This thread helped with the connection
#//***https://stackoverflow.com/questions/37692780/error-28000-login-failed-for-user-domain-user-with-pyodbc

#//**** Update the ODBC Driver
#//**** https://docs.microsoft.com/en-us/sql/connect/odbc/download-odbc-driver-for-sql-server?view=sql-server-ver15
import pyodbc
import datetime
import json
from datetime import date, timedelta
import pandas as pd
print(pyodbc.drivers())

#//*** Use the whole window in the IPYNB editor
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#//*** Maximize columns and rows displayed by pandas
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)

# Some other example server values are
# server = 'localhost\sqlexpress' # for a named instance
# server = 'myserver,port' # to specify an alternate port
server = 'tcp:OM-CASF-DB01' 
server = 'OM-CASF-DLSQL' 
# server = '10.218.97.2'
database = 'DaletDB' 

with open('./ignore_folder/misc.json') as f:
    data = json.loads(f.read())

username = data["user"] 
password = data["password"]
del data
#cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cnxn = pyodbc.connect('Trusted_Connection=yes;DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()
# Out:
# ['SQL Server', 'ODBC Driver 17 for SQL Server', 'SQL Server Native Client 11.0']

# %% [markdown]
# ### SQL Query for MOS Active rundowns ###

# %%
startDate = date.today() + timedelta(days=-30)
endDate = date.today() + timedelta(days=30)
query = f"""
select DISTINCT Clocks.clock_date AS Rundown_date_time, titles.title Rundown_Name, MosDevices.Name, STAT.Content Status, Content
from playoutItemsStatus STAT, clocks, MosDevices, titles 
where
    DeviceType='GatewayItemInfo'
and STAT.ClockId = clocks.clock_id 
and clocks.clock_id = titles.title_id
and Clocks.clock_date > '{startDate}'
and Clocks.clock_date <= '{endDate}'
order by Rundown_date_time;
"""
cursor.execute(query)
tables = cursor.fetchall()
tdict={ "ALEX TEST RUNDOWN" : ""}
for row in tables:
    if '<GatewayItemInfo status.l="10">' in row[3]:
        if row[1] not in tdict.keys():
            tdict[row[1]] = ""
            print(datetime.datetime.date(row[0]),row[1])
# Out:
# 2021-11-27 Dalet OD XPression
# 2021-11-29 Prepak
# 2021-11-30 Promo
# 2021-11-30 11PM WEEKDAY

# %%
query = """
select TOP 10 *
from playoutItemsStatus 

"""
cursor.execute(query)
tables = cursor.fetchall()

for row in tables:
    print(row)



    
query = """
SELECT *
FROM INFORMATION_SCHEMA.COLUMNS
WHERE TABLE_NAME = 'playoutItemsStatus '
"""
cursor.execute(query)
tables = cursor.fetchall()

for row in tables:
    print(row[2],row[3])

query = """
select *
from playoutItemsStatus 
WHERE DeviceType LIKE 'GatewayItemInfo' and DeviceId = '25'
"""
cursor.execute(query)
tables = cursor.fetchall()

for row in tables:
    print(row)
# Out:
# (29934948, '29934948:1000057151', 'ShowTimeTrackingProgramInfo', 'ShowTimeTracking', '<ShowTimeTrackingProgramInfo actualAiredStartTime.td="2021-03-24T18:31:11.273" onairStatus.l="0" startTrackWithBeginTime.l="0" trackUserId.l="-1" triggerStatus.l="1"/>')
# (29934948, '29934948:1000057151:855627', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021-03-24T18:31:11.273" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29934948, '29934948:1000057152:855631', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021-03-24T18:31:11.273" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29934948, '29934948:1000057152:855632', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedDuration.tp="P0.884216S" airedStartTime.td="2021-03-24T18:31:11.273" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>')
# (29934948, '29934948:1000057152:855633', 'ShowTimeTrackingItemInfo', 'ShowTimeTracking', '<ShowTimeTrackingItemInfo airedStartTime.td="2021
 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="0"><statusDescription t="ws">Removed from device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089410:2018787', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="0"><statusDescription t="ws">Removed from device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089410:2018792', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="0"><statusDescription t="ws">Removed from device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089410:2018793', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="0"><statusDescription t="ws">Removed from device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089410:2018794', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089410:2018801', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="0"><statusDescription t="ws">Removed from device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089410:2018802', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="0"><statusDescription t="ws">Removed from device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089411:2007319', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089411:2007320', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089411:2007321', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089411:2007322', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33451435, '33451435:1000085327:1871094', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089406', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">rundown accepted</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089406:2007261', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089406:2007262', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089406:2007263', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089406:2007264', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089408:2018759', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089408:2018760', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089408:2018762', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089408:2018763', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089408:2018765', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089408:2018767', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089408:2018769', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089408:2018771', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089408:2018773', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089408:2018774', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089408:2018795', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="0"><statusDescription t="ws">Removed from device</statusDescription></GatewayItemInfo>')
# (33949540, '33949540:1000089408:2018796', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33952232, '33952232:1000089469', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">rundown accepted</statusDescription></GatewayItemInfo>')
# (33952232, '33952232:1000089469:2008701', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33952232, '33952232:1000089469:2008702', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33952232, '33952232:1000089469:2008703', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33952232, '33952232:1000089469:2008704', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')
# (33952232, '33952232:1000089469:2008714', 'GatewayItemInfo', '25', '<GatewayItemInfo status.l="10"><statusDescription t="ws">Acknowledged by device</statusDescription></GatewayItemInfo>')

# %%
query = """
SELECT *
FROM INFORMATION_SCHEMA.COLUMNS
WHERE TABLE_NAME = 'MosDevices'
"""
cursor.execute(query)
tables = cursor.fetchall()
header = ""
print("======================")
print(tables[0][2])
print("======================")
for row in tables:
    header += row[3] + ", "
    
print(header[:-2])
query = """
select *
from MosDevices 
"""
cursor.execute(query)
tables = cursor.fetchall()

for row in tables:
    print(row[0],row[1],row[2],row[3],row[4],row[5],row[6])
# Out:
# ======================
# MosDevices
# ======================
# Id, Type, Name, Description, HostId, IsIncremental, PreloadByBroadcastServer, Icon, Params
# 19 22 kgo.pcr2.ovd.mos Ross OD PCR 2 203 1 0
# 20 22 kgo.pcr3.ovd.mos Ross OD PCR 3 204 1 0
# 23 22 kgo.pcr2.ovdbu.mos Ross Overdrive PCR2 Backup 205 1 0
# 25 25 webmos.appdev.kgo.abc.mos WEBMOS Prompter 210 1 0
# 22 42 xpn.kgo.abc.mos Ross Xpression 201 1 0
# 14 25 bdl.promptera.kgo.abc.mos Prompter 1 211 1 0
# 24 22 kgo.pcr3.ovdbu.mos Ross Overdrive PCR3 Backup 206 1 0
# 15 25 bdl.prompterb.kgo.abc.mos Prompter 2 212 1 0

# %%
query = """
SELECT *
FROM INFORMATION_SCHEMA.COLUMNS
WHERE TABLE_NAME = 'playoutItemsStatus STAT'
"""
cursor.execute(query)
tables = cursor.fetchall()
header = ""
print("======================")
print(tables)
print("======================")
for row in tables:
    header += row[3] + ", "
    
print(header[:-2])
query = """
select *
from playoutItemsStatus STAT 
"""
cursor.execute(query)
tables = cursor.fetchall()

#//*** Prints lots of Data. Uncomment if needed
#for row in tables:
#    print(row)
# Out:
# ======================
# []
# ======================

# %%
query = """
SELECT
  *
FROM
  INFORMATION_SCHEMA.TABLES
"""

cursor.execute(query)
tables = cursor.fetchall()

# %%
master_tables = []
for table in tables:
    master_tables.append(table[2])
master_tables.sort()

# %%
for table in master_tables:
    print(table)
# Out:
# AD_DomainsPerUser
# AD_Groups
# AFF_FROM_FORMAT
# AFF_FROM_STORAGE
# AFF_TO_FORMAT
# AFF_TO_STORAGE
# AccessRights
# AccessibleFormatForUser
# ActivationPlacements
# ActivationRules
# AdditionalLocatorsFromEDLToCopy
# AdsGroupsToSync
# Affinities
# AliasGroups
# AliasInAliasGroups
# AliasesPools
# AliasesPoolsData
# Allocation_Policies
# ApplicationServerTypes
# ApplicationServers
# Attributes_Order
# AuditTrailActionsConfiguration
# AutoSaveData
# BPMKeyPerformanceIndicators
# BPMTaskListBoardAssociations
# BPMTaskListBoardViews
# BPMTaskListViews
# BPMTaskTypes
# BPMTasksGroups
# BPMTasksUsers
# BlockTemplates
# BrokerJobs
# BrowserViewRules
# BrowserViews
# CGTemplates
# CRConfiguration
# CacheModule
# CacheSetting
# Callers
# Capabilities
# CategoriesCodes
# CategoryNotifyRules
# ChatRoomParticipateGroups
# ChatRoomParticipateUsers
# ChatRooms
# ClassCreationForms
# ClassDataDictDateTime
# ClassDataDictGlossary
# ClassDataDictInteger
# ClassDataDictObject
# ClassDataDictPeriod
# ClassDataDictString
# ClassDataDictText
# ClassDataDictTimeCode
# ClassDataDictTimeCodeDate
# ClassDataDictTitle
# ClassLastUsedForms
# ClipsInputData
# CommentDefaultProperties
# ComplianceWarnings
# ContactFolders
# Contacts
# ContactsInFolders
# ContainerPolicyAssoc
# ContextMapViews
# ContextPlugins
# ConversionRules
# Conversion_Types
# CreateAndModifyLocators
# CreatedModifiedGlossaryValues
# CreatedModifiedItems
# CurrentlyOpenedTitles
# CustomerOptions
# DRCAMFieldsParameters
# DRCCategoryParameters
# DRCParameters
# DRCStatusParameters
# DaletFavoriteItems
# DaletMessageQueues
# DaletSupportedMediaConvertion
# DaletToSolRField
# DataFieldTypes
# DataFields
# DatabaseUpgradeLabels
# DateTimeFormats
# DefaultDisplayedFields
# DefaultEventsMapping
# DefaultPoliciesAssoc
# DetailedFastFetchItems
# DeviceControllerEvents
# DeviceControllerRegEvents
# DeviceControllerTypes
# DeviceControllers
# DialogSpecFields
# DialogSpecRules
# DialogSpecs
# DisplayedFields
# DnDAllocationPolicy
# Domains
# DrcTextParameters
# EnumTypes
# ErrorWires
# FastFetchAccessRights
# FastFetchItems
# FastPurgeTitles
# FastPurgeWires
# Features
# Fields
# FileNameConventionScheme
# FilterFolders
# FilterQueryAttr
# FolderLastUsedViews
# FoldersInMiniFilters
# FoldersInTabs
# FoldersInTabsCount
# FormatIdToSCMov
# FormatLocation
# FormatSet
# FormatTrackMappingDefault
# FormatWrappers
# FormatsMediaPlayers
# GalaxyCommandContexts
# GalaxyCommandSets
# GalaxyCommandSetsBitmaps
# GalaxyCommands
# GalaxyDefaultKeyboardShortcuts
# GalaxyDisabledCommands
# GalaxyGlobalWorkspacesToGroups
# GalaxyKeyboardShortcuts
# GalaxyScripts
# GalaxySearchHistory
# GalaxySearchProfiles
# GalaxySharedHomescreens
# GalaxyToolbarBitmaps
# GalaxyWorkspaces
# GenealogyRenderedSegments
# GenealogySegmentAMfields
# GenericFolders
# GetOrCreateItemCodeSession
# GlossaryAssociatedFieldsHistory
# GlossaryEquivalence
# GlossaryType
# GlossaryTypeAssociatedFields
# GlossaryTypeFields
# GlossaryValue
# GlossaryValueParentChild
# GlossaryValue_Language
# GlossaryValuesToUpdate
# GroupsPluginRights
# HeavyTasksRequired
# HostAlias
# HostGroups
# HostResourceAssociation
# HostWorkspaces
# Hosts
# HostsInHostGroups
# IcingaAlerts
# ImageBaseFormats
# IngestResourceGroups
# IngestResourcesInGroups
# IntegersTo5000
# ItemsToBeIndexed
# ItemsToRemove
# JettySessions
# Languages
# LocalTimeZoneInformation
# LocatorDataDictAssociatedFields
# LocatorDataDictDateTime
# LocatorDataDictGlossary
# LocatorDataDictInteger
# LocatorDataDictObject
# LocatorDataDictPeriod
# LocatorDataDictString
# LocatorDataDictText
# LocatorDataDictTimeCode
# LocatorDataDictTimeCodeDate
# LocatorDataDictTitle
# LocatorFamily
# LocatorThumbnails
# LocatorTypeFields
# LocatorTypes
# LocatorViewRules
# LocatorViews
# LocatorViewsAssoc
# LocatorViewsAssocType
# Locators
# LocatorsFromEDLToCopy
# LockedObjects
# LoggedUsers
# LongTexts
# MEDIA_EXPORT
# MXFDevicesFormats
# MacroTypes
# MapOldClockIdToNewTitleIdHelper
# McsTransitions
# MediaContainerTypes
# MediaContainers
# MediaFormats
# MediaFormatsData
# MediaJobs
# MediaPackTemplateItems
# MediaPackTemplates
# MediaPresets
# MediaProcessStatus
# MediaProfiles
# MediaPurgeRequests
# MediaResource_types
# MediaTemplates
# Media_Purge_Rules
# MigrationProtocols
# Migration_Policies
# MosDeviceCategories
# MosDeviceTypes
# MosDevices
# MutexLocatorTypeGroups
# NLEEditors
# NLEExportFormats
# NLESequencePresets
# NLPExtractionInfo
# NewsWires
# NotifierJMSSettings
# ObjectAssignedStatus
# ObjectStatus
# ObjectTypeAvailFields
# ObjectsInAppServers
# OneCutPreferences
# OneCutPreferencesBkp
# ParsedMediaInfo
# PendingEventsJobList
# PendingEventsSubscriberList
# PlaceHolderRules
# PlanningAreas
# PlanningEventTitles
# PlayoutItemsStatus
# Plugins
# PrintReport
# PurgeLog
# QuotaRuleFormat
# QuotaRuleStorage
# QuotaRules
# RDViewsFieldsStrings
# RULES_ACTIVATIONS
# RcDeviceControllers
# RcEventsMapping
# ReadWires
# RecycleBin
# RecycledObjectsToRemove
# RegisteredSocialApps
# RemovedRecycledObjects
# RemovedRecycledObjectsEx
# RenderProfiles
# RenderProfilesTranisitions
# RenderTranisitionPresets
# ResourceConnections
# ResourceContexts
# RosterGroups
# RosterItems
# RosterItemsInGroups
# RsuAppServers
# RundownViews
# RundownViewsAssociations
# RundownViewsFields
# SOMUpdateHistory
# ScheduledSoMePosts
# SiblingVideoPairs
# SiteObjectTypeDisplayedFields
# SocialMediaAccounts
# SocialNetworkTypes
# SolRCore
# SolRFieldTypes
# SolRIndexes
# SolRSiteConnectionParameters
# SolrIndexDeployment
# SolrSpecialWords
# Sound_Convert
# StatusChangeCategoryRules
# StatusLog
# StatusTN
# StatusTransition
# StatusTransitionAccessRights
# StorageFolders
# StorageUnitDomains
# Storageunit_aliases
# StoryContent
# StoryTemplateAMSection
# StoryTemplateCCConfiguration
# StoryTemplateCGConfiguration
# StoryTemplates
# StoryTransformationPolicy
# StoryViews
# StreamingServers
# StudioCGConfigPerStoryTemplate
# StudioChannels
# StudioDevices
# Studios
# SubtitleDiv
# SubtitleDivStyle
# SubtitleLocatorStyle
# SubtitleLocators
# SubtitleRegion
# SubtitleRegionStyle
# SubtitleStyle
# SubtitleStyleStyle
# SubtitleVideoRegions
# SubtitleVideoStyles
# SubtitlesTypes
# TNVersions
# TableSizesPattern
# Tabs
# TaskListViewRules
# TaskListViews
# Tech_Support
# TitleChangeNotifyRules
# TitleCreationForms
# TitleDataDictDateTime
# TitleDataDictGlossary
# TitleDataDictInteger
# TitleDataDictObject
# TitleDataDictPeriod
# TitleDataDictString
# TitleDataDictText
# TitleDataDictTimeCode
# TitleDataDictTimeCodeDate
# TitleDataDictTitle
# TitleDurationUpdates
# TitleLastUsedForms
# TitleType_to_MediaType
# Title_Files
# TitlesPendingForDelete
# Titles_ExFields
# TrackStackTemplates
# TransferSessions
# UILanguages
# UIMessages
# UsageRestrictaionLocators
# UserObjectDisplayedFields
# UserObjectTypeDisplayedFields
# UserOptions
# ValueOptions
# VersionConfiguraton
# Versions
# VideoCGs
# ViewAssociations
# WeakReferenceMediaInfo
# WebApplications
# WebFolders
# WebLinks
# WebLinksInFolders
# WebSpaceCommands
# WebSpaceDefaultKeyboardShortcuts
# WebSpaceDisabledCommands
# WebSpaceKeyboardShortcuts
# WebSpaceMacros
# WebViewsAssociations
# WebspaceCommandCategory
# WebspaceViews
# WireCategories
# WireFoldersNotify
# WireFormats
# WireFormatsAdditionalRoots
# WireImages
# WiresContributors
# WiresInFilterFolders
# WiresInFolders
# Workspaces
# access_rights_object_types
# admin_user_in_group
# airedStoriesArchiver_rules
# album
# am_layouts
# applicationservers_aliases
# archiveTickerMessages
# artist
# artist_band
# attribute_values
# attributes
# available_access_rights
# band
# block_item
# block_safewindow
# block_types
# blocks
# broadcast_clocks
# broadcast_items
# cClient
# cMediaJobs
# cReservations
# cblock
# cclock
# class_tree
# classes
# clocks
# clocks_references
# commands
# compagny
# config_int
# ctitles
# daletConversation
# ensemble
# ensemble_link
# ensemble_restrictions
# feed_types
# generics
# groups
# historical_rule
# id_factory
# industries
# industry_values
# items
# items_references
# keywords
# kick_rule
# mediaresources
# mediums
# mr_policy
# mr_rule
# object_access_rights
# objects_in_titles
# objects_references
# ofConParticipant
# ofConversation
# ofExtComponentConf
# ofGroup
# ofGroupProp
# ofGroupUser
# ofID
# ofMessageArchive
# ofMucAffiliation
# ofMucConversationLog
# ofMucMember
# ofMucRoom
# ofMucRoomProp
# ofMucService
# ofMucServiceProp
# ofOffline
# ofPresence
# ofPrivacyList
# ofPrivate
# ofProperty
# ofPubsubAffiliation
# ofPubsubDefaultConf
# ofPubsubItem
# ofPubsubNode
# ofPubsubNodeGroups
# ofPubsubNodeJIDs
# ofPubsubSubscription
# ofRRDs
# ofRemoteServerConf
# ofRoster
# ofRosterGroups
# ofSASLAuthorized
# ofSecurityAuditLog
# ofUser
# ofUserFlag
# ofUserProp
# ofVCard
# ofVersion
# opener_rule
# order_interval
# placement_restriction
# policy_rule
# products
# proportion_rule
# radio_attributes
# radio_ensembles
# radio_groups
# radio_recycle_weight
# radios
# radios_in_groups
# randomvalues_view
# recycle_weights
# reg_value_int
# reg_value_string
# reg_value_text
# reg_value_timestamp
# resourceReservations
# restricted_segue
# routerTypes
# routers
# schedule_patterns
# segues_rule
# selectionRelations
# separation_rule
# soundfile_units
# soundfiles
# spots
# sysdiagrams
# texts
# title_artist
# title_interfaces
# title_keyword
# title_types
# titles
# titles_attributes
# titles_comments
# titles_extend
# titles_in_class
# titles_mix
# titles_references
# titles_to_convert
# user_in_group
# user_reg_value_int
# user_reg_value_string
# user_reg_value_timestamp
# users
# voice_inserts

# %%
query = """
SELECT
*
FROM
RundownViews
"""
cursor.execute(query)
results = cursor.fetchall()
for x in results:
    print(x)
# Out:
# (136, '<RundownView id.l="136" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="45"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_Hold</displayName><name t="ws">ITEM_Hold</name><title t="lt"><UIString langId.l="1033"><str t="ws">Float</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="4"><description t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></description><displayName t="ws">TITLE_LockedBy</displayName><name t="ws">TITLE_LockedBy</name><title t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="180"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l= ...
# (128, '<RundownView id.l="128" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="45"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_Hold</displayName><name t="ws">ITEM_Hold</name><title t="lt"><UIString langId.l="1033"><str t="ws">Float</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="4"><description t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></description><displayName t="ws">TITLE_LockedBy</displayName><name t="ws">TITLE_LockedBy</name><title t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="180"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l= ...
# (130, '<RundownView id.l="130" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings itemHighlight.null="" nextItemHighlight.null="" userGroupsForDeviceTracking.ll=""/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="150"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Digital Producer</str></UIString></description><displayName t="ws">OTV Digital Producer</displayName><name t="ws">OTV Digital Producer</name><title t="lt"><UIString langId.l="1033"><str t="ws">Digital Producer</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="1"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" width.l="37"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="400"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">STORY</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">STORY</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="11" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="1"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="200"><field t="t"><FieldDef fieldObjectTypes.ll="8"><displayName t="ws">Digital Reporter</displayName><name t="ws">Digital Reporter</name><title t="lt"><UIString langId.l="1033"><str t="ws">Reporter</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOr ...
# (132, '<RundownView id.l="132" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields HideFrameRateInfo.b="false" ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="25"><field t="t"><FieldDef fieldObjectTypes.ll="4 128"><description t="lt"><UIString langId.l="1033"><str t="ws">Locked</str></UIString></description><displayName t="ws">ITEM_Locking</displayName><name t="ws">ITEM_Locking</name><title t="lt"><UIString langId.l="1033"><str t="ws">L</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="55"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="450"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" exclud ...
# (135, '<RundownView id.l="135" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields HideFrameRateInfo.b="false" ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="85"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_BackTime</displayName><name t="ws">ITEM_BackTime</name><timeFormat t="lt"><UIString langId.l="1033"><str t="ws"> &lt;LocaleTime&gt;</str></UIString></timeFormat></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws"></fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="55"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="150"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0"  ...
# (140, '<RundownView id.l="140" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields HideFrameRateInfo.b="false" ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="85"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_BackTime</displayName><name t="ws">ITEM_BackTime</name><timeFormat t="lt"><UIString langId.l="1033"><str t="ws"> &lt;LocaleTime&gt;</str></UIString></timeFormat></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws"></fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="55"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="150"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0"  ...
# (141, '<RundownView id.l="141" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields HideFrameRateInfo.b="false" ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="25"><field t="t"><FieldDef fieldObjectTypes.ll="4 128"><description t="lt"><UIString langId.l="1033"><str t="ws">Locked</str></UIString></description><displayName t="ws">ITEM_Locking</displayName><name t="ws">ITEM_Locking</name><title t="lt"><UIString langId.l="1033"><str t="ws">L</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="90"><field t="t"><FieldDef fieldObjectTypes.ll="4"><description t="lt"><UIString langId.l="1033"><str t="ws">Status</str></UIString></description><displayName t="ws">TITLE_FullStatus</displayName><name t="ws">TITLE_FullStatus</name><title t="lt"><UIString langId.l="1033"><str t="ws">Status</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="10" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="55"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b=" ...
# (122, '<RundownView id.l="122" viewType.l="2"><blankLineCommentFieldName t="ws"></blankLineCommentFieldName><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="200"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="100"><field t="t"><FieldDef fieldObjectTypes.ll="8"><displayName t="ws">OTV News-Digital Shared</displayName><name t="ws">OTV News-Digital Shared</name><title t="lt"><UIString langId.l="1033"><str t="ws">Usage</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="12253694" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="150"><field t="t"><FieldDef fieldObjectTypes.ll="8"><displayName t="ws">OTV Digital Section</displayName><name t="ws">OTV Digital Section</name><title t="lt"><UIString langId.l="1033"><str t="ws">Digital Section</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="12253694" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="70"><field t="t"><FieldDef fieldObjectTypes.ll="8"><displayName t="ws">OTV Digital Priority</displayName><name t="ws">OTV Digital Priority</name><title t="lt"><UIString langId.l="1033"><str t="ws">Priority</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="12253694" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="5" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="70"><field t="t"><FieldDef fieldObjectTypes.ll="8"><displayName t="ws">OTV Digital Producer</displayName><name t="ws">OTV Digital Producer</name><title t="lt"><UIString langId.l="1033"><str t="ws">Producer</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="12253694" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSi ...
# (123, '<RundownView id.l="123" viewType.l="2"><blankLineCommentFieldName t="ws"></blankLineCommentFieldName><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="60"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="250"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15390696" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="30"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Section</str></UIString></description><displayName t="ws">OTV Sections</displayName><name t="ws">OTV Sections</name><title t="lt"><UIString langId.l="1033"><str t="ws"></str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15390696" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="20"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Sort/priority within the section.</str></UIString></description><displayName t="ws">Desk Priority</displayName><name t="ws">Desk Priority</name><title t="lt"><UIString langId.l="1033"><str t="ws"></str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15390696" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="100"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Event Time</str></UIString></description><displayName t="ws">OTV Shoot Time</displayName><name t="ws">OTV Shoot Time</name><title t="lt"><UIString langId.l="1033"><str t="ws">Event Time</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15390696" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="8" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="5" rtl.l="0" showGlossaryPath.b="false"  ...
# (133, '<RundownView id.l="133" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="45"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="180"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="70"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Segment</str></UIString></description><displayName t="ws">OTV Segment</displayName><name t="ws">OTV Segment</name><title t="lt"><UIString langId.l="1033"><str t="ws">Segment</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="100"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedStartTime</displayName><name t="ws">ITEM_ComputedStartTime</name><timeFormat t="lt"><UIString langId.l="1033"><str t="ws"> h:mm:ss tt</str></UIString></timeFormat></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="12" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap. ...
# (139, '<RundownView id.l="139" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="45"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_Hold</displayName><name t="ws">ITEM_Hold</name><title t="lt"><UIString langId.l="1033"><str t="ws">Float</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="4"><description t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></description><displayName t="ws">TITLE_LockedBy</displayName><name t="ws">TITLE_LockedBy</name><title t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="180"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l= ...
# ...
# (117, '<RundownView id.l="117" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="12" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws"></fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="120"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="1" bkColor.l="15917507" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="12" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws"></fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="15"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Segment</str></UIString></description><displayName t="ws">OTV Segment</displayName><name t="ws">OTV Segment</name><title t="lt"><UIString langId.l="1033"><str t="ws">Segment</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="11" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws"></fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="15"><field t="t"><FieldDef fieldObjectTypes.ll="8"><description t="lt"><UIString langId.l="1033"><str t="ws">Anchor</str></UIString></description><displayName t="ws">OTV Anchor</displayName><name t="ws">OTV Anchor</name><title t="lt"><UIString langId.l="1033"><str t="ws">Anchor</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="0" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="11" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordW ...
# (137, '<RundownView id.l="137" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="60"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_Hold</displayName><name t="ws">ITEM_Hold</name><title t="lt"><UIString langId.l="1033"><str t="ws">Float</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="4"><description t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></description><displayName t="ws">TITLE_LockedBy</displayName><name t="ws">TITLE_LockedBy</name><title t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="180"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l= ...
# (143, '<RundownView id.l="143" viewType.l="1"><blankLineCommentFieldName t="ws">ITEM_Icon</blankLineCommentFieldName><blockTooltipFields t="t"><DisplayedFields ShowResultsAsGrid.b="false"><DisplayedField t="lt"><DisplayedField glossaryLanguageId.l="99" position.l="0" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name></FieldDef></field></DisplayedField><DisplayedField glossaryLanguageId.l="99" position.l="1" textAttributes.null="" width.l="10"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_ComputedDuration</displayName><name t="ws">ITEM_ComputedDuration</name></FieldDef></field></DisplayedField></DisplayedField></DisplayedFields></blockTooltipFields><deviceTrackSettings t="t"><DeviceTrackingSettings/></deviceTrackSettings><displayedFields t="t"><DisplayedFields ShowResultsAsGrid.b="false" secondFragmentInTimeDisplay.l="0"><DisplayedField t="lt"><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="0" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="45"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><displayName t="ws">ITEM_Icon</displayName><name t="ws">ITEM_Icon</name></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="true" glossaryLanguageId.l="99" position.l="1" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="1 2"><displayName t="ws">ITEM_Hold</displayName><name t="ws">ITEM_Hold</name><title t="lt"><UIString langId.l="1033"><str t="ws">Float</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="2" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="40"><field t="t"><FieldDef fieldObjectTypes.ll="4"><description t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></description><displayName t="ws">TITLE_LockedBy</displayName><name t="ws">TITLE_LockedBy</name><title t="lt"><UIString langId.l="1033"><str t="ws">Lock</str></UIString></title></FieldDef></field></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="3" rtl.l="0" showGlossaryPath.b="false" visualizationAsX.b="false" width.l="50"><field t="t"><FieldDef fieldObjectTypes.ll="1"><datafield_name t="ws"></datafield_name><displayName t="ws">ITEM_PageNumber</displayName><name t="ws">ITEM_PageNumber</name><title t="lt"><UIString langId.l="1033"><str t="ws">Page</str></UIString></title></FieldDef></field><textAttributes t="t"><TextAttributes alignment.l="2" bkColor.l="15917507" bold.l="1" displayDynamicAMHeader.b="false" fgColor.l="0" fontSize.l="14" inheritFromOriginalStory.b="false" italic.l="0" underline.l="0" wordWrap.l="0"><delimiter t="ws">,</delimiter><fontFace t="ws">Arial Narrow</fontFace></TextAttributes></textAttributes></DisplayedField><DisplayedField allowGlossaryCandidateValues.b="false" excludeFromPrint.b="false" glossaryLanguageId.l="99" position.l="4" rtl.l="0" showGlossaryPath.b="false" textAttributes.null="" visualizationAsX.b="false" width.l="180"><field t="t"><FieldDef fieldObjectTypes.ll="1 2 4"><description t="lt"><UIString langId.l="1033"><str t="ws">Slug</str></UIString></description><displayName t="ws">ITEM_Name</displayName><name t="ws">ITEM_Name</name><title t="lt"><UIString langId.l= ...

# %%
query = """
SELECT
*
FROM
StoryContent
WHERE
TitleId='29807928'
"""
cursor.execute(query)
results = cursor.fetchall()
for x in results:
    for y in x:
        print(y)

# %%
 
query = """
SELECT *
FROM RundownViewsAssociations 
"""
cursor.execute(query)
results = cursor.fetchall()

# %%
print ([x[0] for x in cursor.description])
for row in results:
    print(row)
# Out:
# ['ObjectId', 'ObjectType', 'RundownViewId', 'Priority', 'DefaultPriority']
# ('438', 'GROUP-Program', 132, 3, None)
# ('9', 'GROUP-Program', 132, 3, None)
# ('438', 'GROUP-Pattern', 137, 1, None)
# ('9', 'GROUP-Program', 136, 4, None)
# ('438', 'GROUP-Program', 143, 2, None)
# ('438', 'GROUP-Program', 135, 5, None)
# ('9', 'GROUP-Pattern', 141, 0, None)
# ('9', 'GROUP-Pattern', 138, 2, None)
# ('438', 'GROUP-Pattern', 141, 3, None)
# ('438', 'GROUP-Pattern', 143, 2, None)
# ('9', 'GROUP-Program', 141, 8, None)
# ('438', 'GROUP-Program', 141, 6, None)
# ('438', 'GROUP-Planning', 123, 0, None)
# ('438', 'GROUP-Program', 133, 5, None)
# ('9', 'GROUP-Program', 133, 4, None)
# ('166', 'GROUP-Program', 139, 0, None)
# ('9', 'GROUP-Program', 139, 6, None)
# ('166', 'GROUP-Program', 138, 1, None)
# ('166', 'GROUP-Pattern', 138, 0, None)
# ('438', 'GROUP-Program', 127, 0, None)
# ('9', 'GROUP-Program', 127, 0, None)
# ('9', 'GROUP-Program', 140, 7, None)
# ('9', 'GROUP-Planning', 123, 0, None)
# ('9', 'GROUP-Program', 138, 5, None)
# ('438', 'GROUP-Pattern', 125, 0, None)
# ('9', 'GROUP-Pattern', 125, 1, None)
# ('438', 'GROUP-Program', 128, 1, None)
# ('9', 'GROUP-Program', 144, 9, None)
# ('438', 'GROUP-Program', 144, 7, None)
# ('9', 'GROUP-Program', 128, 2, None)

# %%
query = """
SELECT * 
FROM INFORMATION_SCHEMA.COLUMNS 
"""
cursor.execute(query)
results = cursor.fetchall()

#for row in results:
#    print(row[3])

# %%
titleid_dict = {}
#//*** Script ID 29807928
#//*** Rundown ID 29620400
for row in results:
    if  row[7] == 'int':
        #print(row[2],row[3])
        loop_query = f"""
        SELECT count(*)
        FROM {row[2]}
        WHERE {row[3]}='29620400' 
        """
        cursor.execute(loop_query)
        loop_result = cursor.fetchall()[0][0]
        if loop_result > 0:
            print(row[2],row[3],loop_result)
            titleid_dict[row[2]] = row[3]

# %%
query = """
SELECT * 
FROM INFORMATION_SCHEMA.COLUMNS 
"""
cursor.execute(query)
results = cursor.fetchall()
titleid_dict = {}
#//*** Script ID 29807928
#//*** Rundown ID 29620400
for row in results:
    #print(row)
    if  row[7] == 'int':
        #print(row[2],row[3])
        loop_query = f"""
        SELECT count(*)
        FROM {row[2]}
        WHERE {row[3]}='29807930' 
        """
        cursor.execute(loop_query)
        loop_result = cursor.fetchall()[0][0]
        if loop_result > 0:
            print(row[2],row[3],loop_result)
            titleid_dict[row[2]] = row[3]

# %%
for table,column in titleid_dict.items():
        loop_query = f"""
        SELECT *
        FROM {table}
        WHERE {column}='29807930' 
        """
        cursor.execute(loop_query)
        loop_result = cursor.fetchall()
        print(f"{table} -- {column}")
        print ([x for x in cursor.description])
        
        for row in loop_result:
            print(row)
        print("=============")

# %%
def hunt_db(input_search,**kwargs):
    
    #//**** Assign Default Values
    input_type='int'
    
    display = {
        "items" : False,
    }
    
    #//*** Scan Kwargs and update defaults as needed
    for key,value in kwargs.items():
        if key == "items":
            display[key] = value
        
        if key == "input_type":
            input_type=value

    query = """
    SELECT * 
    FROM INFORMATION_SCHEMA.COLUMNS 
    """
    cursor.execute(query)
    results = cursor.fetchall()
    titleid_dict = {}
    #//*** Script ID 29807928
    #//*** Rundown ID 29620400
    for row in results:
        #print(row[2], row[3])
        if  row[7] == input_type:
            #print(row[2],row[3])
            loop_query = f"""
            SELECT count(*)
            FROM {row[2]}
            WHERE {row[3]}='{input_search}' 
            """
            cursor.execute(loop_query)
            loop_result = cursor.fetchall()[0][0]
            if loop_result > 0:
                print(row[2],row[3],loop_result)
                titleid_dict[row[2]] = row[3]
                
    for table,column in titleid_dict.items():
        if not display['items']:
            if table == 'items':
                print("**************************************")
                print("Skipping Rundown Creation Items.")
                print("Use items=True to display")
                print("**************************************")
                
                continue
            
        loop_query = f"""
        SELECT *
        FROM {table}
        WHERE {column}='{input_search}' 
        """
        cursor.execute(loop_query)
        loop_result = cursor.fetchall()
        print(f"{table} -- {column}")
        out=""
        for desc in cursor.description:
            out += f"{desc[0]}, "
        print(out)
        #print(desc)
        #print ([x for x in cursor.description])
        print("Table")

        
        for row in loop_result:

            out = "( "
            for field in row:
                out += str(field).replace("&gt;",">").replace("&lt;","\n<").replace("&quot;","\"").replace("&#xd;&#xa;","\n").replace("&#xa;&#xa;","\n")
                out += ", "
            out += " )"
            print(out)

        print("=============")

# %%
hunt_db("1000089407")
# Out:
# items block_id 37
# spots block_id 30
# texts block_id 7
# block_item child_block_id 1
# blocks block_id 1
# **************************************
# Skipping Rundown Creation Items.
# Use items=True to display
# **************************************
# spots -- block_id
# block_id, item_id, title_id, mix_type, volume, begin_offset, end_offset, fade_in, fade_out, crossfade,
# Table
# ( 1000089407, 2007271, 33949576, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2007272, 33949578, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2007273, 33949580, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2007279, 33949585, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2007280, 33949587, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2007281, 33949595, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2007282, 33949604, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2007283, 33949613, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2007284, 33949617, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2007285, 33949623, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2007286, 33949627, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018684, 33983050, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018685, 33983057, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018714, 33983062, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018715, 33983069, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018720, 33983155, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018721, 33983160, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018723, 33983141, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018724, 33983149, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018726, 33983511, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018727, 33983513, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018728, 33983515, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018729, 33983516, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018731, 33983123, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018732, 33983126, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018733, 33983130, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018799, 33983773, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018800, 33983778, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018948, 33984713, 0, 0, 0, 0, 0, 0, 0,  )
# ( 1000089407, 2018949, 33984714, 0, 0, 0, 0, 0, 0, 0,  )
# =============
# texts -- block_id
# block_id, item_id, title, text, title_id, manual_duration,
# Table
# ( 1000089407, 2007274,  ,  , 0, 0,  )
# ( 1000089407, 2018580,  ,  , 0, 0,  )
# ( 1000089407, 2018581,  ,  , 0, 0,  )
# ( 1000089407, 2018603,  ,  , 0, 0,  )
# ( 1000089407, 2018717,  ,  , 0, 0,  )
# ( 1000089407, 2018722,  ,  , 0, 0,  )
# ( 1000089407, 2018725,  ,  , 0, 0,  )
# =============
# block_item -- child_block_id
# block_id, item_id, child_block_id,
# Table
# ( 1000089406, 2007270, 1000089407,  )
# =============
# blocks -- block_id
# block_id, block_type_id, block_level, n_used, last_modif_time, title, block_mode, end_time, duration, shelf_block_id,
# Table
# ( 1000089407, 3, 0, 0, 2021-11-30 06:49:31.613000, A BLOCK, 0, 1900-01-01 00:00:00, 66, None,  )
# =============

# %%
            
            
            
#hunt_db('29807933')

#//*** Hunt for BRIO
#hunt_db('29545833')

#//*** StoryID
print("=========================")
print("=========================")
print("=========================")
print("Story - 31527216")
print("=========================")
print("=========================")
print("=========================")
hunt_db('31527216')
#//*** MOS ID Unfloated MOS
print("=========================")
print("=========================")
print("=========================")
print("UnFLoated - 31527217")
print("=========================")
print("=========================")
print("=========================")
hunt_db('31527217')
#//*** MOS ID Floated MOS
print("=========================")
print("=========================")
print("=========================")
print("floated - 31527218")
print("=========================")
print("=========================")
print("=========================")
hunt_db('31527218')
#hunt_db('1173')
# Out:
# =========================
# =========================
# =========================
# Story - 31527216
# =========================
# =========================
# =========================
# Titles_ExFields Title_id 1
# TitleDataDictInteger TitleId 42
# TitleDataDictString TitleId 29
# TitleDataDictDateTime TitleId 3
# TitleDataDictText TitleId 2
# TitleDataDictPeriod TitleId 2
# titles_extend title_id 1
# ItemsToBeIndexed Item_id 1
# spots title_id 1
# titles_in_class title_id 1
# titles_references title_id 1
# titles_mix title_id 1
# CreatedModifiedItems Item_id 1
# StoryContent TitleId 1
# ObjectStatus ObjectId 1
# titles title_id 1
# StatusLog ObjectId 1
# Titles_ExFields -- Title_id
# Title_id, Language_id, Topic, VersionComment,
# Table
# ( 31527216, 99,  , None,  )
# =============
# TitleDataDictInteger -- TitleId
# DataField_Id, TitleId, ValueOrder, NumValue,
# Table
# ( 67, 31527216, 1, 0,  )
# ( 68, 31527216, 1, 1,  )
# ( 69, 31527216, 1, 0,  )
# ( 71, 31527216, 1, 1,  )
# ( 73, 31527216, 1, 1,  )
# ( 76, 31527216, 1, 0,  )
# ( 78, 31527216, 1, 0,  )
# ( 114, 31527216, 1, 29557028,  )
# ( 114, 31527216, 2, 29922070,  )
# ( 647, 31527216, 1, 1,  )
# ( 648, 31527216, 1, 1,  )
# ( 649, 31527216, 1, 1,  )
# ( 650, 31527216, 1, 1,  )
# ( 651, 31527216, 1, 1,  )
# ( 652, 31527216, 1, 1,  )
# ( 653, 31527216, 1, 1,  )
# ( 654, 31527216, 1, 1,  )
# ( 655, 31527216, 1, 1,  )
# ( 656, 31527216, 1, 1,  )
# ( 657, 31527216, 1, 1,  )
# ( 658, 31527216, 1, 1,  )
# ( 659, 31527216, 1, 1,  )
# ( 660, 31527216, 1, 1,  )
# ( 661, 31527216, 1, 1,  )
# ( 662, 31527216, 1, 1,  )
# ( 663, 31527216, 1, 1,  )
# ( 664, 31527216, 1, 1,  )
# ( 665, 31527216, 1, 1,  )
# ( 666, 31527216, 1, 1,  )
# ( 667, 31527216, 1, 1,  )
# ( 668, 31527216, 1, 1,  )
# ( 669, 31527216, 1, 1,  )
# ( 670, 31527216, 1, 1,  )
# ( 671, 31527216, 1, 1,  )
# ( 672, 31527216, 1, 1,  )
# ( 673, 31527216, 1, 1,  )
# ( 674, 31527216, 1, 1,  )
# ( 675, 31527216, 1, 1,  )
# ( 676, 31527216, 1, 1,  )
# ( 677, 31527216, 1, 1,  )
# ( 678, 31527216, 1, 1,  )
# ( 1466, 31527216, 1, 0,  )
# =============
# TitleDataDictString -- TitleId
# DataField_Id, TitleId, ValueOrder, StrValue,
# Table
# ( 518, 31527216, 1, Not Specified,  )
# ( 519, 31527216, 1, Not Specified,  )
# ( 1173, 31527216, 1,  ,  )
# ( 1178, 31527216, 1, --,  )
# ( 1213, 31527216, 1, web,  )
# ( 1214, 31527216, 1, 500,  )
# ( 1232, 31527216, 1, --,  )
# ( 1238, 31527216, 1, vid,  )
# ( 1248, 31527216, 1, wabc-wx-vid,  )
# ( 1249, 31527216, 1, _wabc_,  )
# ( 1255, 31527216, 1, True,  )
# ( 1258, 31527216, 1, No,  )
# ( 1259, 31527216, 1, Yes,  )
# ( 1268, 31527216, 1, False,  )
# ( 1269, 31527216, 1, hidden,  )
# ( 1272, 31527216, 1, False,  )
# ( 1309, 31527216, 1, img,  )
# ( 1316, 31527216, 1, -wabc-,  )
# ( 1317, 31527216, 1, -vid,  )
# ( 1330, 31527216, 1, wabc-wx-vid,  )
# ( 1375, 31527216, 1, wpvi-wx-vid,  )
# ( 1376, 31527216, 1, wpvi-wx-vid,  )
# ( 1377, 31527216, 1, wpvi-wx-vid,  )
# ( 1378, 31527216, 1, Default Training,  )
# ( 1526, 31527216, 1, --,  )
# ( 1531, 31527216, 1, kabc-wx-vid,  )
# ( 1574, 31527216, 1, 2 Hours,  )
# ( 1575, 31527216, 1, False,  )
# ( 1588, 31527216, 1, --,  )
# =============
# TitleDataDictDateTime -- TitleId
# DataField_Id, TitleId, ValueOrder, DateValue,
# Table
# ( 125, 31527216, 1, 2021-06-29 23:59:03.763000,  )
# ( 1250, 31527216, 1, 2021-06-29 00:08:29.367000,  )
# ( 1303, 31527216, 1, 2021-06-28 00:00:00,  )
# =============
# TitleDataDictText -- TitleId
# DataField_Id, TitleId, ValueOrder, TextValue,
# Table
# ( 1320, 31527216, 1, STORY=\nADDRESS=\nSTRINGER VIDEO=\nNOTES=\n,  )
# ( 1593, 31527216, 1, Linear,  )
# =============
# TitleDataDictPeriod -- TitleId
# DataField_Id, TitleId, ValueOrder, PeriodValue,
# Table
# ( 66, 31527216, 1, 0,  )
# ( 72, 31527216, 1, 112,  )
# =============
# titles_extend -- title_id
# title_id, source, reader, read_rate, year_composed, medium, status, custom1, custom2, label_reference, volume_number, oeuvre, act, orchestra, composer, conductor, period, industry, product, language, cut, version, voice, creator,
# Table
# ( 31527216,  , 0, 0, 1900, 0, 0,  ,  ,  ,  ,  ,  ,  ,  ,  ,  , 0, 0, ,  , p ,  ,  ,  )
# =============
# ItemsToBeIndexed -- Item_id
# Item_id, Item_type, ModifiedAt, IsInRecycleBin,
# Table
# ( 31527216, 2, 2021-07-07 08:35:09.170000, 0,  )
# =============
# spots -- title_id
# block_id, item_id, title_id, mix_type, volume, begin_offset, end_offset, fade_in, fade_out, crossfade,
# Table
# ( 1000070238, 1303444, 31527216, 0, 0, 0, 0, 0, 0, 0,  )
# =============
# titles_in_class -- title_id
# class_id, title_id, is_primary_class, order_in_class,
# Table
# ( 36764, 31527216, 1, 0,  )
# =============
# titles_references -- title_id
# title_id, reference_id, reference_text,
# Table
# ( 31527216, 1, KGO5198194,  )
# =============
# titles_mix -- title_id
# title_id, begin_offset, end_offset, intro1, intro2, outro, fade_in, fade_out, crossfade, is_endless_loop,
# Table
# ( 31527216, 0, 0, 0, 0, 0, 0, 0, 0, 0,  )
# =============
# CreatedModifiedItems -- Item_id
# Item_id, Item_type, CreatedBy, ModifiedBy, CreatedAt, ModifiedAt, CreatedByName, ModifiedByName, IsInRecycleBin,
# Table
# ( 31527216, 2, 1915, 1915, 2021-06-29 00:08:29.403000, 2021-07-07 08:35:09.170000, KGO DaletService, KGO DaletService, 0,  )
# =============
# StoryContent -- TitleId
# TitleId, StoryXml, StoryText,
# Table
# ( 31527216, <StoryContent dilVersion.l="57420" lastModifyMainSection.td="2021-07-07T08:33:08.320" lastModifySoMeSection.td="2021-07-07T08:33:08.320" maxEmbeddedItemId.l="22" nextSocialMediaSectionId.l="1" titleId.l="31527216"><SecondarySections t="lt"><SecondarySection SectionType.l="2" lastModifySection.td="2021-07-07T08:33:08.320"><StoryObjects t="lt"></StoryObjects><rtf t="ws">{\rtf1\ansi\ansicpg1252\deff0\deflang1033{\fonttbl{\f0\fnil\fcharset0 Arial;}}
# {\colortbl ;\red0\green0\blue0;}
# {\*\generator Msftedit 5.41.21.2510;}\viewkind4\uc1\pard\cf1\fs24\par
# }
# </rtf><text t="ws"></text><xml t="ws">
# <?xml version="1.0" ?>
#
# <STORY>
# <FONT color="#000000"/>
# <FONT size="3"/>
# <BR/>
# <FONT/>
# <FONT/>
#
# </STORY>
# </xml></SecondarySection></SecondarySections><SocialMediaSections t="lt"></SocialMediaSections><StoryObjects t="lt"><LiveTimeGap PositionInText.l="24" Time.tp="P0.016S" idInStory.l="16"><Description t="ws">Removed Item: v3c Fade to Black - Ross Video - Transition: FADE TO BLACK CCT...1 Btn:2); CLR XG1-G4 (Bank:3 Btn:29); DIGIFADE (Bank:5 Btn:9);</Description></LiveTimeGap><LiveTimeGap PositionInText.l="27" Time.tp="P0.016S" idInStory.l="17"><Description t="ws">Removed Item: v3c Fade to Black - Ross Video - Transition: FADE TO BLACK CCT...1 Btn:2); CLR XG1-G4 (Bank:3 Btn:29); DIGIFADE (Bank:5 Btn:9);</Description></LiveTimeGap><LiveTimeGap PositionInText.l="29" Time.tp="P0.016S" idInStory.l="18"><Description t="ws">Removed Item: v3c Fade to Black - Ross Video - Transition: FADE TO BLACK CCT...1 Btn:2); CLR XG1-G4 (Bank:3 Btn:29); DIGIFADE (Bank:5 Btn:9);</Description></LiveTimeGap><LiveTimeGap PositionInText.l="54" Time.tp="P0.016S" idInStory.l="19"><Description t="ws">Removed Item: v3 G1 Auto In xp - Ross Video - Audio AFV: Video Only - Custom Controls: KXG1A (Bank:3 Btn:31); </Description></LiveTimeGap><LiveTimeGap PositionInText.l="56" Time.tp="P0.016S" idInStory.l="20"><Description t="ws">Removed Item: v3i Fast to Black - Ross Video - Transition: FAST TO BLACK CCT ... Btn:2); CLR XG1-G4 (Bank:3 Btn:29); DIGIFADE (Bank:5 Btn:9);</Description></LiveTimeGap><LiveTimeGap PositionInText.l="61" Time.tp="P0.016S" idInStory.l="21"><Description t="ws">Removed Item: v3a Hold All Cams - Ross Video - Audio AFV: Video Only - 1 Clip... Clip: IGNITE:9999 - 4 Clip: IGNITE:9999 - 5 Clip: IGNITE:999</Description></LiveTimeGap><LiveTimeGap PositionInText.l="64" Time.tp="P0.016S" idInStory.l="22"><Description t="ws">Removed Item: v3a Pre Segment Black - Ross Video - Transition: FADE TO BLACK ... Btn:2); CLR XG1-G4 (Bank:3 Btn:29); DIGIFADE (Bank:5 Btn:9);</Description></LiveTimeGap></StoryObjects><rtf t="ws">{\rtf1\ansi\ansicpg1252\deff0\deflang1033{\fonttbl{\f0\fnil\fcharset0 Arial;}{\f1\fnil Arial;}}
# {\colortbl ;\red0\green0\blue0;}
# {\*\generator Msftedit 5.41.21.2510;}\viewkind4\uc1\pard\cf1\fs24 (( BREAK NO ITX 1.0 ))\par
# \par
# \objattph\&apos;20\par
# \par
# \f1\objattph\&apos;20\f0\par
# \f1\objattph\&apos;20\f0\par
# (( DIGIBUMP VERSION ))\par
# \objattph\&apos;20\par
# \objattph\&apos;20\par
# \par
# \par
# \par
# \objattph\&apos;20\par
# \par
# \objattph\&apos;20\par
# \par
# \par
# \par
# \par
# \par
# \par
# \par
# \par
# \par
# \par
# \par
# }
# </rtf><text t="ws">(( BREAK NO ITX 1.0 ))
#
#
#
#
#
# (( DIGIBUMP VERSION ))
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </text><textWithoutComments t="ws">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </textWithoutComments><xml t="ws">
# <?xml version="1.0" ?>
#
# <STORY>
# <FONT color="#000000"/>
# <FONT size="3"/>
# <CommentForTimingAndTPS/> BREAK NO ITX 1.0
# <CommentForTimingAndTPE/>
# <BR/>
# <BR/>
# <LiveTimeGap PositionInText.l="24" Time.tp="P0.016S" idInStory.l="16">
# <Description t="ws">Removed Item: v3c Fade to Black - Ross Video - Transition: FADE TO BLACK CCT...1 Btn:2); CLR XG1-G4 (Bank:3 Btn:29); DIGIFADE (Bank:5 Btn:9);
# </Description>
# </LiveTimeGap>
# <BR/>
# <BR/>
# <FONT face="Arial"/>
# <LiveTimeGap PositionInText.l="27" Time.tp="P0.016S" idInStory.l="17">
# <Description t="ws">Removed Item: v3c Fade to Black - Ross Video - Transition: FADE TO BLACK CCT...1 Btn:2); CLR XG1-G4 (Bank:3 Btn:29); DIGIFADE (Bank:5 Btn:9);
# </Description>
# </LiveTimeGap>
# <FONT/>
# <FONT face="Arial"/>
# <BR/>
# <FONT/>
# <FONT face="Arial"/>
# <LiveTimeGap PositionInText.l="29" Time.tp="P0.016S" idInStory.l="18">
# <Description t="ws">Removed Item: v3c Fade to Black - Ross Video - Transition: FADE TO BLACK CCT...1 Btn:2); CLR XG1-G4 (Bank:3 Btn:29); DIGIFADE (Bank:5 Btn:9);
# </Description>
# </LiveTimeGap>
# <FONT/>
# <FONT face="Arial"/>
# <BR/>
# <CommentForTimingAndTPS/> DIGIBUMP VERSION
# <CommentForTimingAndTPE/>
# <BR/>
# <LiveTimeGap PositionInText.l="54" Time.tp="P0.016S" idInStory.l="19">
# <Description t="ws">Removed Item: v3 G1 Auto In xp - Ross Video - Audio AFV: Video Only - Custom Controls: KXG1A (Bank:3 Btn:31);
# </Description>
# </LiveTimeGap>
# <BR/>
# <LiveTimeGap PositionInText.l="56" Time.tp="P0.016S" idInStory.l="20">
# <Description t="ws">Removed Item: v3i Fast to Black - Ross Video - Transition: FAST TO BLACK CCT ... Btn:2); CLR XG1-G4 (Bank:3 Btn:29); DIGIFADE (Bank:5 Btn:9);
# </Description>
# </LiveTimeGap>
# <BR/>
# <BR/>
# <BR/>
# <BR/>
# <LiveTimeGap PositionInText.l="61" Time.tp="P0.016S" idInStory.l="21">
# <Description t="ws">Removed Item: v3a Hold All Cams - Ross Video - Audio AFV: Video Only - 1 Clip... Clip: IGNITE:9999 - 4 Clip: IGNITE:9999 - 5 Clip: IGNITE:999
# </Description>
# </LiveTimeGap>
# <BR/>
# <BR/>
# <LiveTimeGap PositionInText.l="64" Time.tp="P0.016S" idInStory.l="22">
# <Description t="ws">Removed Item: v3a Pre Segment Black - Ross Video - Transition: FADE TO BLACK ... Btn:2); CLR XG1-G4 (Bank:3 Btn:29); DIGIFADE (Bank:5 Btn:9);
# </Description>
# </LiveTimeGap>
# <BR/>
# <BR/>
# <BR/>
# <BR/>
# <BR/>
# <BR/>
# <BR/>
# <BR/>
# <BR/>
# <BR/>
# <BR/>
# <BR/>
# <FONT/>
# <FONT/>
# <FONT/>
#
# </STORY>
# </xml></StoryContent>, (( BREAK NO ITX 1.0 ))
#
#
#
#
#
# (( DIGIBUMP VERSION ))
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,  )
# =============
# ObjectStatus -- ObjectId
# ObjectId, ObjectType, Status_id,
# Table
# ( 31527216, 82, 12040856,  )
# =============
# titles -- title_id
# title_id, title_type_id, title_interface_id, user_id, title, interpret, author, client, duration, is_online, is_recorded, record_date, start_date, end_date, kill_date, audio_duration, use_manual_duration, soundfile_id, year, keywords, site_origin, no_overwrite, is_rotational_cart, replacement, last_words, is_opener, weight, beats_pm, master_record, compagny_id, compagny_disp_name, album_disp_name, package_id, album_id, song_id, day_part_rest_id, keep_date,
# Table
# ( 31527216, 4, 0, 0, BREAK NO ITX,  , Johnson Chris,  , 112, 1, 0, 2021-06-29 00:08:29.347000, 2021-06-29 00:08:29.347000, 2021-07-06 08:26:59.740000, 2021-07-05 08:26:59.740000, 0, 0, 0, 2021,  , 0, 0, 0,  ,  , 0, 100, -1, None, None,  ,  , None, None, None, None, 2021-07-05 08:26:59.740000,  )
# =============
# StatusLog -- ObjectId
# Order1, ObjectId, ObjectType, To_status, Log_date, Commentt, UserLastName, UserFirstName,
# Table
# ( 12976945, 31527216, 82, 12040856, 2021-06-29 00:08:29.407000, Create, ADMIN, ,  )
# =============
# =========================
# =========================
# =========================
# UnFLoated - 31527217
# =========================
# =========================
# =========================
# =========================
# =========================
# =========================
# floated - 31527218
# =========================
# =========================
# =========================

# %%
#//*** StoryID
print("=========================")
print("=========================")
print("=========================")
print("Story - 12976947")
print("=========================")
print("=========================")
print("=========================")
hunt_db('12976947')

#hunt_db('1173')
# Out:
# =========================
# =========================
# =========================
# Story - 12976947
# =========================
# =========================
# =========================

# %%
#select  count(*)
#from playoutItemsStatus, clocks, MosDevices, titles 
#where content like '%onairstatus%' and STAT.ClockId = clocks.clock_id and clocks.clock_id = titles.title_id
#order by Rundown_date_time desc ;
query = """
SELECT *
FROM playoutItemsStatus
"""
cursor.execute(query)
results = cursor.fetchall()
#for x in results:
#    print(x)

# %%
# Datafields are all the Locking metadata fields. This gets a list of all of them

query = f"""
SELECT *
FROM DataFields 
"""
cursor.execute(query)
results = cursor.fetchall()
#for x in results:
#    print(x)
#titles -- title_id

# %%
hunt_db("38122")
# Out:
# items item_order 3
# AccessRights Object_id 12
# titles_in_class class_id 2058
# classes class_id 1
# class_tree child_class_id 1
# ObjectStatus ObjectId 1
# titles duration 2
# ObjectAssignedStatus ObjectId 1
# StatusLog ObjectId 1
# items -- item_order
# block_id, item_id, item_type, item_reference, scheduled_time, computed_time, item_comment, item_order, radio_id, clock_id, use_manual_duration,
# ( 1000060653, 967984, 3,  , 2021-04-17 11:59:59.980000, 2021-04-17 11:59:59.980000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" mode.l="0" startMode.l="1"/>, 38122, 1132, 30338778, 0,  )
# ( 1000066690, 1173908, 1,  , 2021-06-01 22:58:45.937000, 2021-06-01 22:58:45.937000, <Story mode.l="0" orderPageNumber.l="15" startMode.l="1" tp.l="1"><custom10 t="ws">00:00:12 "more affordably"</custom10><custom3 t="ws">cj4p</custom3><pageNumber t="ws">D15</pageNumber></Story>, 38122, 1132, 31067970, 0,  )
# ( 1000074549, 1473179, 1,  , 2021-08-03 22:58:45.937000, 2021-08-03 22:58:45.937000, <Story mode.l="0" orderPageNumber.l="8" startMode.l="1" tp.l="1"><pageNumber t="ws">F8</pageNumber></Story>, 38122, 1132, 32083170, 0,  )
# =============
# AccessRights -- Object_id
# Object_id, ObjectType, group_id, ViewItems, InsertItems, RemoveItems, ViewContainers, InsertContainers, RemoveContainers, ChangeRights,
# ( 38122, 7, 9, 1, 1, 1, 1, 1, 1, 0,  )
# ( 38122, 7, 83, 1, 0, 0, 1, 0, 0, 0,  )
# ( 38122, 7, 148, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 149, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 166, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 169, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 170, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 438, 1, 0, 0, 1, 0, 0, 0,  )
# ( 38122, 7, 623, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 2422, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 2424, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 2425, 1, 1, 1, 1, 1, 0, 0,  )
# =============
# titles_in_class -- class_id
# class_id, title_id, is_primary_class, order_in_class,
# ( 38122, 33936610, 1, None,  )
# ( 38122, 33936619, 1, None,  )
# ( 38122, 33936625, 1, None,  )
# ( 38122, 33936628, 1, None,  )
# ( 38122, 33936634, 1, None,  )
# ( 38122, 33936636, 1, None,  )
# ( 38122, 33936644, 1, None,  )
# ( 38122, 33936653, 1, None,  )
# ( 38122, 33936662, 1, None,  )
# ( 38122, 33936669, 1, None,  )
# ( 38122, 33936671, 1, None,  )
# ( 38122, 33936673, 1, None,  )
# ( 38122, 33936681, 1, None,  )
# ( 38122, 33936684, 1, None,  )
# ( 38122, 33936688, 1, None,  )
# ( 38122, 33936690, 1, None,  )
# ( 38122, 33936696, 1, None,  )
# ( 38122, 33936699, 1, None,  )
# ( 38122, 33936703, 1, None,  )
# ( 38122, 33936706, 1, None,  )
# ( 38122, 33936712, 1, None,  )
# ( 38122, 33936714, 1, None,  )
# ( 38122, 33936722, 1, None,  )
# ( 38122, 33936725, 1, None,  )
# ( 38122, 33936729, 1, None,  )
# ( 38122, 33936731, 1, None,  )
# ( 38122, 33936738, 1, None,  )
# ( 38122, 33936740, 1, None,  )
# ( 38122, 33936749, 1, None,  )
# ( 38122, 33936751, 1, None,  )
# ( 38122, 33936758, 1, None,  )
# ( 38122, 33936760, 1, None,  )
# ( 38122, 33936763, 1, None,  )
# ( 38122, 33936765, 1, None,  )
# ( 38122, 33936771, 1, None,  )
# ( 38122, 33936779, 1, None,  )
# ( 38122, 33936787, 1, None,  )
# ( 38122, 33936809, 1, None,  )
# ( 38122, 33936815, 1, None,  )
# ( 38122, 33936817, 1, None,  )
# ( 38122, 33936824, 1, None,  )
# ( 38122, 33936826, 1, None,  )
# ( 38122, 33951826, 1, None,  )
# ( 38122, 33951829, 1, None,  )
# ( 38122, 33951831, 1, None,  )
# ( 38122, 33951833, 1, None,  )
# ( 38122, 33951835, 1, None,  )
# ( 38122, 33951836, 1, None,  )
# ( 38122, 33951837, 1, None,  )
# ( 38122, 33951845, 1, None,  )
# ( 38122, 33951858, 1, None,  )
# ( 38122, 33951866, 1, None,  )
# ( 38122, 33951872, 1, None,  )
# ( 38122, 33951876, 1, None,  )
# ( 38122, 33951880, 1, None,  )
# ( 38122, 33951884, 1, None,  )
# ( 38122, 33951889, 1, None,  )
# ( 38122, 33951893, 1, None,  )
# ( 38122, 33951900, 1, None,  )
# ( 38122, 33951901, 1, None,  )
# ( 38122, 33951908, 1, None,  )
# ( 38122, 33951921, 1, None,  )
# ( 38122, 33951929, 1, None,  )
# ( 38122, 33951935, 1, None,  )
# ( 38122, 33951939, 1, None,  )
# ( 38122, 33951943, 1, None,  )
# ( 38122, 33951947, 1, None,  )
# ( 38122, 33951952, 1, None,  )
# ( 38122, 33951956, 1, None,  )
# ( 38122, 33951963, 1, None,  )
# ( 38122, 33951964, 1, None,  )
# ( 38122, 33951971, 1, None,  )
# ( 38122, 33951984, 1, None,  )
# ( 38122, 33951992, 1, None,  )
# ( 38122, 33951998, 1, None,  )
# ( 38122, 33952002, 1, None,  )
# ( 38122, 33952006, 1, None,  )
# ( 38122, 33952010, 1, None,  )
# ( 38122, 33952015, 1, None,  )
# ( 38122, 33952019, 1, None,  )
# ( 38122, 33952026, 1, None,  )
# ( 38122, 33952027, 1, None,  )
# ( 38122, 33952034, 1, None,  )
# ( 38122, 33952047, 1, None,  )
# ( 38122, 33952055, 1, None,  )
# ( 38122, 33952061, 1, None,  )
# ( 38122, 33952065, 1, None,  )
# ( 38122, 33952069, 1, None,  )
# ( 38122, 33952073, 1, None,  )
# ( 38122, 33952078, 1, None,  )
# ( 38122, 33952082, 1, None,  )
# ( 38122, 33952090, 1, None,  )
# ( 38122, 33952091, 1, None,  )
# ( 38122, 33952098, 1, None,  )
# ( 38122, 33952111, 1, None,  )
# ( 38122, 33952119, 1, None,  )
# ( 38122, 33952125, 1, None,  )
# ( 38122, 33952129, 1, None,  )
# ( 38122, 33952133, 1, None,  )
# ( 38122, 33952137, 1, None,  )
# ( 38122, 33952142, 1, None,  )
# ( 38122, 33952146, 1, None,  )
# ( 38122, 33952153, 1, None,  )
# ( 38122, 33952154, 1, None,  )
# ( 38122, 33952161, 1, None,  )
# ( 38122, 33952174, 1, None,  )
# ( 38122, 33952182, 1, None,  )
# ( 38122, 33952188, 1, None,  )
# ( 38122, 33952192, 1, None,  )
# ( 38122, 33952196, 1, None,  )
# ( 38122, 33952200, 1, None,  )
# ( 38122, 33952205, 1, None,  )
# ( 38122, 33952209, 1, None,  )
# ( 38122, 33952216, 1, None,  )
# ( 38122, 33952217, 1, None,  )
# ( 38122, 33952220, 1, None,  )
# ( 38122, 33952223, 1, None,  )
# ( 38122, 33952226, 1, None,  )
# ( 38122, 33952233, 1, None,  )
# ( 38122, 33952234, 1, None,  )
# ( 38122, 33952238, 1, None,  )
# ( 38122, 33952239, 1, None,  )
# ( 38122, 33952240, 1, None,  )
# ( 38122, 33952242, 1, None,  )
# ( 38122, 33952245, 1, None,  )
# ( 38122, 33952248, 1, None,  )
# ( 38122, 33952251, 1, None,  )
# ( 38122, 33952252, 1, None,  )
# ( 38122, 33952253, 1, None,  )
# ( 38122, 33952260, 1, None,  )
# ( 38122, 33952261, 1, None,  )
# ( 38122, 33952262, 1, None,  )
# ( 38122, 33952263, 1, None,  )
# ( 38122, 33952264, 1, None,  )
# ( 38122, 33952265, 1, None,  )
# ( 38122, 33952266, 1, None,  )
# ( 38122, 33952267, 1, None,  )
# ( 38122, 33952273, 1, None,  )
# ( 38122, 33952274, 1, None,  )
# ( 38122, 33952275, 1, None,  )
# ( 38122, 33952277, 1, None,  )
# ( 38122, 33952278, 1, None,  )
# ( 38122, 33952279, 1, None,  )
# ( 38122, 33952280, 1, None,  )
# ( 38122, 33952281, 1, None,  )
# ( 38122, 33952282, 1, None,  )
# ( 38122, 33952283, 1, None,  )
# ( 38122, 33953833, 1, None,  )
# ( 38122, 33953835, 1, None,  )
# ( 38122, 33954018, 1, None,  )
# ( 38122, 33954490, 1, None,  )
# ( 38122, 33966504, 1, None,  )
# ( 38122, 33966509, 1, None,  )
# ( 38122, 33966510, 1, None,  )
# ( 38122, 33966515, 1, None,  )
# ( 38122, 33966518, 1, None,  )
# ( 38122, 33966522, 1, None,  )
# ( 38122, 33966531, 1, None,  )
# ( 38122, 33966537, 1, None,  )
# ( 38122, 33966539, 1, None,  )
# ( 38122, 33966543, 1, None,  )
# ( 38122, 33966548, 1, None,  )
# ( 38122, 33966552, 1, None,  )
# ( 38122, 33966554, 1, None,  )
# ( 38122, 33966556, 1, None,  )
# ( 38122, 33966560, 1, None,  )
# ( 38122, 33966564, 1, None,  )
# ( 38122, 33966570, 1, None,  )
# ( 38122, 33966572, 1, None,  )
# ( 38122, 33966575, 1, None,  )
# ( 38122, 33966577, 1, None,  )
# ( 38122, 33966579, 1, None,  )
# ( 38122, 33966585, 1, None,  )
# ( 38122, 33966591, 1, None,  )
# ( 38122, 33966593, 1, None,  )
# ( 38122, 33966597, 1, None,  )
# ( 38122, 33966599, 1, None,  )
# ( 38122, 33966603, 1, None,  )
# ( 38122, 33966605, 1, None,  )
# ( 38122, 33966607, 1, None,  )
# ( 38122, 33966611, 1, None,  )
# ( 38122, 33966613, 1, None,  )
# ( 38122, 33966617, 1, None,  )
# ( 38122, 33966619, 1, None,  )
# ( 38122, 33966623, 1, None,  )
# ( 38122, 33966625, 1, None,  )
# ( 38122, 33966629, 1, None,  )
# ( 38122, 33966632, 1, None,  )
# ( 38122, 33966634, 1, None,  )
# ( 38122, 33966637, 1, None,  )
# ( 38122, 33966643, 1, None,  )
# ( 38122, 33966645, 1, None,  )
# ( 38122, 33966649, 1, None,  )
# ( 38122, 33966651, 1, None,  )
# ( 38122, 33966654, 1, None,  )
# ( 38122, 33974311, 1, None,  )
# ( 38122, 33974336, 1, None,  )
# ( 38122, 33974347, 1, None,  )
# ( 38122, 33974351, 1, None,  )
# ( 38122, 33974353, 1, None,  )
# ( 38122, 33974369, 1, None,  )
# ( 38122, 33974423, 1, None,  )
# ( 38122, 33974440, 1, None,  )
# ( 38122, 33974459, 1, None,  )
# ( 38122, 33974519, 1, None,  )
# ( 38122, 33974522, 1, None,  )
# ( 38122, 33974541, 1, None,  )
# ( 38122, 33974545, 1, None,  )
# ( 38122, 33974548, 1, None,  )
# ( 38122, 33974550, 1, None,  )
# ( 38122, 33974561, 1, None,  )
# ( 38122, 33974575, 1, None,  )
# ( 38122, 33974589, 1, None,  )
# ( 38122, 33974592, 1, None,  )
# ( 38122, 33974643, 1, None,  )
# ( 38122, 33974645, 1, None,  )
# ( 38122, 33974647, 1, None,  )
# ( 38122, 33974653, 1, None,  )
# ( 38122, 33974657, 1, None,  )
# ( 38122, 33974965, 1, None,  )
# ( 38122, 33975132, 1, None,  )
# ( 38122, 33975145, 1, None,  )
# ( 38122, 33975151, 1, None,  )
# ( 38122, 33975155, 1, None,  )
# ( 38122, 33975162, 1, None,  )
# ( 38122, 33975175, 1, None,  )
# ( 38122, 33975182, 1, None,  )
# ( 38122, 33975196, 1, None,  )
# ( 38122, 33975198, 1, None,  )
# ( 38122, 33975200, 1, None,  )
# ( 38122, 33975202, 1, None,  )
# ( 38122, 33975204, 1, None,  )
# ( 38122, 33975206, 1, None,  )
# ( 38122, 33975207, 1, None,  )
# ( 38122, 33975212, 1, None,  )
# ( 38122, 33975213, 1, None,  )
# ( 38122, 33975216, 1, None,  )
# ( 38122, 33975235, 1, None,  )
# ( 38122, 33975236, 1, None,  )
# ( 38122, 33975238, 1, None,  )
# ( 38122, 33975240, 1, None,  )
# ( 38122, 33975243, 1, None,  )
# ( 38122, 33975245, 1, None,  )
# ( 38122, 33975247, 1, None,  )
# ( 38122, 33975248, 1, None,  )
# ( 38122, 33975250, 1, None,  )
# ( 38122, 33975253, 1, None,  )
# ( 38122, 33975255, 1, None,  )
# ( 38122, 33975257, 1, None,  )
# ( 38122, 33975259, 1, None,  )
# ( 38122, 33975261, 1, None,  )
# ( 38122, 33975262, 1, None,  )
# ( 38122, 33975263, 1, None,  )
# ( 38122, 33975276, 1, None,  )
# ( 38122, 33975297, 1, None,  )
# ( 38122, 33975300, 1, None,  )
# ( 38122, 33975321, 1, None,  )
# ( 38122, 33975325, 1, None,  )
# ( 38122, 33975353, 1, None,  )
# ( 38122, 33975357, 1, None,  )
# ( 38122, 33975358, 1, None,  )
# ( 38122, 33975366, 1, None,  )
# ( 38122, 33975372, 1, None,  )
# ( 38122, 33975374, 1, None,  )
# ( 38122, 33975375, 1, None,  )
# ( 38122, 33975388, 1, None,  )
# ( 38122, 33975396, 1, None,  )
# ( 38122, 33975402, 1, None,  )
# ( 38122, 33975407, 1, None,  )
# ( 38122, 33975411, 1, None,  )
# ( 38122, 33975415, 1, None,  )
# ( 38122, 33975420, 1, None,  )
# ( 38122, 33975424, 1, None,  )
# ( 38122, 33975430, 1, None,  )
# ( 38122, 33975438, 1, None,  )
# ( 38122, 33975451, 1, None,  )
# ( 38122, 33975460, 1, None,  )
# ( 38122, 33975468, 1, None,  )
# ( 38122, 33975469, 1, None,  )
# ( 38122, 33975472, 1, None,  )
# ( 38122, 33975475, 1, None,  )
# ( 38122, 33975477, 1, None,  )
# ( 38122, 33975478, 1, None,  )
# ( 38122, 33975481, 1, None,  )
# ( 38122, 33975488, 1, None,  )
# ( 38122, 33975491, 1, None,  )
# ( 38122, 33975501, 1, None,  )
# ( 38122, 33975503, 1, None,  )
# ( 38122, 33975509, 1, None,  )
# ( 38122, 33975510, 1, None,  )
# ( 38122, 33975511, 1, None,  )
# ( 38122, 33975513, 1, None,  )
# ( 38122, 33975515, 1, None,  )
# ( 38122, 33975516, 1, None,  )
# ( 38122, 33975518, 1, None,  )
# ( 38122, 33975524, 1, None,  )
# ( 38122, 33975529, 1, None,  )
# ( 38122, 33975531, 1, None,  )
# ( 38122, 33975533, 1, None,  )
# ( 38122, 33975534, 1, None,  )
# ( 38122, 33975538, 1, None,  )
# ( 38122, 33975543, 1, None,  )
# ( 38122, 33975544, 1, None,  )
# ( 38122, 33975547, 1, None,  )
# ( 38122, 33975549, 1, None,  )
# ( 38122, 33975551, 1, None,  )
# ( 38122, 33975555, 1, None,  )
# ( 38122, 33975570, 1, None,  )
# ( 38122, 33975576, 1, None,  )
# ( 38122, 33975582, 1, None,  )
# ( 38122, 33975586, 1, None,  )
# ( 38122, 33975588, 1, None,  )
# ( 38122, 33975601, 1, None,  )
# ( 38122, 33975603, 1, None,  )
# ( 38122, 33975609, 1, None,  )
# ( 38122, 33975615, 1, None,  )
# ( 38122, 33975621, 1, None,  )
# ( 38122, 33975637, 1, None,  )
# ( 38122, 33975640, 1, None,  )
# ( 38122, 33975654, 1, None,  )
# ( 38122, 33975658, 1, None,  )
# ( 38122, 33975660, 1, None,  )
# ( 38122, 33975673, 1, None,  )
# ( 38122, 33975676, 1, None,  )
# ( 38122, 33975679, 1, None,  )
# ( 38122, 33975683, 1, None,  )
# ( 38122, 33975687, 1, None,  )
# ( 38122, 33975699, 1, None,  )
# ( 38122, 33975720, 1, None,  )
# ( 38122, 33975726, 1, None,  )
# ( 38122, 33975738, 1, None,  )
# ( 38122, 33975747, 1, None,  )
# ( 38122, 33975749, 1, None,  )
# ( 38122, 33975751, 1, None,  )
# ( 38122, 33975789, 1, None,  )
# ( 38122, 33975840, 1, None,  )
# ( 38122, 33975842, 1, None,  )
# ( 38122, 33975899, 1, None,  )
# ( 38122, 33975901, 1, None,  )
# ( 38122, 33975928, 1, None,  )
# ( 38122, 33975940, 1, None,  )
# ( 38122, 33975942, 1, None,  )
# ( 38122, 33975957, 1, None,  )
# ( 38122, 33975966, 1, None,  )
# ( 38122, 33975968, 1, None,  )
# ( 38122, 33975980, 1, None,  )
# ( 38122, 33976040, 1, None,  )
# ( 38122, 33976057, 1, None,  )
# ( 38122, 33982352, 1, None,  )
# ( 38122, 33982701, 1, None,  )
# ( 38122, 33982723, 1, None,  )
# ( 38122, 33982726, 1, None,  )
# ( 38122, 33982936, 1, None,  )
# ( 38122, 33983026, 1, None,  )
# ( 38122, 33983035, 1, None,  )
# ( 38122, 33983042, 1, None,  )
# ( 38122, 33983050, 1, None,  )
# ( 38122, 33983057, 1, None,  )
# ( 38122, 33983062, 1, None,  )
# ( 38122, 33983069, 1, None,  )
# ( 38122, 33983093, 1, None,  )
# ( 38122, 33983098, 1, None,  )
# ( 38122, 33983101, 1, None,  )
# ( 38122, 33983123, 1, None,  )
# ( 38122, 33983126, 1, None,  )
# ( 38122, 33983130, 1, None,  )
# ( 38122, 33983141, 1, None,  )
# ( 38122, 33983146, 1, None,  )
# ( 38122, 33983149, 1, None,  )
# ( 38122, 33983155, 1, None,  )
# ( 38122, 33983160, 1, None,  )
# ( 38122, 33983254, 1, None,  )
# ( 38122, 33983259, 1, None,  )
# ( 38122, 33983310, 1, None,  )
# ( 38122, 33983313, 1, None,  )
# ( 38122, 33983385, 1, None,  )
# ( 38122, 33983387, 1, None,  )
# ( 38122, 33983389, 1, None,  )
# ( 38122, 33983408, 1, None,  )
# ( 38122, 33983472, 1, None,  )
# ( 38122, 33983511, 1, None,  )
# ( 38122, 33983513, 1, None,  )
# ( 38122, 33983515, 1, None,  )
# ( 38122, 33983516, 1, None,  )
# ( 38122, 33983546, 1, None,  )
# ( 38122, 33983549, 1, None,  )
# ( 38122, 33983651, 1, None,  )
# ( 38122, 33983657, 1, None,  )
# ( 38122, 33983661, 1, None,  )
# ( 38122, 33983663, 1, None,  )
# ( 38122, 33983666, 1, None,  )
# ( 38122, 33983670, 1, None,  )
# ( 38122, 33983672, 1, None,  )
# ( 38122, 33983678, 1, None,  )
# ( 38122, 33983680, 1, None,  )
# ( 38122, 33983685, 1, None,  )
# ( 38122, 33983700, 1, None,  )
# ( 38122, 33983705, 1, None,  )
# ( 38122, 33983755, 1, None,  )
# ( 38122, 33983758, 1, None,  )
# ( 38122, 33983761, 1, None,  )
# ( 38122, 33983773, 1, None,  )
# ( 38122, 33983778, 1, None,  )
# =============
# classes -- class_id
# class_id, code, long_name, short_name, description, color, n_child, level_code, killdate_offset, sort_field_id1, sort_field_id2, sort_field_id3, sort_direction, access_rights, endkill_offset, titles_mean_duration, record_limitation, full_name, keepdate_offset, SubCategorySorting, is_running_order, read_rate, SystemClass,
# ( 38122, SRDC, 2021/11/29, 2021/11/29, 2021/11/29, -1, 0, , 5, 0, 0, 0, 0, 111111111, 1, 210000, 0, CATEGORIES/KGO Rundowns/KGO_NEWS Rundowns/2021/11/29, 0, 0, 0, None, None,  )
# =============
# class_tree -- child_class_id
# parent_class_id, child_class_id, class_order,
# ( 31804, 38122, 0,  )
# =============
# ObjectStatus -- ObjectId
# ObjectId, ObjectType, Status_id,
# ( 38122, 83, 1,  )
# =============
# titles -- duration
# title_id, title_type_id, title_interface_id, user_id, title, interpret, author, client, duration, is_online, is_recorded, record_date, start_date, end_date, kill_date, audio_duration, use_manual_duration, soundfile_id, year, keywords, site_origin, no_overwrite, is_rotational_cart, replacement, last_words, is_opener, weight, beats_pm, master_record, compagny_id, compagny_disp_name, album_disp_name, package_id, album_id, song_id, day_part_rest_id, keep_date,
# ( 32781723, 4, 0, 0, 5A SF VOTE,  , Nudelman Leann, , 38122, 1, 0, 2021-09-15 06:20:57.627000, 2021-09-15 06:20:57.627000, 2021-09-22 08:15:02.317000, 2021-09-21 08:15:02.317000, 0, 0, 0, 2021,  , 0, 0, 0,  ,  , 0, 100, -1, None, None,  ,  , None, None, None, None, 2021-09-21 08:15:02.317000,  )
# ( 32785712, 4, 0, 0, 5A SF VOTE,  , Nudelman Leann,  , 38122, 1, 0, 2021-09-15 10:00:00.130000, 2021-09-15 10:00:00.130000, 2021-09-22 08:15:02.317000, 2021-09-21 08:15:02.317000, 0, 0, 0, 2021,  , 0, 0, 0,  ,  , 0, 100, -1, None, None,  ,  , None, None, None, None, 2021-09-21 08:15:02.317000,  )
# =============
# ObjectAssignedStatus -- ObjectId
# ObjectId, ObjectType, AssignedStatusId,
# ( 38122, 83, 12040856,  )
# =============
# StatusLog -- ObjectId
# Order1, ObjectId, ObjectType, To_status, Log_date, Commentt, UserLastName, UserFirstName,
# ( 15776753, 38122, 83, 1, 2021-11-26 14:34:44.970000, Created, ADMIN, ,  )
# =============

# %%
hunt_db("33949540")
# Out:
# CurrentlyOpenedTitles TitleId 4
# Titles_ExFields Title_id 1
# TitleDataDictInteger TitleId 33
# TitleDataDictString TitleId 28
# TitleDataDictDateTime TitleId 2
# TitleDataDictText TitleId 2
# items clock_id 136
# resourceReservations clockId 1
# titles_extend title_id 1
# ItemsToBeIndexed Item_id 1
# titles_in_class title_id 1
# titles_references title_id 1
# titles_mix title_id 1
# CreatedModifiedItems Item_id 1
# PlayoutItemsStatus ClockId 87
# clocks clock_id 1
# ObjectStatus ObjectId 1
# titles title_id 1
# StatusLog ObjectId 1
# CurrentlyOpenedTitles -- TitleId
# TitleId, UserId, ClientId, UseStart, LastUseReset,
# ( 33949540, 2082, 7411ff42-b6db-4551-9444-d52eac97540f, 2021-11-30 06:32:52.733000, 2021-11-30 20:02:22.703000,  )
# ( 33949540, 2123, 4ff4e160-4352-49bf-afd3-69cf74cc3f60, 2021-11-30 19:56:25.070000, 2021-11-30 20:02:25.093000,  )
# ( 33949540, 2205, 2c5e8eb1-0add-4635-acce-0e7e9aab7286, 2021-11-30 17:32:31.667000, 2021-11-30 20:02:01.637000,  )
# ( 33949540, 2304, 13546b0d-5b6f-4eb2-b861-b76a7ff6ce6b, 2021-11-30 04:44:26.347000, 2021-11-30 20:02:00.460000,  )
# =============
# Titles_ExFields -- Title_id
# Title_id, Language_id, Topic, VersionComment,
# ( 33949540, 99, None, None,  )
# =============
# TitleDataDictInteger -- TitleId
# DataField_Id, TitleId, ValueOrder, NumValue,
# ( 647, 33949540, 1, 1,  )
# ( 648, 33949540, 1, 1,  )
# ( 649, 33949540, 1, 1,  )
# ( 650, 33949540, 1, 1,  )
# ( 651, 33949540, 1, 1,  )
# ( 652, 33949540, 1, 1,  )
# ( 653, 33949540, 1, 1,  )
# ( 654, 33949540, 1, 1,  )
# ( 655, 33949540, 1, 1,  )
# ( 656, 33949540, 1, 1,  )
# ( 657, 33949540, 1, 1,  )
# ( 658, 33949540, 1, 1,  )
# ( 659, 33949540, 1, 1,  )
# ( 660, 33949540, 1, 1,  )
# ( 661, 33949540, 1, 1,  )
# ( 662, 33949540, 1, 1,  )
# ( 663, 33949540, 1, 1,  )
# ( 664, 33949540, 1, 1,  )
# ( 665, 33949540, 1, 1,  )
# ( 666, 33949540, 1, 1,  )
# ( 667, 33949540, 1, 1,  )
# ( 668, 33949540, 1, 1,  )
# ( 669, 33949540, 1, 1,  )
# ( 670, 33949540, 1, 1,  )
# ( 671, 33949540, 1, 1,  )
# ( 672, 33949540, 1, 1,  )
# ( 673, 33949540, 1, 1,  )
# ( 674, 33949540, 1, 1,  )
# ( 675, 33949540, 1, 1,  )
# ( 676, 33949540, 1, 1,  )
# ( 677, 33949540, 1, 1,  )
# ( 678, 33949540, 1, 1,  )
# ( 1466, 33949540, 1, 0,  )
# =============
# TitleDataDictString -- TitleId
# DataField_Id, TitleId, ValueOrder, StrValue,
# ( 518, 33949540, 1, Not Specified,  )
# ( 519, 33949540, 1, Not Specified,  )
# ( 1178, 33949540, 1, --,  )
# ( 1213, 33949540, 1, web,  )
# ( 1214, 33949540, 1, 500,  )
# ( 1232, 33949540, 1, --,  )
# ( 1238, 33949540, 1, vid,  )
# ( 1248, 33949540, 1, wabc-wx-vid,  )
# ( 1249, 33949540, 1, _wabc_,  )
# ( 1255, 33949540, 1, True,  )
# ( 1258, 33949540, 1, No,  )
# ( 1259, 33949540, 1, Yes,  )
# ( 1268, 33949540, 1, False,  )
# ( 1269, 33949540, 1, hidden,  )
# ( 1272, 33949540, 1, False,  )
# ( 1309, 33949540, 1, img,  )
# ( 1316, 33949540, 1, -wabc-,  )
# ( 1317, 33949540, 1, -vid,  )
# ( 1330, 33949540, 1, wabc-wx-vid,  )
# ( 1375, 33949540, 1, wpvi-wx-vid,  )
# ( 1376, 33949540, 1, wpvi-wx-vid,  )
# ( 1377, 33949540, 1, wpvi-wx-vid,  )
# ( 1378, 33949540, 1, Default Training,  )
# ( 1526, 33949540, 1, --,  )
# ( 1531, 33949540, 1, kabc-wx-vid,  )
# ( 1574, 33949540, 1, 2 Hours,  )
# ( 1575, 33949540, 1, False,  )
# ( 1588, 33949540, 1, --,  )
# =============
# TitleDataDictDateTime -- TitleId
# DataField_Id, TitleId, ValueOrder, DateValue,
# ( 1250, 33949540, 1, 2021-11-27 21:05:40.077000,  )
# ( 1303, 33949540, 1, 2021-11-27 00:00:00,  )
# =============
# TitleDataDictText -- TitleId
# DataField_Id, TitleId, ValueOrder, TextValue,
# ( 1320, 33949540, 1, STORY=\nADDRESS=\nSTRINGER VIDEO=\nNOTES=\n,  )
# ( 1593, 33949540, 1, Linear,  )
# =============
# items -- clock_id
# block_id, item_id, item_type, item_reference, scheduled_time, computed_time, item_comment, item_order, radio_id, clock_id, use_manual_duration,
# Length items column found...Skipping
# resourceReservations -- clockId
# reservationId, clockId, studioId, stationId, reservedBy, startTime, endTime, status, content, ReservationMode, MediaProfileId, MetadataFormatId,
# ( 63715, 33949540, 1, 1132, STUDIO_ID_1, 2021-11-30 06:59:45.903000, 2021-11-30 07:34:58.947000, 0, <ClockAssignment><descriptionOfUsage t="ws">CLOCK 11PM WEEKDAY assigned to STUDIO_ID_1</descriptionOfUsage><history t="lt"><HistoryElement at.tcd="U2021-11-27T21:06:49.146 TC:60000:1001" status.l="0"><description t="ws">CREATED</description></HistoryElement></history><name t="ws">CLOCK 11PM WEEKDAY</name></ClockAssignment>, 0, None, None,  )
# =============
# titles_extend -- title_id
# title_id, source, reader, read_rate, year_composed, medium, status, custom1, custom2, label_reference, volume_number, oeuvre, act, orchestra, composer, conductor, period, industry, product, language, cut, version, voice, creator,
# ( 33949540,  , 0, 0, 1900, 0, 0,  ,  ,  ,  ,  ,  ,  ,  ,  ,  , 0, 0, ,  , p ,  ,  ,  )
# =============
# ItemsToBeIndexed -- Item_id
# Item_id, Item_type, ModifiedAt, IsInRecycleBin,
# ( 33949540, 2, 2021-11-30 07:31:05.153000, 0,  )
# =============
# titles_in_class -- title_id
# class_id, title_id, is_primary_class, order_in_class,
# ( 38121, 33949540, 1, None,  )
# =============
# titles_references -- title_id
# title_id, reference_id, reference_text,
# ( 33949540, 1, KGO7341881,  )
# =============
# titles_mix -- title_id
# title_id, begin_offset, end_offset, intro1, intro2, outro, fade_in, fade_out, crossfade, is_endless_loop,
# ( 33949540, 0, 0, 0, 0, 0, 0, 0, 0, 0,  )
# =============
# CreatedModifiedItems -- Item_id
# Item_id, Item_type, CreatedBy, ModifiedBy, CreatedAt, ModifiedAt, CreatedByName, ModifiedByName, IsInRecycleBin,
# ( 33949540, 2, 1915, 1962, 2021-11-27 21:05:40.203000, 2021-11-30 07:31:05.153000, KGO DaletService, Burns Emily, 0,  )
# =============
# PlayoutItemsStatus -- ClockId
# ClockId, ItemId, DeviceType, DeviceId, Content,
# ( 33949540, 33949540:1000089406, ShowTimeTrackingProgramInfo, ShowTimeTracking, <ShowTimeTrackingProgramInfo actualAiredStartTime.td="2021-11-30T06:59:51.453" onairStatus.l="0" startTrackWithBeginTime.l="0" trackUserId.l="-1" triggerStatus.l="1"/>,  )
# ( 33949540, 33949540:1000089406:2007261, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedStartTime.td="2021-11-30T06:59:51.453" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089406:2007262, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedStartTime.td="2021-11-30T06:59:51.453" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089406:2007263, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedStartTime.td="2021-11-30T06:59:51.453" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089406:2007264, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedDuration.tp="P8.575233S" airedStartTime.td="2021-11-30T06:59:51.453" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089406:2007265, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedStartTime.td="2021-11-30T07:00:00.029" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089406:2007266, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedStartTime.td="2021-11-30T07:00:00.029" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089406:2007267, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedDuration.tp="P1:1.344616S" airedStartTime.td="2021-11-30T07:00:00.029" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089406:2007268, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedStartTime.td="2021-11-30T07:01:01.375" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089406:2007269, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedDuration.tp="P30.180150S" airedStartTime.td="2021-11-30T07:01:01.375" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089407:2007273, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedDuration.tp="P6.623283S" airedStartTime.td="2021-11-30T07:01:31.560" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089407:
ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedStartTime.td="2021-11-30T07:24:53.583" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089409:2018827, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedDuration.tp="P29.379350S" airedStartTime.td="2021-11-30T07:24:24.211" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089409:2018828, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedStartTime.td="2021-11-30T07:24:53.583" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089409:2018829, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedStartTime.td="2021-11-30T07:24:24.211" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089409:2018967, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedDuration.tp="P16.466450S" airedStartTime.td="2021-11-30T07:24:07.745" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089410:2007315, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedDuration.tp="P3:21.951750S" airedStartTime.td="2021-11-30T07:30:57.594" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089410:2018794, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedDuration.tp="P2:31.801649S" airedStartTime.td="2021-11-30T07:28:25.799" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089411:2007318, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedStartTime.td="2021-11-30T07:34:52.174" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089411:2007319, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedDuration.tp="P10.910899S" airedStartTime.td="2021-11-30T07:34:52.174" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# ( 33949540, 33949540:1000089411:2018901, ShowTimeTrackingItemInfo, ShowTimeTracking, <ShowTimeTrackingItemInfo airedDuration.tp="P32.632600S" airedStartTime.td="2021-11-30T07:34:19.542" automationLock.l="0" currentStory2Offset.tc="P0.000S" isCurrTrackItem.l="0"/>,  )
# =============
# clocks -- clock_id
# clock_id, radio_id, clock_date, block_id, end_time, clock_reference, clock_comment, clock_duration, ruleset_id, DefaultCatId, ArchiveReadOnly, VizrtConcept, KillDateOffset, IsToArchive, isNumbering, IsInRecycleBin,
# ( 33949540, 1132, 2021-11-30 06:59:45.903000, 1000089406, 2021-11-30 07:34:58.947000,  , <Block blockStartMode.l="2" enteredDateTime.td="2021-02-09T01:23:47.145" fromBlockTemplateID.l="-1" fromPlanningEvent.l="-1" hold.l="0" loop.l="1" loops.l="0" modifiedBy.l="1" startMode.l="1" timeStretch.b="false" tp.l="1"><regulation t="t"><Regulation/></regulation></Block>, 0, 0, , 0, , 0, 1, 1, 0,  )
# =============
# ObjectStatus -- ObjectId
# ObjectId, ObjectType, Status_id,
# ( 33949540, 82, 1,  )
# =============
# titles -- title_id
# title_id, title_type_id, title_interface_id, user_id, title, interpret, author, client, duration, is_online, is_recorded, record_date, start_date, end_date, kill_date, audio_duration, use_manual_duration, soundfile_id, year, keywords, site_origin, no_overwrite, is_rotational_cart, replacement, last_words, is_opener, weight, beats_pm, master_record, compagny_id, compagny_disp_name, album_disp_name, package_id, album_id, song_id, day_part_rest_id, keep_date,
# ( 33949540, 25, 0, 0, 11PM WEEKDAY,  , KGO DaletService, , 2113044, 1, 0, 2021-11-27 21:05:40.053000, 2021-11-27 21:05:40.053000, 9999-12-31 08:00:00, 9999-12-31 08:00:00, 0, 0, 0, 2021,  , 0, 0, 0,  ,  , 0, 100, -1, None, None,  ,  , None, None, None, None, 9999-12-31 08:00:00,  )
# =============
# StatusLog -- ObjectId
# Order1, ObjectId, ObjectType, To_status, Log_date, Commentt, UserLastName, UserFirstName,
# ( 15791601, 33949540, 82, 1, 2021-11-27 21:05:40.210000, Create, ADMIN, ,  )
# =============

# %%
#//*** Hunt for ParentID. Current theory is this is an ID that represents a Day's
#//*** worth of stories

hunt_db("38122")
# Out:
# items item_order 3
# AccessRights Object_id 12
# titles_in_class class_id 2052
# classes class_id 1
# class_tree child_class_id 1
# ObjectStatus ObjectId 1
# titles duration 2
# ObjectAssignedStatus ObjectId 1
# StatusLog ObjectId 1
# items -- item_order
# block_id, item_id, item_type, item_reference, scheduled_time, computed_time, item_comment, item_order, radio_id, clock_id, use_manual_duration,
# ( 1000060653, 967984, 3,  , 2021-04-17 11:59:59.980000, 2021-04-17 11:59:59.980000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" mode.l="0" startMode.l="1"/>, 38122, 1132, 30338778, 0,  )
# ( 1000066690, 1173908, 1,  , 2021-06-01 22:58:45.937000, 2021-06-01 22:58:45.937000, <Story mode.l="0" orderPageNumber.l="15" startMode.l="1" tp.l="1"><custom10 t="ws">00:00:12 "more affordably"</custom10><custom3 t="ws">cj4p</custom3><pageNumber t="ws">D15</pageNumber></Story>, 38122, 1132, 31067970, 0,  )
# ( 1000074549, 1473179, 1,  , 2021-08-03 22:58:45.937000, 2021-08-03 22:58:45.937000, <Story mode.l="0" orderPageNumber.l="8" startMode.l="1" tp.l="1"><pageNumber t="ws">F8</pageNumber></Story>, 38122, 1132, 32083170, 0,  )
# =============
# AccessRights -- Object_id
# Object_id, ObjectType, group_id, ViewItems, InsertItems, RemoveItems, ViewContainers, InsertContainers, RemoveContainers, ChangeRights,
# ( 38122, 7, 9, 1, 1, 1, 1, 1, 1, 0,  )
# ( 38122, 7, 83, 1, 0, 0, 1, 0, 0, 0,  )
# ( 38122, 7, 148, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 149, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 166, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 169, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 170, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 438, 1, 0, 0, 1, 0, 0, 0,  )
# ( 38122, 7, 623, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 2422, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 2424, 1, 1, 1, 1, 1, 0, 0,  )
# ( 38122, 7, 2425, 1, 1, 1, 1, 1, 0, 0,  )
# =============
# titles_in_class -- class_id
# class_id, title_id, is_primary_class, order_in_class,
# ( 38122, 33936610, 1, None,  )
# ( 38122, 33936619, 1, None,  )
# ( 38122, 33936625, 1, None,  )
# ( 38122, 33936628, 1, None,  )
# ( 38122, 33936634, 1, None,  )
# ( 38122, 33936636, 1, None,  )
# ( 38122, 33936644, 1, None,  )
# ( 38122, 33936653, 1, None,  )
# ( 38122, 33936662, 1, None,  )
# ( 38122, 33936669, 1, None,  )
# ( 38122, 33936671, 1, None,  )
# ( 38122, 33936673, 1, None,  )
# ( 38122, 33936681, 1, None,  )
# ( 38122, 33936684, 1, None,  )
# ( 38122, 33936688, 1, None,  )
# ( 38122, 33936690, 1, None,  )
# ( 38122, 33936696, 1, None,  )
# ( 38122, 33936699, 1, None,  )
# ( 38122, 33936703, 1, None,  )
# ( 38122, 33936706, 1, None,  )
# ( 38122, 33936712, 1, None,  )
# ( 38122, 33936714, 1, None,  )
# ( 38122, 33936722, 1, None,  )
# ( 38122, 33936725, 1, None,  )
# ( 38122, 33936729, 1, None,  )
# ( 38122, 33936731, 1, None,  )
# ( 38122, 33936738, 1, None,  )
# ( 38122, 33936740, 1, None,  )
# ( 38122, 33936749, 1, None,  )
# ( 38122, 33936751, 1, None,  )
# ( 38122, 33936758, 1, None,  )
# ( 38122, 33936760, 1, None,  )
# ( 38122, 33936763, 1, None,  )
# ( 38122, 33936765, 1, None,  )
# ( 38122, 33936771, 1, None,  )
# ( 38122, 33936779, 1, None,  )
# ( 38122, 33951810, 1, None,  )
# ( 38122, 33951814, 1, None,  )
# ( 38122, 33951818, 1, None,  )
# ( 38122, 33951820, 1, None,  )
# ( 38122, 33951822, 1, None,  )
# ( 38122, 33951824, 1, None,  )
# ( 38122, 33951826, 1, None,  )
# ( 38122, 33951829, 1, None,  )
# ( 38122, 33951831, 1, None,  )
# ( 38122, 33951833, 1, None,  )
# ( 38122, 33951835, 1, None,  )
# ( 38122, 33951836, 1, None,  )
# ( 38122, 33951837, 1, None,  )
# ( 38122, 33951845, 1, None,  )
# ( 38122, 33951858, 1, None,  )
# ( 38122, 33951866, 1, None,  )
# ( 38122, 33951872, 1, None,  )
# ( 38122, 33951876, 1, None,  )
# ( 38122, 33951880, 1, None,  )
# ( 38122, 33951884, 1, None,  )
# ( 38122, 33951889, 1, None,  )
# ( 38122, 33951893, 1, None,  )
# ( 38122, 33951900, 1, None,  )
# ( 38122, 33951901, 1, None,  )
# ( 38122, 33951908, 1, None,  )
# ( 38122, 33951921, 1, None,  )
# ( 38122, 33951929, 1, None,  )
# ( 38122, 33951935, 1, None,  )
# ( 38122, 33951939, 1, None,  )
# ( 38122, 33951943, 1, None,  )
# ( 38122, 33951947, 1, None,  )
# ( 38122, 33951952, 1, None,  )
# ( 38122, 33951956, 1, None,  )
# ( 38122, 33951963, 1, None,  )
# ( 38122, 33951964, 1, None,  )
# ( 38122, 33951971, 1, None,  )
# ( 38122, 33951984, 1, None,  )
# ( 38122, 33951992, 1, None,  )
# ( 38122, 33951998, 1, None,  )
# ( 38122, 33952002, 1, None,  )
# ( 38122, 33952006, 1, None,  )
# ( 38122, 33952010, 1, None,  )
# ( 38122, 33952015, 1, None,  )
# ( 38122, 33952019, 1, None,  )
# ( 38122, 33952026, 1, None,  )
# ( 38122, 33952027, 1, None,  )
# ( 38122, 33952034, 1, None,  )
# ( 38122, 33952047, 1, None,  )
# ( 38122, 33952055, 1, None,  )
# ( 38122, 33952061, 1, None,  )
# ( 38122, 33952065, 1, None,  )
# ( 38122, 33952069, 1, None,  )
# ( 38122, 33952073, 1, None,  )
# ( 38122, 33952078, 1, None,  )
# ( 38122, 33952082, 1, None,  )
# ( 38122, 33952090, 1, None,  )
# ( 38122, 33952091, 1, None,  )
# ( 38122, 33952098, 1, None,  )
# ( 38122, 33952111, 1, None,  )
# ( 38122, 33952119, 1, None,  )
# ( 38122, 33952125, 1, None,  )
# ( 38122, 33952129, 1, None,  )
# ( 38122, 33952133, 1, None,  )
# ( 38122, 33952137, 1, None,  )
# ( 38122, 33952142, 1, None,  )
# ( 38122, 33952146, 1, None,  )
# ( 38122, 33952153, 1, None,  )
# ( 38122, 33952154, 1, None,  )
# ( 38122, 33952161, 1, None,  )
# ( 38122, 33952174, 1, None,  )
# ( 38122, 33952182, 1, None,  )
# ( 38122, 33952188, 1, None,  )
# ( 38122, 33952192, 1, None,  )
# ( 38122, 33952196, 1, None,  )
# ( 38122, 33952200, 1, None,  )
# ( 38122, 33952205, 1, None,  )
# ( 38122, 33952209, 1, None,  )
# ( 38122, 33952216, 1, None,  )
# ( 38122, 33952217, 1, None,  )
# ( 38122, 33952220, 1, None,  )
# ( 38122, 33952223, 1, None,  )
# ( 38122, 33952226, 1, None,  )
# ( 38122, 33952233, 1, None,  )
# ( 38122, 33952234, 1, None,  )
# ( 38122, 33952238, 1, None,  )
# ( 38122, 33952239, 1, None,  )
# ( 38122, 33952240, 1, None,  )
# ( 38122, 33952242, 1, None,  )
# ( 38122, 33952245, 1, None,  )
# ( 38122, 33952248, 1, None,  )
# ( 38122, 33952251, 1, None,  )
# ( 38122, 33952252, 1, None,  )
# ( 38122, 33952253, 1, None,  )
# ( 38122, 33952260, 1, None,  )
# ( 38122, 33952261, 1, None,  )
# ( 38122, 33952262, 1, None,  )
# ( 38122, 33952263, 1, None,  )
# ( 38122, 33952264, 1, None,  )
# ( 38122, 33952265, 1, None,  )
# ( 38122, 33952266, 1, None,  )
# ( 38122, 33952267, 1, None,  )
# ( 38122, 33952273, 1, None,  )
# ( 38122, 33952274, 1, None,  )
# ( 38122, 33952275, 1, None,  )
# ( 38122, 33952277, 1, None,  )
# ( 38122, 33952278, 1, None,  )
# ( 38122, 33952279, 1, None,  )
# ( 38122, 33952280, 1, None,  )
# ( 38122, 33952281, 1, None,  )
# ( 38122, 33952282, 1, None,  )
# ( 38122, 33952283, 1, None,  )
# ( 38122, 33953833, 1, None,  )
# ( 38122, 33953835, 1, None,  )
# ( 38122, 33954018, 1, None,  )
# ( 38122, 33954490, 1, None,  )
# ( 38122, 33966504, 1, None,  )
# ( 38122, 33966509, 1, None,  )
# ( 38122, 33966510, 1, None,  )
# ( 38122, 33966515, 1, None,  )
# ( 38122, 33966518, 1, None,  )
# ( 38122, 33966522, 1, None,  )
# ( 38122, 33966531, 1, None,  )
# ( 38122, 33966537, 1, None,  )
# ( 38122, 33966539, 1, None,  )
# ( 38122, 33966543, 1, None,  )
# ( 38122, 33966548, 1, None,  )
# ( 38122, 33966552, 1, None,  )
# ( 38122, 33966554, 1, None,  )
# ( 38122, 33966556, 1, None,  )
# ( 38122, 33966560, 1, None,  )
# ( 38122, 33966564, 1, None,  )
# ( 38122, 33966570, 1, None,  )
# ( 38122, 33966572, 1, None,  )
# ( 38122, 33966575, 1, None,  )
# ( 38122, 33966577, 1, None,  )
# ( 38122, 33966579, 1, None,  )
# ( 38122, 33966585, 1, None,  )
# ( 38122, 33966591, 1, None,  )
# ( 38122, 33966593, 1, None,  )
# ( 38122, 33966597, 1, None,  )
# ( 38122, 33966599, 1, None,  )
# ( 38122, 33966603, 1, None,  )
# ( 38122, 33966605, 1, None,  )
# ( 38122, 33966607, 1, None,  )
# ( 38122, 33966611, 1, None,  )
# ( 38122, 33966613, 1, None,  )
# ( 38122, 33966617, 1, None,  )
# ( 38122, 33966619, 1, None,  )
# ( 38122, 33966623, 1, None,  )
# ( 38122, 33966625, 1, None,  )
# ( 38122, 33966629, 1, None,  )
# ( 38122, 33966632, 1, None,  )
# ( 38122, 33966634, 1, None,  )
# ( 38122, 33966637, 1, None,  )
# ( 38122, 33966643, 1, None,  )
# ( 38122, 33966645, 1, None,  )
# ( 38122, 33966649, 1, None,  )
# ( 38122, 33966651, 1, None,  )
# ( 38122, 33966654, 1, None,  )
# ( 38122, 33966670, 1, None,  )
# ( 38122, 33966679, 1, None,  )
# ( 38122, 33966770, 1, None,  )
# ( 38122, 33966773, 1, None,  )
# ( 38122, 33966778, 1, None,  )
# ( 38122, 33966796, 1, None,  )
# ( 38122, 33966799, 1, None,  )
# ( 38122, 33966803, 1, None,  )
# ( 38122, 33966805, 1, None,  )
# ( 38122, 33967449, 1, None,  )
# ( 38122, 33967452, 1, None,  )
# ( 38122, 33967455, 1, None,  )
# ( 38122, 33967460, 1, None,  )
# ( 38122, 33967469, 1, None,  )
# ( 38122, 33967503, 1, None,  )
# ( 38122, 33967505, 1, None,  )
# ( 38122, 33967507, 1, None,  )
# ( 38122, 33967511, 1, None,  )
# ( 38122, 33967517, 1, None,  )
# ( 38122, 33967521, 1, None,  )
# ( 38122, 33967523, 1, None,  )
# ( 38122, 33967526, 1, None,  )
# ( 38122, 33967528, 1, None,  )
# ( 38122, 33967532, 1, None,  )
# ( 38122, 33967537, 1, None,  )
# ( 38122, 33967539, 1, None,  )
# ( 38122, 33967541, 1, None,  )
# ( 38122, 33967542, 1, None,  )
# ( 38122, 33967552, 1, None,  )
# ( 38122, 33967556, 1, None,  )
# ( 38122, 33967559, 1, None,  )
# ( 38122, 33967561, 1, None,  )
# ( 38122, 33967569, 1, None,  )
# ( 38122, 33967571, 1, None,  )
# ( 38122, 33967573, 1, None,  )
# ( 38122, 33967575, 1, None,  )
# ( 38122, 33967579, 1, None,  )
# ( 38122, 33967581, 1, None,  )
# ( 38122, 33967586, 1, None,  )
# ( 38122, 33967588, 1, None,  )
# ( 38122, 33967592, 1, None,  )
# ( 38122, 33967594, 1, None,  )
# ( 38122, 33967603, 1, None,  )
# ( 38122, 33967607, 1, None,  )
# ( 38122, 33967609, 1, None,  )
# ( 38122, 33967613, 1, None,  )
# ( 38122, 33967615, 1, None,  )
# ( 38122, 33967619, 1, None,  )
# ( 38122, 33967623, 1, None,  )
# ( 38122, 33967631, 1, None,  )
# ( 38122, 33967633, 1, None,  )
# ( 38122, 33967637, 1, None,  )
# ( 38122, 33967643, 1, None,  )
# ( 38122, 33967652, 1, None,  )
# ( 38122, 33967654, 1, None,  )
# ( 38122, 33967657, 1, None,  )
# ( 38122, 33967659, 1, None,  )
# ( 38122, 33967703, 1, None,  )
# ( 38122, 33967705, 1, None,  )
# ( 38122, 33967727, 1, None,  )
# ( 38122, 33967753, 1, None,  )
# ( 38122, 33967754, 1, None,  )
# ( 38122, 33967765, 1, None,  )
# ( 38122, 33967771, 1, None,  )
# ( 38122, 33967773, 1, None,  )
# ( 38122, 33967775, 1, None,  )
# ( 38122, 33967784, 1, None,  )
# ( 38122, 33967789, 1, None,  )
# ( 38122, 33967793, 1, None,  )
# ( 38122, 33967797, 1, None,  )
# ( 38122, 33967799, 1, None,  )
# ( 38122, 33974301, 1, None,  )
# ( 38122, 33974311, 1, None,  )
# ( 38122, 33974336, 1, None,  )
# ( 38122, 33974347, 1, None,  )
# ( 38122, 33974351, 1, None,  )
# ( 38122, 33974353, 1, None,  )
# ( 38122, 33974369, 1, None,  )
# ( 38122, 33974423, 1, None,  )
# ( 38122, 33974440, 1, None,  )
# ( 38122, 33974459, 1, None,  )
# ( 38122, 33974519, 1, None,  )
# ( 38122, 33974522, 1, None,  )
# ( 38122, 33974541, 1, None,  )
# ( 38122, 33974545, 1, None,  )
# ( 38122, 33974548, 1, None,  )
# ( 38122, 33974550, 1, None,  )
# ( 38122, 33974561, 1, None,  )
# ( 38122, 33974575, 1, None,  )
# ( 38122, 33974589, 1, None,  )
# ( 38122, 33974592, 1, None,  )
# ( 38122, 33974643, 1, None,  )
# ( 38122, 33974645, 1, None,  )
# ( 38122, 33974647, 1, None,  )
# ( 38122, 33974653, 1, None,  )
# ( 38122, 33974657, 1, None,  )
# ( 38122, 33974965, 1, None,  )
# ( 38122, 33975132, 1, None,  )
# ( 38122, 33975145, 1, None,  )
# ( 38122, 33975151, 1, None,  )
# ( 38122, 33975155, 1, None,  )
# ( 38122, 33975162, 1, None,  )
# ( 38122, 33975175, 1, None,  )
# ( 38122, 33975182, 1, None,  )
# ( 38122, 33975196, 1, None,  )
# ( 38122, 33975198, 1, None,  )
# ( 38122, 33975200, 1, None,  )
# ( 38122, 33975202, 1, None,  )
# ( 38122, 33975204, 1, None,  )
# ( 38122, 33975206, 1, None,  )
# ( 38122, 33975207, 1, None,  )
# ( 38122, 33975212, 1, None,  )
# ( 38122, 33975213, 1, None,  )
# ( 38122, 33975216, 1, None,  )
# ( 38122, 33975235, 1, None,  )
# ( 38122, 33975236, 1, None,  )
# ( 38122, 33975238, 1, None,  )
# ( 38122, 33975240, 1, None,  )
# ( 38122, 33975243, 1, None,  )
# ( 38122, 33975245, 1, None,  )
# ( 38122, 33975247, 1, None,  )
# ( 38122, 33975248, 1, None,  )
# ( 38122, 33975250, 1, None,  )
# ( 38122, 33975253, 1, None,  )
# ( 38122, 33975255, 1, None,  )
# ( 38122, 33975257, 1, None,  )
# ( 38122, 33975259, 1, None,  )
# ( 38122, 33975261, 1, None,  )
# ( 38122, 33975262, 1, None,  )
# ( 38122, 33975263, 1, None,  )
# ( 38122, 33975276, 1, None,  )
# ( 38122, 33975297, 1, None,  )
# ( 38122, 33975300, 1, None,  )
# ( 38122, 33975321, 1, None,  )
# ( 38122, 33975325, 1, None,  )
# ( 38122, 33975353, 1, None,  )
# ( 38122, 33975357, 1, None,  )
# ( 38122, 33975358, 1, None,  )
# ( 38122, 33975366, 1, None,  )
# ( 38122, 33975372, 1, None,  )
# ( 38122, 33975374, 1, None,  )
# ( 38122, 33975375, 1, None,  )
# ( 38122, 33975388, 1, None,  )
# ( 38122, 33975396, 1, None,  )
# ( 38122, 33975402, 1, None,  )
# ( 38122, 33975407, 1, None,  )
# ( 38122, 33975411, 1, None,  )
# ( 38122, 33975415, 1, None,  )
# ( 38122, 33975420, 1, None,  )
# ( 38122, 33975424, 1, None,  )
# ( 38122, 33975430, 1, None,  )
# ( 38122, 33975438, 1, None,  )
# ( 38122, 33975451, 1, None,  )
# ( 38122, 33975460, 1, None,  )
# ( 38122, 33975468, 1, None,  )
# ( 38122, 33975469, 1, None,  )
# ( 38122, 33975472, 1, None,  )
# ( 38122, 33975475, 1, None,  )
# ( 38122, 33975477, 1, None,  )
# ( 38122, 33975478, 1, None,  )
# ( 38122, 33975481, 1, None,  )
# ( 38122, 33975488, 1, None,  )
# ( 38122, 33975491, 1, None,  )
# ( 38122, 33975501, 1, None,  )
# ( 38122, 33975503, 1, None,  )
# ( 38122, 33975509, 1, None,  )
# ( 38122, 33975510, 1, None,  )
# ( 38122, 33975511, 1, None,  )
# ( 38122, 33975513, 1, None,  )
# ( 38122, 33975515, 1, None,  )
# ( 38122, 33975516, 1, None,  )
# ( 38122, 33975518, 1, None,  )
# ( 38122, 33975524, 1, None,  )
# ( 38122, 33975529, 1, None,  )
# ( 38122, 33975531, 1, None,  )
# ( 38122, 33975533, 1, None,  )
# ( 38122, 33975534, 1, None,  )
# ( 38122, 33975538, 1, None,  )
# ( 38122, 33975543, 1, None,  )
# ( 38122, 33975544, 1, None,  )
# ( 38122, 33975547, 1, None,  )
# ( 38122, 33975549, 1, None,  )
# ( 38122, 33975551, 1, None,  )
# ( 38122, 33975555, 1, None,  )
# ( 38122, 33975570, 1, None,  )
# ( 38122, 33975576, 1, None,  )
# ( 38122, 33975582, 1, None,  )
# ( 38122, 33975586, 1, None,  )
# ( 38122, 33975588, 1, None,  )
# ( 38122, 33975601, 1, None,  )
# ( 38122, 33975603, 1, None,  )
# ( 38122, 33975609, 1, None,  )
# ( 38122, 33975615, 1, None,  )
# ( 38122, 33975621, 1, None,  )
# ( 38122, 33975637, 1, None,  )
# ( 38122, 33975640, 1, None,  )
# ( 38122, 33975654, 1, None,  )
# ( 38122, 33975658, 1, None,  )
# ( 38122, 33975660, 1, None,  )
# ( 38122, 33975673, 1, None,  )
# ( 38122, 33975676, 1, None,  )
# ( 38122, 33975679, 1, None,  )
# ( 38122, 33975683, 1, None,  )
# ( 38122, 33975687, 1, None,  )
# ( 38122, 33975699, 1, None,  )
# ( 38122, 33975720, 1, None,  )
# ( 38122, 33975726, 1, None,  )
# ( 38122, 33975738, 1, None,  )
# ( 38122, 33975747, 1, None,  )
# ( 38122, 33975749, 1, None,  )
# ( 38122, 33975751, 1, None,  )
# ( 38122, 33975789, 1, None,  )
# ( 38122, 33975840, 1, None,  )
# ( 38122, 33975842, 1, None,  )
# ( 38122, 33975899, 1, None,  )
# ( 38122, 33975901, 1, None,  )
# ( 38122, 33975928, 1, None,  )
# ( 38122, 33975940, 1, None,  )
# ( 38122, 33975942, 1, None,  )
# ( 38122, 33975957, 1, None,  )
# ( 38122, 33975966, 1, None,  )
# ( 38122, 33975968, 1, None,  )
# ( 38122, 33975980, 1, None,  )
# ( 38122, 33976040, 1, None,  )
# ( 38122, 33982340, 1, None,  )
# ( 38122, 33982352, 1, None,  )
# ( 38122, 33982701, 1, None,  )
# ( 38122, 33982723, 1, None,  )
# ( 38122, 33982726, 1, None,  )
# ( 38122, 33982936, 1, None,  )
# ( 38122, 33983026, 1, None,  )
# ( 38122, 33983035, 1, None,  )
# ( 38122, 33983042, 1, None,  )
# ( 38122, 33983050, 1, None,  )
# ( 38122, 33983057, 1, None,  )
# ( 38122, 33983062, 1, None,  )
# ( 38122, 33983069, 1, None,  )
# ( 38122, 33983093, 1, None,  )
# ( 38122, 33983098, 1, None,  )
# ( 38122, 33983101, 1, None,  )
# ( 38122, 33983123, 1, None,  )
# ( 38122, 33983126, 1, None,  )
# ( 38122, 33983130, 1, None,  )
# ( 38122, 33983141, 1, None,  )
# ( 38122, 33983146, 1, None,  )
# ( 38122, 33983149, 1, None,  )
# ( 38122, 33983155, 1, None,  )
# ( 38122, 33983160, 1, None,  )
# ( 38122, 33983254, 1, None,  )
# ( 38122, 33983259, 1, None,  )
# ( 38122, 33983310, 1, None,  )
# ( 38122, 33983313, 1, None,  )
# ( 38122, 33983385, 1, None,  )
# ( 38122, 33983387, 1, None,  )
# ( 38122, 33983389, 1, None,  )
# ( 38122, 33983408, 1, None,  )
# ( 38122, 33983472, 1, None,  )
# ( 38122, 33983511, 1, None,  )
# ( 38122, 33983513, 1, None,  )
# ( 38122, 33983515, 1, None,  )
# ( 38122, 33983516, 1, None,  )
# ( 38122, 33983546, 1, None,  )
# ( 38122, 33983549, 1, None,  )
# ( 38122, 33983651, 1, None,  )
# ( 38122, 33983657, 1, None,  )
# ( 38122, 33983661, 1, None,  )
# ( 38122, 33983663, 1, None,  )
# ( 38122, 33983666, 1, None,  )
# ( 38122, 33983670, 1, None,  )
# ( 38122, 33983672, 1, None,  )
# ( 38122, 33983678, 1, None,  )
# ( 38122, 33983680, 1, None,  )
# ( 38122, 33983685, 1, None,  )
# ( 38122, 33983700, 1, None,  )
# ( 38122, 33983705, 1, None,  )
# ( 38122, 33983755, 1, None,  )
# ( 38122, 33983758, 1, None,  )
# ( 38122, 33983761, 1, None,  )
# ( 38122, 33983773, 1, None,  )
# ( 38122, 33983778, 1, None,  )
# ( 38122, 33984156, 1, None,  )
# ( 38122, 33984162, 1, None,  )
# ( 38122, 33984489, 1, None,  )
# ( 38122, 33984713, 1, None,  )
# ( 38122, 33984714, 1, None,  )
# =============
# classes -- class_id
# class_id, code, long_name, short_name, description, color, n_child, level_code, killdate_offset, sort_field_id1, sort_field_id2, sort_field_id3, sort_direction, access_rights, endkill_offset, titles_mean_duration, record_limitation, full_name, keepdate_offset, SubCategorySorting, is_running_order, read_rate, SystemClass,
# ( 38122, SRDC, 2021/11/29, 2021/11/29, 2021/11/29, -1, 0, , 5, 0, 0, 0, 0, 111111111, 1, 210000, 0, CATEGORIES/KGO Rundowns/KGO_NEWS Rundowns/2021/11/29, 0, 0, 0, None, None,  )
# =============
# class_tree -- child_class_id
# parent_class_id, child_class_id, class_order,
# ( 31804, 38122, 0,  )
# =============
# ObjectStatus -- ObjectId
# ObjectId, ObjectType, Status_id,
# ( 38122, 83, 1,  )
# =============
# titles -- duration
# title_id, title_type_id, title_interface_id, user_id, title, interpret, author, client, duration, is_online, is_recorded, record_date, start_date, end_date, kill_date, audio_duration, use_manual_duration, soundfile_id, year, keywords, site_origin, no_overwrite, is_rotational_cart, replacement, last_words, is_opener, weight, beats_pm, master_record, compagny_id, compagny_disp_name, album_disp_name, package_id, album_id, song_id, day_part_rest_id, keep_date,
# ( 32781723, 4, 0, 0, 5A SF VOTE,  , Nudelman Leann, , 38122, 1, 0, 2021-09-15 06:20:57.627000, 2021-09-15 06:20:57.627000, 2021-09-22 08:15:02.317000, 2021-09-21 08:15:02.317000, 0, 0, 0, 2021,  , 0, 0, 0,  ,  , 0, 100, -1, None, None,  ,  , None, None, None, None, 2021-09-21 08:15:02.317000,  )
# ( 32785712, 4, 0, 0, 5A SF VOTE,  , Nudelman Leann,  , 38122, 1, 0, 2021-09-15 10:00:00.130000, 2021-09-15 10:00:00.130000, 2021-09-22 08:15:02.317000, 2021-09-21 08:15:02.317000, 0, 0, 0, 2021,  , 0, 0, 0,  ,  , 0, 100, -1, None, None,  ,  , None, None, None, None, 2021-09-21 08:15:02.317000,  )
# =============
# ObjectAssignedStatus -- ObjectId
# ObjectId, ObjectType, AssignedStatusId,
# ( 38122, 83, 12040856,  )
# =============
# StatusLog -- ObjectId
# Order1, ObjectId, ObjectType, To_status, Log_date, Commentt, UserLastName, UserFirstName,
# ( 15776753, 38122, 83, 1, 2021-11-26 14:34:44.970000, Created, ADMIN, ,  )
# =============

# %%
#//**** Hunt: Rundown
hunt_db("33998001",items=True)
# Out:
# Titles_ExFields Title_id 1
# TitleDataDictInteger TitleId 33
# TitleDataDictString TitleId 28
# TitleDataDictDateTime TitleId 2
# TitleDataDictText TitleId 2
# items clock_id 143
# resourceReservations clockId 1
# titles_extend title_id 1
# ItemsToBeIndexed Item_id 1
# titles_in_class title_id 1
# titles_references title_id 1
# titles_mix title_id 1
# CreatedModifiedItems Item_id 1
# clocks clock_id 1
# ObjectStatus ObjectId 1
# titles title_id 1
# StatusLog ObjectId 1
# Titles_ExFields -- Title_id
# Title_id, Language_id, Topic, VersionComment,
# Table
# ( 33998001, 99, None, None,  )
# =============
# TitleDataDictInteger -- TitleId
# DataField_Id, TitleId, ValueOrder, NumValue,
# Table
# ( 647, 33998001, 1, 1,  )
# ( 648, 33998001, 1, 1,  )
# ( 649, 33998001, 1, 1,  )
# ( 650, 33998001, 1, 1,  )
# ( 651, 33998001, 1, 1,  )
# ( 652, 33998001, 1, 1,  )
# ( 653, 33998001, 1, 1,  )
# ( 654, 33998001, 1, 1,  )
# ( 655, 33998001, 1, 1,  )
# ( 656, 33998001, 1, 1,  )
# ( 657, 33998001, 1, 1,  )
# ( 658, 33998001, 1, 1,  )
# ( 659, 33998001, 1, 1,  )
# ( 660, 33998001, 1, 1,  )
# ( 661, 33998001, 1, 1,  )
# ( 662, 33998001, 1, 1,  )
# ( 663, 33998001, 1, 1,  )
# ( 664, 33998001, 1, 1,  )
# ( 665, 33998001, 1, 1,  )
# ( 666, 33998001, 1, 1,  )
# ( 667, 33998001, 1, 1,  )
# ( 668, 33998001, 1, 1,  )
# ( 669, 33998001, 1, 1,  )
# ( 670, 33998001, 1, 1,  )
# ( 671, 33998001, 1, 1,  )
# ( 672, 33998001, 1, 1,  )
# ( 673, 33998001, 1, 1,  )
# ( 674, 33998001, 1, 1,  )
# ( 675, 33998001, 1, 1,  )
# ( 676, 33998001, 1, 1,  )
# ( 677, 33998001, 1, 1,  )
# ( 678, 33998001, 1, 1,  )
# ( 1466, 33998001, 1, 0,  )
# =============
# TitleDataDictString -- TitleId
# DataField_Id, TitleId, ValueOrder, StrValue,
# Table
# ( 518, 33998001, 1, Not Specified,  )
# ( 519, 33998001, 1, Not Specified,  )
# ( 1178, 33998001, 1, --,  )
# ( 1213, 33998001, 1, web,  )
# ( 1214, 33998001, 1, 500,  )
# ( 1232, 33998001, 1, --,  )
# ( 1238, 33998001, 1, vid,  )
# ( 1248, 33998001, 1, wabc-wx-vid,  )
# ( 1249, 33998001, 1, _wabc_,  )
# ( 1255, 33998001, 1, True,  )
# ( 1258, 33998001, 1, No,  )
# ( 1259, 33998001, 1, Yes,  )
# ( 1268, 33998001, 1, False,  )
# ( 1269, 33998001, 1, hidden,  )
# ( 1272, 33998001, 1, False,  )
# ( 1309, 33998001, 1, img,  )
# ( 1316, 33998001, 1, -wabc-,  )
# ( 1317, 33998001, 1, -vid,  )
# ( 1330, 33998001, 1, wabc-wx-vid,  )
# ( 1375, 33998001, 1, wpvi-wx-vid,  )
# ( 1376, 33998001, 1, wpvi-wx-vid,  )
# ( 1377, 33998001, 1, wpvi-wx-vid,  )
# ( 1378, 33998001, 1, Default Training,  )
# ( 1526, 33998001, 1, --,  )
# ( 1531, 33998001, 1, kabc-wx-vid,  )
# ( 1574, 33998001, 1, 2 Hours,  )
# ( 1575, 33998001, 1, False,  )
# ( 1588, 33998001, 1, --,  )
# =============
# TitleDataDictDateTime -- TitleId
# DataField_Id, TitleId, ValueOrder, DateValue,
# Table
# ( 1250, 33998001, 1, 2021-11-30 21:17:56.497000,  )
# ( 1303, 33998001, 1, 2021-11-30 00:00:00,  )
# =============
# TitleDataDictText -- TitleId
# DataField_Id, TitleId, ValueOrder, TextValue,
# Table
# ( 1320, 33998001, 1, STORY=\nADDRESS=\nSTRINGER VIDEO=\nNOTES=\n,  )
# ( 1593, 33998001, 1, Linear,  )
# =============
# items -- clock_id
# block_id, item_id, item_type, item_reference, scheduled_time, computed_time, item_comment, item_order, radio_id, clock_id, use_manual_duration,
# Table
# ( 1000089923, 2023218, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-27T22:22:58.234" mode.l="0" startMode.l="1" tp.l="1"><custom3 t="ws">$$$$2.0</custom3></Story>, 10000, 1132, 33998001, 0,  )
# ( 1000089923, 2023219, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-13T20:11:43.225" mode.l="0" startMode.l="1" tp.l="1"/>, 20000, 1132, 33998001, 0,  )
# ( 1000089923, 2023220, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-13T23:13:45.783" mode.l="0" startMode.l="1" tp.l="1"/>, 30000, 1132, 33998001, 0,  )
# ( 1000089923, 2023221, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-01T20:05:49.594" mode.l="0" startMode.l="1" tp.l="1"/>, 40000, 1132, 33998001, 0,  )
# ( 1000089923, 2023222, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-01T19:48:17.207" mode.l="0" startMode.l="1" tp.l="1"><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot></spotsStoredFields></Story>, 50000, 1132, 33998001, 0,  )
# ( 1000089923, 2023223, 5,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Block blockStartMode.l="1" enteredDateTime.td="2020-03-13T23:03:14.095" fromBlockTemplateID.l="-1" fromPlanningEvent.l="-1" mode.l="0" scheduledTime.tc="P0.000S TC:60000:1001" startMode.l="1" timeStretch.b="false" tp.l="1"/>, 60000, 1132, 33998001, 0,  )
# ( 1000089924, 2023224, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-13T23:15:51.988" mode.l="0" plannedDuration.tc="P30.030S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">START 5:58:46</custom10><custom2 t="ws">@ TOP</custom2><custom5 t="ws">DAN</custom5></Story>, 10000, 1132, 33998001, 0,  )
# ( 1000089924, 2023225, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T19:31:59.165" mode.l="0" startMode.l="1" tp.l="1"><custom2 t="ws">IW</custom2><custom3 t="ws">$$$$1.0</custom3><custom7 t="ws">*</custom7></Story>, 20000, 1132, 33998001, 0,  )
# ( 1000089924, 2023226, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T23:04:25.489" mode.l="0" startMode.l="1" tp.l="1"><custom10 t="ws">1st Tease Line ONLY</custom10><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">8</itemId></Spot><Spot hold.l="1"><itemId t="ws">10</itemId></Spot><Spot hold.l="1"><itemId t="ws">11</itemId></Spot></spotsStoredFields></Story>, 30000, 1132, 33998001, 0,  )
# ( 1000089924, 2023227, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-04T22:34:39.754" mode.l="0" startMode.l="1" tp.l="1"/>, 40000, 1132, 33998001, 0,  )
# ( 1000089924, 2023228, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T23:04:31.616" mode.l="0" startMode.l="1" tp.l="1"><custom10 t="ws">2nd,3rd,4th, ONLY</custom10><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">10</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot><Spot hold.l="1"><itemId t="ws">8</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">12</itemId></Spot></spotsStoredFields></Story>, 50000, 1132, 33998001, 0,  )
# ( 1000089924, 2023229, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T23:04:37.724" mode.l="0" startMode.l="1" tp.l="1"><custom10 t="ws">2nd,3rd,4th, ONLY</custom10><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">8</itemId></Spot><Spot hold.l="1"><itemId t="ws">10</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot><Spot hold.l="1"><itemId t="ws">12</itemId></Spot></spotsStoredFields></Story>, 60000, 1132, 33998001, 0,  )
# ( 1000089924, 2023230, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-04-14T00:24:06.232" mode.l="0" startMode.l="1"/>, 70000, 1132, 33998001, 0,  )
# ( 1000089924, 2023231, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T20:57:31.471" hold.l="1" mode.l="0" plannedDuration.tc="P5.004999S TC:60000:1001" startMode.l="1" tp.l="1"><custom3 t="ws">$$$$1.0</custom3></Story>, 80000, 1132, 33998001, 0,  )
# ( 1000089924, 2023232, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-25T02:06:43.222" mode.l="0" plannedDuration.tc="P5.004999S TC:60000:1001" startMode.l="1" tp.l="1"/>, 90000, 1132, 33998001, 0,  )
# ( 1000089924, 2023233, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-25T22:41:07.454" mode.l="0" plannedDuration.tc="P15.015S TC:60000:1001" startMode.l="1" tp.l="1"><custom1 t="ws">ac</custom1></Story>, 100000, 1132, 33998001, 0,  )
# ( 1000089924, 2023234, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-13T23:18:25.164" mode.l="0" plannedDuration.tc="P10.009999S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">AD-INTL</custom10><custom2 t="ws">FR 1-1</custom2><custom5 t="ws">A/D</custom5><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">2</itemId></Spot></spotsStoredFields></Story>, 110000, 1132, 33998001, 0,  )
# ( 1000089924, 2023235, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-04T22:34:39.754" mode.l="0" startMode.l="1" tp.l="1"/>, 120000, 1132, 33998001, 0,  )
# ( 1000089924, 2023236, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-04-14T00:24:10.198" mode.l="0" startMode.l="1"/>, 130000, 1132, 33998001, 0,  )
# ( 1000089924, 2023237, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-13T23:18:58.386" mode.l="0" plannedDuration.tc="P30.030S TC:60000:1001" startMode.l="1" tp.l="1"><custom2 t="ws">@TOP</custom2><custom5 t="ws">D/A</custom5></Story>, 140000, 1132, 33998001, 0,  )
# ( 1000089924, 2023238, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T17:55:01.770" mode.l="0" startMode.l="1" tp.l="1"><custom2 t="ws">IW</custom2><custom3 t="ws">$$$$1.0</custom3><custom7 t="ws">*</custom7></Story>, 150000, 1132, 33998001, 0,  )
# ( 1000089924, 2023239, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T23:01:38.897" mode.l="0" startMode.l="1" tp.l="1"><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="0"><itemId t="ws">8</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot><Spot hold.l="1"><itemId t="ws">10</itemId></Spot><Spot hold.l="0"><itemId t="ws">4</itemId></Spot></spotsStoredFields></Story>, 160000, 1132, 33998001, 0,  )
# ( 1000089924, 2023240, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T23:01:45.366" mode.l="0" startMode.l="1" tp.l="1"><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot></spotsStoredFields></Story>, 170000, 1132, 33998001, 0,  )
# ( 1000089924, 2023241, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T23:01:55.251" mode.l="0" startMode.l="1" tp.l="1"><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot></spotsStoredFields></Story>, 180000, 1132, 33998001, 0,  )
# ( 1000089924, 2023242, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:45:44.531" mode.l="0" startMode.l="1" tp.l="1"><custom7 t="ws">*</custom7><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">3</itemId></Spot></spotsStoredFields></Story>, 190000, 1132, 33998001, 0,  )
# ( 1000089924, 2023243, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-13T23:27:29.536" mode.l="0" plannedDuration.tc="P2:30.083266S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">00:02:20?</custom10><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot></spotsStoredFields></Story>, 200000, 1132, 33998001, 0,  )
# ( 1000089923, 2023244, 5,  , 2021-12-03 01:58:55.937000, 2021-12-03 01:58:45.927000, <Block blockStartMode.l="1" enteredDateTime.td="2020-03-13T23:03:14.095" fromBlockTemplateID.l="-1" fromPlanningEvent.l="-1" mode.l="0" scheduledTime.tc="P10.009999S TC:60000:1001" startMode.l="1" timeStretch.b="false" tp.l="1"/>, 70000, 1132, 33998001, 0,  )
# ( 1000089925, 2023245, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-04T22:34:39.754" mode.l="0" startMode.l="1" tp.l="1"/>, 10000, 1132, 33998001, 0,  )
# ( 1000089925, 2023246, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-04-14T00:24:17.006" mode.l="0" startMode.l="1"/>, 20000, 1132, 33998001, 0,  )
# ( 1000089925, 2023247, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:30:56.473" mode.l="0" plannedDuration.tc="P15.015S TC:60000:1001" startMode.l="1" tp.l="1"><custom2 t="ws">@TOP</custom2><custom5 t="ws">A/D</custom5></Story>, 30000, 1132, 33998001, 0,  )
# ( 1000089925, 2023248, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T17:55:01.770" mode.l="0" startMode.l="1" tp.l="1"><custom2 t="ws">IW</custom2><custom3 t="ws">$$$$1.0</custom3><custom7 t="ws">*</custom7></Story>, 40000, 1132, 33998001, 0,  )
# ( 1000089925, 2023249, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:31:11.240" mode.l="0" startMode.l="1" tp.l="1"><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">8</itemId></Spot></spotsStoredFields></Story>, 50000, 1132, 33998001, 0,  )
# ( 1000089925, 2023250, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-13T23:27:50.284" mode.l="0" plannedDuration.tc="P2:45.098266S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">00:02:35?</custom10><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot></spotsStoredFields></Story>, 60000, 1132, 33998001, 0,  )
# ( 1000089923, 2023251, 5,  , 2021-12-03 01:59:05.947000, 2021-12-03 01:58:45.927000, <Block blockStartMode.l="1" enteredDateTime.td="2020-03-13T23:03:14.095" fromBlockTemplateID.l="-1" fromPlanningEvent.l="-1" mode.l="0" scheduledTime.tc="P20.019999S TC:60000:1001" startMode.l="1" timeStretch.b="false" tp.l="1"/>, 80000, 1132, 33998001, 0,  )
# ( 1000089926, 2023252, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-04T22:34:39.754" mode.l="0" startMode.l="1" tp.l="1"/>, 10000, 1132, 33998001, 0,  )
# ( 1000089926, 2023253, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:35:33.570" mode.l="0" plannedDuration.tc="P10.009999S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">AD-INTL-WXC</custom10><custom2 t="ws">FR 1-1-1</custom2><custom5 t="ws">A/D/WX</custom5><custom7 t="ws">keb*</custom7><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">2</itemId></Spot><Spot hold.l="0"><itemId t="ws">8</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot></spotsStoredFields></Story>, 20000, 1132, 33998001, 0,  )
# ( 1000089926, 2023254, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:46:22.958" mode.l="0" plannedDuration.tc="P3:0.046533S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">00:0?:??</custom10><custom7 t="ws">wx</custom7><custom8 t="ws">5WXC</custom8><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">2</itemId></Spot><Spot hold.l="1"><itemId t="ws">3</itemId></Spot><Spot hold.l="1"><itemId t="ws">8</itemId></Spot><Spot hold.l="1"><itemId t="ws">14</itemId></Spot><Spot hold.l="1"><itemId t="ws">15</itemId></Spot></spotsStoredFields></Story>, 30000, 1132, 33998001, 0,  )
# ( 1000089926, 2023255, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-04-14T00:24:21.805" mode.l="0" startMode.l="1"/>, 40000, 1132, 33998001, 0,  )
# ( 1000089926, 2023256, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:33:21.653" mode.l="0" plannedDuration.tc="P30.030S TC:60000:1001" startMode.l="1" tp.l="1"><custom2 t="ws">@TOP</custom2><custom5 t="ws">DAN</custom5></Story>, 50000, 1132, 33998001, 0,  )
# ( 1000089926, 2023257, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T17:55:01.770" mode.l="0" startMode.l="1" tp.l="1"><custom2 t="ws">IW</custom2><custom3 t="ws">$$$$1.0</custom3><custom7 t="ws">*</custom7></Story>, 60000, 1132, 33998001, 0,  )
# ( 1000089926, 2023258, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-08-06T22:00:46.554" mode.l="0" startMode.l="1" tp.l="1"><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot></spotsStoredFields></Story>, 70000, 1132, 33998001, 0,  )
# ( 1000089926, 2023259, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-04T22:34:39.754" mode.l="0" startMode.l="1" tp.l="1"/>, 80000, 1132, 33998001, 0,  )
# ( 1000089926, 2023260, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-08-06T22:13:52.164" mode.l="0" startMode.l="1" tp.l="1"><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot></spotsStoredFields></Story>, 90000, 1132, 33998001, 0,  )
# ( 1000089926, 2023261, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:33:56.064" mode.l="0" startMode.l="1" tp.l="1"><custom10 t="ws">SCS</custom10><custom2 t="ws">REM</custom2><custom5 t="ws">MFI</custom5><custom7 t="ws">*</custom7><custom8 t="ws">4SP</custom8><pageNumber t="ws"></pageNumber><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">1</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">8</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot><Spot hold.l="1"><itemId t="ws">13</itemId></Spot></spotsStoredFields></Story>, 100000, 1132, 33998001, 0,  )
# ( 1000089926, 2023262, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-13T23:28:18.440" mode.l="0" plannedDuration.tc="P3:0.046533S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">00:02:50?</custom10><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot></spotsStoredFields></Story>, 110000, 1132, 33998001, 0,  )
# ( 1000089923, 2023263, 5,  , 2021-12-03 01:59:15.957000, 2021-12-03 01:58:45.927000, <Block blockStartMode.l="1" enteredDateTime.td="2020-03-13T23:03:14.095" fromBlockTemplateID.l="-1" fromPlanningEvent.l="-1" mode.l="0" scheduledTime.tc="P30.030S TC:60000:1001" startMode.l="1" timeStretch.b="false" tp.l="1"/>, 90000, 1132, 33998001, 0,  )
# ( 1000089927, 2023264, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T20:57:31.471" hold.l="1" mode.l="0" plannedDuration.tc="P5.004999S TC:60000:1001" startMode.l="1" tp.l="1"/>, 10000, 1132, 33998001, 0,  )
# ( 1000089927, 2023265, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-25T02:06:43.222" mode.l="0" plannedDuration.tc="P5.004999S TC:60000:1001" startMode.l="1" tp.l="1"/>, 20000, 1132, 33998001, 0,  )
# ( 1000089927, 2023266, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-25T22:42:00.604" mode.l="0" plannedDuration.tc="P10.009999S TC:60000:1001" startMode.l="1" tp.l="1"><custom1 t="ws">ac</custom1></Story>, 30000, 1132, 33998001, 0,  )
# ( 1000089927, 2023267, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-04T22:34:39.754" mode.l="0" startMode.l="1" tp.l="1"/>, 40000, 1132, 33998001, 0,  )
# ( 1000089927, 2023268, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:43:47.854" mode.l="0" plannedDuration.tc="P10.009999S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">AD-INTL</custom10><spotsStoredFields t="lt"><Spot hold.l="0"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">2</itemId></Spot></spotsStoredFields></Story>, 50000, 1132, 33998001, 0,  )
# ( 1000089927, 2023269, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-04-14T00:25:46.868" mode.l="0" startMode.l="1"/>, 60000, 1132, 33998001, 0,  )
# ( 1000089927, 2023270, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T18:50:17.346" mode.l="0" startMode.l="1" tp.l="1"><custom2 t="ws">IW</custom2><custom7 t="ws">*</custom7></Story>, 70000, 1132, 33998001, 0,  )
# ( 1000089927, 2023271, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:26:21.173" mode.l="0" plannedDuration.tc="P15.015S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">AD</custom10></Story>, 80000, 1132, 33998001, 0,  )
# ( 1000089927, 2023272, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-11T18:12:40.995" mode.l="0" startMode.l="1" tp.l="1"><custom10 t="ws"></custom10><custom2 t="ws">FR1-1</custom2><custom3 t="ws">$$$$1.0</custom3><custom7 t="ws">*</custom7><custom8 t="ws">5-2</custom8><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="0"><itemId t="ws">7</itemId></Spot><Spot hold.l="0"><itemId t="ws">8</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot><Spot hold.l="1"><itemId t="ws">10</itemId></Spot><Spot hold.l="1"><itemId t="ws">11</itemId></Spot><Spot hold.l="1"><itemId t="ws">12</itemId></Spot><Spot hold.l="0"><itemId t="ws">2</itemId></Spot><Spot hold.l="0"><itemId t="ws">14</itemId></Spot><Spot hold.l="1"><itemId t="ws">1</itemId></Spot><Spot hold.l="1"><itemId t="ws">18</itemId></Spot><Spot hold.l="1"><itemId t="ws">19</itemId></Spot></spotsStoredFields></Story>, 90000, 1132, 33998001, 0,  )
# ( 1000089927, 2023273, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-11T18:12:40.995" mode.l="0" plannedDuration.tc="P15.015S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">SCS</custom10><custom2 t="ws">REM INT</custom2><custom3 t="ws">$$$$1.0</custom3><custom8 t="ws">4SCS</custom8><spotsStoredFields t="lt"><Spot hold.l="0"><itemId t="ws">8</itemId></Spot><Spot hold.l="1"><itemId t="ws">11</itemId></Spot><Spot hold.l="1"><itemId t="ws">13</itemId></Spot></spotsStoredFields></Story>, 100000, 1132, 33998001, 0,  )
# ( 1000089927, 2023274, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T18:08:16.788" mode.l="0" plannedDuration.tc="P1:45.038266S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">00:0?:??</custom10><custom2 t="ws">PKG</custom2><custom3 t="ws">$$$$1.0</custom3><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">3</itemId></Spot></spotsStoredFields></Story>, 110000, 1132, 33998001, 0,  )
# ( 1000089927, 2023275, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T17:37:17.562" mode.l="0" plannedDuration.tc="P15.015S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">SCS</custom10><custom2 t="ws">REM TAG</custom2><custom3 t="ws">$$$$1.0</custom3><custom8 t="ws">4SCS</custom8><spotsStoredFields t="lt"><Spot hold.l="0"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="0"><itemId t="ws">10</itemId></Spot><Spot hold.l="0"><itemId t="ws">11</itemId></Spot><Spot hold.l="1"><itemId t="ws">13</itemId></Spot></spotsStoredFields></Story>, 120000, 1132, 33998001, 0,  )
# ( 1000089927, 2023276, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T17:38:24.539" mode.l="0" plannedDuration.tc="P10.009999S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws"></custom10><custom2 t="ws">FR1-1 Q&amp;A</custom2><custom3 t="ws">$$$$1.0</custom3><custom7 t="ws">keb*</custom7><custom8 t="ws">5-2</custom8><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="0"><itemId t="ws">7</itemId></Spot><Spot hold.l="0"><itemId t="ws">8</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot><Spot hold.l="1"><itemId t="ws">10</itemId></Spot><Spot hold.l="1"><itemId t="ws">11</itemId></Spot><Spot hold.l="1"><itemId t="ws">12</itemId></Spot><Spot hold.l="0"><itemId t="ws">1</itemId></Spot><Spot hold.l="1"><itemId t="ws">15</itemId></Spot></spotsStoredFields></Story>, 130000, 1132, 33998001, 0,  )
# ( 1000089927, 2023277, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-04-14T00:24:40.533" mode.l="0" startMode.l="1"/>, 140000, 1132, 33998001, 0,  )
# ( 1000089927, 2023278, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:35:56.944" mode.l="0" plannedDuration.tc="P20.019999S TC:60000:1001" startMode.l="1" tp.l="1"><custom2 t="ws">@TOP</custom2><custom5 t="ws">A/D</custom5></Story>, 150000, 1132, 33998001, 0,  )
# ( 1000089927, 2023279, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T17:55:01.770" mode.l="0" startMode.l="1" tp.l="1"><custom2 t="ws">IW</custom2><custom3 t="ws">$$$$1.0</custom3><custom7 t="ws">*</custom7></Story>, 160000, 1132, 33998001, 0,  )
# ( 1000089927, 2023280, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-09-24T17:58:48.743" mode.l="0" startMode.l="1" tp.l="1"><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">8</itemId></Spot></spotsStoredFields></Story>, 170000, 1132, 33998001, 0,  )
# ( 1000089927, 2023281, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:36:16.934" hold.l="0" mode.l="0" startMode.l="1" tp.l="1"><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot></spotsStoredFields></Story>, 180000, 1132, 33998001, 0,  )
# ( 1000089927, 2023282, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-13T23:28:36.302" mode.l="0" plannedDuration.tc="P2:55.041533S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">00:02:45?</custom10><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot></spotsStoredFields></Story>, 190000, 1132, 33998001, 0,  )
# ( 1000089923, 2023283, 5,  , 2021-12-03 01:59:25.967000, 2021-12-03 01:58:45.927000, <Block blockStartMode.l="1" enteredDateTime.td="2020-03-13T23:03:14.095" fromBlockTemplateID.l="-1" fromPlanningEvent.l="-1" mode.l="0" scheduledTime.tc="P40.039999S TC:60000:1001" startMode.l="1" timeStretch.b="false" tp.l="1"/>, 100000, 1132, 33998001, 0,  )
# ( 1000089928, 2023284, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-04T22:34:39.754" mode.l="0" startMode.l="1" tp.l="1"/>, 10000, 1132, 33998001, 0,  )
# ( 1000089928, 2023285, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-04-14T00:25:50.793" mode.l="0" startMode.l="1"/>, 20000, 1132, 33998001, 0,  )
# ( 1000089928, 2023286, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:36:44.905" mode.l="0" plannedDuration.tc="P15.015S TC:60000:1001" startMode.l="1" tp.l="1"><custom2 t="ws">@TOP</custom2><custom5 t="ws">A/D</custom5></Story>, 30000, 1132, 33998001, 0,  )
# ( 1000089928, 2023287, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T17:55:01.770" mode.l="0" startMode.l="1" tp.l="1"><custom2 t="ws">IW</custom2><custom3 t="ws">$$$$1.0</custom3><custom7 t="ws">*</custom7></Story>, 40000, 1132, 33998001, 0,  )
# ( 1000089928, 2023288, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-08-06T22:40:11.219" mode.l="0" startMode.l="1" tp.l="1"><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot></spotsStoredFields></Story>, 50000, 1132, 33998001, 0,  )
# ( 1000089928, 2023289, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-13T23:28:55.668" mode.l="0" plannedDuration.tc="P2:55.041533S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">00:02:45?</custom10><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot></spotsStoredFields></Story>, 60000, 1132, 33998001, 0,  )
# ( 1000089923, 2023290, 5,  , 2021-12-03 01:59:35.977000, 2021-12-03 01:58:45.927000, <Block blockStartMode.l="1" enteredDateTime.td="2020-03-13T23:03:14.095" fromBlockTemplateID.l="-1" fromPlanningEvent.l="-1" mode.l="0" scheduledTime.tc="P50.050S TC:60000:1001" startMode.l="1" timeStretch.b="false" tp.l="1"/>, 110000, 1132, 33998001, 0,  )
# ( 1000089929, 2023291, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-04T22:34:39.754" mode.l="0" startMode.l="1" tp.l="1"/>, 10000, 1132, 33998001, 0,  )
# ( 1000089929, 2023292, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:51:43.226" mode.l="0" plannedDuration.tc="P10.009999S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">AD-INTL-WXC</custom10><custom2 t="ws">FR 1-1-1</custom2><custom5 t="ws">A/D/WX</custom5><custom7 t="ws">keb*</custom7><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">3</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">2</itemId></Spot><Spot hold.l="0"><itemId t="ws">8</itemId></Spot><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot></spotsStoredFields></Story>, 20000, 1132, 33998001, 0,  )
# ( 1000089929, 2023293, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:46:40.462" mode.l="0" plannedDuration.tc="P45.111733S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">00:0?:??</custom10><custom7 t="ws">wx</custom7><custom8 t="ws">5WXC</custom8><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">2</itemId></Spot><Spot hold.l="1"><itemId t="ws">3</itemId></Spot><Spot hold.l="0"><itemId t="ws">16</itemId></Spot><Spot hold.l="0"><itemId t="ws">14</itemId></Spot><Spot hold.l="1"><itemId t="ws">15</itemId></Spot><Spot hold.l="1"><itemId t="ws">21</itemId></Spot><Spot hold.l="1"><itemId t="ws">20</itemId></Spot><Spot hold.l="1"><itemId t="ws">13</itemId></Spot></spotsStoredFields></Story>, 30000, 1132, 33998001, 0,  )
# ( 1000089929, 2023294, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-04-14T00:25:54.271" mode.l="0" startMode.l="1"/>, 40000, 1132, 33998001, 0,  )
# ( 1000089929, 2023295, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:52:05.887" mode.l="0" plannedDuration.tc="P10.009999S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">AD-INTL-TRAFR</custom10><custom2 t="ws">FR 1-1-1</custom2><custom5 t="ws">A/D/SPX</custom5><custom7 t="ws">keb*</custom7><custom8 t="ws"></custom8><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">2</itemId></Spot><Spot hold.l="1"><itemId t="ws">1</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">10</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot></spotsStoredFields></Story>, 50000, 1132, 33998001, 0,  )
# ( 1000089929, 2023296, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-06-04T01:24:30.426" mode.l="0" startMode.l="1"/>, 60000, 1132, 33998001, 0,  )
# ( 1000089929, 2023297, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:37:26.134" mode.l="0" plannedDuration.tc="P10.009999S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">TRAFR</custom10><custom2 t="ws">REM</custom2><custom5 t="ws">LBE</custom5><custom7 t="ws">spx</custom7><custom8 t="ws">5TRAF</custom8><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">2</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot></spotsStoredFields></Story>, 70000, 1132, 33998001, 0,  )
# ( 1000089929, 2023298, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T17:55:01.770" mode.l="0" startMode.l="1" tp.l="1"><custom2 t="ws">IW</custom2><custom3 t="ws">$$$$1.0</custom3><custom7 t="ws">*</custom7></Story>, 80000, 1132, 33998001, 0,  )
# ( 1000089929, 2023299, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:37:43.804" mode.l="0" startMode.l="1" tp.l="1"/>, 90000, 1132, 33998001, 0,  )
# ( 1000089929, 2023300, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2020-03-13T23:29:17.222" mode.l="0" plannedDuration.tc="P2:40.026533S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">00:02:30?</custom10><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot></spotsStoredFields></Story>, 100000, 1132, 33998001, 0,  )
# ( 1000089923, 2023301, 5,  , 2021-12-03 01:59:40.983000, 2021-12-03 01:58:45.927000, <Block blockStartMode.l="1" enteredDateTime.td="2020-03-13T23:03:14.095" fromBlockTemplateID.l="-1" fromPlanningEvent.l="-1" mode.l="0" scheduledTime.tc="P55.054999S TC:60000:1001" startMode.l="1" timeStretch.b="false" tp.l="1"/>, 120000, 1132, 33998001, 0,  )
# ( 1000089930, 2023302, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T20:57:33.735" hold.l="1" mode.l="0" plannedDuration.tc="P5.004999S TC:60000:1001" startMode.l="1" tp.l="1"><custom3 t="ws">$$$$1.0</custom3></Story>, 10000, 1132, 33998001, 0,  )
# ( 1000089930, 2023303, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T20:58:03.242" hold.l="1" mode.l="0" plannedDuration.tc="P5.004999S TC:60000:1001" startMode.l="1" tp.l="1"><custom3 t="ws">$$$$1.0</custom3></Story>, 20000, 1132, 33998001, 0,  )
# ( 1000089930, 2023304, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-01-25T20:58:02.020" hold.l="0" mode.l="0" plannedDuration.tc="P5.004999S TC:60000:1001" startMode.l="1" tp.l="1"><custom3 t="ws">$$$$1.0</custom3></Story>, 30000, 1132, 33998001, 0,  )
# ( 1000089930, 2023305, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:39:23.738" hold.l="0" mode.l="0" plannedDuration.tc="P3:0.046533S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">TRAF-Right</custom10><custom2 t="ws">REM</custom2><custom5 t="ws">LBE</custom5><custom7 t="ws">spx</custom7><pageNumber t="ws"></pageNumber></Story>, 40000, 1132, 33998001, 0,  )
# ( 1000089930, 2023306, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-04T22:34:39.754" hold.l="0" mode.l="0" startMode.l="1" tp.l="1"/>, 50000, 1132, 33998001, 0,  )
# ( 1000089930, 2023307, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-08-02T16:36:31.004" mode.l="0" startMode.l="1"/>, 60000, 1132, 33998001, 0,  )
# ( 1000089930, 2023308, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-10-04T22:19:31.436" mode.l="0" plannedDuration.tc="P5.005S" startMode.l="1" tp.l="1"><custom7 t="ws">*</custom7></Story>, 70000, 1132, 33998001, 0,  )
# ( 1000089930, 2023309, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:39:54.317" hold.l="0" mode.l="0" plannedDuration.tc="P30.030S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">AD-INTL-TRAFR</custom10><custom2 t="ws">FR 1-1-1</custom2><custom5 t="ws">D/A/L</custom5><custom7 t="ws">keb*</custom7><custom8 t="ws"></custom8><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">2</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot></spotsStoredFields></Story>, 80000, 1132, 33998001, 0,  )
# ( 1000089930, 2023310, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-04-14T00:25:58.231" mode.l="0" startMode.l="1"/>, 90000, 1132, 33998001, 0,  )
# ( 1000089930, 2023311, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-04T22:34:39.754" mode.l="0" startMode.l="1" tp.l="1"/>, 100000, 1132, 33998001, 0,  )
# ( 1000089930, 2023312, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:40:09.372" mode.l="0" plannedDuration.tc="P10.009999S TC:60000:1001" startMode.l="1" tp.l="1"><custom1 t="ws"></custom1><custom10 t="ws"></custom10><custom2 t="ws">FS</custom2><custom5 t="ws">DAN</custom5></Story>, 110000, 1132, 33998001, 0,  )
# ( 1000089930, 2023313, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-11-03T01:20:50.109" mode.l="0" startMode.l="1"/>, 120000, 1132, 33998001, 0,  )
# ( 1000089930, 2023314, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-02T18:55:57.895" mode.l="0" plannedDuration.tc="P10.009999S TC:60000:1001" startMode.l="1" tp.l="1"><custom1 t="ws"></custom1><custom7 t="ws"></custom7></Story>, 130000, 1132, 33998001, 0,  )
# ( 1000089930, 2023315, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="16777215" blankLineTransparent.b="false" enteredDateTime.td="2021-11-03T01:20:45.997" mode.l="0" startMode.l="1"/>, 140000, 1132, 33998001, 0,  )
# ( 1000089930, 2023316, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:40:35.486" mode.l="0" plannedDuration.tc="P20.019999S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">AD-INTL</custom10><custom2 t="ws">FR 1-1</custom2><custom5 t="ws">A/D</custom5><custom7 t="ws"></custom7><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">10</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot></spotsStoredFields></Story>, 150000, 1132, 33998001, 0,  )
# ( 1000089930, 2023317, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:40:44.896" mode.l="0" startMode.l="1" tp.l="1"><custom10 t="ws">DR 6:56:20</custom10><custom5 t="ws">XX</custom5><custom7 t="ws">*</custom7><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">2</itemId></Spot><Spot hold.l="1"><itemId t="ws">3</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">9</itemId></Spot><Spot hold.l="1"><itemId t="ws">10</itemId></Spot><Spot hold.l="0"><itemId t="ws">11</itemId></Spot><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot><Spot hold.l="1"><itemId t="ws">12</itemId></Spot><Spot hold.l="1"><itemId t="ws">13</itemId></Spot><Spot hold.l="1"><itemId t="ws">15</itemId></Spot><Spot hold.l="1"><itemId t="ws">16</itemId></Spot><Spot hold.l="1"><itemId t="ws">17</itemId></Spot><Spot hold.l="1"><itemId t="ws">18</itemId></Spot><Spot hold.l="1"><itemId t="ws">19</itemId></Spot><Spot hold.l="1"><itemId t="ws">20</itemId></Spot><Spot hold.l="1"><itemId t="ws">21</itemId></Spot><Spot hold.l="1"><itemId t="ws">22</itemId></Spot><Spot hold.l="1"><itemId t="ws">23</itemId></Spot><Spot hold.l="0"><itemId t="ws">24</itemId></Spot><Spot hold.l="1"><itemId t="ws">14</itemId></Spot><Spot hold.l="1"><itemId t="ws">8</itemId></Spot></spotsStoredFields></Story>, 160000, 1132, 33998001, 0,  )
# ...
# ( 1000089931, 2023329, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-07-22T16:24:26.755" mode.l="0" plannedDuration.tc="P30.030S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">00:00:30 6:56:51</custom10><custom7 t="ws">*</custom7></Story>, 80000, 1132, 33998001, 0,  )
# ( 1000089931, 2023330, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:40:26.225" mode.l="0" plannedDuration.tc="P1:10.070S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">ADH</custom10><custom7 t="ws">das</custom7></Story>, 90000, 1132, 33998001, 0,  )
# ( 1000089931, 2023331, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:41:49.000" mode.l="0" startMode.l="1" tp.l="1"/>, 100000, 1132, 33998001, 0,  )
# ( 1000089931, 2023332, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="65408" blankLineTransparent.b="true" enteredDateTime.td="2021-02-26T19:47:15.649" mode.l="0" startMode.l="1"/>, 110000, 1132, 33998001, 0,  )
# ( 1000089931, 2023333, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T23:02:06.903" mode.l="0" startMode.l="1" tp.l="1"><custom2 t="ws">REM</custom2><custom5 t="ws">WX</custom5><custom7 t="ws">*</custom7><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">4</itemId></Spot></spotsStoredFields></Story>, 120000, 1132, 33998001, 0,  )
# ( 1000089931, 2023334, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:35:26.239" hold.l="1" mode.l="0" plannedDuration.tc="P3:0.046533S TC:60000:1001" startMode.l="1" tp.l="1"><custom5 t="ws">WX</custom5><custom7 t="ws">wx</custom7><custom8 t="ws">N12</custom8><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">2</itemId></Spot><Spot hold.l="0"><itemId t="ws">1</itemId></Spot><Spot hold.l="1"><itemId t="ws">3</itemId></Spot></spotsStoredFields></Story>, 130000, 1132, 33998001, 0,  )
# ( 1000089931, 2023335, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:35:38.191" hold.l="1" mode.l="0" plannedDuration.tc="P10.009999S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">AD-REM-WXC</custom10><custom2 t="ws">FR 1-1-1</custom2><custom5 t="ws">A/D/WX</custom5><custom7 t="ws">keb*</custom7><spotsStoredFields t="lt"><Spot hold.l="0"><itemId t="ws">3</itemId></Spot><Spot hold.l="1"><itemId t="ws">2</itemId></Spot></spotsStoredFields></Story>, 140000, 1132, 33998001, 0,  )
# ( 1000089931, 2023336, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:51:52.253" hold.l="1" mode.l="0" plannedDuration.tc="P1:0.060S TC:60000:1001" startMode.l="1" tp.l="1"><custom5 t="ws">WX</custom5><custom7 t="ws">wx</custom7><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">2</itemId></Spot><Spot hold.l="1"><itemId t="ws">3</itemId></Spot></spotsStoredFields></Story>, 150000, 1132, 33998001, 0,  )
# ( 1000089931, 2023337, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:46:22.958" mode.l="0" plannedDuration.tc="P3:0.046533S TC:60000:1001" startMode.l="1" tp.l="1"><custom7 t="ws">wx</custom7><spotsStoredFields t="lt"><Spot hold.l="0"><itemId t="ws">2</itemId></Spot><Spot hold.l="0"><itemId t="ws">3</itemId></Spot><Spot hold.l="1"><itemId t="ws">8</itemId></Spot></spotsStoredFields></Story>, 160000, 1132, 33998001, 0,  )
# ( 1000089931, 2023338, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:46:40.462" mode.l="0" plannedDuration.tc="P1:0.060S TC:60000:1001" startMode.l="1" tp.l="1"><custom7 t="ws">wx</custom7></Story>, 170000, 1132, 33998001, 0,  )
# ( 1000089931, 2023339, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:51:58.898" mode.l="0" plannedDuration.tc="P10.009999S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">AD-REM-WXC</custom10><custom2 t="ws">FR 1-1-1</custom2><custom5 t="ws">A/D/WX</custom5><custom7 t="ws">keb*</custom7><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">8</itemId></Spot><Spot hold.l="1"><itemId t="ws">4</itemId></Spot><Spot hold.l="1"><itemId t="ws">5</itemId></Spot><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">2</itemId></Spot></spotsStoredFields></Story>, 180000, 1132, 33998001, 0,  )
# ( 1000089931, 2023340, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="65408" blankLineTransparent.b="true" enteredDateTime.td="2021-02-26T19:50:40.841" mode.l="0" startMode.l="1"/>, 190000, 1132, 33998001, 0,  )
# ( 1000089931, 2023341, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:39:44.558" mode.l="0" plannedDuration.tc="P5.004999S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">TRAFR</custom10><custom2 t="ws">REM</custom2><custom5 t="ws">LBE</custom5><custom7 t="ws">spx</custom7><custom8 t="ws">5TRAF</custom8><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">6</itemId></Spot><Spot hold.l="1"><itemId t="ws">7</itemId></Spot></spotsStoredFields></Story>, 200000, 1132, 33998001, 0,  )
# ( 1000089931, 2023342, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-06-03T01:43:08.498" mode.l="0" plannedDuration.tc="P5.004999S TC:60000:1001" startMode.l="1" tp.l="1"/>, 210000, 1132, 33998001, 0,  )
# ( 1000089931, 2023343, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:39:23.738" hold.l="1" mode.l="0" plannedDuration.tc="P3:0.046533S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">ADS</custom10><custom2 t="ws">REM</custom2><custom5 t="ws">LBE</custom5><custom7 t="ws">spx</custom7></Story>, 220000, 1132, 33998001, 0,  )
# ( 1000089931, 2023344, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-06-10T01:59:43.559" hold.l="0" mode.l="0" plannedDuration.tc="P30.030S TC:60000:1001" startMode.l="1" tp.l="1"><custom8 t="ws"></custom8><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">1</itemId></Spot><Spot hold.l="1"><itemId t="ws">4</itemId></Spot></spotsStoredFields></Story>, 230000, 1132, 33998001, 0,  )
# ( 1000089931, 2023345, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-24T22:39:23.738" hold.l="1" mode.l="0" plannedDuration.tc="P3:0.046533S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">ADS</custom10><custom2 t="ws">REM</custom2><custom5 t="ws">LBE</custom5><custom7 t="ws">spx</custom7></Story>, 240000, 1132, 33998001, 0,  )
# ( 1000089931, 2023346, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:50:55.769" mode.l="0" plannedDuration.tc="P15.015S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">AD-REM-INTL</custom10><custom7 t="ws">keb*</custom7><spotsStoredFields t="lt"><Spot hold.l="1"><itemId t="ws">3</itemId></Spot><Spot hold.l="1"><itemId t="ws">1</itemId></Spot></spotsStoredFields></Story>, 250000, 1132, 33998001, 0,  )
# ( 1000089931, 2023347, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:51:09.065" mode.l="0" plannedDuration.tc="P15.015S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">INTL</custom10><custom7 t="ws">spx</custom7></Story>, 260000, 1132, 33998001, 0,  )
# ( 1000089931, 2023348, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:51:16.994" mode.l="0" plannedDuration.tc="P3:0.046533S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">INTD</custom10><custom7 t="ws">spx</custom7></Story>, 270000, 1132, 33998001, 0,  )
# ( 1000089931, 2023349, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-03-04T22:34:39.754" mode.l="0" startMode.l="1" tp.l="1"/>, 280000, 1132, 33998001, 0,  )
# ( 1000089931, 2023350, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:51:24.165" mode.l="0" plannedDuration.tc="P15.015S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">INTL</custom10><custom7 t="ws">spx</custom7></Story>, 290000, 1132, 33998001, 0,  )
# ( 1000089931, 2023351, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-02-26T19:51:32.436" mode.l="0" plannedDuration.tc="P15.015S TC:60000:1001" startMode.l="1" tp.l="1"><custom10 t="ws">AD-REM-INTL</custom10><custom7 t="ws">keb*</custom7></Story>, 300000, 1132, 33998001, 0,  )
# ( 1000089931, 2023352, 3,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Text blankLineColor.l="65408" blankLineTransparent.b="true" enteredDateTime.td="2021-03-23T18:44:57.835" mode.l="0" startMode.l="1"/>, 310000, 1132, 33998001, 0,  )
# ( 1000089931, 2023353, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story enteredDateTime.td="2021-03-23T18:44:45.326" mode.l="0" plannedDuration.tc="P15.015S TC:60000:1001" startMode.l="1" tp.l="1"/>, 320000, 1132, 33998001, 0,  )
# ( 1000089931, 2023354, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story enteredDateTime.td="2021-03-23T18:45:07.734" mode.l="0" plannedDuration.tc="P3:0.046533S TC:60000:1001" startMode.l="1" tp.l="1"/>, 330000, 1132, 33998001, 0,  )
# ( 1000089931, 2023355, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story enteredDateTime.td="2021-03-23T18:47:17.599" mode.l="0" startMode.l="1" tp.l="1"/>, 340000, 1132, 33998001, 0,  )
# ( 1000089931, 2023356, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story enteredDateTime.td="2021-03-23T18:47:26.916" mode.l="0" startMode.l="1" tp.l="1"/>, 350000, 1132, 33998001, 0,  )
# ( 1000089931, 2023357, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story enteredDateTime.td="2021-03-23T18:47:33.208" mode.l="0" startMode.l="1" tp.l="1"/>, 360000, 1132, 33998001, 0,  )
# ( 1000089931, 2023358, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story enteredDateTime.td="2021-03-23T18:50:05.375" mode.l="0" startMode.l="1" tp.l="1"/>, 370000, 1132, 33998001, 0,  )
# ( 1000089931, 2023359, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story enteredDateTime.td="2021-03-23T18:47:42.495" mode.l="0" plannedDuration.tc="P15.015S TC:60000:1001" startMode.l="1" tp.l="1"/>, 380000, 1132, 33998001, 0,  )
# ( 1000089931, 2023360, 1,  , 2021-12-03 01:58:45.927000, 2021-12-03 01:58:45.927000, <Story copyEmbeddedTitlesInApplyPattern.l="1" copyTitleInApplyPattern.l="1" enteredDateTime.td="2021-11-13T02:29:56.637" mode.l="0" startMode.l="1" tp.l="1"><custom10 t="ws">SCS</custom10></Story>, 390000, 1132, 33998001, 0,  )
# =============
# resourceReservations -- clockId
# reservationId, clockId, studioId, stationId, reservedBy, startTime, endTime, status, content, ReservationMode, MediaProfileId, MetadataFormatId,
# Table
# ( 64089, 33998001, 71, 1132, STUDIO_ID_71, 2021-12-03 01:58:45.927000, 2021-12-03 02:57:21.907000, 0, <ClockAssignment><descriptionOfUsage t="ws">CLOCK 6PM Weekday assigned to STUDIO_ID_71</descriptionOfUsage><history t="lt"><HistoryElement at.tcd="U2021-11-30T21:20:40.809 TC:60000:1001" status.l="0"><description t="ws">CREATED</description></HistoryElement></history><name t="ws">CLOCK 6PM Weekday</name></ClockAssignment>, 0, None, None,  )
# =============
# titles_extend -- title_id
# title_id, source, reader, read_rate, year_composed, medium, status, custom1, custom2, label_reference, volume_number, oeuvre, act, orchestra, composer, conductor, period, industry, product, language, cut, version, voice, creator,
# Table
# ( 33998001,  , 0, 0, 1900, 0, 0,  ,  ,  ,  ,  ,  ,  ,  ,  ,  , 0, 0, ,  , p ,  ,  ,  )
# =============
# ItemsToBeIndexed -- Item_id
# Item_id, Item_type, ModifiedAt, IsInRecycleBin,
# Table
# ( 33998001, 2, 2021-11-30 21:20:40.240000, 0,  )
# =============
# titles_in_class -- title_id
# class_id, title_id, is_primary_class, order_in_class,
# Table
# ( 38147, 33998001, 1, None,  )
# =============
# titles_references -- title_id
# title_id, reference_id, reference_text,
# Table
# ( 33998001, 1, KGO7385036,  )
# =============
# titles_mix -- title_id
# title_id, begin_offset, end_offset, intro1, intro2, outro, fade_in, fade_out, crossfade, is_endless_loop,
# Table
# ( 33998001, 0, 0, 0, 0, 0, 0, 0, 0, 0,  )
# =============
# CreatedModifiedItems -- Item_id
# Item_id, Item_type, CreatedBy, ModifiedBy, CreatedAt, ModifiedAt, CreatedByName, ModifiedByName, IsInRecycleBin,
# Table
# ( 33998001, 2, 1915, 1915, 2021-11-30 21:17:56.603000, 2021-11-30 21:20:40.240000, KGO DaletService, KGO DaletService, 0,  )
# =============
# clocks -- clock_id
# clock_id, radio_id, clock_date, block_id, end_time, clock_reference, clock_comment, clock_duration, ruleset_id, DefaultCatId, ArchiveReadOnly, VizrtConcept, KillDateOffset, IsToArchive, isNumbering, IsInRecycleBin,
# Table
# ( 33998001, 1132, 2021-12-03 01:58:45.927000, 1000089923, 2021-12-03 02:57:21.907000,  , <Block blockStartMode.l="2" enteredDateTime.td="2020-03-13T23:03:14.095" fromBlockTemplateID.l="-1" fromPlanningEvent.l="-1" hold.l="0" loop.l="1" loops.l="0" modifiedBy.l="0" startMode.l="1" timeStretch.b="false" tp.l="1"><regulation t="t"><Regulation/></regulation></Block>, 0, 0, , 0, , 0, 1, 0, 0,  )
# =============
# ObjectStatus -- ObjectId
# ObjectId, ObjectType, Status_id,
# Table
# ( 33998001, 82, 1,  )
# =============
# titles -- title_id
# title_id, title_type_id, title_interface_id, user_id, title, interpret, author, client, duration, is_online, is_recorded, record_date, start_date, end_date, kill_date, audio_duration, use_manual_duration, soundfile_id, year, keywords, site_origin, no_overwrite, is_rotational_cart, replacement, last_words, is_opener, weight, beats_pm, master_record, compagny_id, compagny_disp_name, album_disp_name, package_id, album_id, song_id, day_part_rest_id, keep_date,
# Table
# ( 33998001, 25, 0, 0, 6PM Weekday,  , KGO DaletService, , 3515979, 1, 0, 2021-11-30 21:17:56.473000, 2021-11-30 21:17:56.473000, 9999-12-31 08:00:00, 9999-12-31 08:00:00, 0, 0, 0, 2021,  , 0, 0, 0,  ,  , 0, 100, -1, None, None,  ,  , None, None, None, None, 9999-12-31 08:00:00,  )
# =============
# StatusLog -- ObjectId
# Order1, ObjectId, ObjectType, To_status, Log_date, Commentt, UserLastName, UserFirstName,
# Table
# ( 15846111, 33998001, 82, 1, 2021-11-30 21:17:56.607000, Create, ADMIN, ,  )
# =============

# %%
#//*** Table: titles
#//*** Search Titles by Date to get Rundown IDs
#//*** Titles Contains All titled Objects including scripts rundowns and MOS objects
#//*** title_type_id = 25 <--- Rundown Objects
#//*** duration > 900000 <--- Rundowns Longer than 15 minutes (15 * 60 Seconds * 1000 ms)
#//***                        Automatically filters out short content like cutins
title_cols = ['title_id','title_type_id','title','duration','start_date']
import datetime


tgt_year = 2021
q1 = f"'{tgt_year}-01-01T00:00:00' AND '{tgt_year}-03-31T23:59:59'"
q2 = f"'{tgt_year}-04-01T00:00:00' AND '{tgt_year}-06-30T23:59:59'"
q3 = f"'{tgt_year}-07-01T00:00:00' AND '{tgt_year}-09-30T23:59:59'"
q4 = f"'{tgt_year}-09-01T00:00:00' AND '{tgt_year}-12-31T23:59:59'"

query = f"""
SELECT *
FROM titles 
WHERE title_type_id = 25 
    AND duration > 900000
    AND start_date BETWEEN {q3}
    AND title <> 'Prepak'
    AND title <> 'Tool Kit'
    AND title <> 'Tricaster'
    AND title <> 'PRODUCER HOLD'
    AND title <> 'Promo'
    AND title <> 'Breaking News'
    AND title <> 'Dalet OD XPression'
    AND title <> 'PRACTICE'
    AND title <> '7AM DIGITAL'
    --AND title <> '7:23AM Cutin'
    --AND title <> '7:56AM Cutin'
    --AND title <> '8:27AM Cutin'
    --AND title <> '8:56AM Cutin'
    --AND title <> '12:25PM Cutin'
    --AND title <> '7:27 Cut-In Weekend AM'
    --AND title <> '7:56AM Cut-In Weekend'
    --AND title <> '8:27AM Cut-In Saturdau'
--WHERE title_type_id = 25 AND start_date BETWEEN '2021-11-01T00:00:00' AND '2021-11-29T23:59:59'
--WHERE start_date BETWEEN '2021-01-24T00:00:00' AND '2021-01-24T23:59:59'
"""



#'2012-01-01T00:00:00'
cursor.execute(query)
results = cursor.fetchall()
#results = cursor.fetchmany(100)
#for x in results:
#    print(x)
#titles -- title_id
#print(dir(cursor))

all_rundowns_df = pd.read_sql(query,cnxn)
print(all_rundowns_df.columns)
all_rundowns_df = all_rundowns_df[title_cols]

#//*** Filter out shows that DO NOT USE
all_rundowns_df = all_rundowns_df[all_rundowns_df['title'].str.contains('DO NOT USE')==False]

#//*** Convert Start_Date to Date only
all_rundowns_df['start_date'] = all_rundowns_df['start_date'].apply(lambda x: x.date())

all_dates = all_rundowns_df['start_date'].unique()

#//*** Pick one day to test with
one_day_df = all_rundowns_df[all_rundowns_df['start_date'] == all_dates[-3]]


print("Quarterly Shows : ", len(all_rundowns_df))
print("Quarterly Show Hours: ", all_rundowns_df['duration'].sum() / 60000 / 60)
all_rundowns_df.iloc[-40:]
# Out:
# Index(['title_id', 'title_type_id', 'title_interface_id', 'user_id', 'title',
one_day_df
# Out:
#      title_id  title_type_id                title  duration  start_date
# 755  32991189             25          5AM Weekday   3435031  2021-09-28
# 756  32991966             25          6AM Weekday   3630093  2021-09-28
# 757  32993066             25          11AM Midday   1728993  2021-09-28
# 758  32993292             25       11:30AM Midday   1705970  2021-09-28
# 759  32999966             25         11PM WEEKDAY   2113044  2021-09-28
# 760  33000261             25  3PM Getting Answers   1799998  2021-09-28
# 761  33000392             25          4PM Weekday   3674003  2021-09-28
# 762  33001020             25          5PM Weekday   1680011  2021-09-28
# 763  33001453             25          6PM Weekday   3515979  2021-09-28

# %%
qtr_df = pd.DataFrame()
for date in all_rundowns_df['start_date'].unique():
    one_day_df = all_rundowns_df[all_rundowns_df['start_date'] == date]
    print(date, "/", all_rundowns_df['start_date'].unique()[-1])
    for row in one_day_df.iterrows():
        loop_rundown = row[1]
        loop_title_id = loop_rundown['title_id']
        #print("Rundown ID: ", loop_title_id, loop_rundown['title'])

        #print(loop_rundown)
        #//*** Get the Blocks associated with the Selected Rundown
        query = f"""
        SELECT block_id
        FROM items 

        WHERE clock_id = '{loop_title_id}'
        """
        loop_blocks = pd.read_sql(query,cnxn)['block_id'].unique()

        #//*** Find the A-Block of Selected Rundown
        #//**** Block Query gets just the A BLOCK from the Rundown Block
        #//*** Combines all Blocks into a single query and returns only the A-Block
        block_query = ""
        for block_id in loop_blocks:
            if block_id == loop_blocks[0]:
                block_query += f"(block_id='{block_id}' "
            else:
                block_query += f"OR block_id='{block_id}' "
        block_query += ") AND title='A BLOCK'"

        query = f"""
        SELECT *
        FROM blocks 
        WHERE {block_query}
        """

        tdf = pd.read_sql(query,cnxn)
        #//*** A Block of Selected Rundown
        if len(tdf) == 0:
            print("================")
            print("NO A-Block Found")
            print("================")
            print(one_day_df)
            continue

        a_block = tdf["block_id"].values[0]
        #print("A Block:",a_block)

        #//******************************
        #//*** Get A-Block Story Titles 
        #//******************************
        query = f"""
        SELECT title_id
        --SELECT block_id,item_id,title_id
        FROM spots 
        WHERE block_id = '{a_block}'
        """

        title_id_list = pd.read_sql(query,cnxn)['title_id'].values


        #//****************************************************
        #//*** Get title_id, Story Slug, and Duration
        #//*** Only get Stories with Greater than 0 Duration
        #//****************************************************

        #//*** Build Single Query to get all Titles from Selected Rundown

        title_id_query = ""
        for title_id in title_id_list:
            if title_id == title_id_list[0]:
                title_id_query += f"title_id='{title_id}' "
            else:
                title_id_query += f"OR title_id='{title_id}' "

        query = f"""
        SELECT title_id,title_type_id,title,duration
        FROM titles 
        WHERE {title_id_query}
        """

        titles_df = pd.read_sql(query,cnxn)

        #//*** Remove Stories with Zero Duration
        #//*** This Removes stories with no text
        titles_df = titles_df[titles_df['duration'] > 0]

        #//*** Remove stories with the word tease in slug
        titles_df = titles_df[titles_df['title'].str.lower().str.contains('tease') == False]
        #print(titles_df)
        #//*** Get StoryBody Text
        story_id_list = titles_df['title_id'].values
        story_id_query = ""
        for story_id in story_id_list:
            if story_id == story_id_list[0]:
                story_id_query += f"TitleId='{story_id}' "
            else:
                story_id_query += f"OR TitleId='{story_id}' "

        query = f"""
        SELECT TitleId,StoryText
        FROM StoryContent
        WHERE {story_id_query}
        """

        text_df = pd.read_sql(query,cnxn)
        #print(text_df)

        #//*** Build Stories_df List of all Stories in show with Text and Title
        #//*** Merge titles_df and text_df 
        stories_df = titles_df.merge(text_df,left_on='title_id',right_on='TitleId')

        #//*** Delete the duplicate column
        del stories_df['TitleId']

        #//********************
        #//*** Clean the Text
        #//********************

        #//*** Remove Brackets [[ ]]
        stories_df['StoryText'] = stories_df['StoryText'].str.replace('\[\[\*\*\*.*?\*\*\*\]\]','\\n',regex=True)

        #//*** Remove paranthesis (( ))
        stories_df['StoryText'] = stories_df['StoryText'].str.replace('\(\(.*?\)\)','\\n',regex=True)

        #//*** Covert \r\n to \n
        stories_df['StoryText'] = stories_df['StoryText'].str.replace('\\r\\n','\\n',regex=True)

        #//*** Convert Multiple \n to single \n
        stories_df['StoryText'] = stories_df['StoryText'].str.replace('\\n\\W*\\n','\\n',regex=True)

        #//*** Delete leading \n
        stories_df['StoryText'] = stories_df['StoryText'].str.replace('^\\W*\\n','',regex=True)
        #print(stories_df.iloc[7]['StoryText'])

        #//*** Rename title column to storyslug
        stories_df.columns = ['storyslug' if x=='title' else x for x in list(stories_df.columns)]


        #//*** Start Date, Title, from the current rundown. This Column will have the same value for all rows.
        static_cols = ['start_date','title']

        for col in static_cols:
            stories_df[col] = loop_rundown[col]

        #//*** Shift the static_cols to the beginning of the column list for readability
        cols = (static_cols + list(stories_df.columns))[:(len(static_cols)*-1)]

        stories_df = stories_df[cols]


        #//*** Rename title column to storyslug
        stories_df.columns = ['rundown' if x=='title' else x for x in list(stories_df.columns)]


        #print(cols)
        #print(stories_df)
        qtr_df = pd.concat([qtr_df,stories_df],ignore_index=True)
        #//*** End Get Single Rundown Stories
    
    #//*** End Each Day of Rundowns

#//*** Remove Stories with 0 length Text
qtr_df['StoryText'] = qtr_df['StoryText'].astype(str)
qtr_df['length'] = qtr_df['StoryText'].apply(lambda x : len(x))
qtr_df = qtr_df[qtr_df['length'] > 20]

if 'title_type_id' in qtr_df.columns:
    del qtr_df['title_type_id']
    
if 'length' in qtr_df.columns:
    del qtr_df['length']
tdf = qtr_df
tdf['duration'] = (tdf['duration'] /1000).astype(int)    

#qtr_df.to_csv("2021_Q4_Stories.csv")  

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('2021_Q3_Stories.xlsx', engine='xlsxwriter')
qtr_df.to_excel(writer,sheet_name='sheet1')
writer.save()

qtr_df
#print("Done")
# Out:
# 2021-07-01 / 2021-09-30
# 2021-07-02 / 2021-09-30
# 2021-07-03 / 2021-09-30
# 2021-07-04 / 2021-09-30
# 2021-07-05 / 2021-09-30
# 2021-07-06 / 2021-09-30
# 2021-07-07 / 2021-09-30
# 2021-07-08 / 2021-09-30
# 2021-07-09 / 2021-09-30
# 2021-07-10 / 2021-09-30
# 2021-07-11 / 2021-09-30
# 2021-07-12 / 2021-09-30
# 2021-07-13 / 2021-09-30
# 2021-09-18 / 2021-09-30
# 2021-09-19 / 2021-09-30
# 2021-09-20 / 2021-09-30
# 2021-09-21 / 2021-09-30
# 2021-09-22 / 2021-09-30
# 2021-09-23 / 2021-09-30
# 2021-09-24 / 2021-09-30
# 2021-09-25 / 2021-09-30
# 2021-09-26 / 2021-09-30
# 2021-09-27 / 2021-09-30
# 2021-09-28 / 2021-09-30
# 2021-09-29 / 2021-09-30
# 2021-09-30 / 2021-09-30
#        start_date         rundown  title_id                        storyslug  \
# 7      2021-07-01     5PM Weekday  31565204                     5PCOLDOPEN 1
# 8      2021-07-01     5PM Weekday  31565217                  5P HELLO FRAMES
# 12     2021-07-01     5PM Weekday  31579703        5P FIREWORKS CONCERNS PKG
# 13     2021-07-01     5PM Weekday  31579811  5P BAYVIEW INTERSECTION FLS INT
# 14     2021-07-01     5PM Weekday  31579835      5P BAYVIEW INTERSECTION PKG
# ...           ...             ...       ...                              ...
# 25870  2021-09-30  After The Game  33036449        ATG OREGON VS STANFORD OC
# 25873  2021-09-30  After The Game  33036454         ATG WSU VS CALIFORNIA OC
# 25877  2021-09-30  After The Game  33036496          ATG PADRES VS GIANTS OC
# 25879  2021-09-30  After The Game  33036500          ATG PADRES VS GIANTS OC
# 25880  2021-09-30  After The Game  33036501        ATG BREWERS VS DODGERS OC
#
#        duration                                          StoryText
# 7             8  [[QUOTE: are you playing pop music to drown ou...
# 8             7  Good Evening,  I'm Dan Ashley.\nand I'm Ama Da...
# 12           78  {***PKG***}\nAs Bay Area families prepare to c...
# 13           14  One of the things that neighbors told me is th...
# 14          107  Neighbors began taking pictures after complain...
# ...         ...                                                ...
# 25870       104  onto college football...stanford hosting 3rd r...
# 25873        38  cal lost a heartbreaker last week, fumbling at...
# 25877        95  the giants have won a franchise record-tying 1...
# 25879        27  so, the giants need to beat the padres tomorro...
# 25880        18  the giants don't have to win tomorrow if the d...
#
# [10077 rows x 6 columns]

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('2021_Q4_Stories.xlsx', engine='xlsxwriter')
qtr_df.to_excel(writer,sheet_name='sheet1')
writer.save()
#qtr_df['duration'] = (qtr_df['duration']/1000).astype(int)
#qtr_df.to_csv("2021_Q4_Stories.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     319             try:
# --> 320                 self._store_workbook()
#     321             except IOError as e:
#
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     637         except IOError as e:
# --> 638             raise e
#     639
#
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     634         try:
# --> 635             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
#     636                                 allowZip64=self.allow_zip64)
#
# ~\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#
# PermissionError: [Errno 13] Permission denied: '2021_Q4_Stories.xlsx'
#
# During handling of the above exception, another exception occurred:
#
# FileCreateError                           Traceback (most recent call last)
# <ipython-input-508-03a57e2095e8> in <module>
#       2 writer = pd.ExcelWriter('2021_Q4_Stories.xlsx', engine='xlsxwriter')
#       3 qtr_df.to_excel(writer,sheet_name='sheet1')
# ----> 4 writer.save()
#       5 #qtr_df['duration'] = (qtr_df['duration']/1000).astype(int)
#       6 #qtr_df.to_csv("2021_Q4_Stories.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in save(self)
#     191         Save workbook to disk.
#     192         """
# --> 193         return self.book.close()
#     194
#     195     def write_cells(
#
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     320                 self._store_workbook()
#     321             except IOError as e:
# --> 322                 raise FileCreateError(e)
#     323             except LargeZipFile as e:
#     324                 raise FileSizeError("Filesize would require ZIP64 extensions. "
#
# FileCreateError: [Errno 13] Permission denied: '2021_Q4_Stories.xlsx'

# %%
# Out:
# 0                                                " \r\n"
# 1                                                " \r\n"
# 2                                                " \r\n"
# 3                                                " \r\n"
# 4                                                " \r\n"
#                              ...
# 453                                              " \r\n"
# 454    " \r\n[[***WEBPC***]]\r\nYou can get the lates...
# 455                                              " \r\n"
# 456                                              " \r\n"
# 457    " \r\n[[***VO***]]\r\n((CG:  00-END BANNER))\r...
# Name: StoryText, Length: 458, dtype: object

# %%
stories_df = titles_df.merge(text_df,left_on='title_id',right_on='TitleId')
del stories_df['TitleId']
stories_df['StoryText'] = stories_df['StoryText'].str.replace('\[\[.+\]\]','',regex=True)
stories_df['StoryText'] = stories_df['StoryText'].str.replace('\(\(.+\)\)','',regex=True)
stories_df['StoryText'] = stories_df['StoryText'].str.replace('\\r\\n','\\n',regex=True)
stories_df['StoryText'] = stories_df['StoryText'].str.replace('\\n\\W*\\n','\\n',regex=True)
stories_df['StoryText'] = stories_df['StoryText'].str.replace('^\\W*\\n','',regex=True)
print(stories_df.iloc[7]['StoryText'])
stories_df
# Out:
# <<"HEALTH EXPERTS AROUND THE WORLD ARE UNITED IN AN EFFORT TO ATTAIN MORE INFORMATION REGARDING THE OMICRON VARIANT.
# IT'S ALREADY BEEN DETECTED IN EIGHTEEN COUNTRIES ACROSS THE GLOBE
# SOT: DR. COLLINS: "we are quickly trying to figure out in south Africa is this, in fact, more contagious than other variants? It does look like it's spreading quite quickly there"
# DR. FRANCIS COLLINS OF THE NATIONAL INSTITUTES OF HEALTH SAYS THE BIGGEST QUESTION SURROUNDING OMICRON IS IF THE AVAILABLE VACCINES WILL OFFER THE SAME LEVEL OF PROTECTION AGAINST IT -- A QUESTION THAT CAN'T BE ANSWERED RIGHT NOW.
# SOT: DR. COLLINS: "That is not something you can do overnight no matter how hard you try so people need to kind of hang on here for a couple of weeks"
# PRESIDENT BIDEN SPEAKING TO THE NATION MONDAY SAYS THE VARIANT IS A CAUSE FOR CONCERN BUT NOT A CAUSE FOR PANIC
# SOT: BIDEN:  "If people are vaccinated and wear their mask, there's no need for a  lockdown,"
# THE CDC STRENGTHENING ITS  RECCOMENDATIONS -- NOW SAYING **EVERYONE** 18 AND OVER SHOULD GET A BOOSTER 6 MONTHS AFTER THEIR 2ND DOSE OF PFIZER OR  MODERNA OR 2 MONTHS AFTER THEIR JOHNSON AND JOHNSON SINGLE-SHOT VACCINES
# THE PRESIDENT PROMISING ALL THREE VACCINE MAKERS ARE PREPARING TO UPDATE THEIR VACCINES IF NECESSARY -- STILL COMMUNITIES AROUND THE COUNTRY ARE PREPARING FOR THE WORST.
# NEW YORK CITY ISSUING A NEW MASK ADVISORY MONDAY -- URGING EVERYONE, VACCINATED OR NOT, TO MASK UP IN PUBLIC INDOOR SETTINGS.
# IN NEW JERSEY -- GOVERNOR PHIL MURPHY TELLING THE GARDEN STATE TO GET BOOSTED
# SOT: Governor Phil Murphy: "we must be ready now in anticipation of this variant hitting us."
# THE OMICRON VARIANT HASN'T BEEN DETECTED IN THE  U.S. AS OF NOW...STILL  COVID CONTINUES TO TIGHTEN ITS GRIP ON COMMUNITIES
# IN MINNESOTA -- HOSPITALIZATIONS ROSE 50 PERCENT IN THE LAST MONTH -- COUPLE THAT WITH THE NATION'S HIGHEST CASE RATE AND YOU GET A HOSPITAL WORKFORCE AT WHIT'S END
# SOT: ICU nurse Lydia Bridgeman: "Morale remains low It seems that we've gone from the most trusted profession in the world to the least trusted."
# TAG:
# ABC NEWS LEARNING THAT IN THE COMING DAYS, PFIZER WILL ASK THE FDA TO EXPAND ACCESS TO ITS BOOSTER TO INCLUDE 16 AND 17 YEAR  OLDS.
# IKE  EJIOCHI, ABC NEWS WASHINGTON
#     title_id  title_type_id                         title  duration  \
# 0   33958087           1020                      COLDOPEN      9415
# 1   33958093              4                  ANCHOR INTRO      6384
# 2   33958100              4                  TOSS WEATHER      4674
# 3   33958112              4                       TEASE 1     10203
# 4   33990342              4        11A HOLIDAY VARIANT OC     36805
# 5   33990381              4          11A KEVIN NISHITA OC     39330
# 6   33990511           1020         11A SCHOOL VARIANT VO     48112
# 7   33990711           1020        11A OMICRON LATEST PKG    123462
# 8   33990819              4            11A GRAND SHOOTING     52765
# 9   33992129           1020            11A OMICRON STOCKS     20634
# 10  33992392              4  11A GMA3 OAKLAND PD CHIEF OC     76770
# 11  33992411              4             11A GMA3 TEASE FS      6669
# 12  33992512              4         11A OMICRON LATEST OC     16815
# 13  33993568           1020         11A SR HAZMAT FR 2-1      27702
# 14  33993749              4        11A OMICRON STOCKS REM     18126
#
#                                             StoryText
# 0   \tOakland's police chief-- once again-- pleadi...
# 1   \tHello, I'm Reggie Aqui.\n\tAnd I'm Kristen S...
# 2   BRACE FOR HEAT ... METEOROLOGIST MIKE NICCO SA...
# 3    JUST AHEAD, THE REASON ADELE FANS ARE LOSING ...
# 4   \tWe know a lot of you are wondering how the n...
# 5   \tThis morning, police are hoping someone has ...
# 6   Even though the omicron variant hasn't been de...
# 7   <<"HEALTH EXPERTS AROUND THE WORLD ARE UNITED ...
# 8   \tThe grief-stricken family of Oakland's lates...
# 9   TAKE A LOOK AT THE BIG BOARD from just a littl...
# 10  \tChief LeRonne Armstrong is about to begin a ...
# 11  \tYou can watch Chief Armstrong's full intervi...
# 12  \tDeveloping News involving the worldwide conc...
# 13  \tDeveloping News in the North Bay.\n\tSan Raf...
# 14  THIS IS A LIVE LOOK AT THE BIG BOARD. \nMODERN...

# %%
# Out:
# 771.200776111111
