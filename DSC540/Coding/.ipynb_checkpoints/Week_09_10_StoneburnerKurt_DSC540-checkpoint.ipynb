# %% [markdown]
# # Stoneburner, Kurt
# - ## DSC 540 - Week 09/10

# %%
# //****************************************************************************************
# //*** Set Working Directory to thinkstats folder.
# //*** This pseudo-relative path call should work on all Stoneburner localized projects. 
# //****************************************************************************************

import os
import sys
# //*** Imports and Load Data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#//*** Needed to display the Movie poster :)
from IPython.display import Image, display

# %% [markdown]
# # Activity 9: Top 100 ebooks' name extraction from Gutenberg.org
#
# ## What is Project Gutenberg? -
# Project Gutenberg is a volunteer effort to digitize and archive cultural works, to "encourage the creation and distribution of eBooks". It was founded in 1971 by American writer Michael S. Hart and is the **oldest digital library.** This longest-established ebook project releases books that entered the public domain, and can be freely read or downloaded in various electronic formats.
#
# ## What is this activity all about?
# * **This activity aims to scrape the url of the Project Gutenberg's Top 100 ebooks (yesterday's ranking) for identifying the ebook links. **
# * **It uses BeautifulSoup4 for parsing the HTML and regular expression code for identifying the Top 100 ebook file numbers.**
# * **You can use those book ID numbers to download the book into your local drive if you want**

# %% [markdown]
# ### Import necessary libraries including regex, and beautifulsoup

# %%
import urllib.request, urllib.parse, urllib.error
import requests
from bs4 import BeautifulSoup
import ssl
import re

# %% [markdown]
# ### Ignore SSL errors (this code will be given)

# %%
# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# %% [markdown]
# ### Read the HTML from the URL

# %%
guten_url = "http://www.gutenberg.org/browse/scores/top"
response = requests.get(guten_url)

# %% [markdown]
# ### Write a small function to check the status of web request

# %%
#//*** If Response.ok is False there is a problem
if response.ok == False:
    print("Problem downloading the URL")
    print(f"Statis Code: {response.status_code}")
    for x in response:
        print(x)

#//*** If no error we should be good

# %% [markdown]
# ### Decode the response and pass on to `BeautifulSoup` for HTML parsing

# %%
# Write your code here (decode). The decoding functionality is inlined with the Beautiful soup import. This forces
#//*** Decoding of the content based on the value of response.encoding

# Write your code here (pass on to BS)
if response.ok == True:
    #//*** Make soup...Beautiful Soup
    soup = BeautifulSoup(response.content.decode(response.encoding),'html.parser')

# %% [markdown]
# ### Find all the _href_ tags and store them in the list of links. Check how the list looks like - print first 30 elements

# %%
# Write your code here
href_list = soup.find_all('a')

# %%
# Write your code here (print the list)
for link in href_list:
    print(link)
# Out:
# <a class="no-hover" href="/" id="main_logo">
# <img alt="Project Gutenberg" draggable="false" src="/gutenberg/pg-logo-129x80.png"/>
# </a>
# <a href="/about/">About
#           <span class="drop-icon">▾</span>
# </a>
# <a href="/about/">About Project Gutenberg</a>
# <a href="/policy/collection_development.html">Collection Development</a>
# <a href="/about/contact_information.html">Contact Us</a>
# <a href="/about/background/">History &amp; Philosophy</a>
# <a href="/policy/permission.html">Permissions &amp; License</a>
# <a href="/policy/privacy_policy.html">Privacy Policy</a>
# <a href="/policy/terms_of_use.html">Terms of Use</a>
# <a href="/ebooks/">Search and Browse
#       	  <span class="drop-icon">▾</span>
# </a>
# <a href="/ebooks/">Book Search</a>
# <a href="/ebooks/bookshelf/">Bookshelves</a>
# <a href="/browse/scores/top">Frequently Downloaded</a>
# <a href="/ebooks/offline_catalogs.html">Offline Catalogs</a>
# <a href="/help/">Help
#           <span class="drop-icon">▾</span>
# </a>
# <a href="/help/">All help topics →</a>
# <a href="/help/copyright.html">Copyright Procedures</a>
# <a href="/help/errata.html">Errata, Fixes and Bug Reports</a>
# <a href="/help/file_formats.html">File Formats</a>
# <a href="/help/faq.html">Frequently Asked Questions</a>
# <a href="/policy/">Policies →</a>
# <a href="/help/public_domain_ebook_submission.html">Public Domain eBook Submission</a>
# <a href="/help/submitting_your_own_work.html">Submitting Your Own Work</a>
# <a href="/help/mobile.html">Tablets, Phones and eReaders</a>
# <a href="/attic/">The Attic →</a>
# <a href="/donate/">Donate</a>
# <a href="/donate/">Donation</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/ebooks/1342">Pride and Prejudice by Jane Austen (2238)</a>
# <a href="/ebooks/84">Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (2097)</a>
# <a href="/ebooks/11">Alice's Adventures in Wonderland by Lewis Carroll (872)</a>
# <a href="/ebooks/1080">A Modest Proposal by Jonathan Swift (837)</a>
# <a href="/ebooks/1661">The Adventures of Sherlock Holmes by Arthur Conan Doyle (786)</a>
# <a href="/ebooks/1952">The Yellow Wallpaper by Charlotte Perkins Gilman (763)</a>
# <a href="/ebooks/5200">Metamorphosis by Franz Kafka (750)</a>
# <a href="/ebooks/98">A Tale of Two Cities by Charles Dickens (740)</a>
# <a href="/ebooks/1260">Jane Eyre: An Autobiography by Charlotte Brontë (665)</a>
# <a href="/ebooks/174">The Picture of Dorian Gray by Oscar Wilde (664)</a>
# <a href="/ebooks/2701">Moby Dick; Or, The Whale by Herman Melville (654)</a>
# <a href="/ebooks/25344">The Scarlet Letter by Nathaniel Hawthorne (636)</a>
# <a href="/ebooks/2542">Et dukkehjem. English by Henrik Ibsen (622)</a>
# <a href="/ebooks/844">The Importance of Being Earnest: A Trivial Comedy for Serious People by Oscar Wilde (617)</a>
# <a href="/ebooks/6133">Arsène Lupin, gentleman-cambrioleur. English by Maurice Leblanc (611)</a>
# <a href="/ebooks/46">A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens (608)</a>
# <a href="/ebooks/408">The Souls of Black Folk by W. E. B.  Du Bois (546)</a>
# <a href="/ebooks/76">Adventures of Huckleberry Finn by Mark Twain (539)</a>
# <a href="/ebooks/43">The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson (525)</a>
# <a href="/ebooks/219">Heart of Darkness by Joseph Conrad (514)</a>
# <a href="/ebooks/16328">Beowulf: An Anglo-Saxon Epic Poem (501)</a>
# <a href="/ebooks/205">Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau (483)</a>
# <a href="/ebooks/345">Dracula by Bram Stoker (454)</a>
# <a href="/ebooks/902">The Happy Prince, and Other Tales by Oscar Wilde (443)</a>
# <a href="/ebooks/74">The Adventures of Tom Sawyer, Complete by Mark Twain (439)</a>
# <a href="/ebooks/1250">Anthem by Ayn Rand (434)</a>
# <a href="/ebooks/1232">Il Principe. English by Niccolò Machiavelli (433)</a>
# <a href="/ebooks/1400">Great Expectations by Charles Dickens (424)</a>
# <a href="/ebooks/1497">The Republic by Plato (422)</a>
# <a href="/ebooks/16">Peter Pan by J. M.  Barrie (407)</a>
# <a href="/ebooks/23">Narrative of the Life of Frederick Douglass, an American Slave by Frederick Douglass (397)</a>
# <a href="/ebooks/160">The Awakening, and Selected Short Stories by Kate Chopin (381)</a>
# <a href="/ebooks/64481">Chicken Farm by Ross Rocklynne (380)</a>
# <a href="/ebooks/158">Emma by Jane Austen (377)</a>
# <a href="/ebooks/2600">War and Peace by graf Leo Tolstoy (375)</a>
# <a href="/ebooks/4300">Ulysses by James Joyce (363)</a>
# <a href="/ebooks/64317">The Great Gatsby by F. Scott  Fitzgerald (361)</a>
# <a href="/ebooks/140">The Jungle by Upton Sinclair (357)</a>
# <a href="/ebooks/57775">Le jardin des supplices by Octave Mirbeau (357)</a>
# <a href="/ebooks/2814">Dubliners by James Joyce (352)</a>
# <a href="/ebooks/120">Treasure Island by Robert Louis Stevenson (347)</a>
# <a href="/ebooks/2591">Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm (341)</a>
# <a href="/ebooks/2852">The Hound of the Baskervilles by Arthur Conan Doyle (337)</a>
# <a href="/ebooks/514">Little Women by Louisa May Alcott (330)</a>
# <a href="/ebooks/3207">Leviathan by Thomas Hobbes (317)</a>
# <a href="/ebooks/64474">Planet In Reverse by Henry Guth (309)</a>
# <a href="/ebooks/55">The Wonderful Wizard of Oz by L. Frank  Baum (308)</a>
# <a href="/ebooks/6130">The Iliad by Homer (305)</a>
# <a href="/ebooks/768">Wuthering Heights by Emily Brontë (303)</a>
# <a href="/ebooks/1184">The Count of Monte Cristo, Illustrated by Alexandre Dumas (296)</a>
# <a href="/ebooks/3825">Pygmalion by Bernard Shaw (295)</a>
# <a href="/ebooks/3600">Essays of Michel de Montaigne — Complete by Michel de Montaigne (294)</a>
# <a href="/ebooks/42108">The Slang Dictionary: Etymological, Historical and Andecdotal by John Camden Hotten (294)</a>
# <a href="/ebooks/135">Les Misérables by Victor Hugo (291)</a>
# <a href="/ebooks/45">Anne of Green Gables by L. M.  Montgomery (291)</a>
# <a href="/ebooks/15399">The Interesting Narrative of the Life of Olaudah Equiano, Or Gustavus Vassa, The African by Equiano (290)</a>
# <a href="/ebooks/64476">Panama and the Canal in Picture and Prose by Willis J. Abbott (283)</a>
# <a href="/ebooks/1727">The Odyssey by Homer (283)</a>
# <a href="/ebooks/64480">Amour, Amour, Dear Planet! by Mark Clutter (282)</a>
# <a href="/ebooks/2554">Prestuplenie i nakazanie. English by Fyodor Dostoyevsky (279)</a>
# <a href="/ebooks/1998">Also sprach Zarathustra. English by Friedrich Wilhelm Nietzsche (275)</a>
# <a href="/ebooks/5740">Tractatus Logico-Philosophicus by Ludwig Wittgenstein (274)</a>
# <a href="/ebooks/203">Uncle Tom's Cabin by Harriet Beecher Stowe (273)</a>
# <a href="/ebooks/244">A Study in Scarlet by Arthur Conan Doyle (272)</a>
# <a href="/ebooks/64473">Task of Tau by J. Harvey  Haggard (259)</a>
# <a href="/ebooks/996">Don Quixote by Miguel de Cervantes Saavedra (258)</a>
# <a href="/ebooks/36">The War of the Worlds by H. G.  Wells (255)</a>
# <a href="/ebooks/19942">Candide by Voltaire (253)</a>
# <a href="/ebooks/1934">Songs of Innocence, and Songs of Experience by William Blake (249)</a>
# <a href="/ebooks/829">Gulliver's Travels into Several Remote Nations of the World by Jonathan Swift (248)</a>
# <a href="/ebooks/215">The Call of the Wild by Jack London (247)</a>
# <a href="/ebooks/766">David Copperfield by Charles Dickens (243)</a>
# <a href="/ebooks/58585">The Prophet by Kahlil Gibran (243)</a>
# <a href="/ebooks/64485">The Origin of the Mound Builders by Alfred Oscar Coffin (231)</a>
# <a href="/ebooks/4014">Arsene Lupin by Maurice Leblanc (230)</a>
# <a href="/ebooks/3090">Complete Original Short Stories of Guy De Maupassant by Guy de Maupassant (227)</a>
# <a href="/ebooks/1001">Divine Comedy, Longfellow's Translation, Hell by Dante Alighieri (226)</a>
# <a href="/ebooks/64490">Stories of the Wars of the Jews by A. L. O. E. (225)</a>
# <a href="/ebooks/64488">Roman Stoicism by E. Vernon Arnold (222)</a>
# <a href="/ebooks/113">The Secret Garden by Frances Hodgson Burnett (218)</a>
# <a href="/ebooks/35">The Time Machine by H. G.  Wells (216)</a>
# <a href="/ebooks/20203">Autobiography of Benjamin Franklin by Benjamin Franklin (213)</a>
# <a href="/ebooks/7370">Second Treatise of Government by John Locke (210)</a>
# <a href="/ebooks/851">Narrative of the Captivity and Restoration of Mrs. Mary Rowlandson by Mary White Rowlandson (210)</a>
# <a href="/ebooks/2500">Siddhartha by Hermann Hesse (200)</a>
# <a href="/ebooks/376">A Journal of the Plague Year by Daniel Defoe (200)</a>
# <a href="/ebooks/25929">Daemonologie. by King of England James I (197)</a>
# <a href="/ebooks/30254">The Romance of Lust: A classic Victorian erotic novel by Anonymous (195)</a>
# <a href="/ebooks/863">The Mysterious Affair at Styles by Agatha Christie (193)</a>
# <a href="/ebooks/730">Oliver Twist by Charles Dickens (192)</a>
# <a href="/ebooks/236">The Jungle Book by Rudyard Kipling (192)</a>
# <a href="/ebooks/161">Sense and Sensibility by Jane Austen (191)</a>
# <a href="/ebooks/8800">An Index of The Divine Comedy by Dante by Dante Alighieri (186)</a>
# <a href="/ebooks/4363">Beyond Good and Evil by Friedrich Wilhelm Nietzsche (184)</a>
# <a href="/ebooks/1399">Anna Karenina by graf Leo Tolstoy (184)</a>
# <a href="/ebooks/32415">The Nursery Rhymes of England (179)</a>
# <a href="/ebooks/521">The Life and Adventures of Robinson Crusoe by Daniel Defoe (177)</a>
# <a href="/ebooks/64470">Biblical Revision by Henry Alford (176)</a>
# <a href="/ebooks/779">The Tragical History of Doctor Faustus by Christopher Marlowe (176)</a>
# <a href="/ebooks/2097">The Sign of the Four by Arthur Conan Doyle (175)</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/browse/authors/a#a68">Austen, Jane (3563)</a>
# <a href="/browse/authors/d#a37">Dickens, Charles (3366)</a>
# <a href="/browse/authors/s#a61">Shelley, Mary Wollstonecraft (2487)</a>
# <a href="/browse/authors/d#a69">Doyle, Arthur Conan (2390)</a>
# <a href="/browse/authors/t#a53">Twain, Mark (2351)</a>
# <a href="/browse/authors/w#a111">Wilde, Oscar (2201)</a>
# <a href="/browse/authors/c#a7">Carroll, Lewis (1381)</a>
# <a href="/browse/authors/s#a35">Stevenson, Robert Louis (1331)</a>
# <a href="/browse/authors/s#a65">Shakespeare, William (1311)</a>
# <a href="/browse/authors/s#a326">Swift, Jonathan (1243)</a>
# <a href="/browse/authors/l#a1358">Leblanc, Maurice (1173)</a>
# <a href="/browse/authors/p#a93">Plato (1141)</a>
# <a href="/browse/authors/h#a28">Hawthorne, Nathaniel (1137)</a>
# <a href="/browse/authors/w#a30">Wells, H. G. (Herbert George) (1126)</a>
# <a href="/browse/authors/j#a94">Jowett, Benjamin (1091)</a>
# <a href="/browse/authors/d#a314">Dostoyevsky, Fyodor (1041)</a>
# <a href="/browse/authors/p#a481">Poe, Edgar Allan (1033)</a>
# <a href="/browse/authors/n#a779">Nietzsche, Friedrich Wilhelm (1007)</a>
# <a href="/browse/authors/m#a9">Melville, Herman (1001)</a>
# <a href="/browse/authors/t#a136">Tolstoy, Leo, graf (998)</a>
# <a href="/browse/authors/h#a705">Homer (994)</a>
# <a href="/browse/authors/k#a1735">Kafka, Franz (961)</a>
# <a href="/browse/authors/c#a125">Conrad, Joseph (928)</a>
# <a href="/browse/authors/i#a861">Ibsen, Henrik (911)</a>
# <a href="/browse/authors/g#a2858">Garnett, Constance (906)</a>
# <a href="/browse/authors/g#a27">Gilman, Charlotte Perkins (874)</a>
# <a href="/browse/authors/w#a1736">Wyllie, David (Translator) (859)</a>
# <a href="/browse/authors/j#a1039">Joyce, James (851)</a>
# <a href="/browse/authors/d#a507">Dante Alighieri (850)</a>
# <a href="/browse/authors/l#a120">London, Jack (808)</a>
# <a href="/browse/authors/v#a60">Verne, Jules (792)</a>
# <a href="/browse/authors/j#a113">James, Henry (782)</a>
# <a href="/browse/authors/b#a408">Brontë, Charlotte (775)</a>
# <a href="/browse/authors/d#a226">Du Bois, W. E. B. (William Edward Burghardt) (759)</a>
# <a href="/browse/authors/b#a42">Baum, L. Frank (Lyman Frank) (736)</a>
# <a href="/browse/authors/m#a36">Montgomery, L. M. (Lucy Maud) (719)</a>
# <a href="/browse/authors/d#a1896">Doré, Gustave (715)</a>
# <a href="/browse/authors/d#a492">Dumas, Alexandre (710)</a>
# <a href="/browse/authors/t#a9854">Townsend, F. H. (Frederick Henry) (684)</a>
# <a href="/browse/authors/h#a85">Hugo, Victor (681)</a>
# <a href="/browse/authors/k#a132">Kipling, Rudyard (679)</a>
# <a href="/browse/authors/t#a54">Thoreau, Henry David (671)</a>
# <a href="/browse/authors/l#a9473">Leech, John (665)</a>
# <a href="/browse/authors/a#a102">Alcott, Louisa May (663)</a>
# <a href="/browse/authors/s#a467">Shaw, Bernard (652)</a>
# <a href="/browse/authors/f#a2703">Foote, Mary Hallock (639)</a>
# <a href="/browse/authors/i#a31265">Ipsen, Ludvig Sandöe (636)</a>
# <a href="/browse/authors/a#a31267">Anthony, A. V. S. (Andrew Varick Stout) (636)</a>
# <a href="/browse/authors/d#a204">Defoe, Daniel (635)</a>
# <a href="/browse/authors/b#a10">Barrie, J. M. (James Matthew) (626)</a>
# <a href="/browse/authors/c#a708">Chekhov, Anton Pavlovich (609)</a>
# <a href="/browse/authors/r#a2183">Rizal, José (592)</a>
# <a href="/browse/authors/k#a37155">Kemble, E. W. (Edward Windsor) (564)</a>
# <a href="/browse/authors/b#a73">Burnett, Frances Hodgson (562)</a>
# <a href="/browse/authors/m#a1355">Morley, Henry (546)</a>
# <a href="/browse/authors/s#a190">Stoker, Bram (543)</a>
# <a href="/browse/authors/r#a355">Russell, Bertrand (543)</a>
# <a href="/browse/authors/w#a104">Wharton, Edith (539)</a>
# <a href="/browse/authors/l#a79">Lang, Andrew (530)</a>
# <a href="/browse/authors/c#a80">Chesterton, G. K. (Gilbert Keith) (529)</a>
# <a href="/browse/authors/c#a451">Christie, Agatha (526)</a>
# <a href="/browse/authors/v#a913">Voltaire (519)</a>
# <a href="/browse/authors/p#a907">Pope, Alexander (518)</a>
# <a href="/browse/authors/w#a1961">Widger, David (515)</a>
# <a href="/browse/authors/m#a306">Maupassant, Guy de (509)</a>
# <a href="/browse/authors/f#a420">Fitzgerald, F. Scott (Francis Scott) (505)</a>
# <a href="/browse/authors/b#a748">Butler, Samuel (502)</a>
# <a href="/browse/authors/h#a6638">Hall, J. Lesslie (John Lesslie) (501)</a>
# <a href="/browse/authors/g#a972">Grimm, Wilhelm (499)</a>
# <a href="/browse/authors/g#a971">Grimm, Jacob (499)</a>
# <a href="/browse/authors/c#a505">Cervantes Saavedra, Miguel de (498)</a>
# <a href="/browse/authors/m#a500">Maude, Louise (490)</a>
# <a href="/browse/authors/m#a4589">Maude, Aylmer (481)</a>
# <a href="/browse/authors/m#a563">Machiavelli, Niccolò (481)</a>
# <a href="/browse/authors/d#a34510">Douglass, Frederick (475)</a>
# <a href="/browse/authors/b#a251">Balzac, Honoré de (458)</a>
# <a href="/browse/authors/g#a586">Goethe, Johann Wolfgang von (454)</a>
# <a href="/browse/authors/r#a572">Rand, Ayn (445)</a>
# <a href="/browse/authors/r#a34040">Rocklynne, Ross (443)</a>
# <a href="/browse/authors/m#a564">Marriott, W. K. (William Kenaz) (436)</a>
# <a href="/browse/authors/s#a88">Sinclair, Upton (434)</a>
# <a href="/browse/authors/w#a783">Wodehouse, P. G. (Pelham Grenville) (432)</a>
# <a href="/browse/authors/c#a3622">Cary, Henry Francis (425)</a>
# <a href="/browse/authors/s#a59">Scott, Walter (420)</a>
# <a href="/browse/authors/b#a206">Bierce, Ambrose (419)</a>
# <a href="/browse/authors/f#a92">Franklin, Benjamin (410)</a>
# <a href="/browse/authors/h#a33608">Hapgood, Isabel Florence (403)</a>
# <a href="/browse/authors/m#a1705">Mill, John Stuart (399)</a>
# <a href="/browse/authors/c#a100">Chopin, Kate (392)</a>
# <a href="/browse/authors/p#a292">Potter, Beatrix (385)</a>
# <a href="/browse/authors/b#a48">Burroughs, Edgar Rice (380)</a>
# <a href="/browse/authors/e#a90">Eliot, George (380)</a>
# <a href="/browse/authors/i#a34">Irving, Washington (376)</a>
# <a href="/browse/authors/t#a324">Trollope, Anthony (375)</a>
# <a href="/browse/authors/m#a6950">Mirbeau, Octave (367)</a>
# <a href="/browse/authors/b#a295">Blake, William (357)</a>
# <a href="/browse/authors/o#a506">Ormsby, John (356)</a>
# <a href="/browse/authors/s#a115">Stowe, Harriet Beecher (353)</a>
# <a href="/browse/authors/r#a44215">Rhead, Louis (348)</a>
# <a href="/browse/authors/b#a25301">Buckley, Theodore Alois (344)</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/ebooks/84">Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (26466)</a>
# <a href="/ebooks/1342">Pride and Prejudice by Jane Austen (18723)</a>
# <a href="/ebooks/1080">A Modest Proposal by Jonathan Swift (8557)</a>
# <a href="/ebooks/46">A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens (8036)</a>
# <a href="/ebooks/11">Alice's Adventures in Wonderland by Lewis Carroll (7497)</a>
# <a href="/ebooks/1952">The Yellow Wallpaper by Charlotte Perkins Gilman (7241)</a>
# <a href="/ebooks/25344">The Scarlet Letter by Nathaniel Hawthorne (7198)</a>
# <a href="/ebooks/2542">Et dukkehjem. English by Henrik Ibsen (7160)</a>
# <a href="/ebooks/98">A Tale of Two Cities by Charles Dickens (7103)</a>
# <a href="/ebooks/1250">Anthem by Ayn Rand (6953)</a>
# <a href="/ebooks/844">The Importance of Being Earnest: A Trivial Comedy for Serious People by Oscar Wilde (6640)</a>
# <a href="/ebooks/43">The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson (6637)</a>
# <a href="/ebooks/5200">Metamorphosis by Franz Kafka (6496)</a>
# <a href="/ebooks/1661">The Adventures of Sherlock Holmes by Arthur Conan Doyle (5980)</a>
# <a href="/ebooks/1260">Jane Eyre: An Autobiography by Charlotte Brontë (5961)</a>
# <a href="/ebooks/76">Adventures of Huckleberry Finn by Mark Twain (5808)</a>
# <a href="/ebooks/2701">Moby Dick; Or, The Whale by Herman Melville (5781)</a>
# <a href="/ebooks/174">The Picture of Dorian Gray by Oscar Wilde (5262)</a>
# <a href="/ebooks/219">Heart of Darkness by Joseph Conrad (5034)</a>
# <a href="/ebooks/16328">Beowulf: An Anglo-Saxon Epic Poem (4972)</a>
# <a href="/ebooks/408">The Souls of Black Folk by W. E. B.  Du Bois (4937)</a>
# <a href="/ebooks/6133">Arsène Lupin, gentleman-cambrioleur. English by Maurice Leblanc (4467)</a>
# <a href="/ebooks/74">The Adventures of Tom Sawyer, Complete by Mark Twain (4332)</a>
# <a href="/ebooks/1400">Great Expectations by Charles Dickens (4280)</a>
# <a href="/ebooks/2852">The Hound of the Baskervilles by Arthur Conan Doyle (4200)</a>
# <a href="/ebooks/160">The Awakening, and Selected Short Stories by Kate Chopin (4161)</a>
# <a href="/ebooks/23">Narrative of the Life of Frederick Douglass, an American Slave by Frederick Douglass (4097)</a>
# <a href="/ebooks/345">Dracula by Bram Stoker (4018)</a>
# <a href="/ebooks/1232">Il Principe. English by Niccolò Machiavelli (3963)</a>
# <a href="/ebooks/205">Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau (3899)</a>
# <a href="/ebooks/16">Peter Pan by J. M.  Barrie (3466)</a>
# <a href="/ebooks/64317">The Great Gatsby by F. Scott  Fitzgerald (3437)</a>
# <a href="/ebooks/120">Treasure Island by Robert Louis Stevenson (3431)</a>
# <a href="/ebooks/1497">The Republic by Plato (3365)</a>
# <a href="/ebooks/215">The Call of the Wild by Jack London (3356)</a>
# <a href="/ebooks/55">The Wonderful Wizard of Oz by L. Frank  Baum (3354)</a>
# <a href="/ebooks/2591">Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm (3178)</a>
# <a href="/ebooks/4300">Ulysses by James Joyce (2964)</a>
# <a href="/ebooks/514">Little Women by Louisa May Alcott (2958)</a>
# <a href="/ebooks/2814">Dubliners by James Joyce (2920)</a>
# <a href="/ebooks/158">Emma by Jane Austen (2880)</a>
# <a href="/ebooks/3825">Pygmalion by Bernard Shaw (2862)</a>
# <a href="/ebooks/19942">Candide by Voltaire (2787)</a>
# <a href="/ebooks/2600">War and Peace by graf Leo Tolstoy (2767)</a>
# <a href="/ebooks/140">The Jungle by Upton Sinclair (2761)</a>
# <a href="/ebooks/3207">Leviathan by Thomas Hobbes (2741)</a>
# <a href="/ebooks/768">Wuthering Heights by Emily Brontë (2721)</a>
# <a href="/ebooks/902">The Happy Prince, and Other Tales by Oscar Wilde (2714)</a>
# <a href="/ebooks/45">Anne of Green Gables by L. M.  Montgomery (2611)</a>
# <a href="/ebooks/26184">Simple Sabotage Field Manual by United States. Office of Strategic Services (2531)</a>
# <a href="/ebooks/2554">Prestuplenie i nakazanie. English by Fyodor Dostoyevsky (2491)</a>
# <a href="/ebooks/57775">Le jardin des supplices by Octave Mirbeau (2469)</a>
# <a href="/ebooks/36">The War of the Worlds by H. G.  Wells (2421)</a>
# <a href="/ebooks/244">A Study in Scarlet by Arthur Conan Doyle (2407)</a>
# <a href="/ebooks/1727">The Odyssey by Homer (2358)</a>
# <a href="/ebooks/42108">The Slang Dictionary: Etymological, Historical and Andecdotal by John Camden Hotten (2327)</a>
# <a href="/ebooks/851">Narrative of the Captivity and Restoration of Mrs. Mary Rowlandson by Mary White Rowlandson (2321)</a>
# <a href="/ebooks/1184">The Count of Monte Cristo, Illustrated by Alexandre Dumas (2304)</a>
# <a href="/ebooks/203">Uncle Tom's Cabin by Harriet Beecher Stowe (2250)</a>
# <a href="/ebooks/829">Gulliver's Travels into Several Remote Nations of the World by Jonathan Swift (2248)</a>
# <a href="/ebooks/20203">Autobiography of Benjamin Franklin by Benjamin Franklin (2234)</a>
# <a href="/ebooks/15399">The Interesting Narrative of the Life of Olaudah Equiano, Or Gustavus Vassa, The African by Equiano (2216)</a>
# <a href="/ebooks/58585">The Prophet by Kahlil Gibran (2216)</a>
# <a href="/ebooks/6130">The Iliad by Homer (2204)</a>
# <a href="/ebooks/5740">Tractatus Logico-Philosophicus by Ludwig Wittgenstein (2178)</a>
# <a href="/ebooks/2097">The Sign of the Four by Arthur Conan Doyle (2118)</a>
# <a href="/ebooks/135">Les Misérables by Victor Hugo (2066)</a>
# <a href="/ebooks/2500">Siddhartha by Hermann Hesse (2055)</a>
# <a href="/ebooks/996">Don Quixote by Miguel de Cervantes Saavedra (2036)</a>
# <a href="/ebooks/3600">Essays of Michel de Montaigne — Complete by Michel de Montaigne (2021)</a>
# <a href="/ebooks/25929">Daemonologie. by King of England James I (2015)</a>
# <a href="/ebooks/1934">Songs of Innocence, and Songs of Experience by William Blake (1995)</a>
# <a href="/ebooks/113">The Secret Garden by Frances Hodgson Burnett (1974)</a>
# <a href="/ebooks/730">Oliver Twist by Charles Dickens (1961)</a>
# <a href="/ebooks/7370">Second Treatise of Government by John Locke (1956)</a>
# <a href="/ebooks/4517">Ethan Frome by Edith Wharton (1920)</a>
# <a href="/ebooks/4014">Arsene Lupin by Maurice Leblanc (1855)</a>
# <a href="/ebooks/35">The Time Machine by H. G.  Wells (1854)</a>
# <a href="/ebooks/45502">How the Other Half Lives: Studies Among the Tenements of New York by Jacob A.  Riis (1813)</a>
# <a href="/ebooks/1998">Also sprach Zarathustra. English by Friedrich Wilhelm Nietzsche (1800)</a>
# <a href="/ebooks/1001">Divine Comedy, Longfellow's Translation, Hell by Dante Alighieri (1775)</a>
# <a href="/ebooks/14975">Southern Horrors: Lynch Law in All Its Phases by Ida B. Wells-Barnett (1699)</a>
# <a href="/ebooks/376">A Journal of the Plague Year by Daniel Defoe (1660)</a>
# <a href="/ebooks/766">David Copperfield by Charles Dickens (1653)</a>
# <a href="/ebooks/42324">Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (1612)</a>
# <a href="/ebooks/61">Manifest der Kommunistischen Partei. English by Friedrich Engels and Karl Marx (1565)</a>
# <a href="/ebooks/236">The Jungle Book by Rudyard Kipling (1561)</a>
# <a href="/ebooks/863">The Mysterious Affair at Styles by Agatha Christie (1561)</a>
# <a href="/ebooks/41">The Legend of Sleepy Hollow by Washington Irving (1537)</a>
# <a href="/ebooks/8800">An Index of The Divine Comedy by Dante by Dante Alighieri (1528)</a>
# <a href="/ebooks/11030">Incidents in the Life of a Slave Girl, Written by Herself by Harriet A.  Jacobs (1528)</a>
# <a href="/ebooks/209">The Turn of the Screw by Henry James (1525)</a>
# <a href="/ebooks/37134">The Elements of Style by William Strunk (1524)</a>
# <a href="/ebooks/43453">A Pickle for the Knowing Ones by Timothy Dexter (1502)</a>
# <a href="/ebooks/34901">On Liberty by John Stuart Mill (1494)</a>
# <a href="/ebooks/5827">The Problems of Philosophy by Bertrand Russell (1481)</a>
# <a href="/ebooks/375">An Occurrence at Owl Creek Bridge by Ambrose Bierce (1476)</a>
# <a href="/ebooks/1064">The Masque of the Red Death by Edgar Allan Poe (1463)</a>
# <a href="/ebooks/521">The Life and Adventures of Robinson Crusoe by Daniel Defoe (1456)</a>
# <a href="/ebooks/512">Mosses from an Old Manse, and Other Stories by Nathaniel Hawthorne (1455)</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/browse/authors/d#a37">Dickens, Charles (32101)</a>
# <a href="/browse/authors/s#a61">Shelley, Mary Wollstonecraft (29507)</a>
# <a href="/browse/authors/a#a68">Austen, Jane (28813)</a>
# <a href="/browse/authors/t#a53">Twain, Mark (20432)</a>
# <a href="/browse/authors/d#a69">Doyle, Arthur Conan (20339)</a>
# <a href="/browse/authors/w#a111">Wilde, Oscar (18475)</a>
# <a href="/browse/authors/s#a35">Stevenson, Robert Louis (13891)</a>
# <a href="/browse/authors/s#a326">Swift, Jonathan (12117)</a>
# <a href="/browse/authors/c#a7">Carroll, Lewis (11851)</a>
# <a href="/browse/authors/s#a65">Shakespeare, William (11552)</a>
# <a href="/browse/authors/h#a28">Hawthorne, Nathaniel (11419)</a>
# <a href="/browse/authors/w#a30">Wells, H. G. (Herbert George) (10030)</a>
# <a href="/browse/authors/p#a93">Plato (9631)</a>
# <a href="/browse/authors/i#a861">Ibsen, Henrik (9580)</a>
# <a href="/browse/authors/l#a1358">Leblanc, Maurice (9065)</a>
# <a href="/browse/authors/j#a94">Jowett, Benjamin (9034)</a>
# <a href="/browse/authors/l#a9473">Leech, John (8487)</a>
# <a href="/browse/authors/m#a9">Melville, Herman (8292)</a>
# <a href="/browse/authors/p#a481">Poe, Edgar Allan (8269)</a>
# <a href="/browse/authors/d#a314">Dostoyevsky, Fyodor (8004)</a>
# <a href="/browse/authors/g#a27">Gilman, Charlotte Perkins (7994)</a>
# <a href="/browse/authors/k#a1735">Kafka, Franz (7970)</a>
# <a href="/browse/authors/c#a125">Conrad, Joseph (7872)</a>
# <a href="/browse/authors/h#a705">Homer (7604)</a>
# <a href="/browse/authors/l#a120">London, Jack (7497)</a>
# <a href="/browse/authors/d#a226">Du Bois, W. E. B. (William Edward Burghardt) (7416)</a>
# <a href="/browse/authors/f#a2703">Foote, Mary Hallock (7222)</a>
# <a href="/browse/authors/a#a31267">Anthony, A. V. S. (Andrew Varick Stout) (7198)</a>
# <a href="/browse/authors/i#a31265">Ipsen, Ludvig Sandöe (7198)</a>
# <a href="/browse/authors/j#a1039">Joyce, James (7165)</a>
# <a href="/browse/authors/r#a572">Rand, Ayn (7135)</a>
# <a href="/browse/authors/w#a1736">Wyllie, David (Translator) (7129)</a>
# <a href="/browse/authors/t#a136">Tolstoy, Leo, graf (7110)</a>
# <a href="/browse/authors/n#a779">Nietzsche, Friedrich Wilhelm (6989)</a>
# <a href="/browse/authors/d#a507">Dante Alighieri (6750)</a>
# <a href="/browse/authors/b#a408">Brontë, Charlotte (6683)</a>
# <a href="/browse/authors/g#a2858">Garnett, Constance (6512)</a>
# <a href="/browse/authors/b#a42">Baum, L. Frank (Lyman Frank) (6438)</a>
# <a href="/browse/authors/t#a9854">Townsend, F. H. (Frederick Henry) (6102)</a>
# <a href="/browse/authors/k#a37155">Kemble, E. W. (Edward Windsor) (6032)</a>
# <a href="/browse/authors/j#a113">James, Henry (6017)</a>
# <a href="/browse/authors/k#a132">Kipling, Rudyard (5828)</a>
# <a href="/browse/authors/m#a36">Montgomery, L. M. (Lucy Maud) (5790)</a>
# <a href="/browse/authors/d#a1896">Doré, Gustave (5723)</a>
# <a href="/browse/authors/v#a60">Verne, Jules (5572)</a>
# <a href="/browse/authors/t#a54">Thoreau, Henry David (5352)</a>
# <a href="/browse/authors/s#a467">Shaw, Bernard (5310)</a>
# <a href="/browse/authors/a#a102">Alcott, Louisa May (5172)</a>
# <a href="/browse/authors/d#a492">Dumas, Alexandre (5031)</a>
# <a href="/browse/authors/h#a6638">Hall, J. Lesslie (John Lesslie) (4972)</a>
# <a href="/browse/authors/b#a10">Barrie, J. M. (James Matthew) (4967)</a>
# <a href="/browse/authors/d#a204">Defoe, Daniel (4944)</a>
# <a href="/browse/authors/c#a708">Chekhov, Anton Pavlovich (4853)</a>
# <a href="/browse/authors/r#a355">Russell, Bertrand (4795)</a>
# <a href="/browse/authors/w#a104">Wharton, Edith (4687)</a>
# <a href="/browse/authors/d#a34510">Douglass, Frederick (4647)</a>
# <a href="/browse/authors/g#a971">Grimm, Jacob (4548)</a>
# <a href="/browse/authors/g#a972">Grimm, Wilhelm (4548)</a>
# <a href="/browse/authors/s#a190">Stoker, Bram (4544)</a>
# <a href="/browse/authors/b#a73">Burnett, Frances Hodgson (4490)</a>
# <a href="/browse/authors/m#a563">Machiavelli, Niccolò (4475)</a>
# <a href="/browse/authors/f#a420">Fitzgerald, F. Scott (Francis Scott) (4471)</a>
# <a href="/browse/authors/l#a79">Lang, Andrew (4407)</a>
# <a href="/browse/authors/m#a1355">Morley, Henry (4383)</a>
# <a href="/browse/authors/h#a85">Hugo, Victor (4373)</a>
# <a href="/browse/authors/c#a80">Chesterton, G. K. (Gilbert Keith) (4317)</a>
# <a href="/browse/authors/v#a913">Voltaire (4297)</a>
# <a href="/browse/authors/c#a100">Chopin, Kate (4267)</a>
# <a href="/browse/authors/r#a2183">Rizal, José (4243)</a>
# <a href="/browse/authors/p#a907">Pope, Alexander (4084)</a>
# <a href="/browse/authors/c#a505">Cervantes Saavedra, Miguel de (4040)</a>
# <a href="/browse/authors/m#a564">Marriott, W. K. (William Kenaz) (4004)</a>
# <a href="/browse/authors/w#a1961">Widger, David (3957)</a>
# <a href="/browse/authors/c#a451">Christie, Agatha (3843)</a>
# <a href="/browse/authors/b#a748">Butler, Samuel (3787)</a>
# <a href="/browse/authors/f#a92">Franklin, Benjamin (3769)</a>
# <a href="/browse/authors/i#a34">Irving, Washington (3680)</a>
# <a href="/browse/authors/m#a500">Maude, Louise (3650)</a>
# <a href="/browse/authors/m#a4589">Maude, Aylmer (3582)</a>
# <a href="/browse/authors/b#a206">Bierce, Ambrose (3498)</a>
# <a href="/browse/authors/c#a3622">Cary, Henry Francis (3439)</a>
# <a href="/browse/authors/r#a44215">Rhead, Louis (3433)</a>
# <a href="/browse/authors/g#a586">Goethe, Johann Wolfgang von (3369)</a>
# <a href="/browse/authors/m#a306">Maupassant, Guy de (3331)</a>
# <a href="/browse/authors/s#a88">Sinclair, Upton (3302)</a>
# <a href="/browse/authors/m#a1705">Mill, John Stuart (3272)</a>
# <a href="/browse/authors/h#a941">Hesse, Hermann (3203)</a>
# <a href="/browse/authors/w#a5765">Wells-Barnett, Ida B. (3105)</a>
# <a href="/browse/authors/r#a2297">Robertson, James Alexander (3065)</a>
# <a href="/browse/authors/p#a292">Potter, Beatrix (3030)</a>
# <a href="/browse/authors/h#a33608">Hapgood, Isabel Florence (2979)</a>
# <a href="/browse/authors/s#a59">Scott, Walter (2966)</a>
# <a href="/browse/authors/e#a90">Eliot, George (2961)</a>
# <a href="/browse/authors/b#a251">Balzac, Honoré de (2878)</a>
# <a href="/browse/authors/o#a506">Ormsby, John (2859)</a>
# <a href="/browse/authors/b#a405">Brontë, Emily (2842)</a>
# <a href="/browse/authors/r#a6335">Rackham, Arthur (2836)</a>
# <a href="/browse/authors/h#a23">Hardy, Thomas (2819)</a>
# <a href="/browse/authors/b#a295">Blake, William (2805)</a>
# <a href="/browse/authors/b#a2296">Blair, Emma Helen (2804)</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/ebooks/84">Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (97660)</a>
# <a href="/ebooks/1342">Pride and Prejudice by Jane Austen (76099)</a>
# <a href="/ebooks/46">A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens (46871)</a>
# <a href="/ebooks/1080">A Modest Proposal by Jonathan Swift (37676)</a>
# <a href="/ebooks/11">Alice's Adventures in Wonderland by Lewis Carroll (33746)</a>
# <a href="/ebooks/25344">The Scarlet Letter by Nathaniel Hawthorne (31170)</a>
# <a href="/ebooks/6133">Arsène Lupin, gentleman-cambrioleur. English by Maurice Leblanc (30248)</a>
# <a href="/ebooks/98">A Tale of Two Cities by Charles Dickens (28877)</a>
# <a href="/ebooks/43">The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson (28876)</a>
# <a href="/ebooks/2542">Et dukkehjem. English by Henrik Ibsen (28228)</a>
# <a href="/ebooks/1952">The Yellow Wallpaper by Charlotte Perkins Gilman (26324)</a>
# <a href="/ebooks/1661">The Adventures of Sherlock Holmes by Arthur Conan Doyle (26322)</a>
# <a href="/ebooks/1250">Anthem by Ayn Rand (25752)</a>
# <a href="/ebooks/5200">Metamorphosis by Franz Kafka (25526)</a>
# <a href="/ebooks/2701">Moby Dick; Or, The Whale by Herman Melville (25374)</a>
# <a href="/ebooks/844">The Importance of Being Earnest: A Trivial Comedy for Serious People by Oscar Wilde (24768)</a>
# <a href="/ebooks/1260">Jane Eyre: An Autobiography by Charlotte Brontë (23834)</a>
# <a href="/ebooks/76">Adventures of Huckleberry Finn by Mark Twain (23662)</a>
# <a href="/ebooks/50040">St. Benedict’s Rule for Monasteries (22358)</a>
# <a href="/ebooks/174">The Picture of Dorian Gray by Oscar Wilde (21561)</a>
# <a href="/ebooks/219">Heart of Darkness by Joseph Conrad (20434)</a>
# <a href="/ebooks/16328">Beowulf: An Anglo-Saxon Epic Poem (19536)</a>
# <a href="/ebooks/74">The Adventures of Tom Sawyer, Complete by Mark Twain (18519)</a>
# <a href="/ebooks/23">Narrative of the Life of Frederick Douglass, an American Slave by Frederick Douglass (18299)</a>
# <a href="/ebooks/205">Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau (18017)</a>
# <a href="/ebooks/160">The Awakening, and Selected Short Stories by Kate Chopin (17509)</a>
# <a href="/ebooks/345">Dracula by Bram Stoker (17493)</a>
# <a href="/ebooks/1400">Great Expectations by Charles Dickens (17162)</a>
# <a href="/ebooks/2852">The Hound of the Baskervilles by Arthur Conan Doyle (17030)</a>
# <a href="/ebooks/1232">Il Principe. English by Niccolò Machiavelli (16377)</a>
# <a href="/ebooks/408">The Souls of Black Folk by W. E. B.  Du Bois (16025)</a>
# <a href="/ebooks/16">Peter Pan by J. M.  Barrie (15283)</a>
# <a href="/ebooks/120">Treasure Island by Robert Louis Stevenson (14972)</a>
# <a href="/ebooks/55">The Wonderful Wizard of Oz by L. Frank  Baum (14072)</a>
# <a href="/ebooks/2591">Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm (13648)</a>
# <a href="/ebooks/25929">Daemonologie. by King of England James I (13625)</a>
# <a href="/ebooks/1497">The Republic by Plato (13307)</a>
# <a href="/ebooks/514">Little Women by Louisa May Alcott (13154)</a>
# <a href="/ebooks/215">The Call of the Wild by Jack London (13095)</a>
# <a href="/ebooks/19942">Candide by Voltaire (12854)</a>
# <a href="/ebooks/4014">Arsene Lupin by Maurice Leblanc (12656)</a>
# <a href="/ebooks/2814">Dubliners by James Joyce (12281)</a>
# <a href="/ebooks/158">Emma by Jane Austen (12096)</a>
# <a href="/ebooks/4300">Ulysses by James Joyce (11747)</a>
# <a href="/ebooks/2600">War and Peace by graf Leo Tolstoy (11670)</a>
# <a href="/ebooks/45">Anne of Green Gables by L. M.  Montgomery (11228)</a>
# <a href="/ebooks/36">The War of the Worlds by H. G.  Wells (10737)</a>
# <a href="/ebooks/768">Wuthering Heights by Emily Brontë (10712)</a>
# <a href="/ebooks/25482">The Armed Forces Officer by United States. Department of Defense (10663)</a>
# <a href="/ebooks/3825">Pygmalion by Bernard Shaw (10590)</a>
# <a href="/ebooks/1184">The Count of Monte Cristo, Illustrated by Alexandre Dumas (10539)</a>
# <a href="/ebooks/2554">Prestuplenie i nakazanie. English by Fyodor Dostoyevsky (10360)</a>
# <a href="/ebooks/3207">Leviathan by Thomas Hobbes (10178)</a>
# <a href="/ebooks/2097">The Sign of the Four by Arthur Conan Doyle (9914)</a>
# <a href="/ebooks/58585">The Prophet by Kahlil Gibran (9759)</a>
# <a href="/ebooks/244">A Study in Scarlet by Arthur Conan Doyle (9689)</a>
# <a href="/ebooks/140">The Jungle by Upton Sinclair (9535)</a>
# <a href="/ebooks/64317">The Great Gatsby by F. Scott  Fitzgerald (9341)</a>
# <a href="/ebooks/1727">The Odyssey by Homer (9302)</a>
# <a href="/ebooks/135">Les Misérables by Victor Hugo (9027)</a>
# <a href="/ebooks/42108">The Slang Dictionary: Etymological, Historical and Andecdotal by John Camden Hotten (8911)</a>
# <a href="/ebooks/2500">Siddhartha by Hermann Hesse (8788)</a>
# <a href="/ebooks/35">The Time Machine by H. G.  Wells (8750)</a>
# <a href="/ebooks/5740">Tractatus Logico-Philosophicus by Ludwig Wittgenstein (8732)</a>
# <a href="/ebooks/996">Don Quixote by Miguel de Cervantes Saavedra (8673)</a>
# <a href="/ebooks/57426">Baron Trump's Marvellous Underground Journey by Ingersoll Lockwood (8631)</a>
# <a href="/ebooks/902">The Happy Prince, and Other Tales by Oscar Wilde (8463)</a>
# <a href="/ebooks/1934">Songs of Innocence, and Songs of Experience by William Blake (8456)</a>
# <a href="/ebooks/113">The Secret Garden by Frances Hodgson Burnett (8370)</a>
# <a href="/ebooks/203">Uncle Tom's Cabin by Harriet Beecher Stowe (8358)</a>
# <a href="/ebooks/730">Oliver Twist by Charles Dickens (8289)</a>
# <a href="/ebooks/829">Gulliver's Travels into Several Remote Nations of the World by Jonathan Swift (8203)</a>
# <a href="/ebooks/3600">Essays of Michel de Montaigne — Complete by Michel de Montaigne (8145)</a>
# <a href="/ebooks/4517">Ethan Frome by Edith Wharton (7850)</a>
# <a href="/ebooks/6130">The Iliad by Homer (7679)</a>
# <a href="/ebooks/20203">Autobiography of Benjamin Franklin by Benjamin Franklin (7666)</a>
# <a href="/ebooks/15399">The Interesting Narrative of the Life of Olaudah Equiano, Or Gustavus Vassa, The African by Equiano (7592)</a>
# <a href="/ebooks/1998">Also sprach Zarathustra. English by Friedrich Wilhelm Nietzsche (7543)</a>
# <a href="/ebooks/26184">Simple Sabotage Field Manual by United States. Office of Strategic Services (7503)</a>
# <a href="/ebooks/863">The Mysterious Affair at Styles by Agatha Christie (7364)</a>
# <a href="/ebooks/1001">Divine Comedy, Longfellow's Translation, Hell by Dante Alighieri (7239)</a>
# <a href="/ebooks/376">A Journal of the Plague Year by Daniel Defoe (7226)</a>
# <a href="/ebooks/766">David Copperfield by Charles Dickens (7060)</a>
# <a href="/ebooks/236">The Jungle Book by Rudyard Kipling (6906)</a>
# <a href="/ebooks/41">The Legend of Sleepy Hollow by Washington Irving (6840)</a>
# <a href="/ebooks/37134">The Elements of Style by William Strunk (6583)</a>
# <a href="/ebooks/7370">Second Treatise of Government by John Locke (6555)</a>
# <a href="/ebooks/34901">On Liberty by John Stuart Mill (6485)</a>
# <a href="/ebooks/147">Common Sense by Thomas Paine (6390)</a>
# <a href="/ebooks/851">Narrative of the Captivity and Restoration of Mrs. Mary Rowlandson by Mary White Rowlandson (6358)</a>
# <a href="/ebooks/209">The Turn of the Screw by Henry James (6293)</a>
# <a href="/ebooks/1064">The Masque of the Red Death by Edgar Allan Poe (6248)</a>
# <a href="/ebooks/8800">An Index of The Divine Comedy by Dante by Dante Alighieri (6191)</a>
# <a href="/ebooks/43453">A Pickle for the Knowing Ones by Timothy Dexter (6137)</a>
# <a href="/ebooks/521">The Life and Adventures of Robinson Crusoe by Daniel Defoe (5999)</a>
# <a href="/ebooks/57775">Le jardin des supplices by Octave Mirbeau (5962)</a>
# <a href="/ebooks/61">Manifest der Kommunistischen Partei. English by Friedrich Engels and Karl Marx (5948)</a>
# <a href="/ebooks/2148">The Works of Edgar Allan Poe — Volume 2 by Edgar Allan Poe (5883)</a>
# <a href="/ebooks/42324">Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (5880)</a>
# <a href="/ebooks/1399">Anna Karenina by graf Leo Tolstoy (5866)</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/browse/authors/d#a37">Dickens, Charles (149981)</a>
# <a href="/browse/authors/a#a68">Austen, Jane (117511)</a>
# <a href="/browse/authors/s#a61">Shelley, Mary Wollstonecraft (108851)</a>
# <a href="/browse/authors/t#a53">Twain, Mark (86529)</a>
# <a href="/browse/authors/d#a69">Doyle, Arthur Conan (86322)</a>
# <a href="/browse/authors/w#a111">Wilde, Oscar (70766)</a>
# <a href="/browse/authors/s#a35">Stevenson, Robert Louis (60348)</a>
# <a href="/browse/authors/l#a1358">Leblanc, Maurice (59462)</a>
# <a href="/browse/authors/c#a7">Carroll, Lewis (51564)</a>
# <a href="/browse/authors/s#a326">Swift, Jonathan (51094)</a>
# <a href="/browse/authors/l#a9473">Leech, John (49171)</a>
# <a href="/browse/authors/s#a65">Shakespeare, William (46807)</a>
# <a href="/browse/authors/h#a28">Hawthorne, Nathaniel (46290)</a>
# <a href="/browse/authors/w#a30">Wells, H. G. (Herbert George) (44557)</a>
# <a href="/browse/authors/p#a93">Plato (39030)</a>
# <a href="/browse/authors/i#a861">Ibsen, Henrik (37879)</a>
# <a href="/browse/authors/j#a94">Jowett, Benjamin (36791)</a>
# <a href="/browse/authors/p#a481">Poe, Edgar Allan (34954)</a>
# <a href="/browse/authors/m#a9">Melville, Herman (34805)</a>
# <a href="/browse/authors/d#a314">Dostoyevsky, Fyodor (33849)</a>
# <a href="/browse/authors/c#a125">Conrad, Joseph (32490)</a>
# <a href="/browse/authors/k#a1735">Kafka, Franz (31722)</a>
# <a href="/browse/authors/f#a2703">Foote, Mary Hallock (31251)</a>
# <a href="/browse/authors/i#a31265">Ipsen, Ludvig Sandöe (31170)</a>
# <a href="/browse/authors/a#a31267">Anthony, A. V. S. (Andrew Varick Stout) (31170)</a>
# <a href="/browse/authors/t#a136">Tolstoy, Leo, graf (30580)</a>
# <a href="/browse/authors/n#a779">Nietzsche, Friedrich Wilhelm (29695)</a>
# <a href="/browse/authors/l#a120">London, Jack (29668)</a>
# <a href="/browse/authors/g#a27">Gilman, Charlotte Perkins (29546)</a>
# <a href="/browse/authors/j#a1039">Joyce, James (29135)</a>
# <a href="/browse/authors/h#a705">Homer (28849)</a>
# <a href="/browse/authors/w#a1736">Wyllie, David (Translator) (28074)</a>
# <a href="/browse/authors/d#a507">Dante Alighieri (27184)</a>
# <a href="/browse/authors/g#a2858">Garnett, Constance (27020)</a>
# <a href="/browse/authors/b#a42">Baum, L. Frank (Lyman Frank) (26891)</a>
# <a href="/browse/authors/b#a408">Brontë, Charlotte (26840)</a>
# <a href="/browse/authors/r#a572">Rand, Ayn (26449)</a>
# <a href="/browse/authors/j#a113">James, Henry (24804)</a>
# <a href="/browse/authors/m#a36">Montgomery, L. M. (Lucy Maud) (24749)</a>
# <a href="/browse/authors/k#a37155">Kemble, E. W. (Edward Windsor) (24719)</a>
# <a href="/browse/authors/t#a9854">Townsend, F. H. (Frederick Henry) (24471)</a>
# <a href="/browse/authors/t#a54">Thoreau, Henry David (23980)</a>
# <a href="/browse/authors/d#a1896">Doré, Gustave (23905)</a>
# <a href="/browse/authors/k#a132">Kipling, Rudyard (23846)</a>
# <a href="/browse/authors/v#a60">Verne, Jules (23455)</a>
# <a href="/browse/authors/d#a492">Dumas, Alexandre (22952)</a>
# <a href="/browse/authors/b#a45673">Benedict, Saint, Abbot of Monte Cassino (22358)</a>
# <a href="/browse/authors/d#a45674">Doyle, Leonard J. (Leonard Joseph) (22358)</a>
# <a href="/browse/authors/a#a102">Alcott, Louisa May (22125)</a>
# <a href="/browse/authors/d#a226">Du Bois, W. E. B. (William Edward Burghardt) (21735)</a>
# <a href="/browse/authors/b#a10">Barrie, J. M. (James Matthew) (21402)</a>
# <a href="/browse/authors/s#a467">Shaw, Bernard (20949)</a>
# <a href="/browse/authors/d#a204">Defoe, Daniel (20615)</a>
# <a href="/browse/authors/w#a104">Wharton, Edith (20542)</a>
# <a href="/browse/authors/d#a34510">Douglass, Frederick (20217)</a>
# <a href="/browse/authors/r#a2183">Rizal, José (20201)</a>
# <a href="/browse/authors/s#a190">Stoker, Bram (19983)</a>
# <a href="/browse/authors/h#a6638">Hall, J. Lesslie (John Lesslie) (19536)</a>
# <a href="/browse/authors/g#a971">Grimm, Jacob (19344)</a>
# <a href="/browse/authors/g#a972">Grimm, Wilhelm (19344)</a>
# <a href="/browse/authors/c#a708">Chekhov, Anton Pavlovich (19201)</a>
# <a href="/browse/authors/b#a73">Burnett, Frances Hodgson (19191)</a>
# <a href="/browse/authors/r#a355">Russell, Bertrand (19056)</a>
# <a href="/browse/authors/h#a85">Hugo, Victor (19019)</a>
# <a href="/browse/authors/v#a913">Voltaire (18762)</a>
# <a href="/browse/authors/m#a563">Machiavelli, Niccolò (18599)</a>
# <a href="/browse/authors/c#a80">Chesterton, G. K. (Gilbert Keith) (18335)</a>
# <a href="/browse/authors/m#a1355">Morley, Henry (18075)</a>
# <a href="/browse/authors/c#a451">Christie, Agatha (18042)</a>
# <a href="/browse/authors/l#a79">Lang, Andrew (18001)</a>
# <a href="/browse/authors/c#a100">Chopin, Kate (17960)</a>
# <a href="/browse/authors/c#a505">Cervantes Saavedra, Miguel de (17369)</a>
# <a href="/browse/authors/w#a1961">Widger, David (16930)</a>
# <a href="/browse/authors/m#a564">Marriott, W. K. (William Kenaz) (16554)</a>
# <a href="/browse/authors/l#a9462">Lockwood, Ingersoll (15455)</a>
# <a href="/browse/authors/p#a907">Pope, Alexander (15362)</a>
# <a href="/browse/authors/m#a500">Maude, Louise (15193)</a>
# <a href="/browse/authors/r#a44215">Rhead, Louis (14982)</a>
# <a href="/browse/authors/m#a4589">Maude, Aylmer (14932)</a>
# <a href="/browse/authors/b#a748">Butler, Samuel (14833)</a>
# <a href="/browse/authors/f#a92">Franklin, Benjamin (14605)</a>
# <a href="/browse/authors/g#a586">Goethe, Johann Wolfgang von (14585)</a>
# <a href="/browse/authors/i#a34">Irving, Washington (14581)</a>
# <a href="/browse/authors/m#a306">Maupassant, Guy de (14386)</a>
# <a href="/browse/authors/b#a206">Bierce, Ambrose (14062)</a>
# <a href="/browse/authors/c#a3622">Cary, Henry Francis (13938)</a>
# <a href="/browse/authors/f#a420">Fitzgerald, F. Scott (Francis Scott) (13922)</a>
# <a href="/browse/authors/p#a292">Potter, Beatrix (13770)</a>
# <a href="/browse/authors/j#a7089">James I, King of England (13660)</a>
# <a href="/browse/authors/m#a1705">Mill, John Stuart (13245)</a>
# <a href="/browse/authors/b#a295">Blake, William (13065)</a>
# <a href="/browse/authors/b#a251">Balzac, Honoré de (12986)</a>
# <a href="/browse/authors/h#a33608">Hapgood, Isabel Florence (12904)</a>
# <a href="/browse/authors/w#a783">Wodehouse, P. G. (Pelham Grenville) (12799)</a>
# <a href="/browse/authors/j#a1357">Jepson, Edgar (12770)</a>
# <a href="/browse/authors/s#a59">Scott, Walter (12769)</a>
# <a href="/browse/authors/s#a88">Sinclair, Upton (12424)</a>
# <a href="/browse/authors/o#a506">Ormsby, John (12407)</a>
# <a href="/browse/authors/r#a6335">Rackham, Arthur (12371)</a>
# <a href="/browse/authors/e#a90">Eliot, George (12191)</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/policy/privacy_policy.html" title="Privacy Policy">Privacy policy</a>
# <a href="/about/" title="About Project Gutenberg">About Project Gutenberg</a>
# <a href="/policy/terms_of_use.html" title="Terms of Use">Terms of Use</a>
# <a href="/about/contact_information.html" title="Contact Information">Contact Information</a>
# <a href="/help/" title="Get Help">Get Help</a>
# <a href="https://www.ibiblio.org/" title="Project Gutenberg is hosted by ibiblio">
# <img alt="iBiblio" src="/gutenberg/ibiblio-logo.png"/>
# </a>

# %% [markdown]
# ### Use regular expression to find the numeric digits in these links. <br>These are the file number for the Top 100 books.

# %% [markdown]
# #### Initialize empty list to hold the file numbers

# %%
file_numbers = []

# %% [markdown]
# * Number 19 to 118 in the original list of links have the Top 100 ebooks' number.
# * Loop over appropriate range and use regex to find the numeric digits in the link (href) string.
# * Hint: Use `findall()` method

# %%
#//***********************************************************************************
#//*** I'm going to gather the file numbers for the Top 100 EBooks Yesterday
#//***********************************************************************************

#//*** The list of ebooks starts after the value of pattern_start
pattern_start = "#authors-last30"
begin_match = False

#//*** Loop through the a tag lists
for a in href_list:
    #//*** Get the href for each 'a' tag in the list
    item = a.get('href')
    
    #//*** Look for the start of the relevant items, otherwise do nothing
    if pattern_start in item:
        #//*** Start of content found
        begin_match = True
        
        #//*** Advance to the next item
        continue
    
    #//*** Values are found. Harvest the ebook Items
    if begin_match == True:

        #//*** Quit on next Category tag
        if "#" in item:
            break
        #//*** Verify there is ebooks in the href
        if "ebooks" in item:
            file_numbers.append(item.replace("/ebooks/",""))

# %% [markdown]
# #### Print the file numbers

# %%
x = 0
for y in file_numbers:
    x = x + 1
    print(f"{x}. {y}")
# Out:
# 1. 1342
# 2. 84
# 3. 11
# 4. 1080
# 5. 1661
# 6. 1952
# 7. 5200
# 8. 98
# 9. 1260
# 10. 174
# 11. 2701
# 12. 25344
# 13. 2542
# 14. 844
# 15. 6133
# 16. 46
# 17. 408
# 18. 76
# 19. 43
# 20. 219
# 21. 16328
# 22. 205
# 23. 345
# 24. 902
# 25. 74
# 26. 1250
# 27. 1232
# 28. 1400
# 29. 1497
# 30. 16
# 31. 23
# 32. 160
# 33. 64481
# 34. 158
# 35. 2600
# 36. 4300
# 37. 64317
# 38. 140
# 39. 57775
# 40. 2814
# 41. 120
# 42. 2591
# 43. 2852
# 44. 514
# 45. 3207
# 46. 64474
# 47. 55
# 48. 6130
# 49. 768
# 50. 1184
# 51. 3825
# 52. 3600
# 53. 42108
# 54. 135
# 55. 45
# 56. 15399
# 57. 64476
# 58. 1727
# 59. 64480
# 60. 2554
# 61. 1998
# 62. 5740
# 63. 203
# 64. 244
# 65. 64473
# 66. 996
# 67. 36
# 68. 19942
# 69. 1934
# 70. 829
# 71. 215
# 72. 766
# 73. 58585
# 74. 64485
# 75. 4014
# 76. 3090
# 77. 1001
# 78. 64490
# 79. 64488
# 80. 113
# 81. 35
# 82. 20203
# 83. 7370
# 84. 851
# 85. 2500
# 86. 376
# 87. 25929
# 88. 30254
# 89. 863
# 90. 730
# 91. 236
# 92. 161
# 93. 8800
# 94. 4363
# 95. 1399
# 96. 32415
# 97. 521
# 98. 64470
# 99. 779
# 100. 2097

# %% [markdown]
# ### How does the `soup` object's text look like? Use `.text()` method and print only first 2000 characters (i.e. do not print the whole thing, it is long).
#
# You will notice lot of empty spaces/blanks here and there. Ignore them. They are part of HTML page markup and its whimsical nature!

# %%
print(soup.get_text()[:2000])
# Out:
# Top 100 | Project Gutenberg
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Menu▾
#
#
#
# About
#           ▾
#
# ▾
#
#
# About Project Gutenberg
# Collection Development
# Contact Us
# History & Philosophy
# Permissions & License
# Privacy Policy
# Terms of Use
#
#
#
# Search and Browse
#       	  ▾
#
# ▾
#
#
# Book Search
# Bookshelves
# Frequently Downloaded
# Offline Catalogs
#
#
#
# Help
#           ▾
#
# ▾
#
#
# All help topics →
# Copyright Procedures
# Errata, Fixes and Bug Reports
# File Formats
# Frequently Asked Questions
# Policies →
# Public Domain eBook Submission
# Submitting Your Own Work
# Tablets, Phones and eReaders
# The Attic →
#
#
# Donate
#
#
#
#
#
#
#
#
#
#
# Donation
#
#
#
#
#
#
#
# Frequently Viewed or Downloaded
# These listings are based on the number of times each eBook gets downloaded.
#       Multiple downloads from the same Internet address on the same day count as one download, and addresses that download more than 100 eBooks in a day are considered robots and are not counted.
#
# Downloaded Books
# 2021-02-07168381
# last 7 days1349431
# last 30 days5681061
#
#
#
# Top 100 EBooks yesterday
# Top 100 Authors yesterday
# Top 100 EBooks last 7 days
# Top 100 Authors last 7 days
# Top 100 EBooks last 30 days
# Top 100 Authors last 30 days
#
#
# Top 100 EBooks yesterday
#
# Pride and Prejudice by Jane Austen (2238)
# Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (2097)
# Alice's Adventures in Wonderland by Lewis Carroll (872)
# A Modest Proposal by Jonathan Swift (837)
# The Adventures of Sherlock Holmes by Arthur Conan Doyle (786)
# The Yellow Wallpaper by Charlotte Perkins Gilman (763)
# Metamorphosis by Franz Kafka (750)
# A Tale of Two Cities by Charles Dickens (740)
# Jane Eyre: An Autobiography by Charlotte Brontë (665)
# The Picture of Dorian Gray by Oscar Wilde (664)
# Moby Dick; Or, The Whale by Herman Melville (654)
# The Scarlet Letter by Nathaniel Hawthorne (636)
# Et dukkehjem. English by Henrik Ibsen (622)
# The Importance of Being Earnest: A Trivial Comedy for Serious People by Oscar Wilde (617)
# Arsène Lupin, gentleman-cambrioleur. English by Maurice Leblanc (611)
# A Christmas

# %% [markdown]
# ### Search in the extracted text (using regular expression) from the `soup` object to find the names of top 100 Ebooks (Yesterday's rank)

# %%
#//****************************************************************************
#//*** Going to solve this with more Regex and string processing than Soup.
#//****************************************************************************

#//*** Store the Book Names
book_names = []

#//*** Raw text of the entire html document
raw_text = soup.get_text()

#//*** Define the regex: The key is the [\\W\\w]*?. 
#//*** [\\W\\w] - Matches any Word or Non-Word Character. This matches everything including a newline.
#//*** I learned this trick many moons ago. 
#//*** * matches the preceding value (word or non word)
#//*** ? matches 0 or 1 and makes the regex lazy or ungreedy
pattern = re.compile("Top 100 EBooks yesterday[\\W\\w]*?Top 100 EBooks yesterday\nTop 100 Authors yesterday")

#//*** Apply the regex and keep the first result.
#//*** This is the raw string of the content
result = pattern.findall(raw_text)[0]

#//*** Split the results by newline
for line in result.split("\n"):
    #//*** Filter out the garbage
    
    #//*** Skip empty lines
    if len(line) == 0:
        continue
    
    #//*** Filter out the category names, let's get real specific
    #//*** Title must include Top 100
    if "Top 100" in line:
        #//*** And either Ebooks or Authors
        if "EBooks" or "Authors" in line:
            #//*** And yesterday or last 7 days or last 30 days
            if "yesterday" or "last 7 days" or "last 30 days" in line:
                continue
    #//*** This specificity should avoid skipping the wrong titles.
    
    #//*** Remove everything between the Parenthesis ( ) because we can
    paran_pattern = re.compile("\(.+\)")
    #//*** Perform regex findall for parantheses
    paran_replace = paran_pattern.findall(line) 
    
    #//*** Every line *should* have paranthesis, but let's double check that we do. This is a hard learned 
    #//*** lesson, never assume your data result before working on it. Although I violated this rule
    #//*** on line 17.

    if len(paran_replace) > 0:
        
        #//*** Grab first Item, which is string to replace.
        paran_replace = paran_replace[0]
        line = line.replace(paran_replace,"")

    book_names.append(line)

# %% [markdown]
# # I honestly don't understand any of this. Why use Beautiful Soup if regex can solve the same problem of parsing a chunk of text?#
#
# #### Create a starting index. It should point at the text _"Top 100 Ebooks yesterday"_. Hint: Use `splitlines()` method of the `soup.text`. It splits the lines of the text of the `soup` object.

# %% [markdown]
# #### Loop 1-100 to add the strings of next 100 lines to this temporary list. Hint: `splitlines()` method

# %% [markdown]
# #### Use regular expression to extract only text from the name strings and append to an empty list
# * Hint: Use `match` and `span` to find indices and use them

# %% [markdown]
# #### Print the list of titles

# %%
for x in range(0,len(book_names)):
    print(f"{x+1}. [{file_numbers[x]}] {book_names[x]}")
# Out:
# 1. [1342] Pride and Prejudice by Jane Austen
# 2. [84] Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley
# 3. [11] Alice's Adventures in Wonderland by Lewis Carroll
# 4. [1080] A Modest Proposal by Jonathan Swift
# 5. [1661] The Adventures of Sherlock Holmes by Arthur Conan Doyle
# 6. [1952] The Yellow Wallpaper by Charlotte Perkins Gilman
# 7. [5200] Metamorphosis by Franz Kafka
# 8. [98] A Tale of Two Cities by Charles Dickens
# 9. [1260] Jane Eyre: An Autobiography by Charlotte Brontë
# 10. [174] The Picture of Dorian Gray by Oscar Wilde
# 11. [2701] Moby Dick; Or, The Whale by Herman Melville
# 12. [25344] The Scarlet Letter by Nathaniel Hawthorne
# 13. [2542] Et dukkehjem. English by Henrik Ibsen
# 14. [844] The Importance of Being Earnest: A Trivial Comedy for Serious People by Oscar Wilde
# 15. [6133] Arsène Lupin, gentleman-cambrioleur. English by Maurice Leblanc
# 16. [46] A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens
# 17. [408] The Souls of Black Folk by W. E. B.  Du Bois
# 18. [76] Adventures of Huckleberry Finn by Mark Twain
# 19. [43] The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson
# 20. [219] Heart of Darkness by Joseph Conrad
# 21. [16328] Beowulf: An Anglo-Saxon Epic Poem
# 22. [205] Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau
# 23. [345] Dracula by Bram Stoker
# 24. [902] The Happy Prince, and Other Tales by Oscar Wilde
# 25. [74] The Adventures of Tom Sawyer, Complete by Mark Twain
# 26. [1250] Anthem by Ayn Rand
# 27. [1232] Il Principe. English by Niccolò Machiavelli
# 28. [1400] Great Expectations by Charles Dickens
# 29. [1497] The Republic by Plato
# 30. [16] Peter Pan by J. M.  Barrie
# 31. [23] Narrative of the Life of Frederick Douglass, an American Slave by Frederick Douglass
# 32. [160] The Awakening, and Selected Short Stories by Kate Chopin
# 33. [64481] Chicken Farm by Ross Rocklynne
# 34. [158] Emma by Jane Austen
# 35. [2600] War and Peace by graf Leo Tolstoy
# 36. [4300] Ulysses by James Joyce
# 37. [64317] The Great Gatsby by F. Scott  Fitzgerald
# 38. [140] The Jungle by Upton Sinclair
# 39. [57775] Le jardin des supplices by Octave Mirbeau
# 40. [2814] Dubliners by James Joyce
# 41. [120] Treasure Island by Robert Louis Stevenson
# 42. [2591] Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm
# 43. [2852] The Hound of the Baskervilles by Arthur Conan Doyle
# 44. [514] Little Women by Louisa May Alcott
# 45. [3207] Leviathan by Thomas Hobbes
# 46. [64474] Planet In Reverse by Henry Guth
# 47. [55] The Wonderful Wizard of Oz by L. Frank  Baum
# 48. [6130] The Iliad by Homer
# 49. [768] Wuthering Heights by Emily Brontë
# 50. [1184] The Count of Monte Cristo, Illustrated by Alexandre Dumas
# 51. [3825] Pygmalion by Bernard Shaw
# 52. [3600] Essays of Michel de Montaigne — Complete by Michel de Montaigne
# 53. [42108] The Slang Dictionary: Etymological, Historical and Andecdotal by John Camden Hotten
# 54. [135] Les Misérables by Victor Hugo
# 55. [45] Anne of Green Gables by L. M.  Montgomery
# 56. [15399] The Interesting Narrative of the Life of Olaudah Equiano, Or Gustavus Vassa, The African by Equiano
# 57. [64476] Panama and the Canal in Picture and Prose by Willis J. Abbott
# 58. [1727] The Odyssey by Homer
# 59. [64480] Amour, Amour, Dear Planet! by Mark Clutter
# 60. [2554] Prestuplenie i nakazanie. English by Fyodor Dostoyevsky
# 61. [1998] Also sprach Zarathustra. English by Friedrich Wilhelm Nietzsche
# 62. [5740] Tractatus Logico-Philosophicus by Ludwig Wittgenstein
# 63. [203] Uncle Tom's Cabin by Harriet Beecher Stowe
# 64. [244] A Study in Scarlet by Arthur Conan Doyle
# 65. [64473] Task of Tau by J. Harvey  Haggard
# 66. [996] Don Quixote by Miguel de Cervantes Saavedra
# 67. [36] The War of the Worlds by H. G.  Wells
# 68. [19942] Candide by Voltaire
# 69. [1934] Songs of Innocence, and Songs of Experience by William Blake
# 70. [829] Gulliver's Travels into Several Remote Nations of the World by Jonathan Swift
# 71. [215] The Call of the Wild by Jack London
# 72. [766] David Copperfield by Charles Dickens
# 73. [58585] The Prophet by Kahlil Gibran
# 74. [64485] The Origin of the Mound Builders by Alfred Oscar Coffin
# 75. [4014] Arsene Lupin by Maurice Leblanc
# 76. [3090] Complete Original Short Stories of Guy De Maupassant by Guy de Maupassant
# 77. [1001] Divine Comedy, Longfellow's Translation, Hell by Dante Alighieri
# 78. [64490] Stories of the Wars of the Jews by A. L. O. E.
# 79. [64488] Roman Stoicism by E. Vernon Arnold
# 80. [113] The Secret Garden by Frances Hodgson Burnett
# 81. [35] The Time Machine by H. G.  Wells
# 82. [20203] Autobiography of Benjamin Franklin by Benjamin Franklin
# 83. [7370] Second Treatise of Government by John Locke
# 84. [851] Narrative of the Captivity and Restoration of Mrs. Mary Rowlandson by Mary White Rowlandson
# 85. [2500] Siddhartha by Hermann Hesse
# 86. [376] A Journal of the Plague Year by Daniel Defoe
# 87. [25929] Daemonologie. by King of England James I
# 88. [30254] The Romance of Lust: A classic Victorian erotic novel by Anonymous
# 89. [863] The Mysterious Affair at Styles by Agatha Christie
# 90. [730] Oliver Twist by Charles Dickens
# 91. [236] The Jungle Book by Rudyard Kipling
# 92. [161] Sense and Sensibility by Jane Austen
# 93. [8800] An Index of The Divine Comedy by Dante by Dante Alighieri
# 94. [4363] Beyond Good and Evil by Friedrich Wilhelm Nietzsche
# 95. [1399] Anna Karenina by graf Leo Tolstoy
# 96. [32415] The Nursery Rhymes of England
# 97. [521] The Life and Adventures of Robinson Crusoe by Daniel Defoe
# 98. [64470] Biblical Revision by Henry Alford
# 99. [779] The Tragical History of Doctor Faustus by Christopher Marlowe
# 100. [2097] The Sign of the Four by Arthur Conan Doyle

# %% [markdown]
# # Advanced web scraping and data gathering
# ## Activity 10: Build your own movie database by reading from an API
# ### This notebook does the following
# * Retrieves and prints basic data about a movie (title entered by user) from the web (OMDB database)
# * If a poster of the movie could be found, it downloads the file and saves at a user-specified location

# %%
import urllib.request, urllib.parse, urllib.error
import json

# %% [markdown]
# ### Load the secret API key (you have to get one from OMDB website and use that, 1000 daily limit) from a JSON file, stored in the same folder into a variable
# Hint: Use **`json.loads()`**
#
# #### Note: The following cell will not be executed in the solution notebook because the author cannot give out his private API key.
# #### Students/users/instructor will need to obtain a key and store in a JSON file.
# #### For the code's sake, we are calling this file `APIkeys.json`. But you need to store your own key in this file.
# #### An example file called `"APIkey_Bogus_example.json"` is given along with the notebook. Just change the code in this file and rename as `APIkeys.json`. The file name does not matter of course.

# %%
#//*************************************************
#//*** Read the API key from a JSON encoded file
#//*************************************************
f = open("z_omdb_api.key", "r")

#//*** Fugley Pythonic type conversion
#//*** Loads the file into Dictionary via JSON.loads
#//*** Gets the API key value using the 'api' key
#//*** prepends apikey= so the resulting value is URL ready :]
apikey = "apikey=" + json.loads(f.read())['api']
f.close()

# %% [markdown]
# ### The final URL to be passed should look like: http://www.omdbapi.com/?t=movie_name&apikey=secretapikey
# Do the following,
# * Assign the OMDB portal (http://www.omdbapi.com/?) as a string to a variable `serviceurl` (don't miss the `?`)
# * Create a variable `apikey` with the last portion of the URL ("&apikey=secretapikey"), where `secretapikey` is your own API key (an actual code)
# * The movie name portion i.e. "t=movie_name" will be addressed later

# %%
#//*******************************************************************************
#//*** The Current doc on omdbapi.com the apikey should be included first.
#//*** Stylistically this makes sense, since that's the static part of the call.
#//*******************************************************************************
service_url = "http://www.omdbapi.com/?" + apikey + "&"

# %% [markdown]
# ### Write a utility function to download a poster of the movie based on the information from the jason dataset and save in your local folder
#
# * Use `os` module
# * The poster data is stored in the JSON key 'Poster'
# * You may want to split the name of the Poster file and extract the file extension only. Let's say the extension is ***'jpg'***.
# * Then later join this extension to the movie name and create a filename like ***movie.jpg***
# * Use the Python command `open` to open a file and write the poster data. Close the file after done.
# * This function may not return anything. It just saves the poster data as an image file.

# %%
#//*** Download the movie poster and display it
def get_poster(input_name,input_url):
    
    #//*******************************************************************
    #//*** get file extension, assume the extenstion is after the last .
    #//*** Since we treat the file as temporary, this step isnt needed
    #//*** But it's a nice-to-have
    #//*******************************************************************
    if "." in input_url:
        filename = "z_9_10_" + input_name + "." + input_url.split(".")[-1]
    else:
        #//*** No extension found for some reason. Let's call it a .byebye file.
        #//*** Since it's going byebye no matter what we name it.
        
        filename = input_name + ".byebye"
    
    #//*** Download the file with urllib
    try:
        
        response = urllib.request.urlopen(input_url)
        
    except:
        print("[No Poster image]")
        return
    
   
    #//*** Write Poster to disk
    f = open(filename, "wb") 
    f.write(response.read())
    f.close()
    
    #//*** Display the poster inline. Because we are cool like that
    display(Image(filename=filename))
    
    #//*** Delete the local image, to keep things uncluttered
    if os.path.isfile(filename):
        os.remove(filename)

# %% [markdown]
# ### Write a utility function `print_json` to print nicely the movie data from a JSON file (which we will get from the portal)
# Here are the keys of a JSON file,
#
# 'Title', 'Year', 'Rated', 'Released', 'Runtime', 'Genre', 'Director', 'Writer', 'Actors', 'Plot', 'Language','Country', 'Awards', 'Ratings', 'Metascore', 'imdbRating', 'imdbVotes', 'imdbID'
#
# But why limit ourselves to this list? We should print all-the-JSON.
# If the JSON is layered, we'll use recursion.

# %%
def print_json(input_obj,level=0):

    #//*** If there is a valid Poster URL and Title.
    #//*** Download and Display the movie poster
    if "Poster" in input_obj.keys() and "Title" in input_obj.keys():
        poster_url = input_obj["Poster"]
        poster_name = input_obj["Title"]
        
        get_poster(poster_name,poster_url)
    
    #//*** Tabs are used for recursion
    #//*** For every level of recursion, add a tab
    #//*** My test data only goes down to two levels, it will be fun to test with more
    
    tab=""
    for x in range(level):
        tab += "\t"
    
    #//*** Loop through the JSON keys and values
    for key,value in input_obj.items():
        
        #//*** If the response is True, skip the display
        #//*** This will print on a fale response
        if key == "Response" and value == "True":
            continue
        
        #//*** Skip Poster, it should already by handled
        if key == "Poster":
            continue
    
        #//*** If the Value is a string, print the key and value.
        if isinstance(value,str):
            print(f"{tab}{key}: {value}")

        #//*** If the Object is a list, print the key
        #//*** Iterate through the list calling print_json on each item with a level + 1.
        #//*** Which will increase the tab level with each call ---- Fun Stuff
        elif isinstance(value,list):
                print(f"{tab}{key}:")
                for item in value:
                    print_json(item,level+1)
        else:
            #//*** If it's not a list or string, print it anyway. This leaves a future debugging path open
            print(f"{tab}-->{key}: {type(value)} {value}")

# %% [markdown]
# ### Write a utility function `search_movie` to search a movie by its name, print the downloaded JSON data (use the `print_json` function for this) and save the movie poster in the local folder (use `save_poster` function for this)
#
# * Use `try-except` loop for this i.e. try to connect to the web portal, if successful proceed but if not (i.e. exception raised) then just print an error message
# * Here use the previously created variables `serviceurl` and `apikey`
# * You have to pass on a dictionary with a key `t` and the movie name as the corresponding value to `urllib.parse.urlencode()` function and then add the `serviceurl` and `apikey` to the output of the function to construct the full URL
# * This URL will be used for accessing the data
# * The JSON data has a key called `Response`. If it is `True`, that means the read was successful. Check this before processing the data. If not successful, then print the JSON key `Error`, which will contain the appropriate error message returned by the movie database.

# %%
#//*** Search for a movie on OMDB and print the resulting JSON
def search_movie(input_movie):
    #//*** Moving service URL locally into the function, otherise best practice would be to pass it in.
    service_url = "http://www.omdbapi.com/?" + apikey + "&"
    
    #//*** Format the Movie title for the API request
    #//*** Replace 
    input_movie = "t=" + input_movie.replace(" ","+")
    request_url = service_url + input_movie
    
    try:
        
        response = urllib.request.urlopen(request_url)
        
    except HTTPError as e:
        print("Uh Oh - There is a problem making the API call")
        print(e)
        return
    
    except URLError as e:
        print(f"Failed to connect to server.")
        print(f"Reason: {e.reason}")
    
    #//*** Received a valid response as a string
    #//*** Convert to JSON
    #//*** Print and Display the attributes using the print_json function
    print_json(json.loads(response.read().decode()))

# %% [markdown]
# ### Test `search_movie` function by entering *Titanic*

# %%
search_movie("Titanic")
# Out:
# Title: Titanic
# Year: 1997
# Rated: PG-13
# Released: 19 Dec 1997
# Runtime: 194 min
# Genre: Drama, Romance
# Director: James Cameron
# Writer: James Cameron
# Actors: Leonardo DiCaprio, Kate Winslet, Billy Zane, Kathy Bates
# Plot: A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.
# Language: English, Swedish, Italian, French
# Country: USA, Mexico
# Awards: Won 11 Oscars. Another 112 wins & 83 nominations.
# Ratings:
# 	Source: Internet Movie Database
# 	Value: 7.8/10
# 	Source: Rotten Tomatoes
# 	Value: 89%
# 	Source: Metacritic
# 	Value: 75/100
# Metascore: 75
# imdbRating: 7.8
# imdbVotes: 1,042,391
# imdbID: tt0120338
# Type: movie
# DVD: N/A
# BoxOffice: $659,363,944
# Production: 20th Century Fox, Lightstorm Entertainment, Paramount Pictures
# Website: N/A

# %%
search_movie("the human centipede")
# Out:
# Title: The Human Centipede (First Sequence)
# Year: 2009
# Rated: R
# Released: 28 Apr 2010
# Runtime: 92 min
# Genre: Horror
# Director: Tom Six
# Writer: Tom Six
# Actors: Dieter Laser, Ashley C. Williams, Ashlynn Yennie, Akihiro Kitamura
# Plot: A mad scientist kidnaps and mutilates a trio of tourists in order to reassemble them into a human centipede, created by stitching their mouths to each others' rectums.
# Language: English, German, Japanese
# Country: Netherlands
# Awards: 8 wins & 3 nominations.
# Ratings:
# 	Source: Internet Movie Database
# 	Value: 4.4/10
# 	Source: Rotten Tomatoes
# 	Value: 49%
# 	Source: Metacritic
# 	Value: 33/100
# Metascore: 33
# imdbRating: 4.4
# imdbVotes: 73,230
# imdbID: tt1467304
# Type: movie
# DVD: N/A
# BoxOffice: $181,467
# Production: Six Entertainment
# Website: N/A

# %%
search_movie("saaho")
# Out:
# Title: Saaho
# Year: 2019
# Rated: Not Rated
# Released: 30 Aug 2019
# Runtime: 170 min
# Genre: Action, Thriller
# Director: Sujeeth
# Writer: Sujeeth (screenplay), Sujeeth (telugu dialogue), K.G.R Ashok (tamil dialogue), Abbas Dalal (hindi dialogue), Hussain Dalal (hindi dialogue), Anil Kumar Upadyaula (associate head writer)
# Actors: Prabhas, Shraddha Kapoor, Jackie Shroff, Neil Nitin Mukesh
# Plot: An undercover cop becomes embroiled in a battle with warring criminals who want to acquire a "black box," their ultimate key to a treasure.
# Language: Telugu
# Country: India
# Awards: 2 wins.
# Ratings:
# 	Source: Internet Movie Database
# 	Value: 5.2/10
# 	Source: Rotten Tomatoes
# 	Value: 8%
# Metascore: N/A
# imdbRating: 5.2
# imdbVotes: 15,748
# imdbID: tt6836936
# Type: movie
# DVD: 21 Oct 2019
# BoxOffice: $2,872,057
# Production: UV Creations, ODU Movies
# Website: N/A

# %% [markdown]
# ### Test `search_movie` function by entering "*Random_error*" (obviously this will not be found and you should be able to check whether your error catching code is working properly)

# %%
search_movie("Random_error")
# Out:
# Response: False
# Error: Movie not found!

# %% [markdown]
# ### Look for a folder called 'Posters' in the same directory you are working in. It should contain a file called 'Titanic.jpg'. Open and see if the poster came alright!
#
# It doesn't, because I deleted the files after displaying them

# %% [markdown]
# 3. Connect to the Twitter API and do a simple data pull
#
# a. If you don’t have a twitter account – create one at twitter.com/signup (you can delete the account after this assignment)
#
# b. Sign in to apps.twitter.com
#
# c. Click “Create New App”
#
# d. Give your app a name and description
#
# e. Agree to the developer agreement – you will want to make sure to indicate this is for a class project, and this step can take several days to get through, so don’t wait until last minute to complete this portion of the assignment
#
# f. Create an access token
#
# g. You should receive a consumer key and a token
#
# h. Using either the instructions from the book on connecting to an API or for help look here – pull back data searching for “Bellevue University” and “Data Science” (or something else you are interested in)
#
# i. How to Create a Twitter App and API Interface via Python. (Grogan, 2016)
#
# ii. Welcome Python-Twitter’s Documentation!  (The Python-Twitter Developers, 2016)

# %% [markdown]
# 4. Using one of the datasets provided in Weeks 7 & 8, or a dataset of your own, choose 3 of the following visualizations to complete. You must submit via PDF along with your code. You are free to use Matplotlib, Seaborn or another package if you prefer.
#
# a. Line
#
# b. Scatter
#
# c. Bar
#
# d. Histogram
#
# e. Density Plot
#
# f. Pie Chart
