# %% [markdown]
# # Stoneburner, Kurt
# - ## DSC 540 - Week 09/10

# %%
# //****************************************************************************************
# //*** Set Working Directory to thinkstats folder.
# //*** This pseudo-relative path call should work on all Stoneburner localized projects. 
# //****************************************************************************************

import os
import sys
# //*** Imports and Load Data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#//*** Needed to display the Movie poster :)
from IPython.display import Image, display

# %% [markdown]
# # Activity 9: Top 100 ebooks' name extraction from Gutenberg.org
#
# ## What is Project Gutenberg? -
# Project Gutenberg is a volunteer effort to digitize and archive cultural works, to "encourage the creation and distribution of eBooks". It was founded in 1971 by American writer Michael S. Hart and is the **oldest digital library.** This longest-established ebook project releases books that entered the public domain, and can be freely read or downloaded in various electronic formats.
#
# ## What is this activity all about?
# * **This activity aims to scrape the url of the Project Gutenberg's Top 100 ebooks (yesterday's ranking) for identifying the ebook links. **
# * **It uses BeautifulSoup4 for parsing the HTML and regular expression code for identifying the Top 100 ebook file numbers.**
# * **You can use those book ID numbers to download the book into your local drive if you want**

# %% [markdown]
# ### Import necessary libraries including regex, and beautifulsoup

# %%
import urllib.request, urllib.parse, urllib.error
import requests
from bs4 import BeautifulSoup
import ssl
import re

# %% [markdown]
# ### Ignore SSL errors (this code will be given)

# %%
# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# %% [markdown]
# ### Read the HTML from the URL

# %%
guten_url = "http://www.gutenberg.org/browse/scores/top"
response = requests.get(guten_url)

# %% [markdown]
# ### Write a small function to check the status of web request

# %%
#//*** If Response.ok is False there is a problem
if response.ok == False:
    print("Problem downloading the URL")
    print(f"Statis Code: {response.status_code}")
    for x in response:
        print(x)

#//*** If no error we should be good

# %% [markdown]
# ### Decode the response and pass on to `BeautifulSoup` for HTML parsing

# %%
# Write your code here (decode). The decoding functionality is inlined with the Beautiful soup import. This forces
#//*** Decoding of the content based on the value of response.encoding

# Write your code here (pass on to BS)
if response.ok == True:
    #//*** Make soup...Beautiful Soup
    soup = BeautifulSoup(response.content.decode(response.encoding),'html.parser')

# %% [markdown]
# ### Find all the _href_ tags and store them in the list of links. Check how the list looks like - print first 30 elements

# %%
# Write your code here
href_list = soup.find_all('a')

# %%
# Write your code here (print the list)
for link in href_list:
    print(link)
# Out:
# <a class="no-hover" href="/" id="main_logo">
# <img alt="Project Gutenberg" draggable="false" src="/gutenberg/pg-logo-129x80.png"/>
# </a>
# <a href="/about/">About
#           <span class="drop-icon">▾</span>
# </a>
# <a href="/about/">About Project Gutenberg</a>
# <a href="/policy/collection_development.html">Collection Development</a>
# <a href="/about/contact_information.html">Contact Us</a>
# <a href="/about/background/">History &amp; Philosophy</a>
# <a href="/policy/permission.html">Permissions &amp; License</a>
# <a href="/policy/privacy_policy.html">Privacy Policy</a>
# <a href="/policy/terms_of_use.html">Terms of Use</a>
# <a href="/ebooks/">Search and Browse
#       	  <span class="drop-icon">▾</span>
# </a>
# <a href="/ebooks/">Book Search</a>
# <a href="/ebooks/bookshelf/">Bookshelves</a>
# <a href="/browse/scores/top">Frequently Downloaded</a>
# <a href="/ebooks/offline_catalogs.html">Offline Catalogs</a>
# <a href="/help/">Help
#           <span class="drop-icon">▾</span>
# </a>
# <a href="/help/">All help topics →</a>
# <a href="/help/copyright.html">Copyright Procedures</a>
# <a href="/help/errata.html">Errata, Fixes and Bug Reports</a>
# <a href="/help/file_formats.html">File Formats</a>
# <a href="/help/faq.html">Frequently Asked Questions</a>
# <a href="/policy/">Policies →</a>
# <a href="/help/public_domain_ebook_submission.html">Public Domain eBook Submission</a>
# <a href="/help/submitting_your_own_work.html">Submitting Your Own Work</a>
# <a href="/help/mobile.html">Tablets, Phones and eReaders</a>
# <a href="/attic/">The Attic →</a>
# <a href="/donate/">Donate</a>
# <a href="/donate/">Donation</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/ebooks/1342">Pride and Prejudice by Jane Austen (2514)</a>
# <a href="/ebooks/84">Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (2346)</a>
# <a href="/ebooks/46">A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens (2119)</a>
# <a href="/ebooks/11">Alice's Adventures in Wonderland by Lewis Carroll (1205)</a>
# <a href="/ebooks/6133">Arsène Lupin, gentleman-cambrioleur. English by Maurice Leblanc (1172)</a>
# <a href="/ebooks/43">The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson (1116)</a>
# <a href="/ebooks/1080">A Modest Proposal by Jonathan Swift (968)</a>
# <a href="/ebooks/64317">The Great Gatsby by F. Scott  Fitzgerald (946)</a>
# <a href="/ebooks/1661">The Adventures of Sherlock Holmes by Arthur Conan Doyle (892)</a>
# <a href="/ebooks/25344">The Scarlet Letter by Nathaniel Hawthorne (867)</a>
# <a href="/ebooks/98">A Tale of Two Cities by Charles Dickens (843)</a>
# <a href="/ebooks/2701">Moby Dick; Or, The Whale by Herman Melville (811)</a>
# <a href="/ebooks/2542">Et dukkehjem. English by Henrik Ibsen (761)</a>
# <a href="/ebooks/1260">Jane Eyre: An Autobiography by Charlotte Brontë (733)</a>
# <a href="/ebooks/174">The Picture of Dorian Gray by Oscar Wilde (718)</a>
# <a href="/ebooks/1952">The Yellow Wallpaper by Charlotte Perkins Gilman (713)</a>
# <a href="/ebooks/5200">Metamorphosis by Franz Kafka (677)</a>
# <a href="/ebooks/16">Peter Pan by J. M.  Barrie (650)</a>
# <a href="/ebooks/844">The Importance of Being Earnest: A Trivial Comedy for Serious People by Oscar Wilde (643)</a>
# <a href="/ebooks/1232">Il Principe. English by Niccolò Machiavelli (625)</a>
# <a href="/ebooks/120">Treasure Island by Robert Louis Stevenson (616)</a>
# <a href="/ebooks/2852">The Hound of the Baskervilles by Arthur Conan Doyle (612)</a>
# <a href="/ebooks/219">Heart of Darkness by Joseph Conrad (601)</a>
# <a href="/ebooks/1400">Great Expectations by Charles Dickens (600)</a>
# <a href="/ebooks/205">Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau (585)</a>
# <a href="/ebooks/76">Adventures of Huckleberry Finn by Mark Twain (574)</a>
# <a href="/ebooks/345">Dracula by Bram Stoker (572)</a>
# <a href="/ebooks/74">The Adventures of Tom Sawyer by Mark Twain (566)</a>
# <a href="/ebooks/16328">Beowulf: An Anglo-Saxon Epic Poem (550)</a>
# <a href="/ebooks/25929">Daemonologie. by King of England James I (523)</a>
# <a href="/ebooks/64323">Beyond the Yellow Fog by Robert Emmett McDowell (502)</a>
# <a href="/ebooks/4014">Arsene Lupin by Maurice Leblanc (490)</a>
# <a href="/ebooks/514">Little Women by Louisa May Alcott (486)</a>
# <a href="/ebooks/23">Narrative of the Life of Frederick Douglass, an American Slave by Frederick Douglass (477)</a>
# <a href="/ebooks/1250">Anthem by Ayn Rand (467)</a>
# <a href="/ebooks/408">The Souls of Black Folk by W. E. B.  Du Bois (460)</a>
# <a href="/ebooks/2591">Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm (457)</a>
# <a href="/ebooks/2097">The Sign of the Four by Arthur Conan Doyle (409)</a>
# <a href="/ebooks/1497">The Republic by Plato (403)</a>
# <a href="/ebooks/45">Anne of Green Gables by L. M.  Montgomery (403)</a>
# <a href="/ebooks/158">Emma by Jane Austen (399)</a>
# <a href="/ebooks/160">The Awakening, and Selected Short Stories by Kate Chopin (395)</a>
# <a href="/ebooks/4300">Ulysses by James Joyce (393)</a>
# <a href="/ebooks/2600">War and Peace by graf Leo Tolstoy (385)</a>
# <a href="/ebooks/55">The Wonderful Wizard of Oz by L. Frank  Baum (372)</a>
# <a href="/ebooks/64316">Drawings of David Cox by A. J.  Finberg (356)</a>
# <a href="/ebooks/215">The Call of the Wild by Jack London (352)</a>
# <a href="/ebooks/64320">The Manchester Man by Mrs. G. Linnaeus  Banks (351)</a>
# <a href="/ebooks/1184">The Count of Monte Cristo, Illustrated by Alexandre Dumas (349)</a>
# <a href="/ebooks/58585">The Prophet by Kahlil Gibran (348)</a>
# <a href="/ebooks/244">A Study in Scarlet by Arthur Conan Doyle (345)</a>
# <a href="/ebooks/19942">Candide by Voltaire (345)</a>
# <a href="/ebooks/3825">Pygmalion by Bernard Shaw (343)</a>
# <a href="/ebooks/36">The War of the Worlds by H. G.  Wells (336)</a>
# <a href="/ebooks/2814">Dubliners by James Joyce (331)</a>
# <a href="/ebooks/768">Wuthering Heights by Emily Brontë (325)</a>
# <a href="/ebooks/3207">Leviathan by Thomas Hobbes (324)</a>
# <a href="/ebooks/64319">The History of Esculent Fish by Roger North (322)</a>
# <a href="/ebooks/57426">Baron Trump's Marvellous Underground Journey by Ingersoll Lockwood (310)</a>
# <a href="/ebooks/2554">Prestuplenie i nakazanie. English by Fyodor Dostoyevsky (310)</a>
# <a href="/ebooks/140">The Jungle by Upton Sinclair (303)</a>
# <a href="/ebooks/113">The Secret Garden by Frances Hodgson Burnett (298)</a>
# <a href="/ebooks/730">Oliver Twist by Charles Dickens (293)</a>
# <a href="/ebooks/135">Les Misérables by Victor Hugo (291)</a>
# <a href="/ebooks/5740">Tractatus Logico-Philosophicus by Ludwig Wittgenstein (290)</a>
# <a href="/ebooks/34901">On Liberty by John Stuart Mill (279)</a>
# <a href="/ebooks/996">Don Quixote by Miguel de Cervantes Saavedra (277)</a>
# <a href="/ebooks/42108">The Slang Dictionary: Etymological, Historical and Andecdotal by John Camden Hotten (276)</a>
# <a href="/ebooks/2500">Siddhartha by Hermann Hesse (272)</a>
# <a href="/ebooks/64321">The Convict Ship, Volume 3 (of 3) by William Clark Russell (264)</a>
# <a href="/ebooks/863">The Mysterious Affair at Styles by Agatha Christie (263)</a>
# <a href="/ebooks/1727">The Odyssey by Homer (258)</a>
# <a href="/ebooks/1934">Songs of Innocence, and Songs of Experience by William Blake (251)</a>
# <a href="/ebooks/8102">The Forme of Cury: A Roll of Ancient English Cookery Compiled, about A.D. 1390 by Samuel Pegge (248)</a>
# <a href="/ebooks/766">David Copperfield by Charles Dickens (248)</a>
# <a href="/ebooks/236">The Jungle Book by Rudyard Kipling (244)</a>
# <a href="/ebooks/35">The Time Machine by H. G.  Wells (242)</a>
# <a href="/ebooks/35899">The Philippines a Century Hence by José Rizal (240)</a>
# <a href="/ebooks/64318">April twilights and other poems by Willa Cather (240)</a>
# <a href="/ebooks/3600">Essays of Michel de Montaigne — Complete by Michel de Montaigne (239)</a>
# <a href="/ebooks/1998">Also sprach Zarathustra. English by Friedrich Wilhelm Nietzsche (239)</a>
# <a href="/ebooks/376">A Journal of the Plague Year by Daniel Defoe (233)</a>
# <a href="/ebooks/64326">Black Silence by Robert Emmett McDowell (232)</a>
# <a href="/ebooks/829">Gulliver's Travels into Several Remote Nations of the World by Jonathan Swift (231)</a>
# <a href="/ebooks/1001">Divine Comedy, Longfellow's Translation, Hell by Dante Alighieri (223)</a>
# <a href="/ebooks/902">The Happy Prince, and Other Tales by Oscar Wilde (223)</a>
# <a href="/ebooks/203">Uncle Tom's Cabin by Harriet Beecher Stowe (223)</a>
# <a href="/ebooks/521">The Life and Adventures of Robinson Crusoe by Daniel Defoe (222)</a>
# <a href="/ebooks/147">Common Sense by Thomas Paine (221)</a>
# <a href="/ebooks/41">The Legend of Sleepy Hollow by Washington Irving (220)</a>
# <a href="/ebooks/32854">Arsène Lupin, gentleman-cambrioleur by Maurice Leblanc (218)</a>
# <a href="/ebooks/15399">The Interesting Narrative of the Life of Olaudah Equiano, Or Gustavus Vassa, The African by Equiano (214)</a>
# <a href="/ebooks/60479">1900; or, The last President by Ingersoll Lockwood (212)</a>
# <a href="/ebooks/64314">Beyond the X Ecliptic by Fox B. Holden (211)</a>
# <a href="/ebooks/30254">The Romance of Lust: A classic Victorian erotic novel by Anonymous (209)</a>
# <a href="/ebooks/3300">An Inquiry into the Nature and Causes of the Wealth of Nations by Adam Smith (207)</a>
# <a href="/ebooks/43453">A Pickle for the Knowing Ones by Timothy Dexter (203)</a>
# <a href="/ebooks/209">The Turn of the Screw by Henry James (201)</a>
# <a href="/ebooks/37134">The Elements of Style by William Strunk (196)</a>
# <a href="/ebooks/61">Manifest der Kommunistischen Partei. English by Friedrich Engels and Karl Marx (196)</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/browse/authors/d#a37">Dickens, Charles (5541)</a>
# <a href="/browse/authors/a#a68">Austen, Jane (3820)</a>
# <a href="/browse/authors/d#a69">Doyle, Arthur Conan (3000)</a>
# <a href="/browse/authors/s#a61">Shelley, Mary Wollstonecraft (2762)</a>
# <a href="/browse/authors/t#a53">Twain, Mark (2497)</a>
# <a href="/browse/authors/l#a1358">Leblanc, Maurice (2391)</a>
# <a href="/browse/authors/s#a35">Stevenson, Robert Louis (2236)</a>
# <a href="/browse/authors/l#a9473">Leech, John (2197)</a>
# <a href="/browse/authors/w#a111">Wilde, Oscar (2106)</a>
# <a href="/browse/authors/c#a7">Carroll, Lewis (1750)</a>
# <a href="/browse/authors/s#a65">Shakespeare, William (1401)</a>
# <a href="/browse/authors/h#a28">Hawthorne, Nathaniel (1383)</a>
# <a href="/browse/authors/s#a326">Swift, Jonathan (1381)</a>
# <a href="/browse/authors/w#a30">Wells, H. G. (Herbert George) (1360)</a>
# <a href="/browse/authors/p#a93">Plato (1262)</a>
# <a href="/browse/authors/m#a9">Melville, Herman (1190)</a>
# <a href="/browse/authors/j#a94">Jowett, Benjamin (1175)</a>
# <a href="/browse/authors/f#a420">Fitzgerald, F. Scott (Francis Scott) (1161)</a>
# <a href="/browse/authors/i#a861">Ibsen, Henrik (1048)</a>
# <a href="/browse/authors/d#a314">Dostoyevsky, Fyodor (1030)</a>
# <a href="/browse/authors/t#a136">Tolstoy, Leo, graf (1008)</a>
# <a href="/browse/authors/c#a125">Conrad, Joseph (1000)</a>
# <a href="/browse/authors/n#a779">Nietzsche, Friedrich Wilhelm (998)</a>
# <a href="/browse/authors/p#a481">Poe, Edgar Allan (990)</a>
# <a href="/browse/authors/j#a1039">Joyce, James (939)</a>
# <a href="/browse/authors/r#a2183">Rizal, José (927)</a>
# <a href="/browse/authors/k#a1735">Kafka, Franz (871)</a>
# <a href="/browse/authors/f#a2703">Foote, Mary Hallock (868)</a>
# <a href="/browse/authors/i#a31265">Ipsen, Ludvig Sandöe (867)</a>
# <a href="/browse/authors/a#a31267">Anthony, A. V. S. (Andrew Varick Stout) (867)</a>
# <a href="/browse/authors/g#a2858">Garnett, Constance (866)</a>
# <a href="/browse/authors/v#a60">Verne, Jules (851)</a>
# <a href="/browse/authors/d#a492">Dumas, Alexandre (846)</a>
# <a href="/browse/authors/d#a507">Dante Alighieri (846)</a>
# <a href="/browse/authors/g#a27">Gilman, Charlotte Perkins (820)</a>
# <a href="/browse/authors/b#a10">Barrie, J. M. (James Matthew) (816)</a>
# <a href="/browse/authors/h#a705">Homer (801)</a>
# <a href="/browse/authors/b#a408">Brontë, Charlotte (800)</a>
# <a href="/browse/authors/j#a113">James, Henry (800)</a>
# <a href="/browse/authors/l#a120">London, Jack (799)</a>
# <a href="/browse/authors/t#a54">Thoreau, Henry David (797)</a>
# <a href="/browse/authors/m#a36">Montgomery, L. M. (Lucy Maud) (793)</a>
# <a href="/browse/authors/m#a52422">McDowell, Robert Emmett (788)</a>
# <a href="/browse/authors/w#a1736">Wyllie, David (Translator) (770)</a>
# <a href="/browse/authors/h#a85">Hugo, Victor (759)</a>
# <a href="/browse/authors/a#a102">Alcott, Louisa May (754)</a>
# <a href="/browse/authors/t#a9854">Townsend, F. H. (Frederick Henry) (753)</a>
# <a href="/browse/authors/d#a1896">Doré, Gustave (750)</a>
# <a href="/browse/authors/s#a467">Shaw, Bernard (735)</a>
# <a href="/browse/authors/b#a42">Baum, L. Frank (Lyman Frank) (733)</a>
# <a href="/browse/authors/k#a132">Kipling, Rudyard (729)</a>
# <a href="/browse/authors/m#a563">Machiavelli, Niccolò (679)</a>
# <a href="/browse/authors/d#a204">Defoe, Daniel (663)</a>
# <a href="/browse/authors/s#a190">Stoker, Bram (658)</a>
# <a href="/browse/authors/c#a451">Christie, Agatha (647)</a>
# <a href="/browse/authors/m#a564">Marriott, W. K. (William Kenaz) (625)</a>
# <a href="/browse/authors/d#a226">Du Bois, W. E. B. (William Edward Burghardt) (622)</a>
# <a href="/browse/authors/r#a44215">Rhead, Louis (617)</a>
# <a href="/browse/authors/c#a80">Chesterton, G. K. (Gilbert Keith) (617)</a>
# <a href="/browse/authors/m#a1355">Morley, Henry (609)</a>
# <a href="/browse/authors/k#a37155">Kemble, E. W. (Edward Windsor) (608)</a>
# <a href="/browse/authors/l#a79">Lang, Andrew (597)</a>
# <a href="/browse/authors/g#a972">Grimm, Wilhelm (591)</a>
# <a href="/browse/authors/g#a971">Grimm, Jacob (591)</a>
# <a href="/browse/authors/l#a9462">Lockwood, Ingersoll (588)</a>
# <a href="/browse/authors/w#a104">Wharton, Edith (581)</a>
# <a href="/browse/authors/c#a708">Chekhov, Anton Pavlovich (580)</a>
# <a href="/browse/authors/f#a41747">Finberg, A. J. (Alexander Joseph) (579)</a>
# <a href="/browse/authors/b#a73">Burnett, Frances Hodgson (578)</a>
# <a href="/browse/authors/r#a355">Russell, Bertrand (572)</a>
# <a href="/browse/authors/h#a6638">Hall, J. Lesslie (John Lesslie) (550)</a>
# <a href="/browse/authors/v#a913">Voltaire (543)</a>
# <a href="/browse/authors/m#a306">Maupassant, Guy de (534)</a>
# <a href="/browse/authors/c#a505">Cervantes Saavedra, Miguel de (532)</a>
# <a href="/browse/authors/d#a34510">Douglass, Frederick (530)</a>
# <a href="/browse/authors/w#a1961">Widger, David (524)</a>
# <a href="/browse/authors/j#a7089">James I, King of England (523)</a>
# <a href="/browse/authors/m#a1705">Mill, John Stuart (522)</a>
# <a href="/browse/authors/v#a33400">Vestal, Herman B. (494)</a>
# <a href="/browse/authors/j#a1357">Jepson, Edgar (494)</a>
# <a href="/browse/authors/m#a500">Maude, Louise (489)</a>
# <a href="/browse/authors/m#a4589">Maude, Aylmer (478)</a>
# <a href="/browse/authors/r#a572">Rand, Ayn (470)</a>
# <a href="/browse/authors/b#a251">Balzac, Honoré de (465)</a>
# <a href="/browse/authors/i#a34">Irving, Washington (463)</a>
# <a href="/browse/authors/r#a8948">Russell, William Clark (454)</a>
# <a href="/browse/authors/h#a33608">Hapgood, Isabel Florence (450)</a>
# <a href="/browse/authors/e#a90">Eliot, George (447)</a>
# <a href="/browse/authors/h#a23">Hardy, Thomas (447)</a>
# <a href="/browse/authors/c#a3622">Cary, Henry Francis (446)</a>
# <a href="/browse/authors/p#a292">Potter, Beatrix (439)</a>
# <a href="/browse/authors/d#a4931">Derbyshire, Charles E. (429)</a>
# <a href="/browse/authors/g#a586">Goethe, Johann Wolfgang von (426)</a>
# <a href="/browse/authors/b#a748">Butler, Samuel (420)</a>
# <a href="/browse/authors/n#a407">Nesbit, E. (Edith) (409)</a>
# <a href="/browse/authors/e#a1071">Emerson, Ralph Waldo (404)</a>
# <a href="/browse/authors/c#a100">Chopin, Kate (403)</a>
# <a href="/browse/authors/f#a92">Franklin, Benjamin (400)</a>
# <a href="/browse/authors/r#a6335">Rackham, Arthur (396)</a>
# <a href="/browse/authors/c#a22">Cather, Willa (395)</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/ebooks/84">Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (19275)</a>
# <a href="/ebooks/1342">Pride and Prejudice by Jane Austen (16753)</a>
# <a href="/ebooks/46">A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens (14081)</a>
# <a href="/ebooks/6133">Arsène Lupin, gentleman-cambrioleur. English by Maurice Leblanc (9315)</a>
# <a href="/ebooks/11">Alice's Adventures in Wonderland by Lewis Carroll (7996)</a>
# <a href="/ebooks/1080">A Modest Proposal by Jonathan Swift (7583)</a>
# <a href="/ebooks/25344">The Scarlet Letter by Nathaniel Hawthorne (7291)</a>
# <a href="/ebooks/43">The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson (7012)</a>
# <a href="/ebooks/98">A Tale of Two Cities by Charles Dickens (6593)</a>
# <a href="/ebooks/1661">The Adventures of Sherlock Holmes by Arthur Conan Doyle (6101)</a>
# <a href="/ebooks/2701">Moby Dick; Or, The Whale by Herman Melville (6060)</a>
# <a href="/ebooks/2542">Et dukkehjem. English by Henrik Ibsen (5958)</a>
# <a href="/ebooks/5200">Metamorphosis by Franz Kafka (5384)</a>
# <a href="/ebooks/1250">Anthem by Ayn Rand (5253)</a>
# <a href="/ebooks/1952">The Yellow Wallpaper by Charlotte Perkins Gilman (5224)</a>
# <a href="/ebooks/1260">Jane Eyre: An Autobiography by Charlotte Brontë (5168)</a>
# <a href="/ebooks/57426">Baron Trump's Marvellous Underground Journey by Ingersoll Lockwood (5158)</a>
# <a href="/ebooks/844">The Importance of Being Earnest: A Trivial Comedy for Serious People by Oscar Wilde (5145)</a>
# <a href="/ebooks/76">Adventures of Huckleberry Finn by Mark Twain (5077)</a>
# <a href="/ebooks/174">The Picture of Dorian Gray by Oscar Wilde (4933)</a>
# <a href="/ebooks/219">Heart of Darkness by Joseph Conrad (4516)</a>
# <a href="/ebooks/23">Narrative of the Life of Frederick Douglass, an American Slave by Frederick Douglass (4305)</a>
# <a href="/ebooks/205">Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau (4234)</a>
# <a href="/ebooks/74">The Adventures of Tom Sawyer by Mark Twain (4206)</a>
# <a href="/ebooks/345">Dracula by Bram Stoker (4163)</a>
# <a href="/ebooks/19942">Candide by Voltaire (4058)</a>
# <a href="/ebooks/16328">Beowulf: An Anglo-Saxon Epic Poem (4031)</a>
# <a href="/ebooks/1400">Great Expectations by Charles Dickens (3982)</a>
# <a href="/ebooks/4014">Arsene Lupin by Maurice Leblanc (3975)</a>
# <a href="/ebooks/1232">Il Principe. English by Niccolò Machiavelli (3720)</a>
# <a href="/ebooks/2852">The Hound of the Baskervilles by Arthur Conan Doyle (3716)</a>
# <a href="/ebooks/160">The Awakening, and Selected Short Stories by Kate Chopin (3637)</a>
# <a href="/ebooks/25929">Daemonologie. by King of England James I (3567)</a>
# <a href="/ebooks/120">Treasure Island by Robert Louis Stevenson (3539)</a>
# <a href="/ebooks/16">Peter Pan by J. M.  Barrie (3501)</a>
# <a href="/ebooks/55">The Wonderful Wizard of Oz by L. Frank  Baum (3263)</a>
# <a href="/ebooks/514">Little Women by Louisa May Alcott (3143)</a>
# <a href="/ebooks/2591">Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm (3123)</a>
# <a href="/ebooks/215">The Call of the Wild by Jack London (2925)</a>
# <a href="/ebooks/4300">Ulysses by James Joyce (2732)</a>
# <a href="/ebooks/1497">The Republic by Plato (2704)</a>
# <a href="/ebooks/2814">Dubliners by James Joyce (2632)</a>
# <a href="/ebooks/158">Emma by Jane Austen (2630)</a>
# <a href="/ebooks/45">Anne of Green Gables by L. M.  Montgomery (2627)</a>
# <a href="/ebooks/2600">War and Peace by graf Leo Tolstoy (2625)</a>
# <a href="/ebooks/408">The Souls of Black Folk by W. E. B.  Du Bois (2622)</a>
# <a href="/ebooks/1184">The Count of Monte Cristo, Illustrated by Alexandre Dumas (2509)</a>
# <a href="/ebooks/2097">The Sign of the Four by Arthur Conan Doyle (2420)</a>
# <a href="/ebooks/36">The War of the Worlds by H. G.  Wells (2406)</a>
# <a href="/ebooks/3825">Pygmalion by Bernard Shaw (2359)</a>
# <a href="/ebooks/60479">1900; or, The last President by Ingersoll Lockwood (2318)</a>
# <a href="/ebooks/2554">Prestuplenie i nakazanie. English by Fyodor Dostoyevsky (2296)</a>
# <a href="/ebooks/58585">The Prophet by Kahlil Gibran (2280)</a>
# <a href="/ebooks/768">Wuthering Heights by Emily Brontë (2245)</a>
# <a href="/ebooks/50040">St. Benedict’s Rule for Monasteries (2203)</a>
# <a href="/ebooks/244">A Study in Scarlet by Arthur Conan Doyle (2186)</a>
# <a href="/ebooks/135">Les Misérables by Victor Hugo (2121)</a>
# <a href="/ebooks/3207">Leviathan by Thomas Hobbes (2060)</a>
# <a href="/ebooks/730">Oliver Twist by Charles Dickens (2050)</a>
# <a href="/ebooks/35">The Time Machine by H. G.  Wells (2050)</a>
# <a href="/ebooks/1998">Also sprach Zarathustra. English by Friedrich Wilhelm Nietzsche (1992)</a>
# <a href="/ebooks/2500">Siddhartha by Hermann Hesse (1955)</a>
# <a href="/ebooks/1727">The Odyssey by Homer (1941)</a>
# <a href="/ebooks/113">The Secret Garden by Frances Hodgson Burnett (1933)</a>
# <a href="/ebooks/996">Don Quixote by Miguel de Cervantes Saavedra (1920)</a>
# <a href="/ebooks/5740">Tractatus Logico-Philosophicus by Ludwig Wittgenstein (1886)</a>
# <a href="/ebooks/140">The Jungle by Upton Sinclair (1826)</a>
# <a href="/ebooks/203">Uncle Tom's Cabin by Harriet Beecher Stowe (1817)</a>
# <a href="/ebooks/902">The Happy Prince, and Other Tales by Oscar Wilde (1810)</a>
# <a href="/ebooks/42108">The Slang Dictionary: Etymological, Historical and Andecdotal by John Camden Hotten (1804)</a>
# <a href="/ebooks/3600">Essays of Michel de Montaigne — Complete by Michel de Montaigne (1758)</a>
# <a href="/ebooks/1001">Divine Comedy, Longfellow's Translation, Hell by Dante Alighieri (1733)</a>
# <a href="/ebooks/863">The Mysterious Affair at Styles by Agatha Christie (1732)</a>
# <a href="/ebooks/236">The Jungle Book by Rudyard Kipling (1713)</a>
# <a href="/ebooks/1934">Songs of Innocence, and Songs of Experience by William Blake (1681)</a>
# <a href="/ebooks/766">David Copperfield by Charles Dickens (1658)</a>
# <a href="/ebooks/4517">Ethan Frome by Edith Wharton (1651)</a>
# <a href="/ebooks/41">The Legend of Sleepy Hollow by Washington Irving (1543)</a>
# <a href="/ebooks/1064">The Masque of the Red Death by Edgar Allan Poe (1542)</a>
# <a href="/ebooks/972">The Devil's Dictionary by Ambrose Bierce (1541)</a>
# <a href="/ebooks/35899">The Philippines a Century Hence by José Rizal (1518)</a>
# <a href="/ebooks/829">Gulliver's Travels into Several Remote Nations of the World by Jonathan Swift (1518)</a>
# <a href="/ebooks/15399">The Interesting Narrative of the Life of Olaudah Equiano, Or Gustavus Vassa, The African by Equiano (1483)</a>
# <a href="/ebooks/32854">Arsène Lupin, gentleman-cambrioleur by Maurice Leblanc (1473)</a>
# <a href="/ebooks/376">A Journal of the Plague Year by Daniel Defoe (1464)</a>
# <a href="/ebooks/8800">An Index of The Divine Comedy by Dante by Dante Alighieri (1435)</a>
# <a href="/ebooks/34901">On Liberty by John Stuart Mill (1430)</a>
# <a href="/ebooks/209">The Turn of the Screw by Henry James (1428)</a>
# <a href="/ebooks/37134">The Elements of Style by William Strunk (1402)</a>
# <a href="/ebooks/30254">The Romance of Lust: A classic Victorian erotic novel by Anonymous (1400)</a>
# <a href="/ebooks/147">Common Sense by Thomas Paine (1387)</a>
# <a href="/ebooks/64296">Model Flying Machines (1374)</a>
# <a href="/ebooks/1399">Anna Karenina by graf Leo Tolstoy (1374)</a>
# <a href="/ebooks/7370">Second Treatise of Government by John Locke (1371)</a>
# <a href="/ebooks/4363">Beyond Good and Evil by Friedrich Wilhelm Nietzsche (1351)</a>
# <a href="/ebooks/61">Manifest der Kommunistischen Partei. English by Friedrich Engels and Karl Marx (1351)</a>
# <a href="/ebooks/521">The Life and Adventures of Robinson Crusoe by Daniel Defoe (1348)</a>
# <a href="/ebooks/64317">The Great Gatsby by F. Scott  Fitzgerald (1317)</a>
# <a href="/ebooks/2680">Meditations by Emperor of Rome Marcus Aurelius (1290)</a>
# <a href="/ebooks/27827">The Kama Sutra of Vatsyayana by Vatsyayana (1254)</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/browse/authors/d#a37">Dickens, Charles (38379)</a>
# <a href="/browse/authors/a#a68">Austen, Jane (25755)</a>
# <a href="/browse/authors/s#a61">Shelley, Mary Wollstonecraft (21501)</a>
# <a href="/browse/authors/d#a69">Doyle, Arthur Conan (19391)</a>
# <a href="/browse/authors/t#a53">Twain, Mark (18821)</a>
# <a href="/browse/authors/l#a1358">Leblanc, Maurice (18252)</a>
# <a href="/browse/authors/w#a111">Wilde, Oscar (15516)</a>
# <a href="/browse/authors/l#a9473">Leech, John (14670)</a>
# <a href="/browse/authors/s#a35">Stevenson, Robert Louis (14247)</a>
# <a href="/browse/authors/c#a7">Carroll, Lewis (11995)</a>
# <a href="/browse/authors/s#a65">Shakespeare, William (10610)</a>
# <a href="/browse/authors/h#a28">Hawthorne, Nathaniel (10563)</a>
# <a href="/browse/authors/s#a326">Swift, Jonathan (10320)</a>
# <a href="/browse/authors/w#a30">Wells, H. G. (Herbert George) (10079)</a>
# <a href="/browse/authors/m#a9">Melville, Herman (8196)</a>
# <a href="/browse/authors/l#a9462">Lockwood, Ingersoll (8072)</a>
# <a href="/browse/authors/i#a861">Ibsen, Henrik (8065)</a>
# <a href="/browse/authors/d#a314">Dostoyevsky, Fyodor (7770)</a>
# <a href="/browse/authors/p#a93">Plato (7751)</a>
# <a href="/browse/authors/p#a481">Poe, Edgar Allan (7445)</a>
# <a href="/browse/authors/c#a125">Conrad, Joseph (7346)</a>
# <a href="/browse/authors/f#a2703">Foote, Mary Hallock (7317)</a>
# <a href="/browse/authors/a#a31267">Anthony, A. V. S. (Andrew Varick Stout) (7291)</a>
# <a href="/browse/authors/i#a31265">Ipsen, Ludvig Sandöe (7291)</a>
# <a href="/browse/authors/j#a94">Jowett, Benjamin (7254)</a>
# <a href="/browse/authors/n#a779">Nietzsche, Friedrich Wilhelm (7141)</a>
# <a href="/browse/authors/t#a136">Tolstoy, Leo, graf (7104)</a>
# <a href="/browse/authors/k#a1735">Kafka, Franz (6824)</a>
# <a href="/browse/authors/l#a120">London, Jack (6572)</a>
# <a href="/browse/authors/j#a1039">Joyce, James (6469)</a>
# <a href="/browse/authors/b#a42">Baum, L. Frank (Lyman Frank) (6244)</a>
# <a href="/browse/authors/d#a507">Dante Alighieri (6240)</a>
# <a href="/browse/authors/g#a2858">Garnett, Constance (6155)</a>
# <a href="/browse/authors/g#a27">Gilman, Charlotte Perkins (5970)</a>
# <a href="/browse/authors/w#a1736">Wyllie, David (Translator) (5940)</a>
# <a href="/browse/authors/b#a408">Brontë, Charlotte (5820)</a>
# <a href="/browse/authors/t#a54">Thoreau, Henry David (5598)</a>
# <a href="/browse/authors/h#a705">Homer (5593)</a>
# <a href="/browse/authors/d#a1896">Doré, Gustave (5591)</a>
# <a href="/browse/authors/j#a113">James, Henry (5587)</a>
# <a href="/browse/authors/m#a36">Montgomery, L. M. (Lucy Maud) (5464)</a>
# <a href="/browse/authors/v#a60">Verne, Jules (5445)</a>
# <a href="/browse/authors/d#a492">Dumas, Alexandre (5390)</a>
# <a href="/browse/authors/r#a572">Rand, Ayn (5369)</a>
# <a href="/browse/authors/v#a913">Voltaire (5341)</a>
# <a href="/browse/authors/k#a37155">Kemble, E. W. (Edward Windsor) (5340)</a>
# <a href="/browse/authors/t#a9854">Townsend, F. H. (Frederick Henry) (5318)</a>
# <a href="/browse/authors/k#a132">Kipling, Rudyard (5238)</a>
# <a href="/browse/authors/a#a102">Alcott, Louisa May (5206)</a>
# <a href="/browse/authors/j#a40205">Johnson, Charles Howard (5162)</a>
# <a href="/browse/authors/r#a2183">Rizal, José (5087)</a>
# <a href="/browse/authors/b#a10">Barrie, J. M. (James Matthew) (4840)</a>
# <a href="/browse/authors/s#a467">Shaw, Bernard (4805)</a>
# <a href="/browse/authors/s#a190">Stoker, Bram (4722)</a>
# <a href="/browse/authors/d#a34510">Douglass, Frederick (4702)</a>
# <a href="/browse/authors/h#a85">Hugo, Victor (4521)</a>
# <a href="/browse/authors/d#a204">Defoe, Daniel (4516)</a>
# <a href="/browse/authors/w#a104">Wharton, Edith (4450)</a>
# <a href="/browse/authors/b#a73">Burnett, Frances Hodgson (4339)</a>
# <a href="/browse/authors/g#a972">Grimm, Wilhelm (4327)</a>
# <a href="/browse/authors/g#a971">Grimm, Jacob (4327)</a>
# <a href="/browse/authors/c#a708">Chekhov, Anton Pavlovich (4288)</a>
# <a href="/browse/authors/c#a451">Christie, Agatha (4278)</a>
# <a href="/browse/authors/r#a355">Russell, Bertrand (4229)</a>
# <a href="/browse/authors/c#a80">Chesterton, G. K. (Gilbert Keith) (4158)</a>
# <a href="/browse/authors/m#a563">Machiavelli, Niccolò (4147)</a>
# <a href="/browse/authors/l#a79">Lang, Andrew (4132)</a>
# <a href="/browse/authors/h#a6638">Hall, J. Lesslie (John Lesslie) (4031)</a>
# <a href="/browse/authors/j#a1357">Jepson, Edgar (4000)</a>
# <a href="/browse/authors/c#a505">Cervantes Saavedra, Miguel de (3999)</a>
# <a href="/browse/authors/m#a1355">Morley, Henry (3847)</a>
# <a href="/browse/authors/w#a1961">Widger, David (3780)</a>
# <a href="/browse/authors/m#a564">Marriott, W. K. (William Kenaz) (3763)</a>
# <a href="/browse/authors/c#a100">Chopin, Kate (3715)</a>
# <a href="/browse/authors/j#a7089">James I, King of England (3572)</a>
# <a href="/browse/authors/r#a44215">Rhead, Louis (3540)</a>
# <a href="/browse/authors/d#a226">Du Bois, W. E. B. (William Edward Burghardt) (3523)</a>
# <a href="/browse/authors/m#a500">Maude, Louise (3513)</a>
# <a href="/browse/authors/v#a33400">Vestal, Herman B. (3451)</a>
# <a href="/browse/authors/b#a206">Bierce, Ambrose (3440)</a>
# <a href="/browse/authors/m#a4589">Maude, Aylmer (3438)</a>
# <a href="/browse/authors/c#a3622">Cary, Henry Francis (3270)</a>
# <a href="/browse/authors/g#a586">Goethe, Johann Wolfgang von (3249)</a>
# <a href="/browse/authors/m#a306">Maupassant, Guy de (3246)</a>
# <a href="/browse/authors/p#a292">Potter, Beatrix (3182)</a>
# <a href="/browse/authors/i#a34">Irving, Washington (3162)</a>
# <a href="/browse/authors/b#a748">Butler, Samuel (3160)</a>
# <a href="/browse/authors/r#a6335">Rackham, Arthur (3159)</a>
# <a href="/browse/authors/h#a33608">Hapgood, Isabel Florence (2994)</a>
# <a href="/browse/authors/b#a251">Balzac, Honoré de (2981)</a>
# <a href="/browse/authors/w#a783">Wodehouse, P. G. (Pelham Grenville) (2925)</a>
# <a href="/browse/authors/s#a59">Scott, Walter (2921)</a>
# <a href="/browse/authors/m#a1705">Mill, John Stuart (2909)</a>
# <a href="/browse/authors/o#a506">Ormsby, John (2892)</a>
# <a href="/browse/authors/d#a4931">Derbyshire, Charles E. (2828)</a>
# <a href="/browse/authors/h#a23">Hardy, Thomas (2805)</a>
# <a href="/browse/authors/e#a90">Eliot, George (2793)</a>
# <a href="/browse/authors/p#a907">Pope, Alexander (2721)</a>
# <a href="/browse/authors/c#a483">Cooper, James Fenimore (2558)</a>
# <a href="/browse/authors/h#a941">Hesse, Hermann (2540)</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/ebooks/46">A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens (70650)</a>
# <a href="/ebooks/1342">Pride and Prejudice by Jane Austen (59636)</a>
# <a href="/ebooks/84">Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (56171)</a>
# <a href="/ebooks/11">Alice's Adventures in Wonderland by Lewis Carroll (28040)</a>
# <a href="/ebooks/1661">The Adventures of Sherlock Holmes by Arthur Conan Doyle (23345)</a>
# <a href="/ebooks/98">A Tale of Two Cities by Charles Dickens (23253)</a>
# <a href="/ebooks/25344">The Scarlet Letter by Nathaniel Hawthorne (22293)</a>
# <a href="/ebooks/1080">A Modest Proposal by Jonathan Swift (22171)</a>
# <a href="/ebooks/2701">Moby Dick; Or, The Whale by Herman Melville (22024)</a>
# <a href="/ebooks/50040">St. Benedict’s Rule for Monasteries (21228)</a>
# <a href="/ebooks/43">The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson (19761)</a>
# <a href="/ebooks/5200">Metamorphosis by Franz Kafka (18717)</a>
# <a href="/ebooks/76">Adventures of Huckleberry Finn by Mark Twain (16810)</a>
# <a href="/ebooks/1260">Jane Eyre: An Autobiography by Charlotte Brontë (16805)</a>
# <a href="/ebooks/2542">Et dukkehjem. English by Henrik Ibsen (16617)</a>
# <a href="/ebooks/174">The Picture of Dorian Gray by Oscar Wilde (16363)</a>
# <a href="/ebooks/1952">The Yellow Wallpaper by Charlotte Perkins Gilman (16337)</a>
# <a href="/ebooks/844">The Importance of Being Earnest: A Trivial Comedy for Serious People by Oscar Wilde (15988)</a>
# <a href="/ebooks/6133">Arsène Lupin, gentleman-cambrioleur. English by Maurice Leblanc (14927)</a>
# <a href="/ebooks/1250">Anthem by Ayn Rand (14534)</a>
# <a href="/ebooks/205">Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau (14481)</a>
# <a href="/ebooks/74">The Adventures of Tom Sawyer by Mark Twain (14288)</a>
# <a href="/ebooks/219">Heart of Darkness by Joseph Conrad (14103)</a>
# <a href="/ebooks/345">Dracula by Bram Stoker (14095)</a>
# <a href="/ebooks/1400">Great Expectations by Charles Dickens (12892)</a>
# <a href="/ebooks/16328">Beowulf: An Anglo-Saxon Epic Poem (12474)</a>
# <a href="/ebooks/1232">Il Principe. English by Niccolò Machiavelli (12240)</a>
# <a href="/ebooks/2600">War and Peace by graf Leo Tolstoy (12077)</a>
# <a href="/ebooks/514">Little Women by Louisa May Alcott (11944)</a>
# <a href="/ebooks/160">The Awakening, and Selected Short Stories by Kate Chopin (11908)</a>
# <a href="/ebooks/16">Peter Pan by J. M.  Barrie (11851)</a>
# <a href="/ebooks/2852">The Hound of the Baskervilles by Arthur Conan Doyle (11475)</a>
# <a href="/ebooks/120">Treasure Island by Robert Louis Stevenson (11337)</a>
# <a href="/ebooks/23">Narrative of the Life of Frederick Douglass, an American Slave by Frederick Douglass (11243)</a>
# <a href="/ebooks/2591">Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm (10748)</a>
# <a href="/ebooks/1184">The Count of Monte Cristo, Illustrated by Alexandre Dumas (10674)</a>
# <a href="/ebooks/17135">Twas the Night before Christmas: A Visit from St. Nicholas by Clement Clarke Moore (10524)</a>
# <a href="/ebooks/55">The Wonderful Wizard of Oz by L. Frank  Baum (10380)</a>
# <a href="/ebooks/158">Emma by Jane Austen (10204)</a>
# <a href="/ebooks/4300">Ulysses by James Joyce (9860)</a>
# <a href="/ebooks/58585">The Prophet by Kahlil Gibran (9777)</a>
# <a href="/ebooks/1497">The Republic by Plato (9563)</a>
# <a href="/ebooks/215">The Call of the Wild by Jack London (9458)</a>
# <a href="/ebooks/2814">Dubliners by James Joyce (9213)</a>
# <a href="/ebooks/45">Anne of Green Gables by L. M.  Montgomery (9039)</a>
# <a href="/ebooks/19942">Candide by Voltaire (8526)</a>
# <a href="/ebooks/2554">Prestuplenie i nakazanie. English by Fyodor Dostoyevsky (8490)</a>
# <a href="/ebooks/768">Wuthering Heights by Emily Brontë (8375)</a>
# <a href="/ebooks/36">The War of the Worlds by H. G.  Wells (8310)</a>
# <a href="/ebooks/5740">Tractatus Logico-Philosophicus by Ludwig Wittgenstein (8278)</a>
# <a href="/ebooks/135">Les Misérables by Victor Hugo (8177)</a>
# <a href="/ebooks/6130">The Iliad by Homer (7982)</a>
# <a href="/ebooks/42108">The Slang Dictionary: Etymological, Historical and Andecdotal by John Camden Hotten (7836)</a>
# <a href="/ebooks/408">The Souls of Black Folk by W. E. B.  Du Bois (7828)</a>
# <a href="/ebooks/25929">Daemonologie. by King of England James I (7826)</a>
# <a href="/ebooks/244">A Study in Scarlet by Arthur Conan Doyle (7715)</a>
# <a href="/ebooks/902">The Happy Prince, and Other Tales by Oscar Wilde (7603)</a>
# <a href="/ebooks/3825">Pygmalion by Bernard Shaw (7509)</a>
# <a href="/ebooks/28054">The Brothers Karamazov by Fyodor Dostoyevsky (7345)</a>
# <a href="/ebooks/19337">A Christmas Carol by Charles Dickens (7345)</a>
# <a href="/ebooks/996">Don Quixote by Miguel de Cervantes Saavedra (7325)</a>
# <a href="/ebooks/57426">Baron Trump's Marvellous Underground Journey by Ingersoll Lockwood (7069)</a>
# <a href="/ebooks/1727">The Odyssey by Homer (6987)</a>
# <a href="/ebooks/730">Oliver Twist by Charles Dickens (6980)</a>
# <a href="/ebooks/35">The Time Machine by H. G.  Wells (6792)</a>
# <a href="/ebooks/3600">Essays of Michel de Montaigne — Complete by Michel de Montaigne (6781)</a>
# <a href="/ebooks/2500">Siddhartha by Hermann Hesse (6655)</a>
# <a href="/ebooks/2097">The Sign of the Four by Arthur Conan Doyle (6576)</a>
# <a href="/ebooks/766">David Copperfield by Charles Dickens (6544)</a>
# <a href="/ebooks/863">The Mysterious Affair at Styles by Agatha Christie (6523)</a>
# <a href="/ebooks/203">Uncle Tom's Cabin by Harriet Beecher Stowe (6512)</a>
# <a href="/ebooks/113">The Secret Garden by Frances Hodgson Burnett (6479)</a>
# <a href="/ebooks/3207">Leviathan by Thomas Hobbes (6414)</a>
# <a href="/ebooks/1998">Also sprach Zarathustra. English by Friedrich Wilhelm Nietzsche (6332)</a>
# <a href="/ebooks/33870">Chess Fundamentals by José Raúl Capablanca (6252)</a>
# <a href="/ebooks/30254">The Romance of Lust: A classic Victorian erotic novel by Anonymous (6156)</a>
# <a href="/ebooks/57775">Le jardin des supplices by Octave Mirbeau (6147)</a>
# <a href="/ebooks/4014">Arsene Lupin by Maurice Leblanc (6109)</a>
# <a href="/ebooks/4363">Beyond Good and Evil by Friedrich Wilhelm Nietzsche (5931)</a>
# <a href="/ebooks/209">The Turn of the Screw by Henry James (5909)</a>
# <a href="/ebooks/1399">Anna Karenina by graf Leo Tolstoy (5853)</a>
# <a href="/ebooks/236">The Jungle Book by Rudyard Kipling (5849)</a>
# <a href="/ebooks/1064">The Masque of the Red Death by Edgar Allan Poe (5793)</a>
# <a href="/ebooks/2680">Meditations by Emperor of Rome Marcus Aurelius (5789)</a>
# <a href="/ebooks/1001">Divine Comedy, Longfellow's Translation, Hell by Dante Alighieri (5785)</a>
# <a href="/ebooks/376">A Journal of the Plague Year by Daniel Defoe (5725)</a>
# <a href="/ebooks/140">The Jungle by Upton Sinclair (5633)</a>
# <a href="/ebooks/27827">The Kama Sutra of Vatsyayana by Vatsyayana (5624)</a>
# <a href="/ebooks/43453">A Pickle for the Knowing Ones by Timothy Dexter (5553)</a>
# <a href="/ebooks/8800">An Index of The Divine Comedy by Dante by Dante Alighieri (5527)</a>
# <a href="/ebooks/7256">The Gift of the Magi by O. Henry (5475)</a>
# <a href="/ebooks/24022">A Christmas Carol by Charles Dickens (5346)</a>
# <a href="/ebooks/4517">Ethan Frome by Edith Wharton (5343)</a>
# <a href="/ebooks/829">Gulliver's Travels into Several Remote Nations of the World by Jonathan Swift (5285)</a>
# <a href="/ebooks/41">The Legend of Sleepy Hollow by Washington Irving (5234)</a>
# <a href="/ebooks/972">The Devil's Dictionary by Ambrose Bierce (5178)</a>
# <a href="/ebooks/35899">The Philippines a Century Hence by José Rizal (5123)</a>
# <a href="/ebooks/161">Sense and Sensibility by Jane Austen (5057)</a>
# <a href="/ebooks/61">Manifest der Kommunistischen Partei. English by Friedrich Engels and Karl Marx (4964)</a>
# <a href="/ebooks/37134">The Elements of Style by William Strunk (4904)</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/browse/authors/d#a37">Dickens, Charles (170475)</a>
# <a href="/browse/authors/a#a68">Austen, Jane (93904)</a>
# <a href="/browse/authors/l#a9473">Leech, John (73900)</a>
# <a href="/browse/authors/d#a69">Doyle, Arthur Conan (70343)</a>
# <a href="/browse/authors/t#a53">Twain, Mark (66262)</a>
# <a href="/browse/authors/s#a61">Shelley, Mary Wollstonecraft (63216)</a>
# <a href="/browse/authors/w#a111">Wilde, Oscar (54163)</a>
# <a href="/browse/authors/s#a35">Stevenson, Robert Louis (45506)</a>
# <a href="/browse/authors/c#a7">Carroll, Lewis (43668)</a>
# <a href="/browse/authors/s#a65">Shakespeare, William (37146)</a>
# <a href="/browse/authors/w#a30">Wells, H. G. (Herbert George) (36147)</a>
# <a href="/browse/authors/h#a28">Hawthorne, Nathaniel (34048)</a>
# <a href="/browse/authors/d#a314">Dostoyevsky, Fyodor (32481)</a>
# <a href="/browse/authors/s#a326">Swift, Jonathan (31695)</a>
# <a href="/browse/authors/t#a136">Tolstoy, Leo, graf (30342)</a>
# <a href="/browse/authors/m#a9">Melville, Herman (29319)</a>
# <a href="/browse/authors/l#a1358">Leblanc, Maurice (29082)</a>
# <a href="/browse/authors/n#a779">Nietzsche, Friedrich Wilhelm (27112)</a>
# <a href="/browse/authors/p#a481">Poe, Edgar Allan (26594)</a>
# <a href="/browse/authors/p#a93">Plato (26169)</a>
# <a href="/browse/authors/k#a1735">Kafka, Franz (24538)</a>
# <a href="/browse/authors/h#a705">Homer (24429)</a>
# <a href="/browse/authors/j#a94">Jowett, Benjamin (24387)</a>
# <a href="/browse/authors/c#a125">Conrad, Joseph (24298)</a>
# <a href="/browse/authors/l#a120">London, Jack (23689)</a>
# <a href="/browse/authors/d#a507">Dante Alighieri (23689)</a>
# <a href="/browse/authors/i#a861">Ibsen, Henrik (23595)</a>
# <a href="/browse/authors/g#a2858">Garnett, Constance (23482)</a>
# <a href="/browse/authors/b#a42">Baum, L. Frank (Lyman Frank) (23047)</a>
# <a href="/browse/authors/d#a492">Dumas, Alexandre (22974)</a>
# <a href="/browse/authors/j#a1039">Joyce, James (22499)</a>
# <a href="/browse/authors/f#a2703">Foote, Mary Hallock (22428)</a>
# <a href="/browse/authors/a#a31267">Anthony, A. V. S. (Andrew Varick Stout) (22293)</a>
# <a href="/browse/authors/i#a31265">Ipsen, Ludvig Sandöe (22293)</a>
# <a href="/browse/authors/d#a1896">Doré, Gustave (21481)</a>
# <a href="/browse/authors/v#a60">Verne, Jules (21467)</a>
# <a href="/browse/authors/w#a1736">Wyllie, David (Translator) (21310)</a>
# <a href="/browse/authors/d#a45674">Doyle, Leonard J. (Leonard Joseph) (21228)</a>
# <a href="/browse/authors/b#a45673">Benedict, Saint, Abbot of Monte Cassino (21228)</a>
# <a href="/browse/authors/a#a102">Alcott, Louisa May (20379)</a>
# <a href="/browse/authors/m#a36">Montgomery, L. M. (Lucy Maud) (20307)</a>
# <a href="/browse/authors/k#a132">Kipling, Rudyard (20042)</a>
# <a href="/browse/authors/j#a113">James, Henry (19934)</a>
# <a href="/browse/authors/t#a54">Thoreau, Henry David (19558)</a>
# <a href="/browse/authors/b#a408">Brontë, Charlotte (19432)</a>
# <a href="/browse/authors/g#a27">Gilman, Charlotte Perkins (18837)</a>
# <a href="/browse/authors/h#a85">Hugo, Victor (18140)</a>
# <a href="/browse/authors/k#a37155">Kemble, E. W. (Edward Windsor) (17641)</a>
# <a href="/browse/authors/t#a9854">Townsend, F. H. (Frederick Henry) (17460)</a>
# <a href="/browse/authors/s#a467">Shaw, Bernard (17359)</a>
# <a href="/browse/authors/b#a10">Barrie, J. M. (James Matthew) (16874)</a>
# <a href="/browse/authors/c#a80">Chesterton, G. K. (Gilbert Keith) (16874)</a>
# <a href="/browse/authors/r#a355">Russell, Bertrand (16760)</a>
# <a href="/browse/authors/c#a451">Christie, Agatha (16697)</a>
# <a href="/browse/authors/l#a79">Lang, Andrew (16584)</a>
# <a href="/browse/authors/d#a204">Defoe, Daniel (16574)</a>
# <a href="/browse/authors/w#a1961">Widger, David (16401)</a>
# <a href="/browse/authors/r#a2183">Rizal, José (16361)</a>
# <a href="/browse/authors/s#a190">Stoker, Bram (16274)</a>
# <a href="/browse/authors/b#a73">Burnett, Frances Hodgson (15463)</a>
# <a href="/browse/authors/m#a500">Maude, Louise (15156)</a>
# <a href="/browse/authors/c#a505">Cervantes Saavedra, Miguel de (15063)</a>
# <a href="/browse/authors/c#a708">Chekhov, Anton Pavlovich (15025)</a>
# <a href="/browse/authors/g#a972">Grimm, Wilhelm (14939)</a>
# <a href="/browse/authors/g#a971">Grimm, Jacob (14939)</a>
# <a href="/browse/authors/m#a4589">Maude, Aylmer (14905)</a>
# <a href="/browse/authors/r#a572">Rand, Ayn (14818)</a>
# <a href="/browse/authors/w#a783">Wodehouse, P. G. (Pelham Grenville) (14372)</a>
# <a href="/browse/authors/m#a1355">Morley, Henry (14343)</a>
# <a href="/browse/authors/w#a104">Wharton, Edith (14335)</a>
# <a href="/browse/authors/m#a563">Machiavelli, Niccolò (13857)</a>
# <a href="/browse/authors/v#a913">Voltaire (13652)</a>
# <a href="/browse/authors/p#a907">Pope, Alexander (13643)</a>
# <a href="/browse/authors/v#a33400">Vestal, Herman B. (13566)</a>
# <a href="/browse/authors/i#a34">Irving, Washington (13343)</a>
# <a href="/browse/authors/l#a9462">Lockwood, Ingersoll (13122)</a>
# <a href="/browse/authors/g#a586">Goethe, Johann Wolfgang von (12942)</a>
# <a href="/browse/authors/r#a6335">Rackham, Arthur (12729)</a>
# <a href="/browse/authors/c#a3622">Cary, Henry Francis (12679)</a>
# <a href="/browse/authors/d#a34510">Douglass, Frederick (12665)</a>
# <a href="/browse/authors/h#a6638">Hall, J. Lesslie (John Lesslie) (12474)</a>
# <a href="/browse/authors/m#a564">Marriott, W. K. (William Kenaz) (12369)</a>
# <a href="/browse/authors/m#a306">Maupassant, Guy de (12331)</a>
# <a href="/browse/authors/s#a7158">Smith, Jessie Willcox (12324)</a>
# <a href="/browse/authors/c#a100">Chopin, Kate (12236)</a>
# <a href="/browse/authors/p#a292">Potter, Beatrix (11845)</a>
# <a href="/browse/authors/b#a251">Balzac, Honoré de (11622)</a>
# <a href="/browse/authors/h#a33608">Hapgood, Isabel Florence (11600)</a>
# <a href="/browse/authors/s#a59">Scott, Walter (11596)</a>
# <a href="/browse/authors/b#a748">Butler, Samuel (11590)</a>
# <a href="/browse/authors/b#a206">Bierce, Ambrose (11484)</a>
# <a href="/browse/authors/r#a44215">Rhead, Louis (11349)</a>
# <a href="/browse/authors/m#a7157">Moore, Clement Clarke (11253)</a>
# <a href="/browse/authors/h#a23">Hardy, Thomas (11171)</a>
# <a href="/browse/authors/h#a634">Henry, O. (11059)</a>
# <a href="/browse/authors/d#a226">Du Bois, W. E. B. (William Edward Burghardt) (10717)</a>
# <a href="/browse/authors/o#a506">Ormsby, John (10602)</a>
# <a href="/browse/authors/b#a898">Burton, Richard Francis, Sir (10442)</a>
# <a href="/browse/authors/e#a90">Eliot, George (10423)</a>
# <a href="/browse/authors/g#a1813">Gibran, Kahlil (10347)</a>
# <a href="#books-last1">Top 100 EBooks yesterday</a>
# <a href="#authors-last1">Top 100 Authors yesterday</a>
# <a href="#books-last7">Top 100 EBooks last 7 days</a>
# <a href="#authors-last7">Top 100 Authors last 7 days</a>
# <a href="#books-last30">Top 100 EBooks last 30 days</a>
# <a href="#authors-last30">Top 100 Authors last 30 days</a>
# <a href="/policy/privacy_policy.html" title="Privacy Policy">Privacy policy</a>
# <a href="/about/" title="About Project Gutenberg">About Project Gutenberg</a>
# <a href="/policy/terms_of_use.html" title="Terms of Use">Terms of Use</a>
# <a href="/about/contact_information.html" title="Contact Information">Contact Information</a>
# <a href="/help/" title="Get Help">Get Help</a>
# <a href="https://www.ibiblio.org/" title="Project Gutenberg is hosted by ibiblio">
# <img alt="iBiblio" src="/gutenberg/ibiblio-logo.png"/>
# </a>

# %% [markdown]
# ### Use regular expression to find the numeric digits in these links. <br>These are the file number for the Top 100 books.

# %% [markdown]
# #### Initialize empty list to hold the file numbers

# %%
file_numbers = []

# %% [markdown]
# * Number 19 to 118 in the original list of links have the Top 100 ebooks' number.
# * Loop over appropriate range and use regex to find the numeric digits in the link (href) string.
# * Hint: Use `findall()` method

# %%
#//***********************************************************************************
#//*** I'm going to gather the file numbers for the Top 100 EBooks Yesterday
#//***********************************************************************************

#//*** The list of ebooks starts after the value of pattern_start
pattern_start = "#authors-last30"
begin_match = False

#//*** Loop through the a tag lists
for a in href_list:
    #//*** Get the href for each 'a' tag in the list
    item = a.get('href')
    
    #//*** Look for the start of the relevant items, otherwise do nothing
    if pattern_start in item:
        #//*** Start of content found
        begin_match = True
        
        #//*** Advance to the next item
        continue
    
    #//*** Values are found. Harvest the ebook Items
    if begin_match == True:

        #//*** Quit on next Category tag
        if "#" in item:
            break
        #//*** Verify there is ebooks in the href
        if "ebooks" in item:
            file_numbers.append(item.replace("/ebooks/",""))

# %% [markdown]
# #### Print the file numbers

# %%
x = 0
for y in file_numbers:
    x = x + 1
    print(f"{x}. {y}")
# Out:
# 1. 1342
# 2. 84
# 3. 46
# 4. 11
# 5. 6133
# 6. 43
# 7. 1080
# 8. 64317
# 9. 1661
# 10. 25344
# 11. 98
# 12. 2701
# 13. 2542
# 14. 1260
# 15. 174
# 16. 1952
# 17. 5200
# 18. 16
# 19. 844
# 20. 1232
# 21. 120
# 22. 2852
# 23. 219
# 24. 1400
# 25. 205
# 26. 76
# 27. 345
# 28. 74
# 29. 16328
# 30. 25929
# 31. 64323
# 32. 4014
# 33. 514
# 34. 23
# 35. 1250
# 36. 408
# 37. 2591
# 38. 2097
# 39. 1497
# 40. 45
# 41. 158
# 42. 160
# 43. 4300
# 44. 2600
# 45. 55
# 46. 64316
# 47. 215
# 48. 64320
# 49. 1184
# 50. 58585
# 51. 244
# 52. 19942
# 53. 3825
# 54. 36
# 55. 2814
# 56. 768
# 57. 3207
# 58. 64319
# 59. 57426
# 60. 2554
# 61. 140
# 62. 113
# 63. 730
# 64. 135
# 65. 5740
# 66. 34901
# 67. 996
# 68. 42108
# 69. 2500
# 70. 64321
# 71. 863
# 72. 1727
# 73. 1934
# 74. 8102
# 75. 766
# 76. 236
# 77. 35
# 78. 35899
# 79. 64318
# 80. 3600
# 81. 1998
# 82. 376
# 83. 64326
# 84. 829
# 85. 1001
# 86. 902
# 87. 203
# 88. 521
# 89. 147
# 90. 41
# 91. 32854
# 92. 15399
# 93. 60479
# 94. 64314
# 95. 30254
# 96. 3300
# 97. 43453
# 98. 209
# 99. 37134
# 100. 61

# %% [markdown]
# ### How does the `soup` object's text look like? Use `.text()` method and print only first 2000 characters (i.e. do not print the whole thing, it is long).
#
# You will notice lot of empty spaces/blanks here and there. Ignore them. They are part of HTML page markup and its whimsical nature!

# %%
print(soup.get_text()[:2000])
# Out:
# Top 100 | Project Gutenberg
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Menu▾
#
#
#
# About
#           ▾
#
# ▾
#
#
# About Project Gutenberg
# Collection Development
# Contact Us
# History & Philosophy
# Permissions & License
# Privacy Policy
# Terms of Use
#
#
#
# Search and Browse
#       	  ▾
#
# ▾
#
#
# Book Search
# Bookshelves
# Frequently Downloaded
# Offline Catalogs
#
#
#
# Help
#           ▾
#
# ▾
#
#
# All help topics →
# Copyright Procedures
# Errata, Fixes and Bug Reports
# File Formats
# Frequently Asked Questions
# Policies →
# Public Domain eBook Submission
# Submitting Your Own Work
# Tablets, Phones and eReaders
# The Attic →
#
#
# Donate
#
#
#
#
#
#
#
#
#
#
# Donation
#
#
#
#
#
#
#
# Frequently Viewed or Downloaded
# These listings are based on the number of times each eBook gets downloaded.
#       Multiple downloads from the same Internet address on the same day count as one download, and addresses that download more than 100 eBooks in a day are considered robots and are not counted.
#
# Downloaded Books
# 2021-01-18186142
# last 7 days1294928
# last 30 days4934605
#
#
#
# Top 100 EBooks yesterday
# Top 100 Authors yesterday
# Top 100 EBooks last 7 days
# Top 100 Authors last 7 days
# Top 100 EBooks last 30 days
# Top 100 Authors last 30 days
#
#
# Top 100 EBooks yesterday
#
# Pride and Prejudice by Jane Austen (2514)
# Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley (2346)
# A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens (2119)
# Alice's Adventures in Wonderland by Lewis Carroll (1205)
# Arsène Lupin, gentleman-cambrioleur. English by Maurice Leblanc (1172)
# The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson (1116)
# A Modest Proposal by Jonathan Swift (968)
# The Great Gatsby by F. Scott  Fitzgerald (946)
# The Adventures of Sherlock Holmes by Arthur Conan Doyle (892)
# The Scarlet Letter by Nathaniel Hawthorne (867)
# A Tale of Two Cities by Charles Dickens (843)
# Moby Dick; Or, The Whale by Herman Melville (811)
# Et dukkehjem. English by Henrik Ibsen (761)
# Jane Eyre: An Autobiography by Charlotte Brontë (733)
# The Picture of Dorian Gray

# %% [markdown]
# ### Search in the extracted text (using regular expression) from the `soup` object to find the names of top 100 Ebooks (Yesterday's rank)

# %%
#//****************************************************************************
#//*** Going to solve this with more Regex and string processing than Soup.
#//****************************************************************************

#//*** Store the Book Names
book_names = []

#//*** Raw text of the entire html document
raw_text = soup.get_text()

#//*** Define the regex: The key is the [\\W\\w]*?. 
#//*** [\\W\\w] - Matches any Word or Non-Word Character. This matches everything including a newline.
#//*** I learned this trick many moons ago. 
#//*** * matches the preceding value (word or non word)
#//*** ? matches 0 or 1 and makes the regex lazy or ungreedy
pattern = re.compile("Top 100 EBooks yesterday[\\W\\w]*?Top 100 EBooks yesterday\nTop 100 Authors yesterday")

#//*** Apply the regex and keep the first result.
#//*** This is the raw string of the content
result = pattern.findall(raw_text)[0]

#//*** Split the results by newline
for line in result.split("\n"):
    #//*** Filter out the garbage
    
    #//*** Skip empty lines
    if len(line) == 0:
        continue
    
    #//*** Filter out the category names, let's get real specific
    #//*** Title must include Top 100
    if "Top 100" in line:
        #//*** And either Ebooks or Authors
        if "EBooks" or "Authors" in line:
            #//*** And yesterday or last 7 days or last 30 days
            if "yesterday" or "last 7 days" or "last 30 days" in line:
                continue
    #//*** This specificity should avoid skipping the wrong titles.
    
    #//*** Remove everything between the Parenthesis ( ) because we can
    paran_pattern = re.compile("\(.+\)")
    #//*** Perform regex findall for parantheses
    paran_replace = paran_pattern.findall(line) 
    
    #//*** Every line *should* have paranthesis, but let's double check that we do. This is a hard learned 
    #//*** lesson, never assume your data result before working on it. Although I violated this rule
    #//*** on line 17.

    if len(paran_replace) > 0:
        
        #//*** Grab first Item, which is string to replace.
        paran_replace = paran_replace[0]
        line = line.replace(paran_replace,"")

    book_names.append(line)

# %% [markdown]
# # I honestly don't understand any of this. Why use Beautiful Soup if regex can solve the same problem of parsing a chunk of text?#
#
# #### Create a starting index. It should point at the text _"Top 100 Ebooks yesterday"_. Hint: Use `splitlines()` method of the `soup.text`. It splits the lines of the text of the `soup` object.

# %% [markdown]
# #### Loop 1-100 to add the strings of next 100 lines to this temporary list. Hint: `splitlines()` method

# %% [markdown]
# #### Use regular expression to extract only text from the name strings and append to an empty list
# * Hint: Use `match` and `span` to find indices and use them

# %% [markdown]
# #### Print the list of titles

# %%
for x in range(0,len(book_names)):
    print(f"{x+1}. [{file_numbers[x]}] {book_names[x]}")
# Out:
# 1. [1342] Pride and Prejudice by Jane Austen
# 2. [84] Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley
# 3. [46] A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens
# 4. [11] Alice's Adventures in Wonderland by Lewis Carroll
# 5. [6133] Arsène Lupin, gentleman-cambrioleur. English by Maurice Leblanc
# 6. [43] The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson
# 7. [1080] A Modest Proposal by Jonathan Swift
# 8. [64317] The Great Gatsby by F. Scott  Fitzgerald
# 9. [1661] The Adventures of Sherlock Holmes by Arthur Conan Doyle
# 10. [25344] The Scarlet Letter by Nathaniel Hawthorne
# 11. [98] A Tale of Two Cities by Charles Dickens
# 12. [2701] Moby Dick; Or, The Whale by Herman Melville
# 13. [2542] Et dukkehjem. English by Henrik Ibsen
# 14. [1260] Jane Eyre: An Autobiography by Charlotte Brontë
# 15. [174] The Picture of Dorian Gray by Oscar Wilde
# 16. [1952] The Yellow Wallpaper by Charlotte Perkins Gilman
# 17. [5200] Metamorphosis by Franz Kafka
# 18. [16] Peter Pan by J. M.  Barrie
# 19. [844] The Importance of Being Earnest: A Trivial Comedy for Serious People by Oscar Wilde
# 20. [1232] Il Principe. English by Niccolò Machiavelli
# 21. [120] Treasure Island by Robert Louis Stevenson
# 22. [2852] The Hound of the Baskervilles by Arthur Conan Doyle
# 23. [219] Heart of Darkness by Joseph Conrad
# 24. [1400] Great Expectations by Charles Dickens
# 25. [205] Walden, and On The Duty Of Civil Disobedience by Henry David Thoreau
# 26. [76] Adventures of Huckleberry Finn by Mark Twain
# 27. [345] Dracula by Bram Stoker
# 28. [74] The Adventures of Tom Sawyer by Mark Twain
# 29. [16328] Beowulf: An Anglo-Saxon Epic Poem
# 30. [25929] Daemonologie. by King of England James I
# 31. [64323] Beyond the Yellow Fog by Robert Emmett McDowell
# 32. [4014] Arsene Lupin by Maurice Leblanc
# 33. [514] Little Women by Louisa May Alcott
# 34. [23] Narrative of the Life of Frederick Douglass, an American Slave by Frederick Douglass
# 35. [1250] Anthem by Ayn Rand
# 36. [408] The Souls of Black Folk by W. E. B.  Du Bois
# 37. [2591] Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm
# 38. [2097] The Sign of the Four by Arthur Conan Doyle
# 39. [1497] The Republic by Plato
# 40. [45] Anne of Green Gables by L. M.  Montgomery
# 41. [158] Emma by Jane Austen
# 42. [160] The Awakening, and Selected Short Stories by Kate Chopin
# 43. [4300] Ulysses by James Joyce
# 44. [2600] War and Peace by graf Leo Tolstoy
# 45. [55] The Wonderful Wizard of Oz by L. Frank  Baum
# 46. [64316] Drawings of David Cox by A. J.  Finberg
# 47. [215] The Call of the Wild by Jack London
# 48. [64320] The Manchester Man by Mrs. G. Linnaeus  Banks
# 49. [1184] The Count of Monte Cristo, Illustrated by Alexandre Dumas
# 50. [58585] The Prophet by Kahlil Gibran
# 51. [244] A Study in Scarlet by Arthur Conan Doyle
# 52. [19942] Candide by Voltaire
# 53. [3825] Pygmalion by Bernard Shaw
# 54. [36] The War of the Worlds by H. G.  Wells
# 55. [2814] Dubliners by James Joyce
# 56. [768] Wuthering Heights by Emily Brontë
# 57. [3207] Leviathan by Thomas Hobbes
# 58. [64319] The History of Esculent Fish by Roger North
# 59. [57426] Baron Trump's Marvellous Underground Journey by Ingersoll Lockwood
# 60. [2554] Prestuplenie i nakazanie. English by Fyodor Dostoyevsky
# 61. [140] The Jungle by Upton Sinclair
# 62. [113] The Secret Garden by Frances Hodgson Burnett
# 63. [730] Oliver Twist by Charles Dickens
# 64. [135] Les Misérables by Victor Hugo
# 65. [5740] Tractatus Logico-Philosophicus by Ludwig Wittgenstein
# 66. [34901] On Liberty by John Stuart Mill
# 67. [996] Don Quixote by Miguel de Cervantes Saavedra
# 68. [42108] The Slang Dictionary: Etymological, Historical and Andecdotal by John Camden Hotten
# 69. [2500] Siddhartha by Hermann Hesse
# 70. [64321] The Convict Ship, Volume 3
# 71. [863] The Mysterious Affair at Styles by Agatha Christie
# 72. [1727] The Odyssey by Homer
# 73. [1934] Songs of Innocence, and Songs of Experience by William Blake
# 74. [8102] The Forme of Cury: A Roll of Ancient English Cookery Compiled, about A.D. 1390 by Samuel Pegge
# 75. [766] David Copperfield by Charles Dickens
# 76. [236] The Jungle Book by Rudyard Kipling
# 77. [35] The Time Machine by H. G.  Wells
# 78. [35899] The Philippines a Century Hence by José Rizal
# 79. [64318] April twilights and other poems by Willa Cather
# 80. [3600] Essays of Michel de Montaigne — Complete by Michel de Montaigne
# 81. [1998] Also sprach Zarathustra. English by Friedrich Wilhelm Nietzsche
# 82. [376] A Journal of the Plague Year by Daniel Defoe
# 83. [64326] Black Silence by Robert Emmett McDowell
# 84. [829] Gulliver's Travels into Several Remote Nations of the World by Jonathan Swift
# 85. [1001] Divine Comedy, Longfellow's Translation, Hell by Dante Alighieri
# 86. [902] The Happy Prince, and Other Tales by Oscar Wilde
# 87. [203] Uncle Tom's Cabin by Harriet Beecher Stowe
# 88. [521] The Life and Adventures of Robinson Crusoe by Daniel Defoe
# 89. [147] Common Sense by Thomas Paine
# 90. [41] The Legend of Sleepy Hollow by Washington Irving
# 91. [32854] Arsène Lupin, gentleman-cambrioleur by Maurice Leblanc
# 92. [15399] The Interesting Narrative of the Life of Olaudah Equiano, Or Gustavus Vassa, The African by Equiano
# 93. [60479] 1900; or, The last President by Ingersoll Lockwood
# 94. [64314] Beyond the X Ecliptic by Fox B. Holden
# 95. [30254] The Romance of Lust: A classic Victorian erotic novel by Anonymous
# 96. [3300] An Inquiry into the Nature and Causes of the Wealth of Nations by Adam Smith
# 97. [43453] A Pickle for the Knowing Ones by Timothy Dexter
# 98. [209] The Turn of the Screw by Henry James
# 99. [37134] The Elements of Style by William Strunk
# 100. [61] Manifest der Kommunistischen Partei. English by Friedrich Engels and Karl Marx

# %% [markdown]
# # Advanced web scraping and data gathering
# ## Activity 10: Build your own movie database by reading from an API
# ### This notebook does the following
# * Retrieves and prints basic data about a movie (title entered by user) from the web (OMDB database)
# * If a poster of the movie could be found, it downloads the file and saves at a user-specified location

# %%
import urllib.request, urllib.parse, urllib.error
import json

# %% [markdown]
# ### Load the secret API key (you have to get one from OMDB website and use that, 1000 daily limit) from a JSON file, stored in the same folder into a variable
# Hint: Use **`json.loads()`**
#
# #### Note: The following cell will not be executed in the solution notebook because the author cannot give out his private API key.
# #### Students/users/instructor will need to obtain a key and store in a JSON file.
# #### For the code's sake, we are calling this file `APIkeys.json`. But you need to store your own key in this file.
# #### An example file called `"APIkey_Bogus_example.json"` is given along with the notebook. Just change the code in this file and rename as `APIkeys.json`. The file name does not matter of course.

# %%
#//*************************************************
#//*** Read the API key from a JSON encoded file
#//*************************************************
f = open("z_omdb_api.key", "r")

#//*** Fugley Pythonic type conversion
#//*** Loads the file into Dictionary via JSON.loads
#//*** Gets the API key value using the 'api' key
#//*** prepends apikey= so the resulting value is URL ready :]
apikey = "apikey=" + json.loads(f.read())['api']
f.close()

# %% [markdown]
# ### The final URL to be passed should look like: http://www.omdbapi.com/?t=movie_name&apikey=secretapikey
# Do the following,
# * Assign the OMDB portal (http://www.omdbapi.com/?) as a string to a variable `serviceurl` (don't miss the `?`)
# * Create a variable `apikey` with the last portion of the URL ("&apikey=secretapikey"), where `secretapikey` is your own API key (an actual code)
# * The movie name portion i.e. "t=movie_name" will be addressed later

# %%
#//*******************************************************************************
#//*** The Current doc on omdbapi.com the apikey should be included first.
#//*** Stylistically this makes sense, since that's the static part of the call.
#//*******************************************************************************
service_url = "http://www.omdbapi.com/?" + apikey + "&"

# %% [markdown]
# ### Write a utility function to download a poster of the movie based on the information from the jason dataset and save in your local folder
#
# * Use `os` module
# * The poster data is stored in the JSON key 'Poster'
# * You may want to split the name of the Poster file and extract the file extension only. Let's say the extension is ***'jpg'***.
# * Then later join this extension to the movie name and create a filename like ***movie.jpg***
# * Use the Python command `open` to open a file and write the poster data. Close the file after done.
# * This function may not return anything. It just saves the poster data as an image file.

# %%
#//*** Download the movie poster and display it
#//*** Instead of merely downloading the movie poster, display it in the Notebook
#//*** Das is Ganz Klar!

def get_poster(input_name,input_url):
    
    #//*******************************************************************
    #//*** get file extension, assume the extenstion is after the last .
    #//*** Since we treat the file as temporary, this step isnt needed
    #//*** But it's a nice-to-have
    #//*******************************************************************
    if "." in input_url:
        filename = "z_9_10_" + input_name + "." + input_url.split(".")[-1]
    else:
        #//*** No extension found for some reason. Let's call it a .byebye file.
        #//*** Since it's going byebye no matter what we name it.
        
        filename = input_name + ".byebye"
    
    #//*** Download the file with urllib
    try:
        
        response = urllib.request.urlopen(input_url)
        
    except:
        print("[No Poster image]")
        return
    
   
    #//*** Write Poster to disk
    f = open(filename, "wb") 
    f.write(response.read())
    f.close()
    
    #//*** Display the poster inline. Because we are cool like that
    display(Image(filename=filename))
    
    #//*** Delete the local image, to keep things uncluttered
    if os.path.isfile(filename):
        os.remove(filename)

# %% [markdown]
# ### Write a utility function `print_json` to print nicely the movie data from a JSON file (which we will get from the portal)
# Here are the keys of a JSON file,
#
# 'Title', 'Year', 'Rated', 'Released', 'Runtime', 'Genre', 'Director', 'Writer', 'Actors', 'Plot', 'Language','Country', 'Awards', 'Ratings', 'Metascore', 'imdbRating', 'imdbVotes', 'imdbID'
#
# But why limit ourselves to this list? We should print all-the-JSON.
# If the JSON is layered, we'll use recursion.

# %%
def print_json(input_obj,level=0):

    if isinstance(input_obj,dict) == False:
        tab=""
        for x in range(level):
            tab += "\t"
        print(f"{tab}{input_obj}")
        return
   #//*** If there is a valid Poster URL and Title.
    #//*** Download and Display the movie poster
    if "Poster" in input_obj.keys() and "Title" in input_obj.keys():
        poster_url = input_obj["Poster"]
        poster_name = input_obj["Title"]
        
        try:
            get_poster(poster_name,poster_url)
        except:
            print("[No Poster Available]")

    #//*** Tabs are used for recursion
    #//*** For every level of recursion, add a tab
    #//*** My test data only goes down to two levels, it will be fun to test with more
    
    tab=""
    for x in range(level):
        tab += "\t"
    
    #//*** Loop through the JSON keys and values
    for key,value in input_obj.items():
        
        #//*** If the response is True, skip the display
        #//*** This will print on a fale response
        if key == "Response" and value == "True":
            continue
        
        #//*** Skip Poster, it should already by handled
        if key == "Poster":
            continue
    
        #//*** If the Value is a string, print the key and value.
        if isinstance(value,str) or isinstance(value,int):
            print(f"{tab}{key}: {value}")

        #//*** If the Object is a list, print the key
        #//*** Iterate through the list calling print_json on each item with a level + 1.
        #//*** Which will increase the tab level with each call ---- Fun Stuff
        elif isinstance(value,list):
                print(f"{tab}{key}:")
                for item in value:
                    print_json(item,level+1)
        elif isinstance(value,dict):
            print(f"{tab}{key}:")
            print_json(value,level+1)            
        else:
            #//*** If it's not a list or string, print it anyway. This leaves a future debugging path open
            print(f"{tab}-->{key}: {type(value)} {value}")

# %% [markdown]
# ### Write a utility function `search_movie` to search a movie by its name, print the downloaded JSON data (use the `print_json` function for this) and save the movie poster in the local folder (use `save_poster` function for this)
#
# * Use `try-except` loop for this i.e. try to connect to the web portal, if successful proceed but if not (i.e. exception raised) then just print an error message
# * Here use the previously created variables `serviceurl` and `apikey`
# * You have to pass on a dictionary with a key `t` and the movie name as the corresponding value to `urllib.parse.urlencode()` function and then add the `serviceurl` and `apikey` to the output of the function to construct the full URL
# * This URL will be used for accessing the data
# * The JSON data has a key called `Response`. If it is `True`, that means the read was successful. Check this before processing the data. If not successful, then print the JSON key `Error`, which will contain the appropriate error message returned by the movie database.

# %%
#//*** Search for a movie on OMDB and print the resulting JSON
def search_movie(input_movie):
    #//*** Moving service URL locally into the function, otherise best practice would be to pass it in.
    service_url = "http://www.omdbapi.com/?" + apikey + "&"
    
    #//*** Format the Movie title for the API request
    #//*** Replace 
    input_movie = "t=" + input_movie.replace(" ","+")
    request_url = service_url + input_movie
    
    try:
        
        response = urllib.request.urlopen(request_url)
        
    except HTTPError as e:
        print("Uh Oh - There is a problem making the API call")
        print(e)
        return
    
    except URLError as e:
        print(f"Failed to connect to server.")
        print(f"Reason: {e.reason}")
    
    #//*** Received a valid response as a string
    #//*** Convert to JSON
    #//*** Print and Display the attributes using the print_json function
    print_json(json.loads(response.read().decode()))

# %% [markdown]
# ### Test `search_movie` function by entering *Titanic*

# %%
search_movie("Titanic")
# Out:
# Title: Titanic
# Year: 1997
# Rated: PG-13
# Released: 19 Dec 1997
# Runtime: 194 min
# Genre: Drama, Romance
# Director: James Cameron
# Writer: James Cameron
# Actors: Leonardo DiCaprio, Kate Winslet, Billy Zane, Kathy Bates
# Plot: A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.
# Language: English, Swedish, Italian, French
# Country: USA, Mexico
# Awards: Won 11 Oscars. Another 112 wins & 83 nominations.
# Ratings:
# 	Source: Internet Movie Database
# 	Value: 7.8/10
# 	Source: Rotten Tomatoes
# 	Value: 89%
# 	Source: Metacritic
# 	Value: 75/100
# Metascore: 75
# imdbRating: 7.8
# imdbVotes: 1,042,391
# imdbID: tt0120338
# Type: movie
# DVD: N/A
# BoxOffice: $659,363,944
# Production: 20th Century Fox, Lightstorm Entertainment, Paramount Pictures
# Website: N/A

# %%
top10_url = "https://collider.com/top-10-netflix-movies-list-most-popular/"
response = requests.get(top10_url)
#//*** If Response.ok is False there is a problem
if response.ok == False:
    print("Problem downloading the URL")
    print(f"Statis Code: {response.status_code}")
    for x in response:
        print(x)

#//*** If no error we should be good
# Write your code here (decode). The decoding functionality is inlined with the Beautiful soup import. This forces
#//*** Decoding of the content based on the value of response.encoding

# Write your code here (pass on to BS)
if response.ok == True:
    #//*** Make soup...Beautiful Soup
    soup = BeautifulSoup(response.content.decode(response.encoding),'html.parser')

# %%
#//*** Fun exercise. Because I'd rather do this than waste time on the Twitters.
#//*** Gather the Netflix Current Top 10 shows from Collider. And feed them into OMDB.
#//*** Should be Fun
raw_soup_list = soup.find_all('h2')

pattern = re.compile("^[\\W]*[\\d]*\.\\W*")

non_text_pattern = re.compile("[\\W]+?")

ignore_char = ["+","%"]

top10_netflix = []
for item in raw_soup_list:
    if (len(item.text) > 1):
        matches = pattern.findall(item.text)
        if len(matches) > 0:
            
            #print(f"{matches} -{item.text.replace(matches[0],'')}-")
            #//*** Replace Space with + and & with %26 for url encoding 
            temp_str = item.text.replace(matches[0],'').replace(" ","+").replace("&","%26")
            
            #//*** Remove all other non-text characters
            non_text_match = non_text_pattern.findall(temp_str)
            
            #//*** Loop through all non-text characters found
            for rem_char in non_text_match:
                #//*** Ignore value non-text for encoding
                if rem_char not in ignore_char:
                    #//***Remove waht's left 
                    temp_str = temp_str.replace(rem_char,"")
            
            top10_netflix.append(temp_str)

# %%
#//*** Feed the Top 10 list to OMDB
for show in top10_netflix:
    search_movie(show)
# Out:
# Title: Space Sweepers
# Year: 2021
# Rated: TV-MA
# Released: 05 Feb 2021
# Runtime: 136 min
# Genre: Action, Adventure, Drama, Fantasy, Sci-Fi
# Director: Sung-hee Jo
# Writer: N/A
# Actors: Song Joong-Ki, Kim Tae-ri, Seon-kyu Jin, Hae-Jin Yoo
# Plot: Set in the year 2092 and follows the crew of a space junk collector ship called The Victory. When they discover a humanoid robot named Dorothy that's known to be a weapon of mass destruction, they get involved in a risky business deal.
# Language: Korean, English
# Country: South Korea
# Awards: N/A
# Ratings:
# 	Source: Internet Movie Database
# 	Value: 6.6/10
# Metascore: N/A
# imdbRating: 6.6
# imdbVotes: 6,602
# imdbID: tt12838766
# Type: movie
# DVD: N/A
# BoxOffice: N/A
# Production: N/A
# Website: N/A
# Title: Malcolm & Marie
# Year: 2021
# Rated: R
# Released: 05 Feb 2021
# Runtime: 106 min
# Genre: Drama, Romance
# Director: Sam Levinson
# Writer: Sam Levinson
# Actors: Zendaya, John David Washington
# Plot: A director and his girlfriend's relationship is tested after they return home from his movie premiere and await critics' responses.
# Language: English
# Country: USA
# Awards: N/A
# Ratings:
# 	Source: Internet Movie Database
# 	Value: 6.6/10
# 	Source: Metacritic
# 	Value: 55/100
# Metascore: 55
# imdbRating: 6.6
# imdbVotes: 86
# imdbID: tt12676326
# Type: movie
# DVD: N/A
# BoxOffice: N/A
# Production: N/A
# Website: N/A
# Title: Finding 'Ohana
# Year: 2021
# Rated: PG
# Released: 29 Jan 2021
# Runtime: 123 min
# Genre: Action, Adventure, Comedy, Family
# Director: Jude Weng
# Writer: Christina Strain (screenplay by), Christina Strain
# Actors: Kelly Hu, Ke Huy Quan, Chris Parnell, Marc Evan Jackson
# Plot: A summer in rural O‘ahu takes an exciting turn for two Brooklyn-raised siblings when a journal pointing to long-lost treasure sets them on an epic adventure with new friends, and leads them to reconnect with their Hawaiian heritage.
# Language: English
# Country: USA
# Awards: N/A
# Ratings:
# Metascore: N/A
# imdbRating: N/A
# imdbVotes: N/A
# imdbID: tt10332588
# Type: movie
# DVD: N/A
# BoxOffice: N/A
# Production: N/A
# Website: N/A
# Title: Money Talks
# Year: 1997
# Rated: R
# Released: 22 Aug 1997
# Runtime: 97 min
# Genre: Action, Comedy, Crime, Thriller
# Director: Brett Ratner
# Writer: Joel Cohen, Alec Sokolow
# Actors: Chris Tucker, Charlie Sheen, Heather Locklear, Elise Neal
# Plot: Sought by police and criminals, a small-time huckster makes a deal with a TV newsman for protection.
# Language: English, French
# Country: USA
# Awards: 1 nomination.
# Ratings:
# 	Source: Internet Movie Database
# 	Value: 6.2/10
# 	Source: Rotten Tomatoes
# 	Value: 16%
# Metascore: N/A
# imdbRating: 6.2
# imdbVotes: 27,444
# imdbID: tt0119695
# Type: movie
# DVD: N/A
# BoxOffice: $40,922,619
# Production: New Line Cinema
# Website: N/A
# Title: We Can Be Heroes
# Year: 2020
# Rated: PG
# Released: 25 Dec 2020
# Runtime: 100 min
# Genre: Action, Comedy, Drama, Family, Fantasy
# Director: Robert Rodriguez
# Writer: Robert Rodriguez
# Actors: YaYa Gosselin, Lyon Daniels, Andy Walken, Hala Finley
# Plot: When alien invaders kidnap Earth's superheroes, their children must team up and learn to work together if they want to save their parents and the world.
# Language: English
# Country: USA
# Awards: N/A
# Ratings:
# 	Source: Internet Movie Database
# 	Value: 4.7/10
# 	Source: Metacritic
# 	Value: 51/100
# Metascore: 51
# imdbRating: 4.7
# imdbVotes: 8,592
# imdbID: tt10600398
# Type: movie
# DVD: N/A
# BoxOffice: N/A
# Production: N/A
# Website: N/A
# Title: All About the Benjamins
# Year: 2002
# Rated: R
# Released: 08 Mar 2002
# Runtime: 95 min
# Genre: Action, Comedy, Crime, Thriller
# Director: Kevin Bray
# Writer: Ronald Lang, Ice Cube
# Actors: Ice Cube, Mike Epps, Tommy Flanagan, Carmen Chaplin
# Plot: Bounty hunter Bucum chases bail-jumper Reggie, who runs right into the scene of a diamond heist and murder and gets shot at as well. Later they become partners in their pursuit of the $20M in diamonds and lottery ticket. Their women join.
# Language: English, French
# Country: USA, Germany
# Awards: N/A
# Ratings:
# 	Source: Internet Movie Database
# 	Value: 5.9/10
# 	Source: Rotten Tomatoes
# 	Value: 30%
# 	Source: Metacritic
# 	Value: 34/100
# Metascore: 34
# imdbRating: 5.9
# imdbVotes: 12,603
# imdbID: tt0278295
# Type: movie
# DVD: N/A
# BoxOffice: $25,916,319
# Production: New Line Cinema
# Website: N/A
# [No Poster Available]
# Title: Are We There Yet?
# Year: 2005
# Rated: PG
# Released: 21 Jan 2005
# Runtime: 95 min
# Genre: Adventure, Comedy, Family, Fantasy, Romance
# Director: Brian Levant
# Writer: Steven Gary Banks (story), Claudia Grazioso (story), Steven Gary Banks (screenplay), Claudia Grazioso (screenplay), J. David Stem (screenplay), David N. Weiss (screenplay)
# Actors: Ice Cube, Nia Long, Aleisha Allen, Philip Bolden
# Plot: To impress a foxy divorcee, ladies' man Nick offers to take her kids on an extended road trip, unaware of the torture he's in for.
# Language: English
# Country: USA, Canada
# Awards: 1 win & 8 nominations.
# Ratings:
# 	Source: Internet Movie Database
# 	Value: 4.7/10
# 	Source: Rotten Tomatoes
# 	Value: 12%
# 	Source: Metacritic
# 	Value: 27/100
# Metascore: 27
# imdbRating: 4.7
# imdbVotes: 29,440
# imdbID: tt0368578
# Type: movie
# DVD: N/A
# BoxOffice: $82,674,398
# Production: Revolution Studios
# Website: N/A
# Title: Red Dot
# Year: 2021
# Rated: N/A
# Released: 11 Feb 2021
# Runtime: 85 min
# Genre: Drama, Thriller
# Director: Alain Darborg
# Writer: Alain Darborg, Per Dickson
# Actors: Johannes Kuhnke, Nanna Blondell, Anastasios Soulis, Kalled Mustonen
# Plot: When Nadja becomes pregnant, they make an attempt to rekindle their relationship by traveling to the north of Sweden for a hiking trip but soon thier romantic trip turns into a nightmare.
# Language: Swedish
# Country: Sweden
# Awards: N/A
# Ratings:
# Metascore: N/A
# imdbRating: N/A
# imdbVotes: N/A
# imdbID: tt11307814
# Type: movie
# DVD: N/A
# BoxOffice: N/A
# Production: N/A
# Website: N/A
# Title: Squared Love
# Year: 2021
# Rated: N/A
# Released: 11 Feb 2021
# Runtime: 101 min
# Genre: Comedy, Romance
# Director: Filip Zylber
# Writer: N/A
# Actors: Miroslaw Baka, Mateusz Banasiuk, Adrianna Chlebicka, Krzysztof Czeczot
# Plot: A celebrity journalist and renowned womanizer starts to rethink his life choices after he falls for a mysterious model who leads a double life.
# Language: Polish
# Country: Poland
# Awards: N/A
# Ratings:
# Metascore: N/A
# imdbRating: N/A
# imdbVotes: N/A
# imdbID: tt13846542
# Type: movie
# DVD: N/A
# BoxOffice: N/A
# Production: N/A
# Website: N/A
# Title: War Dogs
# Year: 2016
# Rated: R
# Released: 19 Aug 2016
# Runtime: 114 min
# Genre: Biography, Comedy, Crime, Drama, War
# Director: Todd Phillips
# Writer: Stephen Chin (screenplay), Todd Phillips (screenplay), Jason Smilovic (screenplay), Guy Lawson (Rolling Stone article "Arms and the Dudes")
# Actors: Miles Teller, Steve Lantz, Gregg Weiner, David Packouz
# Plot: Loosely based on the true story of two young men, David Packouz and Efraim Diveroli, who won a three hundred million dollar contract from the Pentagon to arm America's allies in Afghanistan.
# Language: English, Arabic, Albanian, Romanian
# Country: USA, Cambodia, Romania
# Awards: Nominated for 1 Golden Globe. Another 2 nominations.
# Ratings:
# 	Source: Internet Movie Database
# 	Value: 7.1/10
# 	Source: Rotten Tomatoes
# 	Value: 61%
# 	Source: Metacritic
# 	Value: 57/100
# Metascore: 57
# imdbRating: 7.1
# imdbVotes: 177,010
# imdbID: tt2005151
# Type: movie
# DVD: N/A
# BoxOffice: $43,034,523
# Production: Joint Effort, Warner Bros. Pictures, The Mark Gordon Company
# Website: N/A

# %% [markdown]
# ### Test `search_movie` function by entering "*Random_error*" (obviously this will not be found and you should be able to check whether your error catching code is working properly)

# %%
search_movie("Random_error")
# Out:
# Response: False
# Error: Movie not found!

# %% [markdown]
# ### Look for a folder called 'Posters' in the same directory you are working in. It should contain a file called 'Titanic.jpg'. Open and see if the poster came alright!
#
# It doesn't, because I deleted the files after displaying them

# %% [markdown]
# 3. Connect to the Twitter API and do a simple data pull
#
# a. If you don’t have a twitter account – create one at twitter.com/signup (you can delete the account after this assignment)
#
# b. Sign in to apps.twitter.com
#
# c. Click “Create New App”
#
# d. Give your app a name and description
#
# e. Agree to the developer agreement – you will want to make sure to indicate this is for a class project, and this step can take several days to get through, so don’t wait until last minute to complete this portion of the assignment
#
# f. Create an access token
#
# g. You should receive a consumer key and a token
#
# h. Using either the instructions from the book on connecting to an API or for help look here – pull back data searching for “Bellevue University” and “Data Science” (or something else you are interested in)
#
# i. How to Create a Twitter App and API Interface via Python. (Grogan, 2016)
#
# ii. Welcome Python-Twitter’s Documentation!  (The Python-Twitter Developers, 2016)

# %%
#//*********************************************************************************
#//*** Read the API keys from a JSON encoded file
#//*** Located in the ignore_folder sub directory
#//*** This Folder is added to the .gitignore file and does not show up on Github
#//*** This is per the Authentication Best Practices from Twitter
#//*********************************************************************************
f = open("./ignore_folder/coke.rares", "r")

#//*** Fugley Pythonic type conversion
#//*** Loads the file into Dictionary via JSON.loads
#//*** Gets the API key value using the 'api' key
#//*** prepends apikey= so the resulting value is URL ready :]
secrets = json.loads(f.read())
f.close()

# %%
#//*************************************************************************************************************
#//*** I liberally borrowed from the Twitter sample code. And by borrowed I mean copied.
#//*** I added a query for cats that has media and printed the results with the PRINT_JSON function from above.
#//*** This is a minimum effort, due to my personal animus against Twitter (I think it's dumb).
#//*** It has its uses academically and I'll spend more time figuring out Twitter when and if I have too.
#//*************************************************************************************************************
#//*** Why did Twitter thrive? and RSS die? These questions make me fee like a technological luddite
#//*************************************************************************************************************
import requests
import os

def auth():
    return os.environ.get("BEARER_TOKEN")


def create_url():
    #query = "from:twitterdev -is:retweet"
    query = "covid"
    query = "covid has:images"
    query = "cats has:media lang:en"
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    #tweet_fields = "tweet.fields=author_id"
    tweet_fields = "tweet.fields=attachments,author_id,created_at,public_metrics,source"
    media_fields = "&media.fields=duration_ms,public_metrics,type"
    media_fields = "&expansions=attachments.media_keys&media.fields=duration_ms,height,media_key,preview_image_url,public_metrics,type,url,width"
    #url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}".format(query, tweet_fields
    url = f"https://api.twitter.com/2/tweets/search/recent?query={query}&{tweet_fields}{media_fields}"
    return url


def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def connect_to_endpoint(url, headers):
    response = requests.request("GET", url, headers=headers)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()


def main():
    bearer_token = secrets['bearer']
    url = create_url()
    headers = create_headers(bearer_token)
    json_response = connect_to_endpoint(url, headers)
    #print(json.dumps(json_response, indent=4, sort_keys=True))
    print_json(json_response)

main()
# Out:
# 200
# data:
# 	author_id: 1233149299111944192
# 	id: 1360408834586640386
# 	public_metrics:
# 		retweet_count: 34611
# 		reply_count: 0
# 		like_count: 0
# 		quote_count: 0
# 	text: RT @tiredsanrio: don’t mind me,,, just thinking about cats in dollhouses https://t.co/xh789wv0L0
# 	attachments:
# 		media_keys:
# 			3_1359932228348743681
# 			3_1359932228306800641
# 			3_1359932228323532804
# 			3_1359932228348694530
# 	source: Twitter Web App
# 	created_at: 2021-02-13T02:01:55.000Z
# 	author_id: 1278986432074391553
# 	id: 1360408829662539777
# 	public_metrics:
# 		retweet_count: 0
# 		reply_count: 0
# 		like_count: 0
# 		quote_count: 0
# 	text: Save 20% at https://t.co/cTvXQheSzH through Tuesday Feb 16th! Use code CATS20 https://t.co/OaPXDzx7X3 #cats #cat #catsoftwitter #catsofinstagram #catsale https://t.co/qcL0NNCPNV
# 	attachments:
# 		media_keys:
# 			3_1360408761861607426
# 	source: Twitter Web App
# 	created_at: 2021-02-13T02:01:54.000Z
# 	author_id: 1091814179957366785
# 	id: 1360408828349710337
# 	public_metrics:
# 		retweet_count: 162
# 		reply_count: 0
# 		like_count: 0
# 		quote_count: 0
# 	text: RT @Miexriir: Bowser’s Fury Easter Egg:
#
# The cats seen wandering Lake Lapcat are color coded to represent Mario’s closest friends https://t…
# 	source: Twitter for Android
# 	created_at: 2021-02-13T02:01:54.000Z
# 	author_id: 23235680
# 	id: 1360408824457408512
# 	public_metrics:
# 		retweet_count: 34611
# 		reply_count: 0
# 		like_count: 0
# 		quote_count: 0
# 	text: RT @tiredsanrio: don’t mind me,,, just thinking about cats in dollhouses https://t.co/xh789wv0L0
# 	attachments:
# 		media_keys:
# 			3_1359932228348743681
# 			3_1359932228306800641
# 			3_1359932228323532804
# 			3_1359932228348694530
# 	source: Twitter for iPhone
# 	created_at: 2021-02-13T02:01:53.000Z
# 	author_id: 1344757672877371393
# 	id: 1360408817255796738
# 	public_metrics:
# 		retweet_count: 0
# 		reply_count: 0
# 		like_count: 0
# 		quote_count: 0
# 	text: @Malcolm_theCat Cats win. They always win. https://t.co/Kh4eZuNKL2
# 	attachments:
# 		media_keys:
# 			16_1360408806291824640
# 	source: Twitter for Android
# 	created_at: 2021-02-13T02:01:51.000Z
# 	author_id: 889514718850928640
# 	id: 1360408810247053314
# 	public_metrics:
# 		retweet_count: 162
# 		reply_count: 0
# 		like_count: 0
# 		quote_count: 0
# 	text: RT @Miexriir: Bowser’s Fury Easter Egg:
#
# The cats seen wandering Lake Lapcat are color coded to represent Mario’s closest friends https://t…
# 	source: Twitter Web App
# 	created_at: 2021-02-13T02:01:50.000Z
# 	author_id: 810623370957963264
# 	id: 1360408807336120321
# 	public_metrics:
# 		retweet_count: 34611
# 		reply_count: 0
# 		like_count: 0
# 		quote_count: 0
# 	text: RT @tiredsanrio: don’t mind me,,, just thinking about cats in dollhouses https://t.co/xh789wv0L0
# 	attachments:
# 		media_keys:
# 			3_1359932228348743681
# 			3_1359932228306800641
# 			3_1359932228323532804
# 			3_1359932228348694530
# 	source: Twitter for Android
# 	created_at: 2021-02-13T02:01:49.000Z
# 	author_id: 341018943
# 	id: 1360408807294308354
# 	public_metrics:
# 		retweet_count: 1
# 		reply_count: 0
# 		like_count: 0
# 		quote_count: 0
# 	text: RT @missmollysays2: Natural Ways to Cure Constipation in Cats https://t.co/CRKjpFHkCE https://t.co/t8XS9qdMok
# 	attachments:
# 		media_keys:
# 			3_1358067962696056836
# 	source: Twitter Web App
# 	created_at: 2021-02-13T02:01:49.000Z
# 	author_id: 839609664195063808
# 	id: 1360408806312714240
# 	public_metrics:
# 		retweet_count: 6716
# 		reply_count: 0
# 		like_count: 0
# 		quote_count: 0
# 	text: RT @akkitwts: There are 2 types of cats.. https://t.co/FaNeads9nM
# 	attachments:
# 		media_keys:
# 			7_1360003038728101892
# 	source: Twitter for Android
# 	created_at: 2021-02-13T02:01:49.000Z
# 	author_id: 1004341925015670784
# 	id: 1360408805645901826
# 	public_metrics:
# 		retweet_count: 34611
# 		reply_count: 0
# 		like_count: 0
# 		quote_count: 0
# 	text: RT @tiredsanrio: don’t mind me,,, just thinking about cats in dollhouses https://t.co/xh789wv0L0
# 	attachments:
# 		media_keys:
# 			3_1359932228348743681
# 			3_1359932228306800641
# 			3_1359932228323532804
# 			3_1359932228348694530
# 	source: Twitter for Android
# 	created_at: 2021-02-13T02:01:49.000Z
# includes:
# 	media:
# 		height: 299
# 		width: 400
# 		url: https://pbs.twimg.com/media/Et9zKA1VEAEYmXS.jpg
# 		media_key: 3_1359932228348743681
# 		type: photo
# 		height: 380
# 		width: 400
# 		url: https://pbs.twimg.com/media/Et9zKArVEAEqHny.jpg
# 		media_key: 3_1359932228306800641
# 		type: photo
# 		height: 225
# 		width: 400
# 		url: https://pbs.twimg.com/media/Et9zKAvUYAQfG8C.jpg
# 		media_key: 3_1359932228323532804
# 		type: photo
# 		height: 570
# 		width: 400
# 		url: https://pbs.twimg.com/media/Et9zKA1UUAIPsC5.jpg
# 		media_key: 3_1359932228348694530
# 		type: photo
# 		height: 608
# 		width: 1080
# 		url: https://pbs.twimg.com/media/EuEkj6gXEAIcC6L.jpg
# 		media_key: 3_1360408761861607426
# 		type: photo
# 		height: 188
# 		width: 300
# 		preview_image_url: https://pbs.twimg.com/tweet_video_thumb/EuEkmgBWYAA5f7i.jpg
# 		media_key: 16_1360408806291824640
# 		type: animated_gif
# 		height: 534
# 		width: 800
# 		url: https://pbs.twimg.com/media/EtjTneFWQAQhXiT.jpg
# 		media_key: 3_1358067962696056836
# 		type: photo
# 		public_metrics:
# 			view_count: 388244
# 		duration_ms: 25300
# 		height: 640
# 		width: 640
# 		preview_image_url: https://pbs.twimg.com/ext_tw_video_thumb/1360003038728101892/pu/img/3QbhoQJ6x78zo8n4.jpg
# 		media_key: 7_1360003038728101892
# 		type: video
# meta:
# 	newest_id: 1360408834586640386
# 	oldest_id: 1360408805645901826
# 	result_count: 10
# 	next_token: b26v89c19zqg8o3fosnr8ly8uaul8jckq4nyymtwmoo71

# %% [markdown]
# 4. Using one of the datasets provided in Weeks 7 & 8, or a dataset of your own, choose 3 of the following visualizations to complete. You must submit via PDF along with your code. You are free to use Matplotlib, Seaborn or another package if you prefer.
#
# a. Line
#
# b. Scatter
#
# c. Bar
#
# d. Histogram
#
# e. Density Plot
#
# f. Pie Chart

# %%
#//**** Load the Boing Boing Candy Data
candy_df = pd.read_csv("z_candy_df.csv")
# Out:
# C:\Users\family\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
import matplotlib.pyplot as plt 

# //*** Legends automatically generate too many labels based on my looping method.
# //*** Remove the Duplicate Legends. I wrote this for DSC 530 and it keeps on giving.
def deduplicate_legend(input_ax):
    # //**** Get handle and label list for the current legend
    # //**** Use first instance, toss the rest.
    handles, labels = input_ax.get_legend_handles_labels()

    handle_dict = {}

    for x in range(len(labels)):
        if labels[x] not in handle_dict.keys():
            # //*** Label = handle
            handle_dict[labels[x]] = handles[x]

    # //*** Build unique output ists and handles
    out_handles = []
    out_labels = []
    
    for label,handle in handle_dict.items():
        out_handles.append(handle)
        out_labels.append(label)
    
    return out_handles,out_labels

# %%
#//*** Rename the indexes back to categorical names
pretty_rows = { 1 : 'Joy', 2 : 'Despair', 3 : 'Meh', 0 : 'N/A'}

#//*** Get the columns that have candy values ignores year and timestamp
candy_cols = candy_df.columns[2:] 

#//*** New Data frame for the Histogram
hist_df = pd.DataFrame()1

#//**** Build a Histogram of each column
for col in candy_cols:
    hist_df[col] = candy_df[col].value_counts().sort_index().rename(index=pretty_rows)

#//*** Transpose the Histogram
hist_df = hist_df.transpose()

#//*** sum each of the values and sort from greatest to least.
#//*** Use this to sort all the values from greatest to least
sorted_values = list(hist_df.sum().sort_values(ascending=False).index)

#//*** Look upon the despair!!! People hate candy more than it brings them Joy!!!!
#//*** BWhaahahahahahahaha. This is of course likely due to the control questions like Vicodin
print(sorted_values)

#//*** Sort by DESPAIR!!!!!!!
hist_df = hist_df.sort_values(by=sorted_values, ascending=False) 

#//*** Transpose the Data frame for plotting
hist_df = hist_df.transpose()

print(hist_df.head(5))
# Out:
# ['Despair', 'Joy', 'Meh', 'N/A']
#          Broken glow stick  Gum from baseball cards  Dental paraphenalia  \
# N/A                    386                      503                  357
# Joy                    148                      357                  545
# Despair               7905                     7341                 7295
# Meh                    207                      445                  449
#
#          Kale smoothie  \
# N/A                544
# Joy                493
# Despair           7288
# Meh                321
#
#          Candy that is clearly just the stuff given out for free at restaurants  \
# N/A                                                    382
# Joy                                                    298
# Despair                                               7255
# Meh                                                    711
#
#          White Bread  Creepy Religious comics/Chick Tracts  \
# N/A              799                                   382
# Joy              339                                   996
# Despair         7129                                  7079
# Meh              379                                   189
#
#          Anonymous brown globs that come in black and orange wrappers  \
# N/A                                                    355
# Joy                                                    823
# Despair                                               6730
# Meh                                                    738
#
#          Whole Wheat anything  Box'o'Raisins  ...  Peanut M&M’s  \
# N/A                       803            418  ...           322
# Joy                       642            803  ...          6456
# Despair                  6638           6577  ...          1246
# Meh                       563            848  ...           622
#
#          Nestle Crunch  Regular M&Ms  Cash, or other forms of legal tender  \
# N/A                484           397                                   302
# Joy               6117          6101                                  6814
# Despair           1193          1134                                  1073
# Meh                852          1014                                   457
#
#          Licorice (not black)  Snickers  Twix  Reese’s Peanut Butter Cups  \
# N/A                      5644       313   391                         260
# Joy                       943      6991  6990                        7369
# Despair                   853       833   768                         685
# Meh                      1206       509   497                         332
#
#          Kit Kat  Any full-sized candy bar
# N/A          283                       263
# Joy         7252                      7589
# Despair      597                       407
# Meh          514                       387
#
# [4 rows x 80 columns]

# %%
#//*** Display the Histogram of DESPAIR!
#//*** Which is a bar chart and Histogram in ONE!!!
#//*** Because....I have no other reason than because I can
#//*** And I like playing with loops and making big graphs.
#//*** Display count determines the number of columns per graph. There are 80 columns, we could put them all one
#//*** graph, but it would be pretty illegible


display_count = 20
width = .8



color_dict = {
    'Joy' : "#9b3ced",
    'Despair' : "#5ABA84",
    'Meh' : "#ff46db",
    'N/A' : "#d8bf00",
}

#for col in candy_cols:
#    counts_df[col] = candy_df[col].value_counts().sort_index().rename(index=pretty_rows)



#//*** Set the default display size to 80% of the display count. It adds some flexibility to the display size.
plt.rcParams['figure.figsize'] = [display_count*.8, display_count*.8] 

#//*** Divide the columns by the display_count size
#//*** The columns are divided by column index value
for graph_loop in range(0,int( (len(candy_cols)/ display_count))):
    
    #//*** Create the Start index of columns
    min_dex = (graph_loop*display_count)
    #//*** Create the end index of columns
    max_dex = min_dex +(display_count-1)
    

    fig,ax = plt.subplots()
    
    #//*** Draw each bar based on the order of sorted values OF DESPAIR!!!
    #//*** Single line of code generates a bar chart for each value "Despair/Joy/Meh/NA"
    #//*** The .loc is the row value using min_dex & max_dex to select the columns.
    for row in sorted_values:
            ax.bar(hist_df.loc[row].index[min_dex:max_dex],hist_df.loc[row][min_dex:max_dex],width, color=color_dict[row], label=row)

    
    plt.xticks(rotation=90,fontsize=display_count*1.25)

    handles,labels = deduplicate_legend(ax)
    plt.legend(handles,labels, fontsize=display_count)
    plt.title(f"Histogram of Despair with {display_count} elements\n({graph_loop+1} of {int( (len(candy_cols)/ display_count))})",fontsize=display_count*2)
    plt.show()
    
plt.rcParams['figure.figsize'] = [10,10]

# %%
#//*** Draw Histogram based on Joy
#//*** Sort by DESPAIR!!!!!!!
#hist_df = hist_df.sort_values(by=sorted_values, ascending=False) 

#//*** Transpose, sort for joy, transpose for poltting
hist_df = hist_df.transpose().sort_values(by='Joy',ascending=False).transpose()
sorted_values = [ 'Joy', 'Despair', 'Meh', 'N/A' ]

display_count = 20
width = .8



color_dict = {
    'Joy' : "#9b3ced",
    'Despair' : "#5ABA84",
    'Meh' : "#ff46db",
    'N/A' : "#d8bf00",
}

#for col in candy_cols:
#    counts_df[col] = candy_df[col].value_counts().sort_index().rename(index=pretty_rows)



#//*** Set the default display size to 80% of the display count. It adds some flexibility to the display size.
plt.rcParams['figure.figsize'] = [display_count*.8, display_count*.8] 

#//*** Divide the columns by the display_count size
#//*** The columns are divided by column index value
for graph_loop in range(0,int( (len(candy_cols)/ display_count))):
    
    #//*** Create the Start index of columns
    min_dex = (graph_loop*display_count)
    #//*** Create the end index of columns
    max_dex = min_dex +(display_count-1)
    

    fig,ax = plt.subplots()
    
    #//*** Draw each bar based on the order of sorted values OF DESPAIR!!!
    #//*** Single line of code generates a bar chart for each value "Despair/Joy/Meh/NA"
    #//*** The .loc is the row value using min_dex & max_dex to select the columns.
    for row in sorted_values:
            ax.bar(hist_df.loc[row].index[min_dex:max_dex],hist_df.loc[row][min_dex:max_dex],width, color=color_dict[row], label=row)

    
    plt.xticks(rotation=90,fontsize=display_count*1.25)

    handles,labels = deduplicate_legend(ax)
    plt.legend(handles,labels, fontsize=display_count)
    plt.title(f"Histogram of Joy with {display_count} elements\n({graph_loop+1} of {int( (len(candy_cols)/ display_count))})",fontsize=display_count*2)
    plt.show()
    
plt.rcParams['figure.figsize'] = [10,10]
